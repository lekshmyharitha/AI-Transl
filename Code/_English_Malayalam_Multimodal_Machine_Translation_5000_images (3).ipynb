# %% [markdown]
# English -Malayalam Multimodal Machine Translation-5000 images

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import os
import cv2
import matplotlib.image as mp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/Main/train.mn.txt') as file:
    mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/train.en.txt') as file:
    eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/train_images.txt') as file:
    train_images = file.read().split('\n')

# %%
train_images[-1]
# Out:
# ''

# %%
#removing last elements which containing special characters
mal_txt.pop()
mal_txt.pop()
eng_txt.pop()
eng_txt.pop()
train_images.pop()
print(len(mal_txt))
print(len(eng_txt))
print(len(train_images))
img_path=[]
for s in train_images:
    img_path.append("/content/drive/My Drive/Main/trainimages/train/"+s)
# Out:
# 28930
# 28931
# 28931

# %%
print(mal_txt[1])
print(eng_txt[1])
# Out:
# ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# it is an indoor scene

# %%
mal_txt[0:15]
# Out:
# ['ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ',
#  'ഇത് ഒരു ഇൻഡോർ രംഗമാണ്',
#  'കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി',
#  'മനുഷ്യന് ചെറിയ മുടിയുണ്ട്',
#  'ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു',
#  'കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട്',
#  'ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി',
#  'ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ്',
#  'മതിൽ വെളുത്ത ചായം പൂശി',
#  'ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ',
#  'സമുദ്രം അഭിമുഖീകരിക്കുന്ന സ്ത്രീ',
#  'ഇതൊരു ഓഫീസ് രേഖാചിത്രം',
#  'നാല് ലോഹത്തിന്റെ കസേരകൾ',
#  'കോലാഹലം ഒരു മേശപ്പുറത്താണ്',
#  'ഒരു വെളുത്ത മൈക്രോവേവ് ഓവൻ']

# %%
eng_txt[0:15]
# Out:
# ['Male surfer surfing in still in the ocean',
#  'it is an indoor scene\t\t\t\t\t\t',
#  'Computer screens turned on\t\t\t\t\t\t',
#  'man has short hair\t\t\t\t\t\t',
#  "photo album open on an adult's lap\t\t\t\t\t\t",
#  'there is a group of girls beside the black car\t\t\t\t\t\t',
#  'Child in a stroller\t\t\t\t\t\t',
#  'Tall metal lightpost\t\t\t\t\t\t',
#  'wall is painted white\t\t\t\t\t\t',
#  'there are several pictures on the wall\t\t\t\t\t\t',
#  'woman facing the ocean\t\t\t\t\t\t',
#  'this is an office layout\t\t\t\t\t\t',
#  'four metallic chairs\t\t\t\t\t\t',
#  'Clutter is on a table\t\t\t\t\t\t',
#  'a white microwave oven\t\t\t\t\t\t']

# %%
im=mp.imread(img_path[1])
plt.imshow(im)
print(img_path[1])
print("mal:"+mal_txt[1])
print("eng:"+eng_txt[1])
# Out:
# /content/drive/My Drive/Main/trainimages/train/11.jpg
# mal:ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# eng:it is an indoor scene

# %%
im=mp.imread(img_path[0])
plt.imshow(im)
print(img_path[0])
print("mal:"+mal_txt[0])
print("eng:"+eng_txt[0])
# Out:
# /content/drive/My Drive/Main/trainimages/train/10.jpg
# mal:ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# eng:Male surfer surfing in still in the ocean

# %%
#Manually splitting data for training and texting-due to presence of 3 inputs split using Sklearn  is not efficeint
splits=10000
mal_train=mal_txt[:splits]
eng_train=eng_txt[:splits]

# %%
mal_df = pd.DataFrame(mal_train, columns=['Malayalam']) 
eng_df = pd.DataFrame(eng_train, columns=['English'])

# %%
mal_df.head(10)
# Out:
#                                            Malayalam
# 0        ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# 1                              ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# 2                     കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# 3                          മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# 4       ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
# 5     കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട്
# 6                          ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി
# 7                     ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ്
# 8                             മതിൽ വെളുത്ത ചായം പൂശി
# 9  ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന...

# %%
eng_df.head(10)
# Out:
#                                              English
# 0          Male surfer surfing in still in the ocean
# 1                  it is an indoor scene\t\t\t\t\t\t
# 2             Computer screens turned on\t\t\t\t\t\t
# 3                     man has short hair\t\t\t\t\t\t
# 4     photo album open on an adult's lap\t\t\t\t\t\t
# 5  there is a group of girls beside the black car...
# 6                    Child in a stroller\t\t\t\t\t\t
# 7                   Tall metal lightpost\t\t\t\t\t\t
# 8                  wall is painted white\t\t\t\t\t\t
# 9  there are several pictures on the wall\t\t\t\t...

# %%
#Datacleaning by removing special characters
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r" ᠃", "", text)
    text = re.sub(r" ᠂", "", text)
    text = re.sub(r"-", " ", text)
    text = re.sub(r"<5>", "5", text)
    text = re.sub(r"“ ", "", text)
    text = re.sub(r" ”", "", text)
    text = re.sub(r"[+\.\!\/_,$%^*(+\"\']+|[+——！，〈〉《》。︱？?、．％~@#￥%……&*（）’]", "", text)
    text=text.rstrip()
    return text

# %%
mal_text1 = mal_df["Malayalam"].apply(clean_text)
eng_text1 = eng_df["English"].apply(clean_text)
mal_text2 = list(mal_text1.values)
eng_text2 = list(eng_text1.values)

# %%
#cleaned Malayalm data
mal_text1
# Out:
# 0        ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# 1                              ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# 2                     കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# 3                          മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# 4       ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
#                             ...
# 4995            ഫ്രിസ്‌ബീ ഉള്ള പുൽത്തകിടിയിൽ ഒരു നായ
# 4996        ഒരു ഉദ്യാനത്തിൽ ചാരനിറത്തിലുള്ള ലോഹ വേലി
# 4997               തവിട്ടുനിറമുള്ള മുടിയുള്ള മനുഷ്യൻ
# 4998                    ഒരു ജിറാഫ് പുല്ല് തിന്നുന്നു
# 4999                      മുൻവശത്തുള്ള ഒരു പെൺകുട്ടി
# Name: Malayalam, Length: 5000, dtype: object

# %%
#cleaned English data
eng_text1
# Out:
# 0       male surfer surfing in still in the ocean
# 1                           it is an indoor scene
# 2                      computer screens turned on
# 3                              man has short hair
# 4               photo album open on an adults lap
#                           ...
# 4995               a dog on a lawn with a frisbee
# 4996                 a gray metal fence in a park
# 4997                           a brown haired man
# 4998                           the floor is tiled
# 4999               a young girl in the foreground
# Name: English, Length: 5000, dtype: object

# %%
mal_text2[1:5]
# Out:
# ['ഇത് ഒരു ഇൻഡോർ രംഗമാണ്',
#  'കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി',
#  'മനുഷ്യന് ചെറിയ മുടിയുണ്ട്',
#  'ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു']

# %%
eng_text2[1:5]
# Out:
# ['it is an indoor scene',
#  'computer screens turned on',
#  'man has short hair',
#  'photo album open on an adults lap']

# %%
#Adding starting and ending tokens
mal_temp=[]
for s in mal_text2:
    temp="sos "+s+" eos"
    mal_temp.append(temp)
#text2=[]
mal_text2=mal_temp
mal_text2[1:10]
# Out:
# ['sos ഇത് ഒരു ഇൻഡോർ രംഗമാണ് eos',
#  'sos കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി eos',
#  'sos മനുഷ്യന് ചെറിയ മുടിയുണ്ട് eos',
#  'sos ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു eos',
#  'sos കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട് eos',
#  'sos ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി eos',
#  'sos ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ് eos',
#  'sos മതിൽ വെളുത്ത ചായം പൂശി eos',
#  'sos ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
malayalam_words = []
for i in mal_text2:
    malayalam_words.append(len(i.split()))
sn.countplot(malayalam_words).set(title=' Sentence Length -Malayalam')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
english_words = []
for j in eng_text2:
    english_words.append(len(j.split()))
sn.countplot(english_words).set(title=' Sentence Length -English')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
maxlen_malayalam = max(malayalam_words)
maxlen_english = max(english_words)
print('Maximum sentence length-Malayalam :',maxlen_malayalam)
print('Maximum sentence length-English :',maxlen_english)
# Out:
# Maximum sentence length-Malayalam : 13
# Maximum sentence length-English : 14

# %%
#splitting training data into training and validation data
x_tr=eng_text2[:splits-500]
y_tr=mal_text2[:splits-500]
x_val=eng_text2[splits-500:]
y_val=mal_text2[splits-500:]

# %%
x_tr[1:5]
# Out:
# ['it is an indoor scene',
#  'computer screens turned on',
#  'man has short hair',
#  'photo album open on an adults lap']

# %%
y_tr[1:5]
# Out:
# ['sos ഇത് ഒരു ഇൻഡോർ രംഗമാണ് eos',
#  'sos കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി eos',
#  'sos മനുഷ്യന് ചെറിയ മുടിയുണ്ട് eos',
#  'sos ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു eos']

# %%
len(x_tr)
# Out:
# 9500

# %%
len(x_val)
# Out:
# 500

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
x_tokens = Tokenizer()
x_tokens.fit_on_texts(x_tr)
x_tr = x_tokens.texts_to_sequences(x_tr)
x_val = x_tokens.texts_to_sequences(x_val)
print('x_tr:',x_tr)
print('x_val:',x_val)
# Out:
# x_tr: [[463, 238, 230, 6, 817, 6, 2, 239], [149, 5, 32, 1173, 209], [118, 1604, 464, 3], [8, 46, 231, 68], [193, 1605, 158, 3, 32, 1606, 641], [251, 5, 1, 152, 4, 496, 380, 2, 10, 34], [165, 6, 1, 947], [138, 102, 1607], [17, 5, 260, 7], [251, 43, 280, 589, 3, 2, 17], [18, 381, 2, 239], [13, 5, 32, 465, 1608], [288, 1174, 437], [1609, 5, 3, 1, 33], [1, 7, 313, 344], [7, 438, 261, 289, 642], [14, 330, 28, 11, 84], [8, 6, 93, 240, 331, 3, 16], [22, 3, 2, 16], [1, 8, 35, 6, 590, 420], [301, 111, 3, 17], [210, 4, 2, 109], [22, 4, 1, 85], [2, 345, 5, 173], [1, 8, 531, 1, 346], [1, 14, 643, 6, 29], [162, 11, 719, 401], [232, 3, 2, 45], [1, 720, 7, 45], [10, 175, 439], [1, 14, 1175, 532, 6, 2, 233, 4, 2, 34], [21, 34, 67, 382, 1, 28], [34, 3, 2, 28], [948, 1176, 20, 1610], [1, 10, 34, 11, 1, 23, 143], [109, 59, 2, 33], [1, 1611, 52, 3, 1, 201], [127, 290, 4, 1, 16], [22, 3, 1, 16], [19, 33, 35, 3, 54, 4, 1, 110], [110, 162, 5, 3], [1, 23, 47], [421, 4, 2, 60], [533, 62, 218, 2, 16], [644, 10, 80, 11, 1, 7, 302], [1, 71, 202, 62], [1, 163], [8, 46, 19, 68], [51, 6, 1, 65], [1, 37, 19, 60, 233], [56, 34, 6, 63, 4, 1, 16], [8, 497, 59, 201], [18, 35, 59, 1, 346, 440], [26, 1177, 15, 47], [1, 93, 1612, 363], [2, 23, 948, 1178], [71, 110, 6, 2, 135], [1, 138, 534, 60, 241, 2, 645], [109, 179, 32, 1613], [1, 138, 1179, 60], [180, 5, 3, 1614, 17], [2, 105], [2, 1615, 31, 143, 5, 158], [1, 45, 226, 4, 95], [2, 16, 5, 7], [44, 89, 3, 17], [642, 4, 71, 1180], [36, 383, 49, 16], [949, 466, 818, 25], [271, 314, 4, 1616, 9, 1617, 3, 1, 7, 315, 211], [1618, 5, 6, 2, 181], [2, 364, 5, 92], [19, 291, 3, 180], [7, 182, 819, 60], [7, 1619, 3, 2, 28], [21, 194, 6, 498], [2, 25, 5, 15], [8, 41, 365, 49, 31, 4, 48], [1, 8, 330, 2, 28], [25, 3, 2, 17], [22, 6, 1, 166, 186], [2, 118, 203, 5, 15], [133, 1181, 25], [92, 721, 68, 3, 1, 8], [2, 535, 187, 4, 1, 34], [722, 11, 467, 536], [31, 4, 1620, 56, 438], [18, 64, 537, 28], [18, 20, 112, 156], [12, 34, 67, 103, 28, 36], [2, 119, 167, 43, 23], [7, 260, 272, 3, 441], [2, 10, 950, 499, 3, 2, 116], [8, 6, 7, 40, 64, 82, 2, 105], [37, 36, 538, 6, 157], [7, 292, 3, 116], [10, 118, 292, 3, 116], [303, 3, 2, 500], [1, 8, 41, 6, 63, 4, 1, 118, 292], [464, 3, 10, 292], [8, 20, 19, 242], [166, 3, 2, 16], [56, 102, 33, 3, 55], [1, 92, 501, 1621], [61, 42, 94], [1622, 203, 5, 7], [23, 119, 384, 383, 49, 1, 93, 80], [12, 74, 174, 56, 34], [26, 1623, 43, 67], [1, 15, 34, 3, 2, 28], [10, 34, 11, 23, 539], [1, 34, 11, 288, 539], [133, 67, 3, 2, 105], [12, 99, 3, 105], [8, 20, 15, 40], [152, 4, 1182, 67, 120, 49, 402, 385], [23, 1183, 1184, 243, 403], [234, 4, 540], [251, 5, 1, 951, 3, 1185], [22, 3, 7, 186], [332, 43, 138, 502], [44, 34, 380, 591], [13, 5, 1, 14], [592, 3, 2, 262], [2, 16, 11, 1, 23, 364], [2, 163, 5, 723, 82], [36, 6, 2, 157], [10, 74, 5, 67], [2, 8, 6, 2, 36, 15, 422], [133, 331, 252, 10, 646], [7, 503, 3, 22], [2, 1186, 38, 5, 365], [1, 952, 953, 89, 3, 2, 17], [1, 204, 4, 29, 3, 2, 33], [1624, 647, 1187, 49, 2, 17], [109, 120, 49, 173, 116], [1625, 120, 49, 366], [10, 442, 380, 1, 96], [1, 56, 367, 6, 1, 146], [44, 273, 3, 954], [1626, 1627, 3, 2, 186], [1, 7, 9, 212, 820, 135], [648, 1188, 3, 1, 347], [2, 189, 5, 649, 423], [1, 71, 110], [2, 22, 5, 1628], [10, 34, 213, 11, 56, 1189], [1, 288, 1629, 423, 109], [12, 116, 162, 41, 3, 116], [2, 71, 541, 304], [138, 1190, 821], [86, 4, 1, 186, 273], [12, 9, 21, 650, 504], [37, 139, 244], [85, 3, 2, 29], [651, 67, 3, 2, 31, 4, 2, 48], [1, 18, 35, 3, 2, 105], [8, 35, 3, 2, 100], [1, 18, 20, 1, 955, 156], [386, 468, 261, 3, 28], [23, 386, 261, 3, 1, 28], [14, 64, 82, 2, 105, 6, 1, 822, 214], [14, 1191, 3, 105], [152, 4, 39, 5, 35], [10, 34, 3, 2, 28], [22, 4, 1, 34], [182, 120, 49, 29], [1, 95, 304, 3, 1, 105], [14, 330, 3, 823], [219, 261, 215, 36], [23, 386, 3, 2, 48], [22, 3, 2, 16], [293, 5, 20, 1, 112, 40], [212, 87, 111, 3, 1, 183], [1, 7, 58, 3, 1, 443], [469, 67, 3, 2, 443], [44, 22, 3, 147], [34, 3, 2, 48], [44, 404], [60, 233, 5, 652], [14, 6, 12, 3 ...
# x_val: [[2, 18, 6, 2, 262], [188, 6, 30], [26, 64, 3, 55], [1, 326, 4, 1, 33], [341, 3, 2, 17], [2787, 3, 1, 73], [1, 28, 25], [27, 3, 2, 145], [10, 191, 1028, 27, 34], [10, 9, 7, 85, 6, 2, 29], [93, 17, 338, 11, 577], [2, 78, 46, 1, 19, 9, 7, 847], [8, 5, 42, 1, 326], [90, 196, 689, 3, 54, 4, 2, 90], [235, 3, 2, 155, 108], [13, 5, 1, 279], [1, 88, 6, 2, 65], [891, 3, 1, 882, 272, 100], [10, 245, 3, 740], [13, 5, 1, 14], [1, 62, 6, 2, 418], [21, 53, 94, 6, 69], [1, 89, 3, 2, 17], [26, 431, 247, 329, 3, 441], [2, 231, 5, 10], [483, 494, 184, 1810], [2, 23, 1324], [461, 4, 410, 64, 82, 256, 48], [2, 24, 4, 1, 88], [2, 147, 3, 2, 427], [2, 5, 10], [21, 9, 7, 147], [311, 185, 6, 2, 51], [2, 190, 4, 1561, 77], [253, 4, 32, 147, 260, 11, 1617, 9, 10], [8, 42, 1, 814], [127, 224, 6, 1, 493], [1, 118, 128, 2, 485], [22, 3, 2, 16], [377, 4, 1, 8, 3, 2, 55], [8, 20, 12, 87], [53, 94, 137, 289, 69], [2, 8, 3, 2, 101], [920, 41, 6, 2, 2638], [14, 3, 1, 101], [37, 16, 11, 1, 38, 106], [1, 58], [1, 272, 4, 194], [7, 75, 3, 2, 31, 4, 2, 351], [52, 3, 2, 55], [1, 10, 9, 7, 25], [2, 2394, 68, 5, 15], [250, 3, 27], [1, 276, 98, 42, 1, 455], [52, 9, 10, 151, 6, 2, 30], [56, 2342, 170, 100, 3, 717], [222, 88, 35, 134], [2, 428, 167, 43, 3], [29, 30], [39, 81, 53, 6, 1, 28], [1, 7, 136, 3, 1, 7, 45], [26, 176, 81, 53], [161, 3, 2, 51], [25, 6, 2, 742], [409, 4, 160, 15, 30], [39, 83, 2, 656], [99, 6, 2, 742], [79, 3, 1, 38], [18, 35, 3, 2, 51], [1, 23, 105], [37, 89, 291, 3, 17], [1, 38, 3, 2, 17], [123, 4, 1, 101, 11, 52, 245, 3, 2, 55], [348, 3, 1, 45], [27, 145, 3, 2, 55], [2, 160, 30], [283, 4, 1066, 374, 6, 2, 22], [822, 27, 374, 6, 1, 214], [6, 1, 2407], [8, 184, 59, 159, 100], [2, 140, 5, 10], [1392, 8, 3, 229, 376], [44, 45, 11, 3, 454], [1129, 164], [26, 293, 81, 107], [1711], [14, 3, 1, 452], [151, 6, 2, 69], [131, 6, 1, 1190, 351], [1, 10, 223], [342, 50, 6, 155, 98], [1, 58, 5, 6, 2, 30], [8, 3, 1, 101], [1, 1134, 5, 683, 82, 1, 573], [229, 487], [86, 4, 36, 15, 30], [78, 3, 2, 51], [57, 41, 3, 1, 988, 135, 33], [130, 6, 1, 400, 98], [21, 319, 3, 2, 31, 4, 23, 735], [57, 41, 6, 1, 279], [6, 2, 65], [1, 636, 462, 1939], [340, 4, 78, 5, 122], [58], [286, 24, 5, 464, 205], [2, 18, 41, 3, 2, 62], [1, 18, 11, 2, 442], [32, 97, 128, 2, 47], [132, 3, 1, 45], [18, 11, 337, 158], [1, 7, 356, 5, 111], [2, 66, 3, 2, 75], [79, 11, 1, 122, 725], [2, 85, 5, 122], [1, 496, 7, 1425], [21, 9, 7, 28, 25], [1, 23, 9, 12, 150, 144], [18, 20, 7, 605, 54], [131, 120, 49, 131], [24, 4, 32, 97], [1, 8, 2892, 1, 50], [10, 9, 7, 57], [2, 40, 5, 23], [669, 367, 3, 189], [1, 10, 74, 2887, 288, 585], [2787, 3, 2, 73], [18, 20, 285], [263, 25, 11, 598, 35, 2404, 3, 149], [86, 4, 1], [7, 11, 12, 307, 3, 265], [14, 399, 53, 208], [1, 342, 50], [2, 26, 44, 485, 41, 164, 1, 193], [24, 4, 1, 14], [2, 224, 43, 6, 32, 695], [7, 58, 67, 3, 476, 427], [2, 8, 5, 20, 1, 15, 40], [13, 270, 5, 6, 1], [332, 43, 26, 300], [95, 3, 2, 45], [126, 66, 2068, 479, 248], [1, 1247, 209], [23, 444, 3, 2, 48], [2, 24, 4, 1, 88], [38, 108, 6, 2, 989], [2, 85, 3, 2, 29], [2, 840, 5, 21, 9, 23], [191, 1028, 27, 2704], [1, 113, 117, 438], [160, 714, 70, 3, 173, 33], [1, 509, 4, 217, 5, 6, 1, 195], [1, 27, 683, 82, 2, 145], [8, 81, 11, 107], [7, 57, 6, 1, 171, 10, 234], [2, 61, 3, 2, 101], [73, 3, 2, 45], [1, 3, 2, 105], [7, 865, 3, 54, 4, 53, 200], [8, 20, 23], [2, 50, 380, 2, 29], [61, 3, 101], [8, 398, 1467], [133], [58], [21, 194, 6, 2, 123, 4, 2, 199], [26, 39, 215, 60], [2, 494, 4, 1, 8], [10, 50, 11, 872], [435, 59, 2, 45, 613, 164, 2, 94], [2, 367, 6, 2, 189], [847, 3, 2, 84], [148, 7, 436, 3, 40], [2, 132, 46, 931], [32, 69, 1826, 147], [2, 24, 4, 1, 18], [97], [625, 3, 2, 29], [1117, 4, 1137], [18, 20, 1, 267, 112, 40], [224, 64, 6, 1, 65], [2, 24, 4, 1, 88], [1, 696, 4, 21, 51], [150, 144, 59, 508], [2, 14, 331, 3, 2, 17], [14, 20, 7, 40, 11, 10, 448], [2, 140, 5, 10], [280, 390, 218, 1, 838], [1, 204, 4, 299], [256, 609, 19, 55], [1, 353, 4, 217, 3, 1, 201], [88, 3, 2, 262], [10, 48 ...

# %%
#padding with post (appending zeros at the end to equalize sentence length)
from keras.preprocessing.sequence import pad_sequences
x_tr = pad_sequences(x_tr,maxlen = maxlen_english,padding = 'post')
x_val = pad_sequences(x_val,maxlen = maxlen_english,padding = 'post')

# +1 for padding 
x_voc_size   =  len(x_tokens.word_index) +1
print("No of unique words in English",x_voc_size)
# Out:
# No of unique words in English 3031

# %%
# English data preprocessing
from keras.preprocessing.text import Tokenizer
y_tokens = Tokenizer()
y_tokens.fit_on_texts(y_tr)

y_tr = y_tokens.texts_to_sequences(y_tr)
y_val = y_tokens.texts_to_sequences(y_val)

from keras.preprocessing.sequence import pad_sequences
y_tr = pad_sequences(y_tr,maxlen = maxlen_malayalam,padding = 'post')
y_val = pad_sequences(y_val,maxlen = maxlen_malayalam,padding = 'post')

# +1 for padding 
y_voc_size   =  len(y_tokens.word_index) +1
print("No of unique words in Malyalam",y_voc_size)
# Out:
# No of unique words in Malyalam 5674

# %%
pip install keras-applications
# Out:
# Collecting keras-applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.0 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications) (1.5.2)
# Installing collected packages: keras-applications
# Successfully installed keras-applications-1.0.8

# %%
import pandas as pd
import pickle
import numpy as np
import os
import keras
import tensorflow
from keras_applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D,BatchNormalization,Flatten,Input, Convolution2D, Dropout, LSTM, TimeDistributed, Embedding, Bidirectional, Activation, RepeatVector,Concatenate
from keras.models import Sequential, Model
from keras.utils import np_utils
import random
from keras.preprocessing import image, sequence
import matplotlib.pyplot as plt
import keras
from keras import backend as K 
import gensim
from numpy import *
import numpy as np
import pandas as pd 
import re
from tensorflow.keras.applications.vgg16 import VGG16
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed,Conv2D,MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings

# %%
#Loading VGG model for Feature Extraction-Removing classification layers from memory
modelvgg = VGG16(include_top=True,weights="imagenet")
modelvgg.layers.pop()
modelvgg = Model(inputs=modelvgg.inputs, outputs=modelvgg.layers[-2].output)
modelvgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step
# 553476096/553467096 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    modelvgg,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
pip install cv
# Out:
# Collecting cv
#   Downloading cv-1.0.0-py3-none-any.whl (7.3 kB)
# Installing collected packages: cv
# Successfully installed cv-1.0.0

# %%
import cv2
import cv
# Out:
# ERROR:root:Error disabling cv.imshow().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py", line 86, in load_module
#     cv_module.imshow,
# AttributeError: module 'cv' has no attribute 'imshow'

# %%
#tRY RESNET

# %%
#Resizing image and converting grey scale images into RGB images
#split=5000
imagedata=np.zeros(shape=(splits,224,224,3))
for i in range(splits):
    temp=mp.imread(img_path[i])
    if (len(temp.shape)==3):
       temp=cv2.resize(temp,(224,224))
       imagedata[i]=temp
    elif (len(temp.shape)<3):
       #plt.imshow(temp)
       temp=cv2.cvtColor(temp, cv2.COLOR_BGR2RGB)
       temp=cv2.resize(temp,(224,224))
       imagedata[i]=temp    
imagedata=imagedata/255
imagedata=imagedata.astype(np.float16)

# %%
imagedata[1:10]
# Out:
# array([[[[0.4626  , 0.443   , 0.3254  ],
#          [0.4548  , 0.4353  , 0.3176  ],
#          [0.4666  , 0.447   , 0.3293  ],
#          ...,
#          [0.902   , 0.933   , 0.9453  ],
#          [0.906   , 0.937   , 0.949   ],
#          [0.906   , 0.937   , 0.949   ]],
#
#         [[0.4666  , 0.447   , 0.3293  ],
#          [0.4587  , 0.4392  , 0.3215  ],
#          [0.4707  , 0.451   , 0.3333  ],
#          ...,
#          [0.949   , 0.9805  , 0.9883  ],
#          [0.9453  , 0.9766  , 0.9883  ],
#          [0.9453  , 0.9766  , 0.9883  ]],
#
#         [[0.4707  , 0.451   , 0.3333  ],
#          [0.4626  , 0.443   , 0.3254  ],
#          [0.4785  , 0.4587  , 0.341   ],
#          ...,
#          [0.961   , 0.992   , 1.      ],
#          [0.9453  , 0.9766  , 0.992   ],
#          [0.9453  , 0.9766  , 0.992   ]],
#
#         ...,
#
#         [[0.3098  , 0.2864  , 0.2393  ],
#          [0.341   , 0.3098  , 0.2666  ],
#          [0.3647  , 0.3254  , 0.2864  ],
#          ...,
#          [0.1686  , 0.153   , 0.1059  ],
#          [0.1647  , 0.149   , 0.102   ],
#          [0.1569  , 0.1412  , 0.0941  ]],
#
#         [[0.3098  , 0.2864  , 0.2393  ],
#          [0.3215  , 0.2903  , 0.2471  ],
#          [0.3608  , 0.3176  , 0.2783  ],
#          ...,
#          [0.1608  , 0.1451  , 0.098   ],
#          [0.1647  , 0.149   , 0.102   ],
#          [0.153   , 0.1372  , 0.0902  ]],
#
#         [[0.3176  , 0.298   , 0.2471  ],
#          [0.3215  , 0.2903  , 0.2471  ],
#          [0.349   , 0.3098  , 0.2705  ],
#          ...,
#          [0.153   , 0.1372  , 0.0902  ],
#          [0.1686  , 0.153   , 0.1059  ],
#          [0.149   , 0.1333  , 0.0863  ]]],
#
#
#        [[[0.51    , 0.502   , 0.506   ],
#          [0.506   , 0.506   , 0.51    ],
#          [0.51    , 0.506   , 0.5215  ],
#          ...,
#          [0.392   , 0.408   , 0.447   ],
#          [0.3843  , 0.408   , 0.4548  ],
#          [0.3765  , 0.408   , 0.4587  ]],
#
#         [[0.498   , 0.498   , 0.4902  ],
#          [0.502   , 0.502   , 0.4941  ],
#          [0.502   , 0.4941  , 0.498   ],
#          ...,
#          [0.392   , 0.4197  , 0.4824  ],
#          [0.3804  , 0.4119  , 0.4707  ],
#          [0.3726  , 0.4197  , 0.4666  ]],
#
#         [[0.5176  , 0.498   , 0.502   ],
#          [0.51    , 0.5137  , 0.506   ],
#          [0.4941  , 0.5137  , 0.4902  ],
#          ...,
#          [0.3647  , 0.3882  , 0.451   ],
#          [0.349   , 0.3843  , 0.4353  ],
#          [0.3372  , 0.3843  , 0.4314  ]],
#
#         ...,
#
#         [[0.443   , 0.2864  , 0.1843  ],
#          [0.4587  , 0.298   , 0.1765  ],
#          [0.4785  , 0.306   , 0.1765  ],
#          ...,
#          [0.2471  , 0.1765  , 0.1333  ],
#          [0.255   , 0.1804  , 0.1294  ],
#          [0.255   , 0.1804  , 0.1216  ]],
#
#         [[0.4626  , 0.306   , 0.1843  ],
#          [0.4666  , 0.2942  , 0.196   ],
#          [0.4902  , 0.3137  , 0.1843  ],
#          ...,
#          [0.2118  , 0.1569  , 0.1098  ],
#          [0.2471  , 0.1804  , 0.1333  ],
#          [0.2471  , 0.1726  , 0.1177  ]],
#
#         [[0.4587  , 0.298   , 0.1843  ],
#          [0.4707  , 0.3215  , 0.1804  ],
#          [0.4707  , 0.3176  , 0.1882  ],
#          ...,
#          [0.2313  , 0.1686  , 0.1177  ],
#          [0.2588  , 0.1843  , 0.1294  ],
#          [0.2588  , 0.1686  , 0.1098  ]]],
#
#
#        [[[0.9766  , 0.9727  , 0.9727  ],
#          [0.957   , 0.9688  , 0.933   ],
#          [0.953   , 0.9727  , 0.9805  ],
#          ...,
#          [0.306   , 0.3215  , 0.3254  ],
#          [0.2903  , 0.306   , 0.3098  ],
#          [0.2942  , 0.3098  , 0.3137  ]],
#
#         [[0.996   , 0.992   , 0.996   ],
#          [0.9805  , 0.992   , 0.961   ],
#          [0.9727  , 0.9883  , 1.      ],
#          ...,
#          [0.3137  , 0.3293  , 0.3333  ],
#          [0.298   , 0.3137  , 0.3176  ],
#          [0.3098  , 0.3254  , 0.3293  ]],
#
#         [[0.9097  , 0.953   , 0.9688  ],
#          [0.847   , 0.9214  , 0.937   ],
#          [0.816   , 0.886   , 0.953   ],
#          ...,
#          [0.3215  , 0.3372  , 0.341   ],
#          [0.298   , 0.3137  , 0.3176  ],
#          [0.3137  , 0.3293  , 0.3333  ]],
#
#         ...,
#
#         [[0.341   , 0.3804  , 0.4197  ],
#          [0.349   , 0.3882  , 0.4275  ],
#          [0.349   , 0.3882  , 0.4275  ],
#          ...,
#          [0.00392 , 0.011765, 0.      ],
#          [0.011765, 0.0196  , 0.00784 ],
#          [0.011765, 0.0196  , 0.00784 ]],
#
#         [[0.3254  , 0.3647  , 0.4038  ],
#          [0.3372  , 0.3765  , 0.4119  ],
#          [0.3333  , 0.3687  , 0.408   ],
#          ...,
#          [0.011765, 0.0196  , 0.00784 ],
#          [0.00784 , 0.01569 , 0.00392 ],
#          [0.00784 , 0.01569 , 0.00392 ]],
#
#         [[0.3137  , 0.349   , 0.3882  ],
#          [0.3215  , 0.3608  , 0.4     ],
#          [0.3176  , 0.357   , 0.396   ],
#          ...,
#          [0.00392 , 0.011765, 0.      ],
#          [0.00392 , 0.011765, 0.      ],
#          [0.00392 , 0.011765, 0.      ]]],
#
#
#        ...,
#
#
#        [[[0.682   , 0.678   , 0.855   ],
#          [0.757   , 0.855   , 0.847   ],
#          [0.545   , 0.596   , 0.608   ],
#          ...,
#          [0.5293  , 0.6943  , 0.9844  ],
#          [0.5254  , 0.6904  , 0.9805  ],
#          [0.5293  , 0.6943  , 0.9844  ]],
#
#         [[0.6665  , 0.6626  , 0.8394  ],
#          [0.7646  , 0.855   , 0.859   ],
#          [0.604   , 0.655   , 0.6743  ],
#          ...,
#          [0.537   , 0.702   , 0.992   ],
#          [0.541   , 0.706   , 0.996   ],
#          [0.545   , 0.71    , 0.996   ]],
#
#         [[0.682   , 0.678   , 0.8433  ],
#          [0.757   , 0.851   , 0.855   ],
#          [0.6313  , 0.678   , 0.714   ],
#          ...,
#          [0.545   , 0.71    , 1.      ],
#          [0.537   , 0.702   , 0.992   ],
#          [0.545   , 0.71    , 0.996   ]],
#
#         ...,
#
#         [[0.4119  , 0.4197  , 0.4666  ],
#          [0.4275  , 0.4353  , 0.4824  ],
#          [0.447   , 0.4548  , 0.502   ],
#          ...,
#          [0.678   , 0.6943  , 0.741   ],
#          [0.647   , 0.6665  , 0.71    ],
#          [0.6157  , 0.6313  , 0.678   ]],
#
#         [[0.4     , 0.408   , 0.4548  ],
#          [0.4353  , 0.443   , 0.4902  ],
#          [0.4626  , 0.4707  , 0.5176  ],
#          ...,
#          [0.5176  , 0.537   , 0.5845  ],
#          [0.4548  , 0.4707  , 0.5176  ],
#          [0.4392  , 0.4548  , 0.502   ]],
#
#         [[0.4236  , 0.4314  , 0.4785  ],
#          [0.408   , 0.4158  , 0.4626  ],
#          [0.447   , 0.4548  , 0.502   ],
#          ...,
#          [0.6235  , 0.643   , 0.6904  ],
#          [0.643   , 0.6587  , 0.706   ],
#          [0.639   , 0.655   , 0.702   ]]],
#
#
#        [[[0.3293  , 0.3293  , 0.3333  ],
#          [0.1569  , 0.1608  , 0.1412  ],
#          [0.051   , 0.0549  , 0.03137 ],
#          ...,
#          [0.392   , 0.3293  , 0.2783  ],
#          [0.357   , 0.2942  , 0.2705  ],
#          [0.2354  , 0.1804  , 0.1804  ]],
#
#         [[0.3452  , 0.3452  , 0.353   ],
#          [0.1765  , 0.1804  , 0.1608  ],
#          [0.05884 , 0.06274 , 0.0392  ],
#          ...,
#          [0.408   , 0.3452  , 0.2942  ],
#          [0.3647  , 0.306   , 0.2783  ],
#          [0.2393  , 0.1843  , 0.1843  ]],
#
#         [[0.3372  , 0.3372  , 0.341   ],
#          [0.1921  , 0.196   , 0.1765  ],
#          [0.0549  , 0.05884 , 0.0353  ],
#          ...,
#          [0.4158  , 0.353   , 0.302   ],
#          [0.3647  , 0.306   , 0.2783  ],
#          [0.2313  , 0.1726  , 0.1726  ]],
#
#         ...,
#
#         [[0.3215  , 0.298   , 0.3137  ],
#          [0.3215  , 0.298   , 0.3137  ],
#          [0.3215  , 0.298   , 0.3137  ],
#          ...,
#          [0.1059  , 0.0941  , 0.06665 ],
#          [0.1059  , 0.0941  , 0.06665 ],
#          [0.102   , 0.0902  , 0.06274 ]],
#
#         [[0.3176  , 0.2942  , 0.3098  ],
#          [0.3176  , 0.2942  , 0.3098  ],
#          [0.3176  , 0.2942  , 0.3098  ],
#          ...,
#          [0.102   , 0.0902  , 0.06274 ],
#          [0.102   , 0.0902  , 0.06274 ],
#          [0.098   , 0.0863  , 0.05884 ]],
#
#         [[0.3137  , 0.2903  , 0.306   ],
#          [0.3137  , 0.2903  , 0.306   ],
#          [0.3137  , 0.2903  , 0.306   ],
#          ...,
#          [0.098   , 0.0863  , 0.05884 ],
#          [0.102   , 0.0902  , 0.06274 ],
#          [0.0941  , 0.08234 , 0.0549  ]]],
#
#
#        [[[0.961   , 0.9253  , 0.937   ],
#          [0.961   , 0.9453  , 0.949   ],
#          [0.957   , 0.933   , 0.9414  ],
#          ...,
#          [0.7295  , 0.549   , 0.498   ],
#          [0.6626  , 0.569   , 0.502   ],
#          [0.655   , 0.5767  , 0.4863  ]],
#
#         [[0.961   , 0.9414  , 0.9453  ],
#          [0.965   , 0.949   , 0.953   ],
#          [0.965   , 0.949   , 0.953   ],
#          ...,
#          [0.71    , 0.533   , 0.4785  ],
#          [0.643   , 0.565   , 0.506   ],
#          [0.6353  , 0.5566  , 0.51    ]],
#
#         [[0.9727  , 0.957   , 0.953   ],
#          [0.9688  , 0.953   , 0.957   ],
#          [0.9688  , 0.953   , 0.957   ],
#          ...,
#          [0.7256  , 0.5605  , 0.5137  ],
#          [0.6665  , 0.5884  , 0.545   ],
#          [0.651   , 0.5767  , 0.5176  ]],
#
#         ...,
#
#         [[0.255   , 0.149   , 0.1372  ],
#          [0.2196  , 0.1216  , 0.1098  ],
#          [0.2235  , 0.1412  , 0.149   ],
#          ...,
#          [0.9414  , 0.937   , 0.961   ],
#          [0.9453  , 0.933   , 0.961   ],
#          [0.937   , 0.9253  , 0.953   ]],
#
#         [[0.2235  , 0.1412  , 0.1216  ],
#          [0.2274  , 0.1372  , 0.1255  ],
#          [0.2274  , 0.1333  , 0.1098  ],
#          ...,
#          [0.949   , 0.9453  , 0.9688  ],
#          [0.949   , 0.937   , 0.965   ],
#          [0.9414  , 0.929   , 0.957   ]],
#
#         [[0.2627  , 0.1608  , 0.153   ],
#          [0.2588  , 0.1333  , 0.1333  ],
#          [0.196   , 0.1255  , 0.1216  ],
#          ...,
#          [0.961   , 0.957   , 0.9766  ],
#          [0.929   , 0.9175  , 0.949   ],
#          [0.9253  , 0.9136  , 0.9414  ]]]], dtype=float16)

# %%
with open('/content/drive/My Drive/Main/imagedatas.txt', 'w') as writefile:
    writefile.write("imagedata")

# %%
#preprocessing images
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
from collections import OrderedDict
jpgs=img_path[:splits]
images_new = OrderedDict()
npix = 224
target_size = (npix,npix,3)
for i,name in enumerate(jpgs): 
    filename = name
    image = load_img(filename, target_size=target_size)
    # convert the image pixels to a numpy array
    image = img_to_array(image)
    nimage = preprocess_input(image)
    y_pred = modelvgg.predict(nimage.reshape( (1,) + nimage.shape[:3]))
    images_new [name] = y_pred.flatten()
    if i%200==0:
        print(i,filename)
# Out:
# 0 /content/drive/My Drive/Main/trainimages/train/10.jpg
# 200 /content/drive/My Drive/Main/trainimages/train/739.jpg
# 400 /content/drive/My Drive/Main/trainimages/train/1529.jpg
# 600 /content/drive/My Drive/Main/trainimages/train/2238.jpg
# 800 /content/drive/My Drive/Main/trainimages/train/2970.jpg
# 1000 /content/drive/My Drive/Main/trainimages/train/3693.jpg
# 1200 /content/drive/My Drive/Main/trainimages/train/4450.jpg
# 1400 /content/drive/My Drive/Main/trainimages/train/150275.jpg
# 1600 /content/drive/My Drive/Main/trainimages/train/497937.jpg
# 1800 /content/drive/My Drive/Main/trainimages/train/713300.jpg
# 2000 /content/drive/My Drive/Main/trainimages/train/1159284.jpg
# 2200 /content/drive/My Drive/Main/trainimages/train/1160083.jpg
# 2400 /content/drive/My Drive/Main/trainimages/train/1592294.jpg
# 2600 /content/drive/My Drive/Main/trainimages/train/1592957.jpg
# 2800 /content/drive/My Drive/Main/trainimages/train/2315779.jpg
# 3000 /content/drive/My Drive/Main/trainimages/train/2316528.jpg
# 3200 /content/drive/My Drive/Main/trainimages/train/2317337.jpg
# 3400 /content/drive/My Drive/Main/trainimages/train/2318048.jpg
# 3600 /content/drive/My Drive/Main/trainimages/train/2318796.jpg
# 3800 /content/drive/My Drive/Main/trainimages/train/2319593.jpg
# 4000 /content/drive/My Drive/Main/trainimages/train/2320436.jpg
# 4200 /content/drive/My Drive/Main/trainimages/train/2321247.jpg
# 4400 /content/drive/My Drive/Main/trainimages/train/2322001.jpg
# 4600 /content/drive/My Drive/Main/trainimages/train/2322763.jpg
# 4800 /content/drive/My Drive/Main/trainimages/train/2323538.jpg
# 5000 /content/drive/My Drive/Main/trainimages/train/2324400.jpg
# 5200 /content/drive/My Drive/Main/trainimages/train/2325137.jpg
# 5400 /content/drive/My Drive/Main/trainimages/train/2325912.jpg
# 5600 /content/drive/My Drive/Main/trainimages/train/2326777.jpg
# 5800 /content/drive/My Drive/Main/trainimages/train/2327564.jpg
# 6000 /content/drive/My Drive/Main/trainimages/train/2328291.jpg
# 6200 /content/drive/My Drive/Main/trainimages/train/2329112.jpg
# 6400 /content/drive/My Drive/Main/trainimages/train/2329883.jpg
# 6600 /content/drive/My Drive/Main/trainimages/train/2330601.jpg
# 6800 /content/drive/My Drive/Main/trainimages/train/2331402.jpg
# 7000 /content/drive/My Drive/Main/trainimages/train/2332176.jpg
# 7200 /content/drive/My Drive/Main/trainimages/train/2333032.jpg
# 7400 /content/drive/My Drive/Main/trainimages/train/2333847.jpg
# 7600 /content/drive/My Drive/Main/trainimages/train/2334602.jpg
# 7800 /content/drive/My Drive/Main/trainimages/train/2335353.jpg
# 8000 /content/drive/My Drive/Main/trainimages/train/2336144.jpg
# 8200 /content/drive/My Drive/Main/trainimages/train/2336923.jpg
# 8400 /content/drive/My Drive/Main/trainimages/train/2337672.jpg
# 8600 /content/drive/My Drive/Main/trainimages/train/2338520.jpg
# 8800 /content/drive/My Drive/Main/trainimages/train/2339266.jpg
# 9000 /content/drive/My Drive/Main/trainimages/train/2339991.jpg
# 9200 /content/drive/My Drive/Main/trainimages/train/2340756.jpg
# 9400 /content/drive/My Drive/Main/trainimages/train/2341498.jpg
# 9600 /content/drive/My Drive/Main/trainimages/train/2342276.jpg
# 9800 /content/drive/My Drive/Main/trainimages/train/2343119.jpg

# %%
print(list(images_new.values())[1])
# Out:
# [0.6324536 1.3856603 0.        ... 0.        0.        2.182263 ]

# %%
#storing image pixels sepearetely
vgg_feature=np.zeros(shape=(len(jpgs),4096))
for i in range(len(jpgs)):
    vgg_feature[i]=images_new[jpgs[i]]
vgg_feature[1:10]
# Out:
# array([[0.63245362, 1.38566029, 0.        , ..., 0.        , 0.        ,
#         2.1822629 ],
#        [0.54209262, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.93312246],
#        [1.5215044 , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.11626244, 1.3521657 , 0.05647588, ..., 0.        , 2.70661497,
#         0.        ],
#        [2.4945612 , 1.68215179, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.26692578, 4.36360025, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
#splitting image pixels for training and validation
vgg_train_=vgg_feature[:splits-500]
vgg_val=vgg_feature[splits-500:]

# %%
#Generating a repeat vector from image pixels
img_inputs=Input(shape=(4096,))
d_1=Dense(512, activation='relu')(img_inputs)
r_1=RepeatVector(maxlen_english)(d_1)
vf_model = Model(img_inputs, r_1)
vf_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 4096)]            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2097664
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 14, 512)           0
# =================================================================
# Total params: 2,097,664
# Trainable params: 2,097,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_voc=x_voc_size
y_voc=y_voc_size

# %%
#Model
x_voc=x_voc_size
y_voc=y_voc_size
latent_dim = 512
embedding_dim=512
#Encoder
encoder_inputs = Input(shape=(maxlen_english,))
#The model will take as input an integer matrix of size (batch,input_length)and the largest integer (i.e. word index) in the input
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)
print(encoder_inputs.get_shape)
print(enc_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 14) dtype=float32 (created by layer 'input_3')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 14, 512) dtype=float32 (created by layer 'embedding')>>

# %%
#encoder LSTM Layer 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
#The dimension of each state equals to the LSTM unit number
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)
print(encoder_lstm1.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 14, 512), (None, 512), (None, 512)]

# %%
#LSTM layer 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)
print(encoder_lstm2.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 14, 512), (None, 512), (None, 512)]

# %%
#Concatenating image features with text input 
encoder_output2=Concatenate(axis=-1)([encoder_output2,r_1])

# %%
#LSTM layer 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
print(encoder_lstm3.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 14, 512), (None, 512), (None, 512)]

# %%
#Decoder
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)
print(decoder_inputs.get_shape)
print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_4')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None, 512) dtype=float32 (created by layer 'embedding_1')>>

# %%
#Decoder LSTM layer1
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])
print(decoder_lstm.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, None, 512), (None, 512), (None, 512)]

# %%
#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)
print(decoder_dense.output_shape)
# Out:
# (None, None, 5674)

# %%
model = Model([encoder_inputs,decoder_inputs,img_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 14)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 14, 512)      1551872     input_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 14, 512), (N 2099200     embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          2097664     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 14, 512), (N 2099200     lstm[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 14, 512)      0           dense[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 1024)     0           lstm_1[0][0]
#                                                                  repeat_vector[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 512)    2905088     input_4[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 14, 512), (N 3147776     concatenate[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 512),  2099200     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 5674)   2910762     lstm_3[0][0]
# ==================================================================================================
# Total params: 18,910,762
# Trainable params: 18,910,762
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
in

# %%
#compiling model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit([x_tr,y_tr[:,:-1],vgg_train_], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,validation_data=([x_val,y_val[:,:-1],vgg_val], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]),epochs=100,batch_size=512)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 15s 324ms/step - loss: 4.0751 - accuracy: 0.5762 - val_loss: 2.3049 - val_accuracy: 0.6590
# Epoch 2/100
# 19/19 [==============================] - 5s 271ms/step - loss: 2.4583 - accuracy: 0.6436 - val_loss: 2.0995 - val_accuracy: 0.6740
# Epoch 3/100
# 19/19 [==============================] - 5s 263ms/step - loss: 2.2810 - accuracy: 0.6799 - val_loss: 1.9948 - val_accuracy: 0.7192
# Epoch 4/100
# 19/19 [==============================] - 5s 274ms/step - loss: 2.1676 - accuracy: 0.7091 - val_loss: 1.9167 - val_accuracy: 0.7365
# Epoch 5/100
# 19/19 [==============================] - 5s 270ms/step - loss: 2.1056 - accuracy: 0.7140 - val_loss: 1.8812 - val_accuracy: 0.7372
# Epoch 6/100
# 19/19 [==============================] - 5s 268ms/step - loss: 2.0594 - accuracy: 0.7151 - val_loss: 1.8566 - val_accuracy: 0.7367
# Epoch 7/100
# 19/19 [==============================] - 5s 263ms/step - loss: 2.0141 - accuracy: 0.7181 - val_loss: 1.8298 - val_accuracy: 0.7388
# Epoch 8/100
# 19/19 [==============================] - 5s 273ms/step - loss: 1.9649 - accuracy: 0.7265 - val_loss: 1.8054 - val_accuracy: 0.7458
# Epoch 9/100
# 19/19 [==============================] - 5s 276ms/step - loss: 1.9147 - accuracy: 0.7343 - val_loss: 1.7776 - val_accuracy: 0.7500
# Epoch 10/100
# 19/19 [==============================] - 5s 276ms/step - loss: 1.8653 - accuracy: 0.7399 - val_loss: 1.7477 - val_accuracy: 0.7558
# Epoch 11/100
# 19/19 [==============================] - 5s 272ms/step - loss: 1.8208 - accuracy: 0.7464 - val_loss: 1.7261 - val_accuracy: 0.7587
# Epoch 12/100
# 19/19 [==============================] - 5s 273ms/step - loss: 1.7808 - accuracy: 0.7510 - val_loss: 1.7065 - val_accuracy: 0.7652
# Epoch 13/100
# 19/19 [==============================] - 5s 271ms/step - loss: 1.7465 - accuracy: 0.7548 - val_loss: 1.6945 - val_accuracy: 0.7662
# Epoch 14/100
# 19/19 [==============================] - 5s 274ms/step - loss: 1.7173 - accuracy: 0.7562 - val_loss: 1.6844 - val_accuracy: 0.7668
# Epoch 15/100
# 19/19 [==============================] - 5s 271ms/step - loss: 1.6913 - accuracy: 0.7575 - val_loss: 1.6757 - val_accuracy: 0.7683
# Epoch 16/100
# 19/19 [==============================] - 5s 274ms/step - loss: 1.6674 - accuracy: 0.7592 - val_loss: 1.6695 - val_accuracy: 0.7678
# Epoch 17/100
# 19/19 [==============================] - 5s 279ms/step - loss: 1.6450 - accuracy: 0.7604 - val_loss: 1.6655 - val_accuracy: 0.7682
# Epoch 18/100
# 19/19 [==============================] - 5s 279ms/step - loss: 1.6233 - accuracy: 0.7614 - val_loss: 1.6642 - val_accuracy: 0.7677
# Epoch 19/100
# 19/19 [==============================] - 5s 279ms/step - loss: 1.6023 - accuracy: 0.7624 - val_loss: 1.6580 - val_accuracy: 0.7685
# Epoch 20/100
# 19/19 [==============================] - 5s 275ms/step - loss: 1.5819 - accuracy: 0.7640 - val_loss: 1.6535 - val_accuracy: 0.7693
# Epoch 21/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.5611 - accuracy: 0.7652 - val_loss: 1.6552 - val_accuracy: 0.7698
# Epoch 22/100
# 19/19 [==============================] - 5s 281ms/step - loss: 1.5411 - accuracy: 0.7662 - val_loss: 1.6526 - val_accuracy: 0.7702
# Epoch 23/100
# 19/19 [==============================] - 5s 267ms/step - loss: 1.5216 - accuracy: 0.7677 - val_loss: 1.6476 - val_accuracy: 0.7715
# Epoch 24/100
# 19/19 [==============================] - 5s 282ms/step - loss: 1.5021 - accuracy: 0.7684 - val_loss: 1.6469 - val_accuracy: 0.7722
# Epoch 25/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.4835 - accuracy: 0.7694 - val_loss: 1.6487 - val_accuracy: 0.7730
# Epoch 26/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.4647 - accuracy: 0.7703 - val_loss: 1.6469 - val_accuracy: 0.7728
# Epoch 27/100
# 19/19 [==============================] - 5s 277ms/step - loss: 1.4463 - accuracy: 0.7721 - val_loss: 1.6477 - val_accuracy: 0.7733
# Epoch 28/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.4275 - accuracy: 0.7733 - val_loss: 1.6485 - val_accuracy: 0.7732
# Epoch 29/100
# 19/19 [==============================] - 5s 275ms/step - loss: 1.4097 - accuracy: 0.7743 - val_loss: 1.6484 - val_accuracy: 0.7738
# Epoch 30/100
# 19/19 [==============================] - 5s 267ms/step - loss: 1.3921 - accuracy: 0.7755 - val_loss: 1.6507 - val_accuracy: 0.7728
# Epoch 31/100
# 19/19 [==============================] - 5s 271ms/step - loss: 1.3746 - accuracy: 0.7767 - val_loss: 1.6494 - val_accuracy: 0.7727
# Epoch 32/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.3577 - accuracy: 0.7782 - val_loss: 1.6517 - val_accuracy: 0.7725
# Epoch 33/100
# 19/19 [==============================] - 5s 268ms/step - loss: 1.3407 - accuracy: 0.7796 - val_loss: 1.6549 - val_accuracy: 0.7717
# Epoch 34/100
# 19/19 [==============================] - 5s 273ms/step - loss: 1.3240 - accuracy: 0.7806 - val_loss: 1.6551 - val_accuracy: 0.7725
# Epoch 35/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.3063 - accuracy: 0.7825 - val_loss: 1.6543 - val_accuracy: 0.7728
# Epoch 36/100
# 19/19 [==============================] - 5s 273ms/step - loss: 1.2903 - accuracy: 0.7841 - val_loss: 1.6575 - val_accuracy: 0.7732
# Epoch 37/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.2739 - accuracy: 0.7855 - val_loss: 1.6608 - val_accuracy: 0.7732
# Epoch 38/100
# 19/19 [==============================] - 5s 271ms/step - loss: 1.2568 - accuracy: 0.7875 - val_loss: 1.6604 - val_accuracy: 0.7733
# Epoch 39/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.2412 - accuracy: 0.7895 - val_loss: 1.6646 - val_accuracy: 0.7735
# Epoch 40/100
# 19/19 [==============================] - 5s 272ms/step - loss: 1.2259 - accuracy: 0.7918 - val_loss: 1.6671 - val_accuracy: 0.7725
# Epoch 41/100
# 19/19 [==============================] - 5s 280ms/step - loss: 1.2098 - accuracy: 0.7943 - val_loss: 1.6687 - val_accuracy: 0.7725
# Epoch 42/100
# 19/19 [==============================] - 5s 271ms/step - loss: 1.1945 - accuracy: 0.7962 - val_loss: 1.6704 - val_accuracy: 0.7738
# Epoch 43/100
# 19/19 [==============================] - 5s 277ms/step - loss: 1.1791 - accuracy: 0.7990 - val_loss: 1.6756 - val_accuracy: 0.7730
# Epoch 44/100
# 19/19 [==============================] - 5s 276ms/step - loss: 1.1647 - accuracy: 0.8013 - val_loss: 1.6765 - val_accuracy: 0.7737
# Epoch 45/100
# 19/19 [==============================] - 5s 268ms/step - loss: 1.1495 - accuracy: 0.8034 - val_loss: 1.6801 - val_accuracy: 0.7735
# Epoch 46/100
# 19/19 [==============================] - 5s 276ms/step - loss: 1.1354 - accuracy: 0.8056 - val_loss: 1.6815 - val_accuracy: 0.7745
# Epoch 47/100
# 19/19 [==============================] - 5s 276ms/step - loss: 1.1208 - accuracy: 0.8080 - val_loss: 1.6870 - val_accuracy: 0.7738
# Epoch 48/100
# 19/19 [==============================] - 5s 272ms/step - loss: 1.1072 - accuracy: 0.8099 - val_loss: 1.6882 - val_accuracy: 0.7743
# Epoch 49/100
# 19/19 [==============================] - 5s 269ms/step - loss: 1.0942 - accuracy: 0.8127 - val_loss: 1.6925 - val_accuracy: 0.7737
# Epoch 50/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.0810 - accuracy: 0.8143 - val_loss: 1.6956 - val_accuracy: 0.7747
# Epoch 51/100
# 19/19 [==============================] - 5s 268ms/step - loss: 1.0690 - accuracy: 0.8162 - val_loss: 1.6968 - val_accuracy: 0.7742
# Epoch 52/100
# 19/19 [==============================] - 5s 271ms/step - loss: 1.0559 - accuracy: 0.8179 - val_loss: 1.7009 - val_accuracy: 0.7735
# Epoch 53/100
# 19/19 [==============================] - 5s 266ms/step - loss: 1.0443 - accuracy: 0.8207 - val_loss: 1.7039 - val_accuracy: 0.7740
# Epoch 54/100
# 19/19 [==============================] - 5s 266ms/step - loss: 1.0335 - accuracy: 0.8215 - val_loss: 1.7063 - val_accuracy: 0.7742
# Epoch 55/100
# 19/19 [==============================] - 5s 270ms/step - loss: 1.0238 - accuracy: 0.8235 - val_loss: 1.7128 - val_accuracy: 0.7732
# Epoch 56/100
# 19/19 [==============================] - 5s 283ms/step - loss: 1.0120 - accuracy: 0.8253 - val_loss: 1.7109 - val_accuracy: 0.7738
# Epoch 57/100
# 19/19 [==============================] - 5s 267ms/step - loss: 0.9998 - accuracy: 0.8274 - val_loss: 1.7129 - val_accuracy: 0.7743
# Epoch 58/100
# 19/19 [==============================] - 5s 280ms/step - loss: 0.9897 - accuracy: 0.8286 - val_loss: 1.7128 - val_accuracy: 0.7743
# Epoch 59/100
# 19/19 [==============================] - 5s 283ms/step - loss: 0.9793 - accuracy: 0.8303 - val_loss: 1.7178 - val_accuracy: 0.7743
# Epoch 60/100
# 19/19 [==============================] - 5s 275ms/step - loss: 0.9688 - accuracy: 0.8319 - val_loss: 1.7186 - val_accuracy: 0.7750
# Epoch 61/100
# 19/19 [==============================] - 5s 272ms/step - loss: 0.9584 - accuracy: 0.8333 - val_loss: 1.7211 - val_accuracy: 0.7752
# Epoch 62/100
# 19/19 [==============================] - 5s 280ms/step - loss: 0.9481 - accuracy: 0.8354 - val_loss: 1.7210 - val_accuracy: 0.7758
# Epoch 63/100
# 19/19 [==============================] - 5s 273ms/step - loss: 0.9381 - accuracy: 0.8371 - val_loss: 1.7218 - val_accuracy: 0.7743
# Epoch 64/100
# 19/19 [==============================] - 5s 267ms/step - loss: 0.9276 - accuracy: 0.8370 - val_loss: 1.7214 - val_accuracy: 0.7750
# Epoch 65/100
# 19/19 [==============================] - 5s 270ms/step - loss: 0.9170 - accuracy: 0.8393 - val_loss: 1.7222 - val_accuracy: 0.7753
# Epoch 66/100
# 19/19 [==============================] - 5s 274ms/step - loss: 0.9078 - accuracy: 0.8407 - val_loss: 1.7201 - val_accuracy: 0.7760
# Epoch 67/100
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8979 - accuracy: 0.8417 - val_loss: 1.7221 - val_accuracy: 0.7753
# Epoch 68/100
# 19/19 [==============================] - 5s 280ms/step - loss: 0.8885 - accuracy: 0.8432 - val_loss: 1.7232 - val_accuracy: 0.7762
# Epoch 69/100
# 19/19 [==============================] - 5s 272ms/step - loss: 0.8800 - accuracy: 0.8440 - val_loss: 1.7211 - val_accuracy: 0.7747
# Epoch 70/100
# 19/19 [==============================] - 5s 272ms/step - loss: 0.8692 - accuracy: 0.8453 - val_loss: 1.7183 - val_accuracy: 0.7750
# Epoch 71/100
# 19/19 [==============================] - 5s 279ms/step - loss: 0.8585 - accuracy: 0.8465 - val_loss: 1.7190 - val_accuracy: 0.7758
# Epoch 72/100
# 19/19 [==============================] - 5s 275ms/step - loss: 0.8484 - accuracy: 0.8479 - val_loss: 1.7161 - val_accuracy: 0.7760
# Epoch 73/100
# 19/19 [==============================] - 5s 270ms/step - loss: 0.8373 - accuracy: 0.8496 - val_loss: 1.7127 - val_accuracy: 0.7767
# Epoch 74/100
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8277 - accuracy: 0.8501 - val_loss: 1.7116 - val_accuracy: 0.7748
# Epoch 75/100
# 19/19 [==============================] - 5s 270ms/step - loss: 0.8182 - accuracy: 0.8515 - val_loss: 1.7087 - val_accuracy: 0.7760
# Epoch 76/100
# 19/19 [==============================] - 5s 276ms/step - loss: 0.8085 - accuracy: 0.8526 - val_loss: 1.7067 - val_accuracy: 0.7770
# Epoch 77/100
# 19/19 [==============================] - 5s 278ms/step - loss: 0.7980 - accuracy: 0.8546 - val_loss: 1.7044 - val_accuracy: 0.7767
# Epoch 78/100
# 19/19 [==============================] - 5s 279ms/step - loss: 0.7869 - accuracy: 0.8553 - val_loss: 1.7031 - val_accuracy: 0.7775
# Epoch 79/100
# 19/19 [==============================] - 5s 272ms/step - loss: 0.7768 - accuracy: 0.8564 - val_loss: 1.7035 - val_accuracy: 0.7760
# Epoch 80/100
# 19/19 [==============================] - 5s 276ms/step - loss: 0.7660 - accuracy: 0.8572 - val_loss: 1.7028 - val_accuracy: 0.7772
# Epoch 81/100
# 19/19 [==============================] - 5s 268ms/step - loss: 0.7534 - accuracy: 0.8590 - val_loss: 1.6956 - val_accuracy: 0.7777
# Epoch 82/100
# 19/19 [==============================] - 5s 266ms/step - loss: 0.7402 - accuracy: 0.8605 - val_loss: 1.7000 - val_accuracy: 0.7762
# Epoch 83/100
# 19/19 [==============================] - 5s 279ms/step - loss: 0.7249 - accuracy: 0.8620 - val_loss: 1.6893 - val_accuracy: 0.7785
# Epoch 84/100
# 19/19 [==============================] - 5s 266ms/step - loss: 0.7098 - accuracy: 0.8652 - val_loss: 1.6888 - val_accuracy: 0.7772
# Epoch 85/100
# 19/19 [==============================] - 5s 274ms/step - loss: 0.6942 - accuracy: 0.8664 - val_loss: 1.6882 - val_accuracy: 0.7788
# Epoch 86/100
# 19/19 [==============================] - 5s 270ms/step - loss: 0.6780 - accuracy: 0.8691 - val_loss: 1.6877 - val_accuracy: 0.7768
# Epoch 87/100
# 19/19 [==============================] - 5s 273ms/step - loss: 0.6639 - accuracy: 0.8709 - val_loss: 1.6777 - val_accuracy: 0.7792
# Epoch 88/100
# 19/19 [==============================] - 5s 283ms/step - loss: 0.6471 - accuracy: 0.8732 - val_loss: 1.6780 - val_accuracy: 0.7797
# Epoch 89/100
# 19/19 [==============================] - 5s 267ms/step - loss: 0.6302 - accuracy: 0.8751 - val_loss: 1.6741 - val_accuracy: 0.7803
# Epoch 90/100
# 19/19 [==============================] - 5s 282ms/step - loss: 0.6130 - accuracy: 0.8778 - val_loss: 1.6678 - val_accuracy: 0.7813
# Epoch 91/100
# 19/19 [==============================] - 5s 269ms/step - loss: 0.5940 - accuracy: 0.8809 - val_loss: 1.6731 - val_accuracy: 0.7780
# Epoch 92/100
# 19/19 [==============================] - 5s 275ms/step - loss: 0.5745 - accuracy: 0.8832 - val_loss: 1.6709 - val_accuracy: 0.7818
# Epoch 93/100
# 19/19 [==============================] - 5s 272ms/step - loss: 0.5566 - accuracy: 0.8869 - val_loss: 1.6658 - val_accuracy: 0.7813
# Epoch 94/100
# 19/19 [==============================] - 5s 282ms/step - loss: 0.5361 - accuracy: 0.8902 - val_loss: 1.6641 - val_accuracy: 0.7803
# Epoch 95/100
# 19/19 [==============================] - 5s 274ms/step - loss: 0.5163 - accuracy: 0.8939 - val_loss: 1.6630 - val_accuracy: 0.7795
# Epoch 96/100
# 19/19 [==============================] - 5s 270ms/step - loss: 0.4943 - accuracy: 0.8974 - val_loss: 1.6676 - val_accuracy: 0.7803
# Epoch 97/100
# 19/19 [==============================] - 5s 270ms/step - loss: 0.4715 - accuracy: 0.9020 - val_loss: 1.6797 - val_accuracy: 0.7793
# Epoch 98/100
# 19/19 [==============================] - 5s 277ms/step - loss: 0.4481 - accuracy: 0.9064 - val_loss: 1.6774 - val_accuracy: 0.7797
# Epoch 99/100
# 19/19 [==============================] - 5s 268ms/step - loss: 0.4270 - accuracy: 0.9104 - val_loss: 1.6817 - val_accuracy: 0.7790
# Epoch 100/100
# 19/19 [==============================] - 5s 272ms/step - loss: 0.4037 - accuracy: 0.9149 - val_loss: 1.6856 - val_accuracy: 0.7795

# %%
import keras
from matplotlib import pyplot as plt
#history = model1.fit(train_x, train_y,validation_split = 0.1, epochs=50, batch_size=4)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
reverse_target_word_index=y_tokens.index_word
reverse_target_word_index
# Out:
# {1: 'sos',
#  2: 'eos',
#  3: 'ഒരു',
#  4: 'കറുത്ത',
#  5: 'വെളുത്ത',
#  6: 'സ്ത്രീ',
#  7: 'ധരിച്ച',
#  8: 'മനുഷ്യൻ',
#  9: 'പച്ച',
#  10: 'വലിയ',
#  11: 'നീല',
#  12: 'ബാഗ്',
#  13: 'വർണ്ണാഭമായ',
#  14: 'ചുവന്ന',
#  15: 'ചാരനിറത്തിലുള്ള',
#  16: 'സ്കാർഫ്',
#  17: 'ട്രാഷ്',
#  18: 'റോഡിന്റെ',
#  19: 'വിൻഡോ',
#  20: 'പുല്ലിന്റെ',
#  21: 'മഞ്ഞ',
#  22: 'വശങ്ങളിൽ',
#  23: 'സ്ട്രിപ്പുകൾ',
#  24: 'വ്യക്തി',
#  25: 'ഇതൊരു',
#  26: 'രണ്ട്',
#  27: 'ചെറിയ',
#  28: 'കെട്ടിടത്തിലെ',
#  29: 'നിലത്ത്',
#  30: 'ആന',
#  31: 'വെള്ള',
#  32: 'ഒരാൾ',
#  33: 'ഉള്ള',
#  34: 'ചുവപ്പ്',
#  35: 'തവിട്ട്',
#  36: 'കുഞ്ഞ്',
#  37: 'ജിറാഫ്',
#  38: 'വെള്ളയും',
#  39: 'ഓറഞ്ച്',
#  40: 'മുകളിൽ',
#  41: 'പുല്ല്',
#  42: 'എഞ്ചിൻ',
#  43: 'ചിഹ്നം',
#  44: 'കാർ',
#  45: 'കെട്ടിടത്തിന്റെ',
#  46: 'മേശപ്പുറത്ത്',
#  47: 'പുള്ളി',
#  48: 'ആളുകൾ',
#  49: 'നിറമുള്ള',
#  50: 'ടെന്നീസ്',
#  51: 'രംഗം',
#  52: 'ട്രെയിൻ',
#  53: 'തലം',
#  54: 'ഇത്',
#  55: 'ബീച്ച്',
#  56: 'നിൽക്കുന്നു',
#  57: 'തിന്നുന്നു',
#  58: 'നിൽക്കുന്ന',
#  59: 'ദ്വീപ്',
#  60: 'ഇരിക്കുന്നു',
#  61: 'വശത്ത്',
#  62: 'നായ',
#  63: 'മതിൽ',
#  64: 'മരം',
#  65: 'ബേസ്ബോൾ',
#  66: 'തെരുവിൽ',
#  67: 'ബസ്',
#  68: 'വിമാനം',
#  69: 'ചുവപ്പും',
#  70: 'ഷർട്ട്',
#  71: 'പാർക്ക്',
#  72: 'ഉണ്ട്',
#  73: 'കറുപ്പും',
#  74: 'നടക്കുന്നു',
#  75: 'ഇരിക്കുന്ന',
#  76: 'പെൺകുട്ടി',
#  77: 'വെള്ളത്തിൽ',
#  78: 'വെള്ളി',
#  79: 'പൂച്ച',
#  80: 'തൊപ്പി',
#  81: 'ചെയ്യുന്നു',
#  82: 'ആണ്',
#  83: 'കുട്ടി',
#  84: 'കൂട്ടം',
#  85: 'പിസ്സ',
#  86: 'മിഠായി',
#  87: 'കോട്ടൺ',
#  88: 'വൈറ്റ്',
#  89: 'പക്ഷി',
#  90: 'ഗ്ലാസ്',
#  91: 'നീലയും',
#  92: 'മോട്ടോർ',
#  93: 'പിടിക്കുന്നു',
#  94: 'തല',
#  95: 'ട്രക്ക്',
#  96: 'ഭാഗം',
#  97: 'തെരുവ്',
#  98: 'പുല്ലിൽ',
#  99: 'മനുഷ്യന്റെ',
#  100: 'പിങ്ക്',
#  101: 'വായുവിൽ',
#  102: 'അടയാളം',
#  103: 'ഘടികാരം',
#  104: 'ചുവരിൽ',
#  105: 'റോഡിൽ',
#  106: 'കുട',
#  107: 'കളിക്കാരൻ',
#  108: 'ലൈറ്റ്',
#  109: 'ടോയ്\u200cലറ്റ്',
#  110: 'മൂന്ന്',
#  111: 'ചിത്രം',
#  112: 'ഇരുണ്ട',
#  113: 'ചെയ്യുന്ന',
#  114: 'കുതിര',
#  115: 'ക്ലോക്ക്',
#  116: 'മുന്നിൽ',
#  117: 'ചുമരിൽ',
#  118: 'പ്ലേറ്റിൽ',
#  119: 'നിന്ന്',
#  120: 'ബെഞ്ച്',
#  121: 'വിളക്ക്',
#  122: 'സ്ത്രീയുടെ',
#  123: 'പാത്രം',
#  124: 'ധരിക്കുന്നു',
#  125: 'വയലിൽ',
#  126: 'തടി',
#  127: 'വ്യക്തിയാണ്',
#  128: 'ആകാശത്ത്',
#  129: 'നിറത്തിലുള്ള',
#  130: 'കരടി',
#  131: 'കേക്ക്',
#  132: 'കമ്പ്യൂട്ടർ',
#  133: 'പിന്നിൽ',
#  134: 'ഫോൺ',
#  135: 'വെളുപ്പും',
#  136: 'രണ്ടുപേർ',
#  137: 'ഉയരമുള്ള',
#  138: 'മെറ്റൽ',
#  139: 'ട്രാഫിക്',
#  140: 'തവിട്ടുനിറത്തിലുള്ള',
#  141: 'കെട്ടിടത്തിന്',
#  142: 'പ്ലേറ്റ്',
#  143: 'ഹെൽമെറ്റ്',
#  144: 'ഭക്ഷണം',
#  145: 'വാഴപ്പഴം',
#  146: 'ആകാശം',
#  147: 'സീബ്ര',
#  148: 'ബെഞ്ചിൽ',
#  149: 'പോൾ',
#  150: 'വെളിച്ചം',
#  151: 'നീളമുള്ള',
#  152: 'കളിക്കുന്നു',
#  153: 'കട്ടിലിൽ',
#  154: 'ചെയ്ത',
#  155: 'വെളുത്തതാണ്',
#  156: 'ലാപ്\u200cടോപ്പ്',
#  157: 'വ്യക്തിയുടെ',
#  158: 'കൈവശമുള്ള',
#  159: 'പച്ചയും',
#  160: 'ജലാംശം',
#  161: 'സൈക്കിൾ',
#  162: 'പാത്രത്തിൽ',
#  163: 'ബ്രൗൺ',
#  164: 'ഇഷ്ടിക',
#  165: 'മുടിയുള്ള',
#  166: 'മുകളിലുള്ള',
#  167: 'കെട്ടിടം',
#  168: 'ബോട്ട്',
#  169: 'കൈ',
#  170: 'ബാറ്റ്',
#  171: 'പന്ത്',
#  172: 'സെൽ',
#  173: 'കസേര',
#  174: 'പയ്യൻ',
#  175: 'ഓടിക്കുന്നു',
#  176: 'പറക്കുന്നു',
#  177: 'ഈ',
#  178: 'കിടക്കുന്നു',
#  179: 'ബൈക്ക്',
#  180: 'സിൽവർ',
#  181: 'കപ്പ്',
#  182: 'വെള്ളം',
#  183: 'ജാക്കറ്റ്',
#  184: 'തുറന്ന',
#  185: 'റാക്കറ്റ്',
#  186: 'പശു',
#  187: 'ചെയ്തിരിക്കുന്നു',
#  188: 'ധ്രുവത്തിൽ',
#  189: 'നടക്കുന്ന',
#  190: 'പതാക',
#  191: 'പഴയ',
#  192: 'അഗ്നി',
#  193: 'നിരവധി',
#  194: 'കറുത്തതാണ്',
#  195: 'വാതിൽ',
#  196: 'കളിക്കുന്ന',
#  197: 'മുഖം',
#  198: 'ആടുകൾ',
#  199: 'മനുഷ്യന്',
#  200: 'മുടിയുണ്ട്',
#  201: 'നീലയാണ്',
#  202: 'അക്ഷരം',
#  203: 'പർപ്പിൾ',
#  204: 'പ്ലാസ്റ്റിക്',
#  205: 'തറയിൽ',
#  206: 'സ്കേറ്റ്ബോർഡ്',
#  207: 'കടൽത്തീരത്ത്',
#  208: 'ഫ്രിസ്ബീ',
#  209: 'പാർക്കിംഗ്',
#  210: 'ഇളം',
#  211: 'തലയിൽ',
#  212: 'ചുവപ്പാണ്',
#  213: 'തീവണ്ടി',
#  214: 'ബോൾ',
#  215: 'തൂക്കിയിരിക്കുന്നു',
#  216: 'ടാൻ',
#  217: 'ബോർഡ്',
#  218: 'നോക്കുന്നു',
#  219: 'സർഫിംഗ്',
#  220: 'കാഴ്ച',
#  221: 'സോക്കർ',
#  222: 'നിറമാണ്',
#  223: 'വരയുള്ള',
#  224: 'പൂക്കൾ',
#  225: 'ലൈറ്റുകൾ',
#  226: 'നടപ്പാതയിൽ',
#  227: 'ടയർ',
#  228: 'ഫ്ലാഗ്',
#  229: 'അടുക്കള',
#  230: 'വാൻ',
#  231: 'വളരെ',
#  232: 'മരത്തിൽ',
#  233: 'മഞ്ഞയും',
#  234: 'വേലി',
#  235: 'സ്വർണ്ണ',
#  236: 'മനുഷ്യനാണ്',
#  237: 'ആൺകുട്ടി',
#  238: 'സർഫ്ബോർഡ്',
#  239: 'കയ്യിൽ',
#  240: 'സ്റ്റോപ്പ്',
#  241: 'ഗെയിം',
#  242: 'ഫ്രെയിം',
#  243: 'ഉപയോഗിച്ച്',
#  244: 'കണ്ണ്',
#  245: 'കസേരയിൽ',
#  246: 'ടൈ',
#  247: 'നിറത്തിലാണ്',
#  248: 'കിടക്കുന്ന',
#  249: 'ജിറാഫുകൾ',
#  250: 'ടെഡി',
#  251: 'ബിയർ',
#  252: 'ചെവി',
#  253: 'ട്രെയിനിന്റെ',
#  254: 'മുൻവശത്ത്',
#  255: 'മോട്ടോർസൈക്കിൾ',
#  256: 'കുപ്പി',
#  257: 'വിമാനത്തിന്റെ',
#  258: 'കഴിക്കുന്നു',
#  259: 'കൈറ്റ്',
#  260: 'കഷണം',
#  261: 'കണ്ണട',
#  262: 'നടപ്പാതയിലൂടെ',
#  263: 'നിർത്തി',
#  264: 'തൂക്കിയിട്ടിരിക്കുന്ന',
#  265: 'നിറഞ്ഞ',
#  266: 'ഒരുമിച്ച്',
#  267: 'ഇതാണ്',
#  268: 'മഞ്ഞ്',
#  269: 'കൊച്ചു',
#  270: 'നായയുടെ',
#  271: 'സീബ്രകൾ',
#  272: 'നാല്',
#  273: 'കെട്ടിടത്തിൽ',
#  274: 'കാൽ',
#  275: 'ഇല',
#  276: 'സ്ക്രീൻ',
#  277: 'അടുത്തുള്ള',
#  278: 'മേശ',
#  279: 'ധാരാളം',
#  280: 'മുടി',
#  281: 'കറുപ്പ്',
#  282: 'ഇലകൾ',
#  283: 'സവാരി',
#  284: 'ആപ്പിൾ',
#  285: 'ചിഹ്നത്തിൽ',
#  286: 'ട്രാക്കുകളിൽ',
#  287: 'ബസിന്റെ',
#  288: 'മുഖത്ത്',
#  289: 'കണ്ണാടി',
#  290: 'സ്ത്രീകൾ',
#  291: 'മഞ്ഞുവീഴ്ചയിൽ',
#  292: 'ചുറ്റും',
#  293: 'ടിവി',
#  294: 'കോഫി',
#  295: 'നീലാകാശം',
#  296: 'വശത്തുള്ള',
#  297: 'തവിട്ടുനിറമാണ്',
#  298: 'കിടക്ക',
#  299: 'വസ്ത്രം',
#  300: 'മേശയിൽ',
#  301: 'സീബ്രയുടെ',
#  302: 'ആനയുടെ',
#  303: 'കോർട്ടിൽ',
#  304: 'ഹോട്ട്',
#  305: 'പിടിക്കുന്ന',
#  306: 'സ്യൂട്ട്',
#  307: 'സ്കീയർ',
#  308: 'ജിറാഫിന്റെ',
#  309: 'ചാരനിറമാണ്',
#  310: 'ടവർ',
#  311: 'ചെയ്തു',
#  312: 'പ്രതിഫലനം',
#  313: 'വാഹനം',
#  314: 'വൃത്താകൃതിയിലുള്ള',
#  315: 'പ്രകാശം',
#  316: 'ട്രെയിനിൽ',
#  317: 'ക്യാമറ',
#  318: 'കത്തി',
#  319: 'മൂക്ക്',
#  320: 'തളികയിൽ',
#  321: 'ഫ്രിസ്\u200cബീ',
#  322: 'ഓടിക്കുന്ന',
#  323: 'കൈവശം',
#  324: 'സൈക്കിളിൽ',
#  325: 'പട്ടം',
#  326: 'ചായം',
#  327: 'കാറിന്റെ',
#  328: 'തെരുവിലൂടെ',
#  329: 'മരത്തിന്റെ',
#  330: 'മരങ്ങൾ',
#  331: 'സീലിംഗിൽ',
#  332: 'മോണിറ്റർ',
#  333: 'പരസ്പരം',
#  334: 'പാന്റ്സ്',
#  335: 'മുറിയിൽ',
#  336: 'പ്രതിമ',
#  337: 'പുറകിൽ',
#  338: 'പുറത്ത്',
#  339: 'പുഷ്പം',
#  340: 'മേഘങ്ങൾ',
#  341: 'ടൈൽ',
#  342: 'സാൻഡ്\u200cവിച്ച്',
#  343: 'ഷർട്ടിൽ',
#  344: 'സ്കേറ്റ്ബോർഡിൽ',
#  345: 'മൈതാനത്ത്',
#  346: 'സ്കീയിംഗ്',
#  347: 'സർഫർ',
#  348: 'ജാലകം',
#  349: 'വാൽ',
#  350: 'മൂലയിൽ',
#  351: 'നിർമ്മിച്ച',
#  352: 'ചക്രം',
#  353: 'വര',
#  354: 'ജോടി',
#  355: 'റൗണ്ട്',
#  356: 'നിലത്തു',
#  357: 'കഴിക്കുന്ന',
#  358: 'തൂവാല',
#  359: 'പറക്കുന്ന',
#  360: 'സ്കേറ്റ്ബോർഡർ',
#  361: 'നിഴൽ',
#  362: 'ജെറ്റ്',
#  363: 'ഷൂ',
#  364: 'പശ്ചാത്തലത്തിൽ',
#  365: 'പൂച്ചയുടെ',
#  366: 'ട്രക്കിന്റെ',
#  367: 'മുറിയിലെ',
#  368: 'അരികിൽ',
#  369: 'ഇവ',
#  370: 'സിങ്ക്',
#  371: 'ഫോണിൽ',
#  372: 'ടാക്സി',
#  373: 'സ്ത്രീയും',
#  374: 'പേപ്പർ',
#  375: 'ഷർട്ടും',
#  376: 'കല്ല്',
#  377: 'ജനൽ',
#  378: 'പെട്ടി',
#  379: 'പെൺകുട്ടിയുടെ',
#  380: 'ബോട്ടിൽ',
#  381: 'റോഡ്',
#  382: 'ഡോനട്ട്',
#  383: 'ഡോഗ്',
#  384: 'കുതിരയുടെ',
#  385: 'ശേഖരം',
#  386: 'ബോർഡിൽ',
#  387: 'മൈക്രോവേവ്',
#  388: 'തലയിണ',
#  389: 'കണ്ണാടിയിൽ',
#  390: 'മഞ്ഞയാണ്',
#  391: 'വിൻഡോയിൽ',
#  392: 'സമീപം',
#  393: 'അമേരിക്കൻ',
#  394: 'ചെയ്തിരിക്കുന്ന',
#  395: 'കുപ്പായം',
#  396: 'റൊട്ടി',
#  397: 'ടെലിവിഷൻ',
#  398: 'അടുക്കളയിൽ',
#  399: 'സംസാരിക്കുന്നു',
#  400: 'കൊണ്ട്',
#  401: 'സീറ്റ്',
#  402: 'പക്ഷിയുടെ',
#  403: 'ധരിക്കുന്ന',
#  404: 'അവൻ',
#  405: 'ഹാൻഡിൽ',
#  406: 'വൈ',
#  407: 'സ്കേറ്റ്',
#  408: 'കുട്ടികൾ',
#  409: 'ചെറുപ്പക്കാരൻ',
#  410: 'പെൺകുട്ടിക്ക്',
#  411: 'സ്കീ',
#  412: 'മീറ്റർ',
#  413: 'നമ്പർ',
#  414: 'പുരുഷന്മാർ',
#  415: 'തിളങ്ങുന്ന',
#  416: 'തറ',
#  417: 'വൃക്ഷം',
#  418: 'ഡെസ്\u200cകിൽ',
#  419: 'ചെയ്യുക',
#  420: 'ചവറ്റുകുട്ട',
#  421: 'കുളിമുറിയിൽ',
#  422: 'വീടിന്റെ',
#  423: 'വിമാനങ്ങൾ',
#  424: 'അടയാളങ്ങൾ',
#  425: 'ചതുര',
#  426: 'നിറത്തിൽ',
#  427: 'സ്ത്രീക്ക്',
#  428: 'ഇടത്',
#  429: 'ജീൻസ്',
#  430: 'പച്ചയാണ്',
#  431: 'ചില',
#  432: 'നഗര',
#  433: 'കാട്ടിൽ',
#  434: 'പക്ഷികൾ',
#  435: 'പിടിച്ചിരിക്കുന്ന',
#  436: 'സ്റ്റഫ്',
#  437: 'മണൽ',
#  438: 'പോസ്',
#  439: 'വാട്ടർ',
#  440: 'വെള്ളിയും',
#  441: 'കാരറ്റ്',
#  442: 'അതിൽ',
#  443: 'സർഫ്',
#  444: 'റെഡ്',
#  445: 'സൺഗ്ലാസുകൾ',
#  446: 'കൊച്ചുകുട്ടി',
#  447: 'സ്വിംഗ്',
#  448: 'വേലിക്ക്',
#  449: 'ആനകൾ',
#  450: 'ടൂത്ത്',
#  451: 'നടപ്പാത',
#  452: 'നേരെ',
#  453: 'വരകൾ',
#  454: 'അവന്റെ',
#  455: 'നിര',
#  456: 'മഞ്ഞിൽ',
#  457: 'കുടകൾ',
#  458: 'എന്ന',
#  459: 'പുസ്തകം',
#  460: 'സീലിംഗ്',
#  461: 'അക്ഷരങ്ങളുള്ള',
#  462: 'ബ്ലാക്ക്',
#  463: 'സഞ്ചരിക്കുന്ന',
#  464: 'സമീപമുള്ള',
#  465: 'കുന്നിൻ',
#  466: 'തെളിഞ്ഞ',
#  467: 'നടപ്പാതയിലെ',
#  468: 'റെയിൽ',
#  469: 'സ്വെറ്റർ',
#  470: 'റൺവേയിൽ',
#  471: 'തന്റെ',
#  472: 'സർഫ്ബോർഡിൽ',
#  473: 'ഫയർ',
#  474: 'കാണുന്ന',
#  475: 'സ്യൂട്ട്കേസ്',
#  476: 'ഗതാഗത',
#  477: 'കൈയിൽ',
#  478: 'ഓടുന്നു',
#  479: 'ഗോപുരം',
#  480: 'തെരുവിലെ',
#  481: 'കളിക്കാർ',
#  482: 'മൃഗം',
#  483: 'പശുക്കൾ',
#  484: 'വായുവിലാണ്',
#  485: 'തന്ത്രം',
#  486: 'ബട്ടൺ',
#  487: 'പിസ്സയിൽ',
#  488: 'ലോഹത്തിന്റെ',
#  489: 'കൗണ്ടറിൽ',
#  490: 'ടേബിൾ',
#  491: 'കട്ടിയുള്ള',
#  492: 'അടുത്ത്',
#  493: 'സിഗ്നൽ',
#  494: 'ഫുട്പാത്തിൽ',
#  495: 'മണലിൽ',
#  496: 'കൊണ്ടുള്ള',
#  497: 'പോസ്റ്റിൽ',
#  498: 'വിമാനത്തിലെ',
#  499: 'അലങ്കരിച്ച',
#  500: 'പേർ',
#  501: 'ലഗേജ്',
#  502: 'പെയിന്റിംഗ്',
#  503: 'കൊട്ടയിൽ',
#  504: 'ഗ്രേ',
#  505: 'സിങ്കിൽ',
#  506: 'കൈകൾ',
#  507: 'മനോഹരമായ',
#  508: 'റിമോട്ട്',
#  509: 'ടോപ്പ്',
#  510: 'അക്ഷരങ്ങൾ',
#  511: 'തിളക്കമുള്ള',
#  512: 'വാസ്',
#  513: 'മുൻവശത്തെ',
#  514: 'മുൻ',
#  515: 'ഫാൻ',
#  516: 'വായിൽ',
#  517: 'അമ്പടയാളം',
#  518: 'വഴിയിൽ',
#  519: 'പാച്ച്',
#  520: 'വണ്ടി',
#  521: 'കാറുകൾ',
#  522: 'കടും',
#  523: 'വസ്ത്രങ്ങൾ',
#  524: 'സ്കൂൾ',
#  525: 'തക്കാളി',
#  526: 'പാലം',
#  527: 'പാത്രങ്ങൾ',
#  528: 'വ്യക്തമായ',
#  529: 'ശിരോകവജം',
#  530: 'വിമാനത്തിൽ',
#  531: 'ചുമക്കുന്ന',
#  532: 'പകുതി',
#  533: 'ധരിച്ചിരിക്കുന്നു',
#  534: 'കിടക്കയിൽ',
#  535: 'പാസഞ്ചർ',
#  536: 'സ്കേറ്റ്ബോർഡിംഗ്',
#  537: 'ബൈക്കിന്റെ',
#  538: 'അത്',
#  539: 'ആട്',
#  540: 'ഇരട്ട',
#  541: 'റഫ്രിജറേറ്റർ',
#  542: 'കരടികൾ',
#  543: 'കരടിയുടെ',
#  544: 'ഉള്ളിൽ',
#  545: 'ഫോട്ടോയിലെ',
#  546: 'ആടുകളുടെ',
#  547: 'കഷ്ണം',
#  548: 'കുട്ടിയുടെ',
#  549: 'ഫോട്ടോ',
#  550: 'മുറിച്ചുകടക്കുന്ന',
#  551: 'ഓണാണ്',
#  552: 'തുമ്പിക്കൈ',
#  553: 'തുറന്നു',
#  554: 'ചീസ്',
#  555: 'പെയിന്റ്',
#  556: 'കാറിന്',
#  557: 'മേശയുടെ',
#  558: 'സ്റ്റീൽ',
#  559: 'വെള്ളത്തിനടുത്തുള്ള',
#  560: 'ടാർമാക്കിൽ',
#  561: 'മേഘം',
#  562: 'വലത്',
#  563: 'വള്ളം',
#  564: 'പുരുഷന്റെ',
#  565: 'നീണ്ട',
#  566: 'മുറിയുടെ',
#  567: 'പോലീസ്',
#  568: 'പാളി',
#  569: 'കടലാസ്',
#  570: 'ഇടതുവശത്ത്',
#  571: 'പാലത്തിൽ',
#  572: 'കാറിലെ',
#  573: 'വീട്',
#  574: 'ശൂന്യമായ',
#  575: 'കലം',
#  576: 'ദമ്പതികൾ',
#  577: 'പകൽ',
#  578: 'ആകാശത്തിന്റെ',
#  579: 'ശാഖയിൽ',
#  580: 'പോസ്റ്റ്',
#  581: 'അഴുക്കുചാലിൽ',
#  582: 'ട്രക്കിൽ',
#  583: 'നിറം',
#  584: 'പാറ',
#  585: 'വീഡിയോ',
#  586: 'കഴുത്തിൽ',
#  587: 'റോഡിലെ',
#  588: 'ചരട്',
#  589: 'പുറത്തേക്ക്',
#  590: 'നനഞ്ഞ',
#  591: 'കേസ്',
#  592: 'ആൺകുട്ടിക്ക്',
#  593: 'ഗ്ലാസുകൾ',
#  594: 'ട്രേയിൽ',
#  595: 'അരിഞ്ഞ',
#  596: 'ഫ്രിസ്\u200cബിയെ',
#  597: 'യുവാവ്',
#  598: 'കോട്ട്',
#  599: 'വീഞ്ഞ്',
#  600: 'സുന്ദരമായ',
#  601: 'ഗോപുരത്തിലെ',
#  602: 'കുതിരകൾ',
#  603: 'വിരൽ',
#  604: 'പിൻഭാഗം',
#  605: 'ഏഷ്യൻ',
#  606: 'ട്രാക്കിൽ',
#  607: 'മുകളിലൂടെ',
#  608: 'ആൻഡ്',
#  609: 'കത്ത്',
#  610: 'താഴേക്ക്',
#  611: 'പശുവിന്റെ',
#  612: 'സഞ്ചരിക്കുന്നു',
#  613: 'നിറമുളള',
#  614: 'ബ്രൊക്കോളി',
#  615: 'മൃഗങ്ങൾ',
#  616: 'കുളിമുറിയുടെ',
#  617: 'ലോഗോ',
#  618: 'സ്കേറ്റ്ബോർഡിലെ',
#  619: 'കാബിനറ്റ്',
#  620: 'ജാലകങ്ങൾ',
#  621: 'ഘടിപ്പിച്ചിരിക്കുന്നു',
#  622: 'മേൽക്കൂര',
#  623: 'അകലെ',
#  624: 'നരച്ച',
#  625: 'പിൻ',
#  626: 'കുപ്പായമുള്ള',
#  627: 'ബാക്ക്പാക്ക്',
#  628: 'വെളുത്തതും',
#  629: 'മുറി',
#  630: 'സോഫ',
#  631: 'പ്രദേശം',
#  632: 'ക്യാബ്',
#  633: 'നഗരത്തിലെ',
#  634: 'പാറകൾ',
#  635: 'പുരുഷനും',
#  636: 'അലമാരയിൽ',
#  637: 'മിറർ',
#  638: 'സ്ലാറ്റ്',
#  639: 'സർഫ്ബോർഡിലെ',
#  640: 'കൂമ്പാരം',
#  641: 'സ്റ്റാൻഡിൽ',
#  642: 'ബീജ്',
#  643: 'പൂശിയ',
#  644: 'തൂങ്ങിക്കിടക്കുന്നു',
#  645: 'അലങ്കാര',
#  646: 'മുകളിലാണ്',
#  647: 'പൂക്കളുള്ള',
#  648: 'കലത്തിൽ',
#  649: 'പോളിൽ',
#  650: 'വളഞ്ഞ',
#  651: 'വിളക്കുകൾ',
#  652: 'ഭുജം',
#  653: 'ചിമ്മിനി',
#  654: 'ശോഭയുള്ള',
#  655: 'വസ്ത്രത്തിൽ',
#  656: 'അക്കങ്ങൾ',
#  657: 'മതിലിനു',
#  658: 'സ്ഥലത്ത്',
#  659: 'പാർക്കിൽ',
#  660: 'ഭക്ഷണത്തിന്റെ',
#  661: 'വീട്ടിൽ',
#  662: 'ധ്രുവത്തിലെ',
#  663: 'കവർ',
#  664: 'പുല്ലിന്',
#  665: 'ചിത്രത്തിനായി',
#  666: 'വ്യത്യസ്ത',
#  667: 'സൈനിക',
#  668: 'വച്ചിരിക്കുന്ന',
#  669: 'ടാഗ്',
#  670: 'പുക',
#  671: 'ഷോർട്ട്സ്',
#  672: 'സ്നോ',
#  673: 'ചതുരാകൃതിയിലുള്ള',
#  674: 'കീബോർഡ്',
#  675: 'മഞ്ഞുമൂടിയ',
#  676: 'പൂച്ചയ്ക്ക്',
#  677: 'ഗ്ലാസിൽ',
#  678: 'ഡബിൾ',
#  679: 'ഡെക്കർ',
#  680: 'വൈൻ',
#  681: 'മൗസ്',
#  682: 'മേൽ',
#  683: 'നിലം',
#  684: 'മുറിച്ചു',
#  685: 'തലയിണകൾ',
#  686: 'വെള്ളത്തിന്',
#  687: 'കുളിമുറിയാണ്',
#  688: 'ബസുകൾ',
#  689: 'കീഴിൽ',
#  690: 'ടവറിൽ',
#  691: 'ബാറ്റർ',
#  692: 'പെട്ടിയിൽ',
#  693: 'പൂച്ചയാണ്',
#  694: 'തറയിലെ',
#  695: 'ഓടുന്ന',
#  696: 'ബ്ലെൻഡർ',
#  697: 'സ്നോബോർഡർ',
#  698: 'ആൺകുട്ടിയുടെ',
#  699: 'കടൽത്തീരത്താണ്',
#  700: 'ആകാശത്തിലെ',
#  701: 'മതിലിന്റെ',
#  702: 'അഴുക്ക്',
#  703: 'കുറച്ച്',
#  704: 'പശ്ചാത്തലത്തിലുള്ള',
#  705: 'പക്ഷിയാണ്',
#  706: 'കൈയിലുള്ള',
#  707: 'ബോർഡിലെ',
#  708: 'പുരുഷ',
#  709: 'കസേരകൾ',
#  710: 'ഓവൻ',
#  711: 'ഫലം',
#  712: 'കൺട്രോളർ',
#  713: 'നില',
#  714: 'ഈന്തപ്പന',
#  715: 'മരത്തിന്',
#  716: 'വശം',
#  717: 'ലൈൻ',
#  718: 'ചെടി',
#  719: 'രാത്രി',
#  720: 'പ്ലെയ്ഡ്',
#  721: 'ഭക്ഷണ',
#  722: 'ക്രോസ്',
#  723: 'സ്കീസ്',
#  724: 'സൂര്യൻ',
#  725: 'വലുതാണ്',
#  726: 'ചട്ടി',
#  727: 'ഫ്ലാറ്റ്',
#  728: 'ഡെസ്ക്',
#  729: 'നിറച്ച',
#  730: 'ക',
#  731: 'ചതുരം',
#  732: 'നിറയെ',
#  733: 'തിളങ്ങുന്നു',
#  734: 'കാറാണ്',
#  735: 'ചാര',
#  736: 'വാഹനത്തിന്റെ',
#  737: 'അഗ്രം',
#  738: 'അടുക്കളയിലെ',
#  739: 'ഇന്റീരിയർ',
#  740: 'തൂക്കിയിട്ട',
#  741: 'വലതുവശത്ത്',
#  742: 'ജാലകമുണ്ട്',
#  743: 'വരച്ച',
#  744: 'വാണിജ്യ',
#  745: 'വരി',
#  746: 'അഭിമുഖമായി',
#  747: 'ട്രാക്കുകൾ',
#  748: 'റോഡിന്',
#  749: 'പുഷ്പ',
#  750: 'ജാക്കറ്റിലുള്ള',
#  751: 'മേശപ്പുറത്തുണ്ട്',
#  752: 'മുറ്റത്ത്',
#  753: 'കപ്പിൽ',
#  754: 'ട്രിം',
#  755: 'കളിക്കാരന്റെ',
#  756: 'ചെടിയിൽ',
#  757: 'ഘടിപ്പിച്ചിരിക്കുന്ന',
#  758: 'കേക്കിൽ',
#  759: 'വൃദ്ധൻ',
#  760: 'ചോക്ലേറ്റ്',
#  761: 'തവിട്ടുനിറമുള്ള',
#  762: 'ടോയ്\u200cലറ്റിന്റെ',
#  763: 'ബൈക്കിൽ',
#  764: 'പുറകിലുള്ള',
#  765: 'ഗോപുരത്തിന്റെ',
#  766: 'സ്കേറ്റിംഗ്',
#  767: 'സ്കി',
#  768: 'ഇറങ്ങുന്നു',
#  769: 'ലൈറ്റുകളുള്ള',
#  770: 'ടി',
#  771: 'തൊപ്പിയും',
#  772: 'കളി',
#  773: 'കയറുന്ന',
#  774: 'ഹിമത്തിൽ',
#  775: 'ചെരുപ്പ്',
#  776: 'ബാത്ത്റൂം',
#  777: 'സ്കൈ',
#  778: 'സ്നോബോർഡ്',
#  779: 'ട്രെയിനിലെ',
#  780: 'വെള്ളത്തിലാണ്',
#  781: 'യൂണിഫോം',
#  782: 'ബോട്ടുകൾ',
#  783: 'സുരക്ഷാ',
#  784: 'ഉണങ്ങിയ',
#  785: 'ബസ്സിലെ',
#  786: 'പ്രദർശിപ്പിച്ചിരിക്കുന്നു',
#  787: 'പിസ്സയുടെ',
#  788: 'സമുദ്രത്തിൽ',
#  789: 'കാലുകൾ',
#  790: 'കുടിക്കുന്നു',
#  791: 'ചുരുണ്ട',
#  792: 'വാചകം',
#  793: 'ചെവിയിൽ',
#  794: 'തുരുമ്പിച്ച',
#  795: 'വാഴപ്പഴത്തിന്റെ',
#  796: 'പല്ല്',
#  797: 'മേയുന്നു',
#  798: 'കത്രിക',
#  799: 'പുഞ്ചിരിക്കുന്ന',
#  800: 'ടൈലുകൾ',
#  801: 'പ്ലാറ്റ്ഫോമിൽ',
#  802: 'മൃഗശാലയിലെ',
#  803: 'മുതിർന്ന',
#  804: 'നായ്ക്കൾ',
#  805: 'പഴം',
#  806: 'കടൽത്തീരത്തെ',
#  807: 'അക്ഷരങ്ങളിൽ',
#  808: 'കണ്ണുകൾ',
#  809: 'സമുദ്രത്തിലെ',
#  810: 'തിരമാലയിൽ',
#  811: 'സ്കീസിൽ',
#  812: 'വേവിച്ച',
#  813: 'കടലിൽ',
#  814: 'പൂശി',
#  815: 'സമുദ്രം',
#  816: 'ഓഫീസ്',
#  817: 'എസ്\u200cയുവി',
#  818: 'ഡ്രൈവിംഗ്',
#  819: 'കുടയുമായി',
#  820: 'നീന്തുന്നു',
#  821: 'ധ്രുവം',
#  822: 'സോസ്',
#  823: 'പട്ടിക',
#  824: 'തലകീഴായി',
#  825: 'ടെലിഫോൺ',
#  826: 'കട്ടിലിന്',
#  827: 'ചെറുതാണ്',
#  828: 'അടുത്താണ്',
#  829: 'മുഴുവൻ',
#  830: 'പരവതാനി',
#  831: 'പാവാട',
#  832: 'പാനീയം',
#  833: 'ജനാല',
#  834: 'സ്ത്രീയാണ്',
#  835: 'ലൈസൻസ്',
#  836: 'പറയുന്നു',
#  837: 'എഴുത്ത്',
#  838: 'വിൻഡോയിലെ',
#  839: 'വുഡൻ',
#  840: 'നിയന്ത്രണം',
#  841: 'കളർ',
#  842: 'റെയിലിംഗ്',
#  843: 'വഴി',
#  844: 'പ്രവേശന',
#  845: 'വളരുന്ന',
#  846: 'വെള്ളിയാണ്',
#  847: 'അടുപ്പിൽ',
#  848: 'തുണിയിൽ',
#  849: 'നിർമ്മിച്ചിരിക്കുന്നത്',
#  850: 'ടെയിൽ',
#  851: 'സ്ട്രീറ്റ്',
#  852: 'പള്ളി',
#  853: 'പേഴ്സ്',
#  854: 'കടൽത്തീരം',
#  855: 'ഇലകളുള്ള',
#  856: 'സീബ്രയിൽ',
#  857: 'മേഘങ്ങളുള്ള',
#  858: 'ഗ്രീൻ',
#  859: 'വേലിയിൽ',
#  860: 'ബെഞ്ചിന്റെ',
#  861: 'ലെഗ്',
#  862: 'ഷൂസ്',
#  863: 'പാറ്റേൺ',
#  864: 'നിറമുണ്ട്',
#  865: 'റിബൺ',
#  866: 'എന്ന്',
#  867: 'പറയുന്ന',
#  868: 'ജലത്തിന്റെ',
#  869: 'കോൺ',
#  870: 'വിന്റേജ്',
#  871: 'പാനൽ',
#  872: 'കാബിനറ്റിൽ',
#  873: 'ജലാശയം',
#  874: 'പാത',
#  875: 'ഷർട്ടിലുള്ള',
#  876: 'സ്യൂട്ടിലുള്ള',
#  877: 'പൊതിഞ്ഞ',
#  878: 'ഹൈഡ്രാന്റ്',
#  879: 'പേര്',
#  880: 'പുഞ്ചിരിക്കുന്നു',
#  881: 'സ്കേറ്റ്ബോർഡിലാണ്',
#  882: 'തീവണ്ടിയുടെ',
#  883: 'ലേബൽ',
#  884: 'കളിപ്പാട്ടം',
#  885: 'ലിഡ്',
#  886: 'സ്റ്റേഷനിൽ',
#  887: 'കടൽ',
#  888: 'മേൽക്കൂരയിൽ',
#  889: 'സ്ലൈസ്',
#  890: 'അലകൾ',
#  891: 'കൈറ്റ്സ്',
#  892: 'ഘടികാര',
#  893: 'ചൂണ്ടുന്ന',
#  894: 'കാണുന്നു',
#  895: 'ആൺകുട്ടികൾ',
#  896: 'പിടിച്ചിരിക്കുന്നു',
#  897: 'മധ്യത്തിൽ',
#  898: 'വ്യക്തവുമാണ്',
#  899: 'വായിക്കുന്ന',
#  900: 'ബസിന്',
#  901: 'യുദ്ധവിമാനം',
#  902: 'സൂപ്പ്',
#  903: 'സിറ്റി',
#  904: 'റേസിംഗ്',
#  905: 'യുവതി',
#  906: 'പൈ',
#  907: 'നിയോൺ',
#  908: 'തയ്യാറാണ്',
#  909: 'വ്യക്തിക്ക്',
#  910: 'റോമൻ',
#  911: 'രണ്ടു',
#  912: 'വച്ചിരിക്കുന്നു',
#  913: 'തുറക്കുക',
#  914: 'വാക്കുകൾ',
#  915: 'സെൽഫോൺ',
#  916: 'പുതിയ',
#  917: 'മാല',
#  918: 'ജോഡി',
#  919: 'വൃത്താകൃതിയിലാണ്',
#  920: 'മുട്ട',
#  921: 'ജന്മദിന',
#  922: 'ഉറങ്ങുന്നു',
#  923: 'കൊമ്പുകൾ',
#  924: 'കഷ്ണങ്ങൾ',
#  925: 'സ്\u200cക്രീൻ',
#  926: 'വെച്ചിരിക്കുന്ന',
#  927: 'അവരുടെ',
#  928: 'പാൽ',
#  929: 'അവർ',
#  930: 'പാണ്ട',
#  931: 'കുളിമുറി',
#  932: 'വയലിലെ',
#  933: 'പോലെ',
#  934: 'കുട്ടികളുടെ',
#  935: 'നിർത്തുക',
#  936: 'ചിത്രങ്ങൾ',
#  937: 'അതിന്റെ',
#  938: 'സ്കീയർമാർ',
#  939: 'സർഫറുകൾ',
#  940: 'മുൻഭാഗം',
#  941: 'തൊപ്പിയിൽ',
#  942: 'പ്രവർത്തിക്കുന്ന',
#  943: 'അറ്റം',
#  944: 'നീലയുമാണ്',
#  945: 'അവൾ',
#  946: 'സ്നോബോർഡിംഗ്',
#  947: 'അഞ്ച്',
#  948: 'പോകുന്ന',
#  949: 'കുടയുള്ള',
#  950: 'നല്ല',
#  951: 'നീലാകാശത്തിൽ',
#  952: 'ചിത്രത്തിലെ',
#  953: 'ബിയറിന്റെ',
#  954: 'കാർഡ്ബോർഡ്',
#  955: 'ജോലി',
#  956: 'ചക്രങ്ങൾ',
#  957: 'ഇവിടെ',
#  958: 'ചട്ടിയിൽ',
#  959: 'യാത്രാ',
#  960: 'മിഡ്',
#  961: 'ആനയാണ്',
#  962: 'ഹോം',
#  963: 'ആനകളുടെ',
#  964: 'വായുവിലെ',
#  965: 'ബെഡ്',
#  966: 'ശാന്തമായ',
#  967: 'നടത്തുന്ന',
#  968: 'ഓണാക്കി',
#  969: 'മടിയിൽ',
#  970: 'കസേരയുടെ',
#  971: 'തണലുള്ള',
#  972: 'പുസ്തക',
#  973: 'വശത്തെ',
#  974: 'ബർഗർ',
#  975: 'ഗ്രൂപ്പ്',
#  976: 'സ്ഥലം',
#  977: 'ഹൗസ്',
#  978: 'മേൽക്കൂരയുള്ള',
#  979: 'തിരശ്ശീല',
#  980: 'ഫോസെറ്റ്',
#  981: 'ഹോട്ടൽ',
#  982: 'സ്റ്റെയിൻലെസ്',
#  983: 'സ്റ്റാൻഡ്',
#  984: 'നിർത്തിയിട്ടിരിക്കുന്ന',
#  985: 'വാഹനങ്ങൾ',
#  986: 'ബൈക്കുകൾ',
#  987: 'പിന്നിലെ',
#  988: 'സ്കൂട്ടർ',
#  989: 'ബോക്സ്',
#  990: 'ദ്വാരം',
#  991: 'ചരക്ക്',
#  992: 'ചുറ്റുമുള്ള',
#  993: 'പാഡിൽ',
#  994: 'വെളുത്തതുമായ',
#  995: 'ജാലകത്തിന്',
#  996: 'കുളം',
#  997: 'റെസിഡൻഷ്യൽ',
#  998: 'ഇടതുവശത്തുള്ള',
#  999: 'മുറിക്കുക',
#  1000: 'പൂത്തട്ടം',
#  ...}

# %%
reverse_source_word_index=x_tokens.index_word
reverse_source_word_index
# Out:
# {1: 'a',
#  2: 'the',
#  3: 'on',
#  4: 'of',
#  5: 'is',
#  6: 'in',
#  7: 'white',
#  8: 'man',
#  9: 'and',
#  10: 'black',
#  11: 'with',
#  12: 'red',
#  13: 'this',
#  14: 'person',
#  15: 'blue',
#  16: 'building',
#  17: 'wall',
#  18: 'woman',
#  19: 'brown',
#  20: 'wearing',
#  21: 'green',
#  22: 'window',
#  23: 'yellow',
#  24: 'head',
#  25: 'sign',
#  26: 'two',
#  27: 'train',
#  28: 'street',
#  29: 'water',
#  30: 'sky',
#  31: 'side',
#  32: 'an',
#  33: 'table',
#  34: 'car',
#  35: 'standing',
#  36: 'light',
#  37: 'large',
#  38: 'clock',
#  39: 'people',
#  40: 'shirt',
#  41: 'sitting',
#  42: 'holding',
#  43: 'are',
#  44: 'small',
#  45: 'plate',
#  46: 'has',
#  47: 'bus',
#  48: 'road',
#  49: 'to',
#  50: 'dog',
#  51: 'grass',
#  52: 'orange',
#  53: 'tennis',
#  54: 'top',
#  55: 'ground',
#  56: 'silver',
#  57: 'cat',
#  58: 'plane',
#  59: 'at',
#  60: 'tree',
#  61: 'boy',
#  62: 'bench',
#  63: 'front',
#  64: 'walking',
#  65: 'field',
#  66: 'girl',
#  67: 'parked',
#  68: 'hair',
#  69: 'air',
#  70: 'glass',
#  71: 'wooden',
#  72: 'baseball',
#  73: 'pizza',
#  74: 'truck',
#  75: 'horse',
#  76: 'snow',
#  77: 'bear',
#  78: 'giraffe',
#  79: 'bird',
#  80: 'pole',
#  81: 'playing',
#  82: 'down',
#  83: 'riding',
#  84: 'umbrella',
#  85: 'boat',
#  86: 'part',
#  87: 'hat',
#  88: 'zebra',
#  89: 'picture',
#  90: 'toilet',
#  91: 'player',
#  92: 'grey',
#  93: 'gray',
#  94: 'ball',
#  95: 'food',
#  96: 'bed',
#  97: 'elephant',
#  98: 'hand',
#  99: 'motorcycle',
#  100: 'phone',
#  101: 'skateboard',
#  102: 'metal',
#  103: 'by',
#  104: 'board',
#  105: 'sidewalk',
#  106: 'tower',
#  107: 'frisbee',
#  108: 'face',
#  109: 'chair',
#  110: 'floor',
#  111: 'hanging',
#  112: 'pink',
#  113: 'dark',
#  114: 'color',
#  115: 'surfboard',
#  116: 'desk',
#  117: 'colored',
#  118: 'computer',
#  119: 'traffic',
#  120: 'next',
#  121: 'clouds',
#  122: 'long',
#  123: 'back',
#  124: 'beach',
#  125: 'eating',
#  126: 'young',
#  127: 'three',
#  128: 'near',
#  129: 'laptop',
#  130: 'helmet',
#  131: 'sheep',
#  132: 'cake',
#  133: 'bike',
#  134: 'up',
#  135: 'room',
#  136: 'bowl',
#  137: 'flying',
#  138: 'tall',
#  139: 'kitchen',
#  140: 'letter',
#  141: 'stop',
#  142: 'cow',
#  143: 'door',
#  144: 'hydrant',
#  145: 'tracks',
#  146: 'bathroom',
#  147: 'airplane',
#  148: 'round',
#  149: 'it',
#  150: 'fire',
#  151: 'kite',
#  152: 'group',
#  153: 'over',
#  154: 'that',
#  155: 'mans',
#  156: 'jacket',
#  157: 'ceiling',
#  158: 'open',
#  159: 'his',
#  160: 'clear',
#  161: 'leaves',
#  162: 'lamp',
#  163: 'cup',
#  164: 'for',
#  165: 'child',
#  166: 'brick',
#  167: 'lights',
#  168: 'fence',
#  169: 'piece',
#  170: 'cell',
#  171: 'big',
#  172: 'from',
#  173: 'wood',
#  174: 'behind',
#  175: 'game',
#  176: 'men',
#  177: 'vase',
#  178: 'bat',
#  179: 'inside',
#  180: 'mirror',
#  181: 'vehicle',
#  182: 'flowers',
#  183: 'post',
#  184: 'looking',
#  185: 'laying',
#  186: 'house',
#  187: 'view',
#  188: 'flag',
#  189: 'sink',
#  190: 'ear',
#  191: 'old',
#  192: 'little',
#  193: 'photo',
#  194: 'trees',
#  195: 'box',
#  196: 'paper',
#  197: 'left',
#  198: 'out',
#  199: 'giraffes',
#  200: 'court',
#  201: 'counter',
#  202: 'park',
#  203: 'screen',
#  204: 'bottle',
#  205: 'around',
#  206: 'purple',
#  207: 'tie',
#  208: 'racket',
#  209: 'scene',
#  210: 'leg',
#  211: 'couch',
#  212: 'tan',
#  213: 'tire',
#  214: 'city',
#  215: 'under',
#  216: 'corner',
#  217: 'bananas',
#  218: 'outside',
#  219: 'van',
#  220: 'plastic',
#  221: 'flower',
#  222: 'baby',
#  223: 'camera',
#  224: 'zebras',
#  225: 'soccer',
#  226: 'full',
#  227: 'eye',
#  228: 'background',
#  229: 'ski',
#  230: 'surfing',
#  231: 'short',
#  232: 'fruit',
#  233: 'trunk',
#  234: 'bag',
#  235: 'glasses',
#  236: 'banana',
#  237: 'gold',
#  238: 'surfer',
#  239: 'ocean',
#  240: 'pants',
#  241: 'above',
#  242: 'sunglasses',
#  243: 'parking',
#  244: 'area',
#  245: 'wheel',
#  246: 'body',
#  247: 'teddy',
#  248: 'hands',
#  249: 'skiing',
#  250: 'number',
#  251: 'there',
#  252: 'against',
#  253: 'tail',
#  254: 'tv',
#  255: 'coffee',
#  256: 'dirt',
#  257: 'seat',
#  258: 'cap',
#  259: 'engine',
#  260: 'painted',
#  261: 'driving',
#  262: 'sand',
#  263: 'square',
#  264: 'bridge',
#  265: 'suit',
#  266: 'pot',
#  267: 'bright',
#  268: 'sandwich',
#  269: 'jet',
#  270: 'skier',
#  271: 'colorful',
#  272: 'line',
#  273: 'plant',
#  274: 'right',
#  275: 'mountain',
#  276: 'womans',
#  277: 'lady',
#  278: 'one',
#  279: 'suitcase',
#  280: 'several',
#  281: 'row',
#  282: 'made',
#  283: 'reflection',
#  284: 'together',
#  285: 'shoes',
#  286: 'horses',
#  287: 'double',
#  288: 'four',
#  289: 'through',
#  290: 'windows',
#  291: 'frame',
#  292: 'monitor',
#  293: 'women',
#  294: 'shelf',
#  295: 'jeans',
#  296: 'pair',
#  297: 'guy',
#  298: 'apple',
#  299: 'wine',
#  300: 'elephants',
#  301: 'painting',
#  302: 'stripe',
#  303: 'handle',
#  304: 'stand',
#  305: 'cloud',
#  306: 'set',
#  307: 'arm',
#  308: 'shoe',
#  309: 'skateboarder',
#  310: 'skateboarding',
#  311: 'cows',
#  312: 'dogs',
#  313: 'microwave',
#  314: 'pillow',
#  315: 'striped',
#  316: 'very',
#  317: 'skis',
#  318: 'statue',
#  319: 'letters',
#  320: 'cut',
#  321: 'half',
#  322: 'leaf',
#  323: 'stone',
#  324: 'can',
#  325: 'some',
#  326: 'knife',
#  327: 'kid',
#  328: 'track',
#  329: 'bears',
#  330: 'crossing',
#  331: 'leaning',
#  332: 'these',
#  333: 'luggage',
#  334: 'logo',
#  335: 'during',
#  336: 'day',
#  337: 'mouth',
#  338: 'covered',
#  339: 'edge',
#  340: 'neck',
#  341: 'tile',
#  342: 'hot',
#  343: 'players',
#  344: 'oven',
#  345: 'cabinet',
#  346: 'book',
#  347: 'stove',
#  348: 'bread',
#  349: 'keyboard',
#  350: 'bicycle',
#  351: 'hill',
#  352: 'rock',
#  353: 'bunch',
#  354: 'he',
#  355: 'animal',
#  356: 'towel',
#  357: 'nose',
#  358: 'smiling',
#  359: 'wii',
#  360: 'carrying',
#  361: 'display',
#  362: 'lying',
#  363: 'basket',
#  364: 'roof',
#  365: 'off',
#  366: 'television',
#  367: 'faucet',
#  368: 'pool',
#  369: 'many',
#  370: 'stack',
#  371: 'remote',
#  372: 'time',
#  373: 'tray',
#  374: 'station',
#  375: 'cover',
#  376: 'slope',
#  377: 'shadow',
#  378: 'broccoli',
#  379: 'mid',
#  380: 'beside',
#  381: 'facing',
#  382: 'along',
#  383: 'attached',
#  384: 'signal',
#  385: 'other',
#  386: 'taxi',
#  387: 'shorts',
#  388: 'daytime',
#  389: 'taken',
#  390: 'signs',
#  391: 'talking',
#  392: 'case',
#  393: 'birds',
#  394: 'container',
#  395: 'rail',
#  396: 'posing',
#  397: 'slice',
#  398: 'doing',
#  399: 'swinging',
#  400: 'persons',
#  401: 'shade',
#  402: 'each',
#  403: 'lot',
#  404: 'rocks',
#  405: 'american',
#  406: 'base',
#  407: 'umbrellas',
#  408: 'rug',
#  409: 'patch',
#  410: 'animals',
#  411: 'dress',
#  412: 'numbers',
#  413: 'wave',
#  414: 'fridge',
#  415: 'decker',
#  416: 'trick',
#  417: 'its',
#  418: 'foreground',
#  419: 'running',
#  420: 'cars',
#  421: 'branch',
#  422: 'coat',
#  423: 'steel',
#  424: 'store',
#  425: 'stairs',
#  426: 'says',
#  427: 'runway',
#  428: 'spot',
#  429: 'coming',
#  430: 'cross',
#  431: 'stuffed',
#  432: 'skate',
#  433: 'being',
#  434: 'refrigerator',
#  435: 'batter',
#  436: 'button',
#  437: 'chairs',
#  438: 'suv',
#  439: 'controller',
#  440: 'cart',
#  441: 'pavement',
#  442: 'backpack',
#  443: 'tarmac',
#  444: 'lines',
#  445: 'middle',
#  446: 'flat',
#  447: 'empty',
#  448: 'lettering',
#  449: 'couple',
#  450: 'arrow',
#  451: 'sweater',
#  452: 'snowboard',
#  453: 'watching',
#  454: 'doughnut',
#  455: 'fork',
#  456: 'sea',
#  457: 'boys',
#  458: 'motorbike',
#  459: 'mouse',
#  460: 'meter',
#  461: 'herd',
#  462: 'jumping',
#  463: 'male',
#  464: 'turned',
#  465: 'office',
#  466: 'not',
#  467: 'cheese',
#  468: 'cab',
#  469: 'planes',
#  470: 'like',
#  471: 'slat',
#  472: 'writing',
#  473: 'dish',
#  474: 'beige',
#  475: 'clean',
#  476: 'concrete',
#  477: 'toy',
#  478: 'stripes',
#  479: 'her',
#  480: 'sliced',
#  481: 'pan',
#  482: 'surf',
#  483: 'cats',
#  484: 'their',
#  485: 'children',
#  486: 'passenger',
#  487: 'goggles',
#  488: 'uniform',
#  489: 'motorcycles',
#  490: 'cream',
#  491: 'cooked',
#  492: 'scissors',
#  493: 'zoo',
#  494: 'eyes',
#  495: 'here',
#  496: 'girls',
#  497: 'sits',
#  498: 'distance',
#  499: 'pen',
#  500: 'mug',
#  501: 'trash',
#  502: 'buildings',
#  503: 'curtain',
#  504: 'sofa',
#  505: 'style',
#  506: 'into',
#  507: 'motor',
#  508: 'bottom',
#  509: 'pile',
#  510: 'fan',
#  511: 'interior',
#  512: 'river',
#  513: 'donut',
#  514: 'name',
#  515: 'tag',
#  516: 'carrot',
#  517: 'beer',
#  518: 'blonde',
#  519: 'airport',
#  520: 'held',
#  521: 'asian',
#  522: 'wet',
#  523: 'pillows',
#  524: 'chain',
#  525: 'blender',
#  526: 'grazing',
#  527: 'feet',
#  528: 'tiles',
#  529: 'platform',
#  530: 'bun',
#  531: 'reading',
#  532: 'something',
#  533: 'cement',
#  534: 'palm',
#  535: 'rear',
#  536: 'sauce',
#  537: 'across',
#  538: 'fixture',
#  539: 'doors',
#  540: 'oranges',
#  541: 'night',
#  542: 'hole',
#  543: 'skirt',
#  544: 'haired',
#  545: 'filled',
#  546: 'looks',
#  547: 'license',
#  548: 'older',
#  549: 'rectangular',
#  550: 'framed',
#  551: 'living',
#  552: 'church',
#  553: 'railing',
#  554: 'words',
#  555: 'hood',
#  556: 'wears',
#  557: 'tomato',
#  558: 'walk',
#  559: 'yard',
#  560: 'video',
#  561: 'forest',
#  562: 'school',
#  563: 'foot',
#  564: 'fluffy',
#  565: 'design',
#  566: 'lawn',
#  567: 'napkin',
#  568: 'end',
#  569: 'apples',
#  570: 'ready',
#  571: 'chocolate',
#  572: 'different',
#  573: 'ramp',
#  574: 'lid',
#  575: 'finger',
#  576: 't',
#  577: 'spots',
#  578: 'garbage',
#  579: 'pulling',
#  580: 'soup',
#  581: 'vest',
#  582: 'sleeping',
#  583: 'buses',
#  584: 'waves',
#  585: 'wheels',
#  586: 'lots',
#  587: 'working',
#  588: 'childs',
#  589: 'pictures',
#  590: 'between',
#  591: 'curb',
#  592: 'bull',
#  593: 'cage',
#  594: 'scooter',
#  595: 'sun',
#  596: 'print',
#  597: 'police',
#  598: 'no',
#  599: 'pane',
#  600: 'holder',
#  601: 'word',
#  602: 'juice',
#  603: 'cord',
#  604: 'lit',
#  605: 'tank',
#  606: 'way',
#  607: 'knob',
#  608: 'balcony',
#  609: 'covering',
#  610: 'block',
#  611: 'chimney',
#  612: 'ornate',
#  613: 'waiting',
#  614: 'stick',
#  615: 'windshield',
#  616: 'military',
#  617: 'woods',
#  618: 'skating',
#  619: 'kites',
#  620: 'pointing',
#  621: 'grill',
#  622: 'clothing',
#  623: 'electric',
#  624: 'carrots',
#  625: 'boats',
#  626: 'kids',
#  627: 'written',
#  628: 'cellphone',
#  629: 'platter',
#  630: 'plates',
#  631: 'female',
#  632: 'skiers',
#  633: 'birthday',
#  634: 'about',
#  635: 'holds',
#  636: 'snowboarder',
#  637: 'vases',
#  638: 'home',
#  639: 'carriage',
#  640: 'taking',
#  641: 'lap',
#  642: 'intersection',
#  643: 'swimming',
#  644: 'thick',
#  645: 'horizon',
#  646: 'gate',
#  647: 'telephone',
#  648: 'five',
#  649: 'stainless',
#  650: 'plaid',
#  651: 'vehicles',
#  652: 'broken',
#  653: 'moving',
#  654: 'parrot',
#  655: 'highway',
#  656: 'bikes',
#  657: 'restroom',
#  658: 'machine',
#  659: 'cloth',
#  660: 'polar',
#  661: 'rainbow',
#  662: 'paint',
#  663: 'walls',
#  664: 'traveling',
#  665: 'visible',
#  666: 'decorative',
#  667: 'bedroom',
#  668: 'legs',
#  669: 'curved',
#  670: 'commercial',
#  671: 'deep',
#  672: 'teeth',
#  673: 'shot',
#  674: 'ears',
#  675: 'bush',
#  676: 'blanket',
#  677: 'using',
#  678: 'stool',
#  679: 'panel',
#  680: 'center',
#  681: 'mounted',
#  682: 'crowd',
#  683: 'going',
#  684: 'straw',
#  685: 'spotted',
#  686: 'restaurant',
#  687: 'golden',
#  688: 'cutting',
#  689: 'roll',
#  690: 'cooking',
#  691: 'ice',
#  692: 'wire',
#  693: 'shower',
#  694: 'dot',
#  695: 'enclosure',
#  696: 'section',
#  697: 'sandy',
#  698: 'donuts',
#  699: 'beautiful',
#  700: 'swing',
#  701: 'text',
#  702: 'horns',
#  703: 'gravel',
#  704: 'suitcases',
#  705: 'brushing',
#  706: 'resting',
#  707: 'vegetables',
#  708: 'lighthouse',
#  709: 'fur',
#  710: 'monkey',
#  711: 'adult',
#  712: 'poles',
#  713: 'snowboarding',
#  714: 'drinking',
#  715: 'toppings',
#  716: 'sticker',
#  717: 'surface',
#  718: 'meal',
#  719: 'glowing',
#  720: 'porcelain',
#  721: 'beard',
#  722: 'burger',
#  723: 'upside',
#  724: 'dock',
#  725: 'beak',
#  726: 'paved',
#  727: 'rack',
#  728: 'dresser',
#  729: 'pipe',
#  730: 'scarf',
#  731: 'residential',
#  732: 'butter',
#  733: 'shiny',
#  734: 'brightly',
#  735: 'banner',
#  736: 'entrance',
#  737: 'tea',
#  738: 'kettle',
#  739: 'match',
#  740: 'wagon',
#  741: 'purse',
#  742: 'forefront',
#  743: 'art',
#  744: 'circle',
#  745: 'growing',
#  746: 'close',
#  747: 'watch',
#  748: 'heads',
#  749: 'shining',
#  750: '2',
#  751: 'pier',
#  752: 'place',
#  753: 'log',
#  754: 'trim',
#  755: 'ribbon',
#  756: 'leather',
#  757: 'all',
#  758: 'vintage',
#  759: 'hard',
#  760: 'trolley',
#  761: 'dead',
#  762: 'safety',
#  763: 'clocks',
#  764: 'label',
#  765: 'opened',
#  766: 'smoke',
#  767: 'outfit',
#  768: 'cone',
#  769: 'socks',
#  770: 'elderly',
#  771: 'ripples',
#  772: 'fighter',
#  773: 'racing',
#  774: 'pie',
#  775: 'neon',
#  776: 'deck',
#  777: 'roman',
#  778: 'catcher',
#  779: 'liquid',
#  780: 'bottles',
#  781: 'leash',
#  782: 'touching',
#  783: 'country',
#  784: 'structure',
#  785: 'snowy',
#  786: 'slices',
#  787: 'rusted',
#  788: 'bending',
#  789: 'phones',
#  790: 'they',
#  791: 'panda',
#  792: 'wing',
#  793: 'tiny',
#  794: 'pitcher',
#  795: 'baked',
#  796: 'tied',
#  797: 'surfers',
#  798: 'surfboards',
#  799: 'clothes',
#  800: 'carpet',
#  801: 'seated',
#  802: 'wild',
#  803: 'she',
#  804: 'pasture',
#  805: 'trains',
#  806: 'preparing',
#  807: 'glove',
#  808: 'perched',
#  809: 'blond',
#  810: 'salad',
#  811: 'crust',
#  812: 'catching',
#  813: 'vegetable',
#  814: 'toothbrush',
#  815: 'hitting',
#  816: 'fo',
#  817: 'still',
#  818: 'enter',
#  819: 'beneath',
#  820: 'hotel',
#  821: 'plants',
#  822: 'busy',
#  823: 'crosswalk',
#  824: 'duck',
#  825: 'decorated',
#  826: 'tub',
#  827: 'suspended',
#  828: 'cargo',
#  829: 'stair',
#  830: 'outdoor',
#  831: 'poster',
#  832: 'snack',
#  833: 'mountains',
#  834: 'lake',
#  835: 'headboard',
#  836: 'thin',
#  837: 'grown',
#  838: 'bar',
#  839: 'fish',
#  840: 'awning',
#  841: 'object',
#  842: 'extended',
#  843: 'bushes',
#  844: 'dinner',
#  845: 'circular',
#  846: 'fountain',
#  847: 'pattern',
#  848: 'arch',
#  849: 'petal',
#  850: 'patio',
#  851: 'styrofoam',
#  852: 'terminal',
#  853: 'doorway',
#  854: 'sit',
#  855: 'shop',
#  856: 'fireplace',
#  857: 'railroad',
#  858: 'having',
#  859: 'branches',
#  860: 'stuff',
#  861: 'cupcake',
#  862: 'bell',
#  863: 'aircraft',
#  864: 'doughnuts',
#  865: 'net',
#  866: 'apron',
#  867: 'worn',
#  868: 'meat',
#  869: 'meters',
#  870: 'key',
#  871: 'family',
#  872: 'collar',
#  873: 'mostly',
#  874: 'control',
#  875: 'equipment',
#  876: 'pulled',
#  877: 'reflecting',
#  878: 'pieces',
#  879: 'headband',
#  880: 'lined',
#  881: 'barrier',
#  882: 'multi',
#  883: 'pepper',
#  884: 'dirty',
#  885: 'whole',
#  886: 'colors',
#  887: 'dry',
#  888: 'play',
#  889: 'sides',
#  890: 'subway',
#  891: 'buttons',
#  892: 'fruits',
#  893: 'cabinets',
#  894: 'race',
#  895: 'iron',
#  896: 'jersey',
#  897: 'stacked',
#  898: 'eyeglasses',
#  899: 'plush',
#  900: 'towels',
#  901: 'egg',
#  902: 'as',
#  903: 'mini',
#  904: 'kept',
#  905: 'frosting',
#  906: 'link',
#  907: 'curly',
#  908: 'bow',
#  909: 'cloudy',
#  910: 'skies',
#  911: 'public',
#  912: 'setting',
#  913: 'weather',
#  914: 'kitten',
#  915: 'shaped',
#  916: 'paw',
#  917: 'path',
#  918: 'hotdog',
#  919: 'fries',
#  920: 'spectators',
#  921: 'wings',
#  922: 'shore',
#  923: 'rod',
#  924: 'sticking',
#  925: 'carton',
#  926: 'countertop',
#  927: 'dressed',
#  928: 'goat',
#  929: 'f',
#  930: 'fresh',
#  931: 'candles',
#  932: 'nice',
#  933: 'performing',
#  934: 'flags',
#  935: 'pasta',
#  936: 'pickle',
#  937: 'pocket',
#  938: 'image',
#  939: 'happy',
#  940: 'single',
#  941: 'throwing',
#  942: 'furry',
#  943: 'getting',
#  944: 'darkness',
#  945: 'cardboard',
#  946: 'rectangle',
#  947: 'stroller',
#  948: 'construction',
#  949: 'do',
#  950: 'tipped',
#  951: 'band',
#  952: 'medium',
#  953: 'sized',
#  954: 'porch',
#  955: 'rain',
#  956: 'minivan',
#  957: 'electrical',
#  958: 'step',
#  959: 'seagull',
#  960: 'arms',
#  961: 'paddle',
#  962: 'shopping',
#  963: 'assorted',
#  964: 'trail',
#  965: 'pigeon',
#  966: 'docked',
#  967: 'pointed',
#  968: 'steps',
#  969: 'delivery',
#  970: 'rubber',
#  971: 'banners',
#  972: 'fallen',
#  973: 'jeep',
#  974: 'whtie',
#  975: 'cardigan',
#  976: 'sill',
#  977: 'decorations',
#  978: 'tip',
#  979: 'leading',
#  980: 'space',
#  981: 'surrounding',
#  982: 'rounded',
#  983: 'closet',
#  984: 'soap',
#  985: 'lampshade',
#  986: 'nightstand',
#  987: 'corded',
#  988: 'dining',
#  989: 'sunlight',
#  990: 'range',
#  991: 'switch',
#  992: 'arched',
#  993: 'balloon',
#  994: 'utility',
#  995: 'rope',
#  996: 'sedan',
#  997: 'picnic',
#  998: 'walkway',
#  999: 'urban',
#  1000: 'pushing',
#  ...}

# %%
target_word_index=y_tokens.word_index
target_word_index
# Out:
# {'sos': 1,
#  'eos': 2,
#  'ഒരു': 3,
#  'കറുത്ത': 4,
#  'വെളുത്ത': 5,
#  'സ്ത്രീ': 6,
#  'ധരിച്ച': 7,
#  'മനുഷ്യൻ': 8,
#  'പച്ച': 9,
#  'വലിയ': 10,
#  'നീല': 11,
#  'ബാഗ്': 12,
#  'വർണ്ണാഭമായ': 13,
#  'ചുവന്ന': 14,
#  'ചാരനിറത്തിലുള്ള': 15,
#  'സ്കാർഫ്': 16,
#  'ട്രാഷ്': 17,
#  'റോഡിന്റെ': 18,
#  'വിൻഡോ': 19,
#  'പുല്ലിന്റെ': 20,
#  'മഞ്ഞ': 21,
#  'വശങ്ങളിൽ': 22,
#  'സ്ട്രിപ്പുകൾ': 23,
#  'വ്യക്തി': 24,
#  'ഇതൊരു': 25,
#  'രണ്ട്': 26,
#  'ചെറിയ': 27,
#  'കെട്ടിടത്തിലെ': 28,
#  'നിലത്ത്': 29,
#  'ആന': 30,
#  'വെള്ള': 31,
#  'ഒരാൾ': 32,
#  'ഉള്ള': 33,
#  'ചുവപ്പ്': 34,
#  'തവിട്ട്': 35,
#  'കുഞ്ഞ്': 36,
#  'ജിറാഫ്': 37,
#  'വെള്ളയും': 38,
#  'ഓറഞ്ച്': 39,
#  'മുകളിൽ': 40,
#  'പുല്ല്': 41,
#  'എഞ്ചിൻ': 42,
#  'ചിഹ്നം': 43,
#  'കാർ': 44,
#  'കെട്ടിടത്തിന്റെ': 45,
#  'മേശപ്പുറത്ത്': 46,
#  'പുള്ളി': 47,
#  'ആളുകൾ': 48,
#  'നിറമുള്ള': 49,
#  'ടെന്നീസ്': 50,
#  'രംഗം': 51,
#  'ട്രെയിൻ': 52,
#  'തലം': 53,
#  'ഇത്': 54,
#  'ബീച്ച്': 55,
#  'നിൽക്കുന്നു': 56,
#  'തിന്നുന്നു': 57,
#  'നിൽക്കുന്ന': 58,
#  'ദ്വീപ്': 59,
#  'ഇരിക്കുന്നു': 60,
#  'വശത്ത്': 61,
#  'നായ': 62,
#  'മതിൽ': 63,
#  'മരം': 64,
#  'ബേസ്ബോൾ': 65,
#  'തെരുവിൽ': 66,
#  'ബസ്': 67,
#  'വിമാനം': 68,
#  'ചുവപ്പും': 69,
#  'ഷർട്ട്': 70,
#  'പാർക്ക്': 71,
#  'ഉണ്ട്': 72,
#  'കറുപ്പും': 73,
#  'നടക്കുന്നു': 74,
#  'ഇരിക്കുന്ന': 75,
#  'പെൺകുട്ടി': 76,
#  'വെള്ളത്തിൽ': 77,
#  'വെള്ളി': 78,
#  'പൂച്ച': 79,
#  'തൊപ്പി': 80,
#  'ചെയ്യുന്നു': 81,
#  'ആണ്': 82,
#  'കുട്ടി': 83,
#  'കൂട്ടം': 84,
#  'പിസ്സ': 85,
#  'മിഠായി': 86,
#  'കോട്ടൺ': 87,
#  'വൈറ്റ്': 88,
#  'പക്ഷി': 89,
#  'ഗ്ലാസ്': 90,
#  'നീലയും': 91,
#  'മോട്ടോർ': 92,
#  'പിടിക്കുന്നു': 93,
#  'തല': 94,
#  'ട്രക്ക്': 95,
#  'ഭാഗം': 96,
#  'തെരുവ്': 97,
#  'പുല്ലിൽ': 98,
#  'മനുഷ്യന്റെ': 99,
#  'പിങ്ക്': 100,
#  'വായുവിൽ': 101,
#  'അടയാളം': 102,
#  'ഘടികാരം': 103,
#  'ചുവരിൽ': 104,
#  'റോഡിൽ': 105,
#  'കുട': 106,
#  'കളിക്കാരൻ': 107,
#  'ലൈറ്റ്': 108,
#  'ടോയ്\u200cലറ്റ്': 109,
#  'മൂന്ന്': 110,
#  'ചിത്രം': 111,
#  'ഇരുണ്ട': 112,
#  'ചെയ്യുന്ന': 113,
#  'കുതിര': 114,
#  'ക്ലോക്ക്': 115,
#  'മുന്നിൽ': 116,
#  'ചുമരിൽ': 117,
#  'പ്ലേറ്റിൽ': 118,
#  'നിന്ന്': 119,
#  'ബെഞ്ച്': 120,
#  'വിളക്ക്': 121,
#  'സ്ത്രീയുടെ': 122,
#  'പാത്രം': 123,
#  'ധരിക്കുന്നു': 124,
#  'വയലിൽ': 125,
#  'തടി': 126,
#  'വ്യക്തിയാണ്': 127,
#  'ആകാശത്ത്': 128,
#  'നിറത്തിലുള്ള': 129,
#  'കരടി': 130,
#  'കേക്ക്': 131,
#  'കമ്പ്യൂട്ടർ': 132,
#  'പിന്നിൽ': 133,
#  'ഫോൺ': 134,
#  'വെളുപ്പും': 135,
#  'രണ്ടുപേർ': 136,
#  'ഉയരമുള്ള': 137,
#  'മെറ്റൽ': 138,
#  'ട്രാഫിക്': 139,
#  'തവിട്ടുനിറത്തിലുള്ള': 140,
#  'കെട്ടിടത്തിന്': 141,
#  'പ്ലേറ്റ്': 142,
#  'ഹെൽമെറ്റ്': 143,
#  'ഭക്ഷണം': 144,
#  'വാഴപ്പഴം': 145,
#  'ആകാശം': 146,
#  'സീബ്ര': 147,
#  'ബെഞ്ചിൽ': 148,
#  'പോൾ': 149,
#  'വെളിച്ചം': 150,
#  'നീളമുള്ള': 151,
#  'കളിക്കുന്നു': 152,
#  'കട്ടിലിൽ': 153,
#  'ചെയ്ത': 154,
#  'വെളുത്തതാണ്': 155,
#  'ലാപ്\u200cടോപ്പ്': 156,
#  'വ്യക്തിയുടെ': 157,
#  'കൈവശമുള്ള': 158,
#  'പച്ചയും': 159,
#  'ജലാംശം': 160,
#  'സൈക്കിൾ': 161,
#  'പാത്രത്തിൽ': 162,
#  'ബ്രൗൺ': 163,
#  'ഇഷ്ടിക': 164,
#  'മുടിയുള്ള': 165,
#  'മുകളിലുള്ള': 166,
#  'കെട്ടിടം': 167,
#  'ബോട്ട്': 168,
#  'കൈ': 169,
#  'ബാറ്റ്': 170,
#  'പന്ത്': 171,
#  'സെൽ': 172,
#  'കസേര': 173,
#  'പയ്യൻ': 174,
#  'ഓടിക്കുന്നു': 175,
#  'പറക്കുന്നു': 176,
#  'ഈ': 177,
#  'കിടക്കുന്നു': 178,
#  'ബൈക്ക്': 179,
#  'സിൽവർ': 180,
#  'കപ്പ്': 181,
#  'വെള്ളം': 182,
#  'ജാക്കറ്റ്': 183,
#  'തുറന്ന': 184,
#  'റാക്കറ്റ്': 185,
#  'പശു': 186,
#  'ചെയ്തിരിക്കുന്നു': 187,
#  'ധ്രുവത്തിൽ': 188,
#  'നടക്കുന്ന': 189,
#  'പതാക': 190,
#  'പഴയ': 191,
#  'അഗ്നി': 192,
#  'നിരവധി': 193,
#  'കറുത്തതാണ്': 194,
#  'വാതിൽ': 195,
#  'കളിക്കുന്ന': 196,
#  'മുഖം': 197,
#  'ആടുകൾ': 198,
#  'മനുഷ്യന്': 199,
#  'മുടിയുണ്ട്': 200,
#  'നീലയാണ്': 201,
#  'അക്ഷരം': 202,
#  'പർപ്പിൾ': 203,
#  'പ്ലാസ്റ്റിക്': 204,
#  'തറയിൽ': 205,
#  'സ്കേറ്റ്ബോർഡ്': 206,
#  'കടൽത്തീരത്ത്': 207,
#  'ഫ്രിസ്ബീ': 208,
#  'പാർക്കിംഗ്': 209,
#  'ഇളം': 210,
#  'തലയിൽ': 211,
#  'ചുവപ്പാണ്': 212,
#  'തീവണ്ടി': 213,
#  'ബോൾ': 214,
#  'തൂക്കിയിരിക്കുന്നു': 215,
#  'ടാൻ': 216,
#  'ബോർഡ്': 217,
#  'നോക്കുന്നു': 218,
#  'സർഫിംഗ്': 219,
#  'കാഴ്ച': 220,
#  'സോക്കർ': 221,
#  'നിറമാണ്': 222,
#  'വരയുള്ള': 223,
#  'പൂക്കൾ': 224,
#  'ലൈറ്റുകൾ': 225,
#  'നടപ്പാതയിൽ': 226,
#  'ടയർ': 227,
#  'ഫ്ലാഗ്': 228,
#  'അടുക്കള': 229,
#  'വാൻ': 230,
#  'വളരെ': 231,
#  'മരത്തിൽ': 232,
#  'മഞ്ഞയും': 233,
#  'വേലി': 234,
#  'സ്വർണ്ണ': 235,
#  'മനുഷ്യനാണ്': 236,
#  'ആൺകുട്ടി': 237,
#  'സർഫ്ബോർഡ്': 238,
#  'കയ്യിൽ': 239,
#  'സ്റ്റോപ്പ്': 240,
#  'ഗെയിം': 241,
#  'ഫ്രെയിം': 242,
#  'ഉപയോഗിച്ച്': 243,
#  'കണ്ണ്': 244,
#  'കസേരയിൽ': 245,
#  'ടൈ': 246,
#  'നിറത്തിലാണ്': 247,
#  'കിടക്കുന്ന': 248,
#  'ജിറാഫുകൾ': 249,
#  'ടെഡി': 250,
#  'ബിയർ': 251,
#  'ചെവി': 252,
#  'ട്രെയിനിന്റെ': 253,
#  'മുൻവശത്ത്': 254,
#  'മോട്ടോർസൈക്കിൾ': 255,
#  'കുപ്പി': 256,
#  'വിമാനത്തിന്റെ': 257,
#  'കഴിക്കുന്നു': 258,
#  'കൈറ്റ്': 259,
#  'കഷണം': 260,
#  'കണ്ണട': 261,
#  'നടപ്പാതയിലൂടെ': 262,
#  'നിർത്തി': 263,
#  'തൂക്കിയിട്ടിരിക്കുന്ന': 264,
#  'നിറഞ്ഞ': 265,
#  'ഒരുമിച്ച്': 266,
#  'ഇതാണ്': 267,
#  'മഞ്ഞ്': 268,
#  'കൊച്ചു': 269,
#  'നായയുടെ': 270,
#  'സീബ്രകൾ': 271,
#  'നാല്': 272,
#  'കെട്ടിടത്തിൽ': 273,
#  'കാൽ': 274,
#  'ഇല': 275,
#  'സ്ക്രീൻ': 276,
#  'അടുത്തുള്ള': 277,
#  'മേശ': 278,
#  'ധാരാളം': 279,
#  'മുടി': 280,
#  'കറുപ്പ്': 281,
#  'ഇലകൾ': 282,
#  'സവാരി': 283,
#  'ആപ്പിൾ': 284,
#  'ചിഹ്നത്തിൽ': 285,
#  'ട്രാക്കുകളിൽ': 286,
#  'ബസിന്റെ': 287,
#  'മുഖത്ത്': 288,
#  'കണ്ണാടി': 289,
#  'സ്ത്രീകൾ': 290,
#  'മഞ്ഞുവീഴ്ചയിൽ': 291,
#  'ചുറ്റും': 292,
#  'ടിവി': 293,
#  'കോഫി': 294,
#  'നീലാകാശം': 295,
#  'വശത്തുള്ള': 296,
#  'തവിട്ടുനിറമാണ്': 297,
#  'കിടക്ക': 298,
#  'വസ്ത്രം': 299,
#  'മേശയിൽ': 300,
#  'സീബ്രയുടെ': 301,
#  'ആനയുടെ': 302,
#  'കോർട്ടിൽ': 303,
#  'ഹോട്ട്': 304,
#  'പിടിക്കുന്ന': 305,
#  'സ്യൂട്ട്': 306,
#  'സ്കീയർ': 307,
#  'ജിറാഫിന്റെ': 308,
#  'ചാരനിറമാണ്': 309,
#  'ടവർ': 310,
#  'ചെയ്തു': 311,
#  'പ്രതിഫലനം': 312,
#  'വാഹനം': 313,
#  'വൃത്താകൃതിയിലുള്ള': 314,
#  'പ്രകാശം': 315,
#  'ട്രെയിനിൽ': 316,
#  'ക്യാമറ': 317,
#  'കത്തി': 318,
#  'മൂക്ക്': 319,
#  'തളികയിൽ': 320,
#  'ഫ്രിസ്\u200cബീ': 321,
#  'ഓടിക്കുന്ന': 322,
#  'കൈവശം': 323,
#  'സൈക്കിളിൽ': 324,
#  'പട്ടം': 325,
#  'ചായം': 326,
#  'കാറിന്റെ': 327,
#  'തെരുവിലൂടെ': 328,
#  'മരത്തിന്റെ': 329,
#  'മരങ്ങൾ': 330,
#  'സീലിംഗിൽ': 331,
#  'മോണിറ്റർ': 332,
#  'പരസ്പരം': 333,
#  'പാന്റ്സ്': 334,
#  'മുറിയിൽ': 335,
#  'പ്രതിമ': 336,
#  'പുറകിൽ': 337,
#  'പുറത്ത്': 338,
#  'പുഷ്പം': 339,
#  'മേഘങ്ങൾ': 340,
#  'ടൈൽ': 341,
#  'സാൻഡ്\u200cവിച്ച്': 342,
#  'ഷർട്ടിൽ': 343,
#  'സ്കേറ്റ്ബോർഡിൽ': 344,
#  'മൈതാനത്ത്': 345,
#  'സ്കീയിംഗ്': 346,
#  'സർഫർ': 347,
#  'ജാലകം': 348,
#  'വാൽ': 349,
#  'മൂലയിൽ': 350,
#  'നിർമ്മിച്ച': 351,
#  'ചക്രം': 352,
#  'വര': 353,
#  'ജോടി': 354,
#  'റൗണ്ട്': 355,
#  'നിലത്തു': 356,
#  'കഴിക്കുന്ന': 357,
#  'തൂവാല': 358,
#  'പറക്കുന്ന': 359,
#  'സ്കേറ്റ്ബോർഡർ': 360,
#  'നിഴൽ': 361,
#  'ജെറ്റ്': 362,
#  'ഷൂ': 363,
#  'പശ്ചാത്തലത്തിൽ': 364,
#  'പൂച്ചയുടെ': 365,
#  'ട്രക്കിന്റെ': 366,
#  'മുറിയിലെ': 367,
#  'അരികിൽ': 368,
#  'ഇവ': 369,
#  'സിങ്ക്': 370,
#  'ഫോണിൽ': 371,
#  'ടാക്സി': 372,
#  'സ്ത്രീയും': 373,
#  'പേപ്പർ': 374,
#  'ഷർട്ടും': 375,
#  'കല്ല്': 376,
#  'ജനൽ': 377,
#  'പെട്ടി': 378,
#  'പെൺകുട്ടിയുടെ': 379,
#  'ബോട്ടിൽ': 380,
#  'റോഡ്': 381,
#  'ഡോനട്ട്': 382,
#  'ഡോഗ്': 383,
#  'കുതിരയുടെ': 384,
#  'ശേഖരം': 385,
#  'ബോർഡിൽ': 386,
#  'മൈക്രോവേവ്': 387,
#  'തലയിണ': 388,
#  'കണ്ണാടിയിൽ': 389,
#  'മഞ്ഞയാണ്': 390,
#  'വിൻഡോയിൽ': 391,
#  'സമീപം': 392,
#  'അമേരിക്കൻ': 393,
#  'ചെയ്തിരിക്കുന്ന': 394,
#  'കുപ്പായം': 395,
#  'റൊട്ടി': 396,
#  'ടെലിവിഷൻ': 397,
#  'അടുക്കളയിൽ': 398,
#  'സംസാരിക്കുന്നു': 399,
#  'കൊണ്ട്': 400,
#  'സീറ്റ്': 401,
#  'പക്ഷിയുടെ': 402,
#  'ധരിക്കുന്ന': 403,
#  'അവൻ': 404,
#  'ഹാൻഡിൽ': 405,
#  'വൈ': 406,
#  'സ്കേറ്റ്': 407,
#  'കുട്ടികൾ': 408,
#  'ചെറുപ്പക്കാരൻ': 409,
#  'പെൺകുട്ടിക്ക്': 410,
#  'സ്കീ': 411,
#  'മീറ്റർ': 412,
#  'നമ്പർ': 413,
#  'പുരുഷന്മാർ': 414,
#  'തിളങ്ങുന്ന': 415,
#  'തറ': 416,
#  'വൃക്ഷം': 417,
#  'ഡെസ്\u200cകിൽ': 418,
#  'ചെയ്യുക': 419,
#  'ചവറ്റുകുട്ട': 420,
#  'കുളിമുറിയിൽ': 421,
#  'വീടിന്റെ': 422,
#  'വിമാനങ്ങൾ': 423,
#  'അടയാളങ്ങൾ': 424,
#  'ചതുര': 425,
#  'നിറത്തിൽ': 426,
#  'സ്ത്രീക്ക്': 427,
#  'ഇടത്': 428,
#  'ജീൻസ്': 429,
#  'പച്ചയാണ്': 430,
#  'ചില': 431,
#  'നഗര': 432,
#  'കാട്ടിൽ': 433,
#  'പക്ഷികൾ': 434,
#  'പിടിച്ചിരിക്കുന്ന': 435,
#  'സ്റ്റഫ്': 436,
#  'മണൽ': 437,
#  'പോസ്': 438,
#  'വാട്ടർ': 439,
#  'വെള്ളിയും': 440,
#  'കാരറ്റ്': 441,
#  'അതിൽ': 442,
#  'സർഫ്': 443,
#  'റെഡ്': 444,
#  'സൺഗ്ലാസുകൾ': 445,
#  'കൊച്ചുകുട്ടി': 446,
#  'സ്വിംഗ്': 447,
#  'വേലിക്ക്': 448,
#  'ആനകൾ': 449,
#  'ടൂത്ത്': 450,
#  'നടപ്പാത': 451,
#  'നേരെ': 452,
#  'വരകൾ': 453,
#  'അവന്റെ': 454,
#  'നിര': 455,
#  'മഞ്ഞിൽ': 456,
#  'കുടകൾ': 457,
#  'എന്ന': 458,
#  'പുസ്തകം': 459,
#  'സീലിംഗ്': 460,
#  'അക്ഷരങ്ങളുള്ള': 461,
#  'ബ്ലാക്ക്': 462,
#  'സഞ്ചരിക്കുന്ന': 463,
#  'സമീപമുള്ള': 464,
#  'കുന്നിൻ': 465,
#  'തെളിഞ്ഞ': 466,
#  'നടപ്പാതയിലെ': 467,
#  'റെയിൽ': 468,
#  'സ്വെറ്റർ': 469,
#  'റൺവേയിൽ': 470,
#  'തന്റെ': 471,
#  'സർഫ്ബോർഡിൽ': 472,
#  'ഫയർ': 473,
#  'കാണുന്ന': 474,
#  'സ്യൂട്ട്കേസ്': 475,
#  'ഗതാഗത': 476,
#  'കൈയിൽ': 477,
#  'ഓടുന്നു': 478,
#  'ഗോപുരം': 479,
#  'തെരുവിലെ': 480,
#  'കളിക്കാർ': 481,
#  'മൃഗം': 482,
#  'പശുക്കൾ': 483,
#  'വായുവിലാണ്': 484,
#  'തന്ത്രം': 485,
#  'ബട്ടൺ': 486,
#  'പിസ്സയിൽ': 487,
#  'ലോഹത്തിന്റെ': 488,
#  'കൗണ്ടറിൽ': 489,
#  'ടേബിൾ': 490,
#  'കട്ടിയുള്ള': 491,
#  'അടുത്ത്': 492,
#  'സിഗ്നൽ': 493,
#  'ഫുട്പാത്തിൽ': 494,
#  'മണലിൽ': 495,
#  'കൊണ്ടുള്ള': 496,
#  'പോസ്റ്റിൽ': 497,
#  'വിമാനത്തിലെ': 498,
#  'അലങ്കരിച്ച': 499,
#  'പേർ': 500,
#  'ലഗേജ്': 501,
#  'പെയിന്റിംഗ്': 502,
#  'കൊട്ടയിൽ': 503,
#  'ഗ്രേ': 504,
#  'സിങ്കിൽ': 505,
#  'കൈകൾ': 506,
#  'മനോഹരമായ': 507,
#  'റിമോട്ട്': 508,
#  'ടോപ്പ്': 509,
#  'അക്ഷരങ്ങൾ': 510,
#  'തിളക്കമുള്ള': 511,
#  'വാസ്': 512,
#  'മുൻവശത്തെ': 513,
#  'മുൻ': 514,
#  'ഫാൻ': 515,
#  'വായിൽ': 516,
#  'അമ്പടയാളം': 517,
#  'വഴിയിൽ': 518,
#  'പാച്ച്': 519,
#  'വണ്ടി': 520,
#  'കാറുകൾ': 521,
#  'കടും': 522,
#  'വസ്ത്രങ്ങൾ': 523,
#  'സ്കൂൾ': 524,
#  'തക്കാളി': 525,
#  'പാലം': 526,
#  'പാത്രങ്ങൾ': 527,
#  'വ്യക്തമായ': 528,
#  'ശിരോകവജം': 529,
#  'വിമാനത്തിൽ': 530,
#  'ചുമക്കുന്ന': 531,
#  'പകുതി': 532,
#  'ധരിച്ചിരിക്കുന്നു': 533,
#  'കിടക്കയിൽ': 534,
#  'പാസഞ്ചർ': 535,
#  'സ്കേറ്റ്ബോർഡിംഗ്': 536,
#  'ബൈക്കിന്റെ': 537,
#  'അത്': 538,
#  'ആട്': 539,
#  'ഇരട്ട': 540,
#  'റഫ്രിജറേറ്റർ': 541,
#  'കരടികൾ': 542,
#  'കരടിയുടെ': 543,
#  'ഉള്ളിൽ': 544,
#  'ഫോട്ടോയിലെ': 545,
#  'ആടുകളുടെ': 546,
#  'കഷ്ണം': 547,
#  'കുട്ടിയുടെ': 548,
#  'ഫോട്ടോ': 549,
#  'മുറിച്ചുകടക്കുന്ന': 550,
#  'ഓണാണ്': 551,
#  'തുമ്പിക്കൈ': 552,
#  'തുറന്നു': 553,
#  'ചീസ്': 554,
#  'പെയിന്റ്': 555,
#  'കാറിന്': 556,
#  'മേശയുടെ': 557,
#  'സ്റ്റീൽ': 558,
#  'വെള്ളത്തിനടുത്തുള്ള': 559,
#  'ടാർമാക്കിൽ': 560,
#  'മേഘം': 561,
#  'വലത്': 562,
#  'വള്ളം': 563,
#  'പുരുഷന്റെ': 564,
#  'നീണ്ട': 565,
#  'മുറിയുടെ': 566,
#  'പോലീസ്': 567,
#  'പാളി': 568,
#  'കടലാസ്': 569,
#  'ഇടതുവശത്ത്': 570,
#  'പാലത്തിൽ': 571,
#  'കാറിലെ': 572,
#  'വീട്': 573,
#  'ശൂന്യമായ': 574,
#  'കലം': 575,
#  'ദമ്പതികൾ': 576,
#  'പകൽ': 577,
#  'ആകാശത്തിന്റെ': 578,
#  'ശാഖയിൽ': 579,
#  'പോസ്റ്റ്': 580,
#  'അഴുക്കുചാലിൽ': 581,
#  'ട്രക്കിൽ': 582,
#  'നിറം': 583,
#  'പാറ': 584,
#  'വീഡിയോ': 585,
#  'കഴുത്തിൽ': 586,
#  'റോഡിലെ': 587,
#  'ചരട്': 588,
#  'പുറത്തേക്ക്': 589,
#  'നനഞ്ഞ': 590,
#  'കേസ്': 591,
#  'ആൺകുട്ടിക്ക്': 592,
#  'ഗ്ലാസുകൾ': 593,
#  'ട്രേയിൽ': 594,
#  'അരിഞ്ഞ': 595,
#  'ഫ്രിസ്\u200cബിയെ': 596,
#  'യുവാവ്': 597,
#  'കോട്ട്': 598,
#  'വീഞ്ഞ്': 599,
#  'സുന്ദരമായ': 600,
#  'ഗോപുരത്തിലെ': 601,
#  'കുതിരകൾ': 602,
#  'വിരൽ': 603,
#  'പിൻഭാഗം': 604,
#  'ഏഷ്യൻ': 605,
#  'ട്രാക്കിൽ': 606,
#  'മുകളിലൂടെ': 607,
#  'ആൻഡ്': 608,
#  'കത്ത്': 609,
#  'താഴേക്ക്': 610,
#  'പശുവിന്റെ': 611,
#  'സഞ്ചരിക്കുന്നു': 612,
#  'നിറമുളള': 613,
#  'ബ്രൊക്കോളി': 614,
#  'മൃഗങ്ങൾ': 615,
#  'കുളിമുറിയുടെ': 616,
#  'ലോഗോ': 617,
#  'സ്കേറ്റ്ബോർഡിലെ': 618,
#  'കാബിനറ്റ്': 619,
#  'ജാലകങ്ങൾ': 620,
#  'ഘടിപ്പിച്ചിരിക്കുന്നു': 621,
#  'മേൽക്കൂര': 622,
#  'അകലെ': 623,
#  'നരച്ച': 624,
#  'പിൻ': 625,
#  'കുപ്പായമുള്ള': 626,
#  'ബാക്ക്പാക്ക്': 627,
#  'വെളുത്തതും': 628,
#  'മുറി': 629,
#  'സോഫ': 630,
#  'പ്രദേശം': 631,
#  'ക്യാബ്': 632,
#  'നഗരത്തിലെ': 633,
#  'പാറകൾ': 634,
#  'പുരുഷനും': 635,
#  'അലമാരയിൽ': 636,
#  'മിറർ': 637,
#  'സ്ലാറ്റ്': 638,
#  'സർഫ്ബോർഡിലെ': 639,
#  'കൂമ്പാരം': 640,
#  'സ്റ്റാൻഡിൽ': 641,
#  'ബീജ്': 642,
#  'പൂശിയ': 643,
#  'തൂങ്ങിക്കിടക്കുന്നു': 644,
#  'അലങ്കാര': 645,
#  'മുകളിലാണ്': 646,
#  'പൂക്കളുള്ള': 647,
#  'കലത്തിൽ': 648,
#  'പോളിൽ': 649,
#  'വളഞ്ഞ': 650,
#  'വിളക്കുകൾ': 651,
#  'ഭുജം': 652,
#  'ചിമ്മിനി': 653,
#  'ശോഭയുള്ള': 654,
#  'വസ്ത്രത്തിൽ': 655,
#  'അക്കങ്ങൾ': 656,
#  'മതിലിനു': 657,
#  'സ്ഥലത്ത്': 658,
#  'പാർക്കിൽ': 659,
#  'ഭക്ഷണത്തിന്റെ': 660,
#  'വീട്ടിൽ': 661,
#  'ധ്രുവത്തിലെ': 662,
#  'കവർ': 663,
#  'പുല്ലിന്': 664,
#  'ചിത്രത്തിനായി': 665,
#  'വ്യത്യസ്ത': 666,
#  'സൈനിക': 667,
#  'വച്ചിരിക്കുന്ന': 668,
#  'ടാഗ്': 669,
#  'പുക': 670,
#  'ഷോർട്ട്സ്': 671,
#  'സ്നോ': 672,
#  'ചതുരാകൃതിയിലുള്ള': 673,
#  'കീബോർഡ്': 674,
#  'മഞ്ഞുമൂടിയ': 675,
#  'പൂച്ചയ്ക്ക്': 676,
#  'ഗ്ലാസിൽ': 677,
#  'ഡബിൾ': 678,
#  'ഡെക്കർ': 679,
#  'വൈൻ': 680,
#  'മൗസ്': 681,
#  'മേൽ': 682,
#  'നിലം': 683,
#  'മുറിച്ചു': 684,
#  'തലയിണകൾ': 685,
#  'വെള്ളത്തിന്': 686,
#  'കുളിമുറിയാണ്': 687,
#  'ബസുകൾ': 688,
#  'കീഴിൽ': 689,
#  'ടവറിൽ': 690,
#  'ബാറ്റർ': 691,
#  'പെട്ടിയിൽ': 692,
#  'പൂച്ചയാണ്': 693,
#  'തറയിലെ': 694,
#  'ഓടുന്ന': 695,
#  'ബ്ലെൻഡർ': 696,
#  'സ്നോബോർഡർ': 697,
#  'ആൺകുട്ടിയുടെ': 698,
#  'കടൽത്തീരത്താണ്': 699,
#  'ആകാശത്തിലെ': 700,
#  'മതിലിന്റെ': 701,
#  'അഴുക്ക്': 702,
#  'കുറച്ച്': 703,
#  'പശ്ചാത്തലത്തിലുള്ള': 704,
#  'പക്ഷിയാണ്': 705,
#  'കൈയിലുള്ള': 706,
#  'ബോർഡിലെ': 707,
#  'പുരുഷ': 708,
#  'കസേരകൾ': 709,
#  'ഓവൻ': 710,
#  'ഫലം': 711,
#  'കൺട്രോളർ': 712,
#  'നില': 713,
#  'ഈന്തപ്പന': 714,
#  'മരത്തിന്': 715,
#  'വശം': 716,
#  'ലൈൻ': 717,
#  'ചെടി': 718,
#  'രാത്രി': 719,
#  'പ്ലെയ്ഡ്': 720,
#  'ഭക്ഷണ': 721,
#  'ക്രോസ്': 722,
#  'സ്കീസ്': 723,
#  'സൂര്യൻ': 724,
#  'വലുതാണ്': 725,
#  'ചട്ടി': 726,
#  'ഫ്ലാറ്റ്': 727,
#  'ഡെസ്ക്': 728,
#  'നിറച്ച': 729,
#  'ക': 730,
#  'ചതുരം': 731,
#  'നിറയെ': 732,
#  'തിളങ്ങുന്നു': 733,
#  'കാറാണ്': 734,
#  'ചാര': 735,
#  'വാഹനത്തിന്റെ': 736,
#  'അഗ്രം': 737,
#  'അടുക്കളയിലെ': 738,
#  'ഇന്റീരിയർ': 739,
#  'തൂക്കിയിട്ട': 740,
#  'വലതുവശത്ത്': 741,
#  'ജാലകമുണ്ട്': 742,
#  'വരച്ച': 743,
#  'വാണിജ്യ': 744,
#  'വരി': 745,
#  'അഭിമുഖമായി': 746,
#  'ട്രാക്കുകൾ': 747,
#  'റോഡിന്': 748,
#  'പുഷ്പ': 749,
#  'ജാക്കറ്റിലുള്ള': 750,
#  'മേശപ്പുറത്തുണ്ട്': 751,
#  'മുറ്റത്ത്': 752,
#  'കപ്പിൽ': 753,
#  'ട്രിം': 754,
#  'കളിക്കാരന്റെ': 755,
#  'ചെടിയിൽ': 756,
#  'ഘടിപ്പിച്ചിരിക്കുന്ന': 757,
#  'കേക്കിൽ': 758,
#  'വൃദ്ധൻ': 759,
#  'ചോക്ലേറ്റ്': 760,
#  'തവിട്ടുനിറമുള്ള': 761,
#  'ടോയ്\u200cലറ്റിന്റെ': 762,
#  'ബൈക്കിൽ': 763,
#  'പുറകിലുള്ള': 764,
#  'ഗോപുരത്തിന്റെ': 765,
#  'സ്കേറ്റിംഗ്': 766,
#  'സ്കി': 767,
#  'ഇറങ്ങുന്നു': 768,
#  'ലൈറ്റുകളുള്ള': 769,
#  'ടി': 770,
#  'തൊപ്പിയും': 771,
#  'കളി': 772,
#  'കയറുന്ന': 773,
#  'ഹിമത്തിൽ': 774,
#  'ചെരുപ്പ്': 775,
#  'ബാത്ത്റൂം': 776,
#  'സ്കൈ': 777,
#  'സ്നോബോർഡ്': 778,
#  'ട്രെയിനിലെ': 779,
#  'വെള്ളത്തിലാണ്': 780,
#  'യൂണിഫോം': 781,
#  'ബോട്ടുകൾ': 782,
#  'സുരക്ഷാ': 783,
#  'ഉണങ്ങിയ': 784,
#  'ബസ്സിലെ': 785,
#  'പ്രദർശിപ്പിച്ചിരിക്കുന്നു': 786,
#  'പിസ്സയുടെ': 787,
#  'സമുദ്രത്തിൽ': 788,
#  'കാലുകൾ': 789,
#  'കുടിക്കുന്നു': 790,
#  'ചുരുണ്ട': 791,
#  'വാചകം': 792,
#  'ചെവിയിൽ': 793,
#  'തുരുമ്പിച്ച': 794,
#  'വാഴപ്പഴത്തിന്റെ': 795,
#  'പല്ല്': 796,
#  'മേയുന്നു': 797,
#  'കത്രിക': 798,
#  'പുഞ്ചിരിക്കുന്ന': 799,
#  'ടൈലുകൾ': 800,
#  'പ്ലാറ്റ്ഫോമിൽ': 801,
#  'മൃഗശാലയിലെ': 802,
#  'മുതിർന്ന': 803,
#  'നായ്ക്കൾ': 804,
#  'പഴം': 805,
#  'കടൽത്തീരത്തെ': 806,
#  'അക്ഷരങ്ങളിൽ': 807,
#  'കണ്ണുകൾ': 808,
#  'സമുദ്രത്തിലെ': 809,
#  'തിരമാലയിൽ': 810,
#  'സ്കീസിൽ': 811,
#  'വേവിച്ച': 812,
#  'കടലിൽ': 813,
#  'പൂശി': 814,
#  'സമുദ്രം': 815,
#  'ഓഫീസ്': 816,
#  'എസ്\u200cയുവി': 817,
#  'ഡ്രൈവിംഗ്': 818,
#  'കുടയുമായി': 819,
#  'നീന്തുന്നു': 820,
#  'ധ്രുവം': 821,
#  'സോസ്': 822,
#  'പട്ടിക': 823,
#  'തലകീഴായി': 824,
#  'ടെലിഫോൺ': 825,
#  'കട്ടിലിന്': 826,
#  'ചെറുതാണ്': 827,
#  'അടുത്താണ്': 828,
#  'മുഴുവൻ': 829,
#  'പരവതാനി': 830,
#  'പാവാട': 831,
#  'പാനീയം': 832,
#  'ജനാല': 833,
#  'സ്ത്രീയാണ്': 834,
#  'ലൈസൻസ്': 835,
#  'പറയുന്നു': 836,
#  'എഴുത്ത്': 837,
#  'വിൻഡോയിലെ': 838,
#  'വുഡൻ': 839,
#  'നിയന്ത്രണം': 840,
#  'കളർ': 841,
#  'റെയിലിംഗ്': 842,
#  'വഴി': 843,
#  'പ്രവേശന': 844,
#  'വളരുന്ന': 845,
#  'വെള്ളിയാണ്': 846,
#  'അടുപ്പിൽ': 847,
#  'തുണിയിൽ': 848,
#  'നിർമ്മിച്ചിരിക്കുന്നത്': 849,
#  'ടെയിൽ': 850,
#  'സ്ട്രീറ്റ്': 851,
#  'പള്ളി': 852,
#  'പേഴ്സ്': 853,
#  'കടൽത്തീരം': 854,
#  'ഇലകളുള്ള': 855,
#  'സീബ്രയിൽ': 856,
#  'മേഘങ്ങളുള്ള': 857,
#  'ഗ്രീൻ': 858,
#  'വേലിയിൽ': 859,
#  'ബെഞ്ചിന്റെ': 860,
#  'ലെഗ്': 861,
#  'ഷൂസ്': 862,
#  'പാറ്റേൺ': 863,
#  'നിറമുണ്ട്': 864,
#  'റിബൺ': 865,
#  'എന്ന്': 866,
#  'പറയുന്ന': 867,
#  'ജലത്തിന്റെ': 868,
#  'കോൺ': 869,
#  'വിന്റേജ്': 870,
#  'പാനൽ': 871,
#  'കാബിനറ്റിൽ': 872,
#  'ജലാശയം': 873,
#  'പാത': 874,
#  'ഷർട്ടിലുള്ള': 875,
#  'സ്യൂട്ടിലുള്ള': 876,
#  'പൊതിഞ്ഞ': 877,
#  'ഹൈഡ്രാന്റ്': 878,
#  'പേര്': 879,
#  'പുഞ്ചിരിക്കുന്നു': 880,
#  'സ്കേറ്റ്ബോർഡിലാണ്': 881,
#  'തീവണ്ടിയുടെ': 882,
#  'ലേബൽ': 883,
#  'കളിപ്പാട്ടം': 884,
#  'ലിഡ്': 885,
#  'സ്റ്റേഷനിൽ': 886,
#  'കടൽ': 887,
#  'മേൽക്കൂരയിൽ': 888,
#  'സ്ലൈസ്': 889,
#  'അലകൾ': 890,
#  'കൈറ്റ്സ്': 891,
#  'ഘടികാര': 892,
#  'ചൂണ്ടുന്ന': 893,
#  'കാണുന്നു': 894,
#  'ആൺകുട്ടികൾ': 895,
#  'പിടിച്ചിരിക്കുന്നു': 896,
#  'മധ്യത്തിൽ': 897,
#  'വ്യക്തവുമാണ്': 898,
#  'വായിക്കുന്ന': 899,
#  'ബസിന്': 900,
#  'യുദ്ധവിമാനം': 901,
#  'സൂപ്പ്': 902,
#  'സിറ്റി': 903,
#  'റേസിംഗ്': 904,
#  'യുവതി': 905,
#  'പൈ': 906,
#  'നിയോൺ': 907,
#  'തയ്യാറാണ്': 908,
#  'വ്യക്തിക്ക്': 909,
#  'റോമൻ': 910,
#  'രണ്ടു': 911,
#  'വച്ചിരിക്കുന്നു': 912,
#  'തുറക്കുക': 913,
#  'വാക്കുകൾ': 914,
#  'സെൽഫോൺ': 915,
#  'പുതിയ': 916,
#  'മാല': 917,
#  'ജോഡി': 918,
#  'വൃത്താകൃതിയിലാണ്': 919,
#  'മുട്ട': 920,
#  'ജന്മദിന': 921,
#  'ഉറങ്ങുന്നു': 922,
#  'കൊമ്പുകൾ': 923,
#  'കഷ്ണങ്ങൾ': 924,
#  'സ്\u200cക്രീൻ': 925,
#  'വെച്ചിരിക്കുന്ന': 926,
#  'അവരുടെ': 927,
#  'പാൽ': 928,
#  'അവർ': 929,
#  'പാണ്ട': 930,
#  'കുളിമുറി': 931,
#  'വയലിലെ': 932,
#  'പോലെ': 933,
#  'കുട്ടികളുടെ': 934,
#  'നിർത്തുക': 935,
#  'ചിത്രങ്ങൾ': 936,
#  'അതിന്റെ': 937,
#  'സ്കീയർമാർ': 938,
#  'സർഫറുകൾ': 939,
#  'മുൻഭാഗം': 940,
#  'തൊപ്പിയിൽ': 941,
#  'പ്രവർത്തിക്കുന്ന': 942,
#  'അറ്റം': 943,
#  'നീലയുമാണ്': 944,
#  'അവൾ': 945,
#  'സ്നോബോർഡിംഗ്': 946,
#  'അഞ്ച്': 947,
#  'പോകുന്ന': 948,
#  'കുടയുള്ള': 949,
#  'നല്ല': 950,
#  'നീലാകാശത്തിൽ': 951,
#  'ചിത്രത്തിലെ': 952,
#  'ബിയറിന്റെ': 953,
#  'കാർഡ്ബോർഡ്': 954,
#  'ജോലി': 955,
#  'ചക്രങ്ങൾ': 956,
#  'ഇവിടെ': 957,
#  'ചട്ടിയിൽ': 958,
#  'യാത്രാ': 959,
#  'മിഡ്': 960,
#  'ആനയാണ്': 961,
#  'ഹോം': 962,
#  'ആനകളുടെ': 963,
#  'വായുവിലെ': 964,
#  'ബെഡ്': 965,
#  'ശാന്തമായ': 966,
#  'നടത്തുന്ന': 967,
#  'ഓണാക്കി': 968,
#  'മടിയിൽ': 969,
#  'കസേരയുടെ': 970,
#  'തണലുള്ള': 971,
#  'പുസ്തക': 972,
#  'വശത്തെ': 973,
#  'ബർഗർ': 974,
#  'ഗ്രൂപ്പ്': 975,
#  'സ്ഥലം': 976,
#  'ഹൗസ്': 977,
#  'മേൽക്കൂരയുള്ള': 978,
#  'തിരശ്ശീല': 979,
#  'ഫോസെറ്റ്': 980,
#  'ഹോട്ടൽ': 981,
#  'സ്റ്റെയിൻലെസ്': 982,
#  'സ്റ്റാൻഡ്': 983,
#  'നിർത്തിയിട്ടിരിക്കുന്ന': 984,
#  'വാഹനങ്ങൾ': 985,
#  'ബൈക്കുകൾ': 986,
#  'പിന്നിലെ': 987,
#  'സ്കൂട്ടർ': 988,
#  'ബോക്സ്': 989,
#  'ദ്വാരം': 990,
#  'ചരക്ക്': 991,
#  'ചുറ്റുമുള്ള': 992,
#  'പാഡിൽ': 993,
#  'വെളുത്തതുമായ': 994,
#  'ജാലകത്തിന്': 995,
#  'കുളം': 996,
#  'റെസിഡൻഷ്യൽ': 997,
#  'ഇടതുവശത്തുള്ള': 998,
#  'മുറിക്കുക': 999,
#  'പൂത്തട്ടം': 1000,
#  ...}

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=[encoder_inputs,img_inputs],outputs=[encoder_outputs, state_h, state_c])
encoder_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 14)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 14, 512)      1551872     input_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 14, 512), (N 2099200     embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          2097664     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 14, 512), (N 2099200     lstm[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 14, 512)      0           dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 14, 1024)     0           lstm_1[0][0]
#                                                                  repeat_vector[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 14, 512), (N 3147776     concatenate[0][0]
# ==================================================================================================
# Total params: 10,995,712
# Trainable params: 10,995,712
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    encoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(maxlen_english,latent_dim))
print(decoder_inputs.get_shape)
#print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_4')>>

# %%
# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])
decoder_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 512)    2905088     input_4[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 512),  2099200     embedding_1[1][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 14, 512)]    0
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 5674)   2910762     lstm_3[1][0]
# ==================================================================================================
# Total params: 7,915,050
# Trainable params: 7,915,050
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    decoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
def decode_sequence(input_seq,img):
    img=img[np.newaxis,:]
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict([input_seq,img])
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sos']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eos'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eos'  or len(decoded_sentence.split()) >= (maxlen_malayalam -1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sos']) and i!=target_word_index['eos']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

for i in range(5):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
    print("\n")
# Out:
# Review: male surfer surfing in still in the ocean
# Original summary: ശാന്തമായ കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# Predicted summary:  തിരമാലയിൽ കയറുന്ന ഒരാൾ
#
#
# Review: it is an indoor scene
# Original summary: ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# Predicted summary:  മനുഷ്യന്റെ തലയിൽ കറുത്ത മാസ്ക്
#
#
# Review: computer screens turned on
# Original summary: കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# Predicted summary:  കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
#
#
# Review: man has short hair
# Original summary: മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# Predicted summary:  മനുഷ്യൻ സ്റ്റ യിൽ നിൽക്കുന്നു
#
#
# Review: photo album open on an adults lap
# Original summary: ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
# Predicted summary:  ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു

# %%
i=4
print("Review:",seq2text(x_tr[i]))
#print("Original summary:",seq2summary(y_tr[i]))
print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
plt.imshow(imagedata[i].astype(np.float32))
# Out:
# Review: photo album open on an adults lap
# Predicted summary:  ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു

# %%
i=0
print("Review:",seq2text(x_tr[i]))
print("Original summary:",seq2summary(y_tr[i]))
print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
plt.imshow(imagedata[i].astype(np.float32))
# Out:
# Review: male surfer surfing in still in the ocean
# Original summary: ശാന്തമായ കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# Predicted summary:  തിരമാലയിൽ കയറുന്ന ഒരാൾ

# %%
# !pip install sacrebleu
import sacrebleu
import random
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.7 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
temp_o=[]
temp_p=[]
for i in range(50):
    s=random.randint(0,len(y_tr)-1)
    temp_o.append(seq2summary(y_tr[s]))
    temp_p.append(decode_sequence(x_tr[s].reshape(1,maxlen_english),vgg_train_[s]))

bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 25.403027683651814

# %%
temp_o=[]
temp_p=[]
for i in range(10000):
    s=random.randint(0,len(y_tr)-1)
    temp_o.append(seq2summary(y_tr[s]))
    temp_p.append(decode_sequence(x_tr[s].reshape(1,maxlen_english),vgg_train_[s]))

bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 32.396260550602484

# %%
i=6
print("Review:",seq2text(x_tr[i]))
print("Original summary:",seq2summary(y_tr[i]))
print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
plt.imshow(imagedata[i].astype(np.float32))
# Out:
# Review: child in a stroller
# Original summary: ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി
# Predicted summary:  ഒരു കറുത്ത ട്രാഷ് ബാഗ്

# %%
i=3
print("Review:",seq2text(x_tr[i]))
print("Original summary:",seq2summary(y_tr[i]))
print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
plt.imshow(imagedata[i].astype(np.float32))
# Out:
# Review: man has short hair
# Original summary: മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# Predicted summary:  മനുഷ്യൻ സ്റ്റ യിൽ നിൽക്കുന്നു
