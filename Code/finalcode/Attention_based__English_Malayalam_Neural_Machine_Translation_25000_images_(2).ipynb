# %% [markdown]
# English_Malayalam_Multimodal_Machine_Translation

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import os
import cv2
import matplotlib.image as mp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Training data preprocessing

# %%
with open('/content/drive/My Drive/Main/train.mn.txt') as file:
    train_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/train.en.txt') as file:
    train_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/train_images.txt') as file:
    train_images = file.read().split('\n')

# %%
print(len(train_mal_txt))
print(len(train_eng_txt))
# Out:
# 28932
# 28933

# %%
train_mal_txt.pop()
train_eng_txt.pop()
train_eng_txt.pop()
# Out:
# '\t\t\t\t\t\t'

# %%
print(len(train_mal_txt))
print(len(train_eng_txt))
# Out:
# 28931
# 28931

# %%
print(train_mal_txt[-1])
print(train_eng_txt[-1])
# Out:
# ഒരു ട്രെയിനിന്റെ ഇടത് ടെയിൽ ലൈറ്റ്
# a train's left tail light

# %%
#Datacleaning by removing special characters
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r" ᠃", "", text)
    text = re.sub(r" ᠂", "", text)
    text = re.sub(r"-", " ", text)
    text = re.sub(r"<5>", "5", text)
    text = re.sub(r"“ ", "", text)
    text = re.sub(r" ”", "", text)
    text = re.sub(r"[+\.\!\/_,$%^*(+\"\']+|[+——！，〈〉《》。︱？?、．％~@#￥%……&*（）’]", "", text)
    text=text.rstrip()
    return text

# %%
with open('/content/drive/My Drive/Main/maltest.txt') as file:
   test_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/engtest.txt') as file:
   test_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/testimages.txt') as file:
    test_images = file.read().split('\n')

# %%
def remove(mal_txt,eng_txt):
        mal_txt.pop()
        eng_txt.pop()
        eng_txt.pop()
        #trainimages.pop()
        #trainimages,link
        print(len(mal_txt))
        print(len(eng_txt))
        #print(len(trainimages))
        #img_path=[]
        #for s in trainimages:
                 #img_path.append(link+s)
        #return mal_txt,eng_txt,train_images,img_path
        return mal_txt,eng_txt

# %%
trmal_df = pd.DataFrame(train_mal_txt, columns=['Malayalam']) 
treng_df = pd.DataFrame(train_eng_txt, columns=['English'])

# %%
trmal_text1 = trmal_df["Malayalam"].apply(clean_text)
treng_text1 = treng_df["English"].apply(clean_text)
trmal_text2 = list(trmal_text1.values)
treng_text2 = list(treng_text1.values)

# %%
trmal_temp=[]
for s in trmal_text2:
    trtemp="sos "+s+" eos"
    trmal_temp.append(trtemp)
#text2=[]
trmal_text2=trmal_temp
trmal_text2[1:10]
# Out:
# ['sos ഇത് ഒരു ഇൻഡോർ രംഗമാണ് eos',
#  'sos കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി eos',
#  'sos മനുഷ്യന് ചെറിയ മുടിയുണ്ട് eos',
#  'sos ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു eos',
#  'sos കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട് eos',
#  'sos ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി eos',
#  'sos ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ് eos',
#  'sos മതിൽ വെളുത്ത ചായം പൂശി eos',
#  'sos ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
trmalayalam_words = []
for i in trmal_text2:
    trmalayalam_words.append(len(i.split()))
sn.countplot(trmalayalam_words).set(title=' Sentence Length -Malayalam')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
trenglish_words = []
for j in treng_text2:
    trenglish_words.append(len(j.split()))
sn.countplot(trenglish_words).set(title=' Sentence Length -English')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
trmaxlen_malayalam = max(trmalayalam_words)
trmaxlen_english = max(trenglish_words)
print('Maximum sentence length-Malayalam :',trmaxlen_malayalam)
print('Maximum sentence length-English :',trmaxlen_english)
# Out:
# Maximum sentence length-Malayalam : 22
# Maximum sentence length-English : 24

# %% [markdown]
# Validation Data Preprocessing

# %%
with open('/content/drive/My Drive/Main/maldev.txt') as file:
    dev_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/endev.txt') as file:
    dev_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/devimage.txt') as file:
    dev_images = file.read().split('\n')

# %%
print(len(dev_mal_txt))
print(len(dev_eng_txt))
# Out:
# 999
# 1000

# %%
print(dev_mal_txt[-2])
print(dev_eng_txt[-2])
# Out:
# റാക്കറ്റ് പിടിച്ചിരിക്കുന്ന മനുഷ്യൻ

# %%
dev_mal_txt.pop()
dev_eng_txt.pop()
# Out:
# ''

# %%
dev_eng_txt.pop()
# Out:
# '\t\t\t\t\t\t'

# %%
print(len(dev_mal_txt))
print(len(dev_eng_txt))
# Out:
# 998
# 998

# %%
dmal_df = pd.DataFrame(dev_mal_txt, columns=['Malayalam']) 
deng_df = pd.DataFrame(dev_eng_txt, columns=['English'])

# %%
dmal_text1 = dmal_df["Malayalam"].apply(clean_text)
deng_text1 = deng_df["English"].apply(clean_text)
dmal_text2 = list(dmal_text1.values)
deng_text2 = list(deng_text1.values)

# %%
dmal_temp=[]
for s in dmal_text2:
    dtemp="sos "+s+" eos"
    dmal_temp.append(dtemp)
#text2=[]
dmal_text2=dmal_temp
dmal_text2[1:10]
# Out:
# ['sos ഒരു കെട്ടിടത്തിന്റെ വിൻഡോ eos',
#  'sos ഡ്രോയറുകളുള്ള ഇരുണ്ട ചാരനിറത്തിലുള്ള കമ്പ്യൂട്ടർ ഡെസ്ക് eos',
#  'sos നിലത്ത് നാല് കാലുകളുള്ള ഉരുക്ക് കസേര eos',
#  'sos തെരുവിൽ സൈക്കിൾ ചവിട്ടുന്ന മനുഷ്യൻ eos',
#  'sos ഈ കാറുകൾ അഴുക്കിൽ പാർക്ക് ചെയ്തിരിക്കുന്നു eos',
#  'sos ആകാശത്ത് വെളുത്ത മേഘങ്ങൾ eos',
#  'sos ഗ്ലാസ് വാതിലുകളുടെ ഗണം eos',
#  'sos പ്രൊജക്ടർ സ്ക്രീൻ ചുരുട്ടി വെച്ചിരിക്കുന്നു eos',
#  'sos ചാരനിറത്തിലുള്ള സ്വെറ്റർ ധരിച്ച മനുഷ്യൻ eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
dmalayalam_words = []
for i in dmal_text2:
    dmalayalam_words.append(len(i.split()))
sn.countplot(dmalayalam_words).set(title=' Sentence Length -Malayalam')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
denglish_words = []
for j in deng_text2:
    denglish_words.append(len(j.split()))
sn.countplot(denglish_words).set(title=' Sentence Length -English')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dmaxlen_malayalam = max(dmalayalam_words)
dmaxlen_english = max(denglish_words)
print('Maximum sentence length-Malayalam :',dmaxlen_malayalam)
print('Maximum sentence length-English :',dmaxlen_english)
# Out:
# Maximum sentence length-Malayalam : 13
# Maximum sentence length-English : 13

# %% [markdown]
# Test data preprocessing

# %%
with open('/content/drive/My Drive/Main/maltest.txt') as file:
   test_mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/engtest.txt') as file:
   test_eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/testimages.txt') as file:
    test_images = file.read().split('\n')

# %%
print(len(test_mal_txt))
print(len(test_eng_txt))
# Out:
# 1401
# 1401

# %%
test_mal_txt[-2]
# Out:
# 'റോഡിൽ ഇംഗ്ലീഷ് സിറ്റി ബസ്'

# %%
test_eng_txt[-2]
# Out:
# 'English city bus on the road\t'

# %%
test_mal_txt.pop()
test_eng_txt.pop()
# Out:
# ''

# %%
print(len(test_mal_txt))
print(len(test_eng_txt))
# Out:
# 1400
# 1400

# %%
ttmal_df = pd.DataFrame(test_mal_txt, columns=['Malayalam']) 
tteng_df = pd.DataFrame(test_eng_txt, columns=['English'])

# %%
ttmal_text1 = ttmal_df["Malayalam"].apply(clean_text)
tteng_text1 = tteng_df["English"].apply(clean_text)
ttmal_text2 = list(ttmal_text1.values)
tteng_text2 = list(tteng_text1.values)

# %%
ttmal_temp=[]
for s in ttmal_text2:
    tttemp="sos "+s+" eos"
    ttmal_temp.append(tttemp)
#text2=[]
ttmal_text2=ttmal_temp
ttmal_text2[1:10]
# Out:
# ['sos കത്തികൊണ്ട് കൗണ്ടറിൽ ഇരിക്കുന്ന കത്തി ബ്ലോക്ക് eos',
#  'sos ചട്ടിയിൽ രണ്ടാമത്തെ പിസ്സ eos',
#  'sos ബീജ് സ്റ്റെയർ വേ രണ്ടാം ലെവലിലേക്ക് പോകുന്നു eos',
#  'sos ടാൻ ഹൗസിലെ ഇളം നിറമുള്ള രണ്ടാം നില eos',
#  'sos കെട്ടിടങ്ങളുടെ രണ്ടാമത്തെ നിലയിലെ ബാൽക്കണി eos',
#  'sos രാത്രി സ്റ്റാന്റിലെ വിളക്ക് കട്ടിലിന്റെ ഇടതുവശത്ത് നിൽക്കുന്നു eos',
#  'sos നൈറ്റ് സ്റ്റാൻഡിന് മുകളിൽ ഒരു വെളുത്ത അലാറം ക്ലോക്ക് ഉണ്ട് eos',
#  'sos ഒരു കറുത്ത സംഗീത സ്റ്റാൻഡ് eos',
#  'sos തെരുവ് മുറിച്ചുകടക്കാൻ കാത്തിരിക്കുന്ന സ്ത്രീ eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
ttmalayalam_words = []
for i in ttmal_text2:
    ttmalayalam_words.append(len(i.split()))
sn.countplot(ttmalayalam_words).set(title=' Sentence Length -Malayalam')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ttenglish_words = []
for j in tteng_text2:
    ttenglish_words.append(len(j.split()))
sn.countplot(ttenglish_words).set(title=' Sentence Length -English')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ttmaxlen_malayalam = max(ttmalayalam_words)
ttmaxlen_english = max(ttenglish_words)
print('Maximum sentence length-Malayalam :',ttmaxlen_malayalam)
print('Maximum sentence length-English :',ttmaxlen_english)
# Out:
# Maximum sentence length-Malayalam : 15
# Maximum sentence length-English : 17

# %%
x_tt=tteng_text2
y_tt=ttmal_text2

# %% [markdown]
# Tokenizing

# %%
x_tr=treng_text2
y_tr=trmal_text2
x_val=deng_text2
y_val=dmal_text2

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
x_tokens = Tokenizer()
x_tokens.fit_on_texts(x_tr)
 1326, 161], [14, 5, 1, 98], [36, 4, 1, 120], [17, 455, 3, 61], [1, 1134, 4, 487, 1, 781], [15, 20, 7, 49], [14, 5, 1, 131], [777, 6, 2, 26], [48, 3, 1, 68], [15, 20, 1, 112, 13, 409], [1, 100, 11, 589, 6, 145], [1, 34, 94, 6, 2, 26], [2155, 614, 2, 143], [226, 5, 3, 40], [18, 342, 1, 16, 9, 13, 83], [34, 135, 4, 31], [1, 106, 9, 12, 368, 206], [1, 388, 4, 602, 193], [1, 451, 3, 92], [47, 3, 60, 4, 239], [88, 165, 6, 1, 357], [1, 58, 45, 156, 428, 162, 168], [14, 5, 1, 18], [8, 6, 1, 211, 865], [15, 37, 3, 1, 99], [1, 81, 5, 1326, 3, 1, 339], [8, 448, 1, 87, 4, 156, 102], [12, 833, 4210, 327], [2, 134, 3, 2, 137, 36], [13, 219, 6, 2, 520, 148], [14, 5, 1, 146], [1, 86, 2112, 122], [1344, 609, 102, 6, 365, 4, 44], [2, 232, 4, 2, 61], [466, 3, 1, 228, 226], [14, 5, 1, 22], [298, 3, 2, 41], [1, 288, 113, 17, 338], [1, 47, 6, 2, 87], [1, 43, 3, 1, 92], [16, 360, 3, 76], [8, 20, 10, 230], [2, 147, 5, 105, 16], [1, 222, 12, 127, 22], [1, 42, 53, 474, 3422], [15, 9, 40, 74, 3, 2, 110], [1, 12, 9, 7, 127, 22], [1, 199, 1083, 743], [15, 20, 7, 693], [111, 6, 137, 104], [1, 115, 53, 61], [1363, 3, 2, 44], [308, 391, 423], [537, 121, 205, 1053], [75, 11, 1912, 9, 413], [2, 867, 3, 2, 137, 626], [8, 6, 94], [12, 94], [1002, 6, 2, 26], [212, 31, 82, 3, 2, 72], [1, 10, 9, 106, 394], [227, 6, 677], [2, 109, 353], [292, 27, 2, 399], [2, 166, 5, 6, 10, 9, 7], [12, 126, 90, 4, 2, 89 ...

# %%
x_tokens.index_word
# Out:
# {1: 'a',
#  2: 'the',
#  3: 'on',
#  4: 'of',
#  5: 'is',
#  6: 'in',
#  7: 'white',
#  8: 'man',
#  9: 'and',
#  10: 'black',
#  11: 'with',
#  12: 'red',
#  13: 'blue',
#  14: 'this',
#  15: 'woman',
#  16: 'green',
#  17: 'brown',
#  18: 'person',
#  19: 'two',
#  20: 'wearing',
#  21: 'yellow',
#  22: 'sign',
#  23: 'train',
#  24: 'sky',
#  25: 'wall',
#  26: 'water',
#  27: 'are',
#  28: 'building',
#  29: 'an',
#  30: 'table',
#  31: 'people',
#  32: 'standing',
#  33: 'street',
#  34: 'large',
#  35: 'tennis',
#  36: 'head',
#  37: 'sitting',
#  38: 'part',
#  39: 'clock',
#  40: 'dog',
#  41: 'bus',
#  42: 'small',
#  43: 'light',
#  44: 'plate',
#  45: 'holding',
#  46: 'to',
#  47: 'cat',
#  48: 'grass',
#  49: 'shirt',
#  50: 'window',
#  51: 'has',
#  52: 'at',
#  53: 'orange',
#  54: 'side',
#  55: 'ground',
#  56: 'plane',
#  57: 'bear',
#  58: 'boy',
#  59: 'car',
#  60: 'top',
#  61: 'giraffe',
#  62: 'girl',
#  63: 'playing',
#  64: 'road',
#  65: 'snow',
#  66: 'baseball',
#  67: 'horse',
#  68: 'field',
#  69: 'bench',
#  70: 'air',
#  71: 'silver',
#  72: 'elephant',
#  73: 'front',
#  74: 'walking',
#  75: 'pizza',
#  76: 'tree',
#  77: 'zebra',
#  78: 'toilet',
#  79: 'hair',
#  80: 'down',
#  81: 'bird',
#  82: 'riding',
#  83: 'umbrella',
#  84: 'truck',
#  85: 'three',
#  86: 'skateboard',
#  87: 'picture',
#  88: 'wooden',
#  89: 'player',
#  90: 'hat',
#  91: 'parked',
#  92: 'pole',
#  93: 'ball',
#  94: 'boat',
#  95: 'frisbee',
#  96: 'gray',
#  97: 'pink',
#  98: 'motorcycle',
#  99: 'bed',
#  100: 'glass',
#  101: 'kite',
#  102: 'food',
#  103: 'flying',
#  104: 'hand',
#  105: 'by',
#  106: 'grey',
#  107: 'face',
#  108: 'floor',
#  109: 'metal',
#  110: 'beach',
#  111: 'phone',
#  112: 'long',
#  113: 'dark',
#  114: 'board',
#  115: 'young',
#  116: 'back',
#  117: 'surfboard',
#  118: 'tall',
#  119: 'tower',
#  120: 'sheep',
#  121: 'hanging',
#  122: 'up',
#  123: 'cow',
#  124: 'bike',
#  125: 'laptop',
#  126: 'color',
#  127: 'stop',
#  128: 'airplane',
#  129: 'traffic',
#  130: 'eating',
#  131: 'bowl',
#  132: 'bathroom',
#  133: 'chair',
#  134: 'helmet',
#  135: 'group',
#  136: 'clouds',
#  137: 'mans',
#  138: 'for',
#  139: 'sidewalk',
#  140: 'clear',
#  141: 'fire',
#  142: 'hydrant',
#  143: 'tracks',
#  144: 'looking',
#  145: 'it',
#  146: 'computer',
#  147: 'cake',
#  148: 'room',
#  149: 'next',
#  150: 'colored',
#  151: 'bat',
#  152: 'over',
#  153: 'round',
#  154: 'near',
#  155: 'men',
#  156: 'his',
#  157: 'child',
#  158: 'teddy',
#  159: 'from',
#  160: 'left',
#  161: 'giraffes',
#  162: 'door',
#  163: 'old',
#  164: 'desk',
#  165: 'fence',
#  166: 'photo',
#  167: 'kitchen',
#  168: 'open',
#  169: 'baby',
#  170: 'wood',
#  171: 'glasses',
#  172: 'vase',
#  173: 'ocean',
#  174: 'big',
#  175: 'racket',
#  176: 'that',
#  177: 'little',
#  178: 'mirror',
#  179: 'piece',
#  180: 'laying',
#  181: 'outside',
#  182: 'jacket',
#  183: 'out',
#  184: 'zebras',
#  185: 'skiing',
#  186: 'flowers',
#  187: 'surfing',
#  188: 'lights',
#  189: 'ceiling',
#  190: 'paper',
#  191: 'trees',
#  192: 'sink',
#  193: 'bananas',
#  194: 'right',
#  195: 'box',
#  196: 'letter',
#  197: 'court',
#  198: 'number',
#  199: 'purple',
#  200: 'cup',
#  201: 'behind',
#  202: 'post',
#  203: 'elephants',
#  204: 'bottle',
#  205: 'above',
#  206: 'tie',
#  207: 'one',
#  208: 'lamp',
#  209: 'tan',
#  210: 'leaves',
#  211: 'ski',
#  212: 'four',
#  213: 'cell',
#  214: 'game',
#  215: 'flag',
#  216: 'plastic',
#  217: 'brick',
#  218: 'eye',
#  219: 'couch',
#  220: 'screen',
#  221: 'cap',
#  222: 'bright',
#  223: 'lady',
#  224: 'background',
#  225: 'park',
#  226: 'ear',
#  227: 'skier',
#  228: 'cows',
#  229: 'double',
#  230: 'pants',
#  231: 'under',
#  232: 'tail',
#  233: 'wheel',
#  234: 'flower',
#  235: 'camera',
#  236: 'guy',
#  237: 'surfer',
#  238: 'there',
#  239: 'bag',
#  240: 'covered',
#  241: 'edge',
#  242: 'counter',
#  243: 'banana',
#  244: 'short',
#  245: 'parking',
#  246: 'taken',
#  247: 'pair',
#  248: 'city',
#  249: 'very',
#  250: 'sandwich',
#  251: 'horses',
#  252: 'scene',
#  253: 'made',
#  254: 'sand',
#  255: 'visible',
#  256: 'bunch',
#  257: 'suitcase',
#  258: 'fruit',
#  259: 'around',
#  260: 'gold',
#  261: 'engine',
#  262: 'seat',
#  263: 'through',
#  264: 'mountain',
#  265: 'soccer',
#  266: 'full',
#  267: 'shoes',
#  268: 'dogs',
#  269: 'house',
#  270: 'line',
#  271: 'bicycle',
#  272: 'hill',
#  273: 'view',
#  274: 'tv',
#  275: 'together',
#  276: 'inside',
#  277: 'striped',
#  278: 'women',
#  279: 'dirt',
#  280: 'some',
#  281: 'hot',
#  282: 'track',
#  283: 'nose',
#  284: 'colorful',
#  285: 'vehicle',
#  286: 'row',
#  287: 'suit',
#  288: 'womans',
#  289: 'station',
#  290: 'hands',
#  291: 'trunk',
#  292: 'these',
#  293: 'wine',
#  294: 'off',
#  295: 'apple',
#  296: 'jet',
#  297: 'eyes',
#  298: 'tire',
#  299: 'decker',
#  300: 'area',
#  301: 'shelf',
#  302: 'signs',
#  303: 'her',
#  304: 'slice',
#  305: 'against',
#  306: 'shorts',
#  307: 'wii',
#  308: 'skateboarder',
#  309: 'skateboarding',
#  310: 'shadow',
#  311: 'painted',
#  312: 'cloud',
#  313: 'reflection',
#  314: 'pot',
#  315: 'broccoli',
#  316: 'statue',
#  317: 'smiling',
#  318: 'swinging',
#  319: 'leg',
#  320: 'handle',
#  321: 'logo',
#  322: 'can',
#  323: 'birds',
#  324: 'snowboard',
#  325: 'refrigerator',
#  326: 'skis',
#  327: 'shoe',
#  328: 'being',
#  329: 'grazing',
#  330: 'pillow',
#  331: 'corner',
#  332: 'coffee',
#  333: 'animals',
#  334: 'wave',
#  335: 'tray',
#  336: 'several',
#  337: 'windows',
#  338: 'sunglasses',
#  339: 'plant',
#  340: 'many',
#  341: 'square',
#  342: 'carrying',
#  343: 'display',
#  344: 'oven',
#  345: 'driving',
#  346: 'leaning',
#  347: 'stand',
#  348: 'half',
#  349: 'knife',
#  350: 'tile',
#  351: 'bears',
#  352: 'microwave',
#  353: 'bridge',
#  354: 'stone',
#  355: 'body',
#  356: 'running',
#  357: 'lot',
#  358: 'sun',
#  359: 'letters',
#  360: 'leaf',
#  361: 'players',
#  362: 'mouse',
#  363: 'meter',
#  364: 'book',
#  365: 'middle',
#  366: 'rock',
#  367: 'animal',
#  368: 'neck',
#  369: 'kid',
#  370: 'bread',
#  371: 'remote',
#  372: 'cut',
#  373: 'jeans',
#  374: 'stuffed',
#  375: 'passenger',
#  376: 'television',
#  377: 'container',
#  378: 'towel',
#  379: 'lying',
#  380: 'batter',
#  381: 'roof',
#  382: 'stove',
#  383: 'van',
#  384: 'donut',
#  385: 'jumping',
#  386: 'other',
#  387: 'into',
#  388: 'pile',
#  389: 'dish',
#  390: 'slope',
#  391: 'doing',
#  392: 'basket',
#  393: 'day',
#  394: 'keyboard',
#  395: 'concrete',
#  396: 'runway',
#  397: 'fork',
#  398: 'cats',
#  399: 'boats',
#  400: 'frame',
#  401: 'coat',
#  402: 'luggage',
#  403: 'mouth',
#  404: 'stripes',
#  405: 'wet',
#  406: 'foreground',
#  407: 'base',
#  408: 'empty',
#  409: 'dress',
#  410: 'sleeping',
#  411: 'cars',
#  412: 'distance',
#  413: 'cheese',
#  414: 'american',
#  415: 'arm',
#  416: 'blonde',
#  417: 'boys',
#  418: 'motorcycles',
#  419: 'girls',
#  420: 'signal',
#  421: 'surf',
#  422: 'going',
#  423: 'trick',
#  424: 'its',
#  425: 'branch',
#  426: 'monitor',
#  427: 'ready',
#  428: 'fridge',
#  429: 'pan',
#  430: 'beautiful',
#  431: 'persons',
#  432: 'male',
#  433: 'attached',
#  434: 'faucet',
#  435: 'says',
#  436: 'river',
#  437: 'cutting',
#  438: 'wheels',
#  439: 'mid',
#  440: 'chairs',
#  441: 'crossing',
#  442: 'cabinet',
#  443: 'each',
#  444: 'flat',
#  445: 'during',
#  446: 'bottom',
#  447: 'scissors',
#  448: 'taking',
#  449: 'beside',
#  450: 'painting',
#  451: 'stripe',
#  452: 'oranges',
#  453: 'steel',
#  454: 'rail',
#  455: 'spot',
#  456: 'cover',
#  457: 'uniform',
#  458: 'daytime',
#  459: 'umbrellas',
#  460: 'writing',
#  461: 'set',
#  462: 'name',
#  463: 'watching',
#  464: 'chocolate',
#  465: 'doughnut',
#  466: 'tag',
#  467: 't',
#  468: 'kites',
#  469: 'shade',
#  470: 'rocks',
#  471: 'talking',
#  472: 'case',
#  473: 'framed',
#  474: 'toy',
#  475: 'zoo',
#  476: 'along',
#  477: 'sauce',
#  478: 'filled',
#  479: 'polar',
#  480: 'lettering',
#  481: 'patch',
#  482: 'time',
#  483: 'coming',
#  484: 'video',
#  485: 'foot',
#  486: 'apples',
#  487: 'pulling',
#  488: 'snowboarder',
#  489: 'lines',
#  490: 'like',
#  491: 'shiny',
#  492: 'couple',
#  493: 'skate',
#  494: 'drinking',
#  495: 'surface',
#  496: 'facing',
#  497: 'cart',
#  498: 'sweater',
#  499: 'design',
#  500: 'lid',
#  501: 'sea',
#  502: 'motorbike',
#  503: 'children',
#  504: 'roll',
#  505: 'herd',
#  506: 'turned',
#  507: 'trash',
#  508: 'buildings',
#  509: 'no',
#  510: 'tank',
#  511: 'posing',
#  512: 'cone',
#  513: 'wire',
#  514: 'cooked',
#  515: 'button',
#  516: 'controller',
#  517: 'word',
#  518: 'lit',
#  519: 'way',
#  520: 'living',
#  521: 'arrow',
#  522: 'circle',
#  523: 'pattern',
#  524: 'using',
#  525: 'center',
#  526: 'spoon',
#  527: 'about',
#  528: 'feet',
#  529: 'platform',
#  530: 'bun',
#  531: 'sofa',
#  532: 'planes',
#  533: 'stack',
#  534: 'bedroom',
#  535: 'railing',
#  536: 'numbers',
#  537: 'cross',
#  538: 'airport',
#  539: 'spotted',
#  540: 'asian',
#  541: 'golden',
#  542: 'carrots',
#  543: 'donuts',
#  544: 'vegetables',
#  545: 'glove',
#  546: 'porcelain',
#  547: 'sits',
#  548: 'across',
#  549: 'pavement',
#  550: 'mug',
#  551: 'backpack',
#  552: 'bikes',
#  553: 'store',
#  554: 'he',
#  555: 'waiting',
#  556: 'forest',
#  557: 'blanket',
#  558: 'written',
#  559: 'female',
#  560: 'cream',
#  561: 'cloudy',
#  562: 'wing',
#  563: 'pitcher',
#  564: 'trains',
#  565: 'toothbrush',
#  566: 'getting',
#  567: 'not',
#  568: 'cloth',
#  569: 'pool',
#  570: 'rug',
#  571: 'older',
#  572: 'fluffy',
#  573: 'ramp',
#  574: 'soup',
#  575: 'dirty',
#  576: 'kids',
#  577: 'section',
#  578: 'skiers',
#  579: 'public',
#  580: 'photograph',
#  581: 'ceramic',
#  582: 'reading',
#  583: 'something',
#  584: 'fixture',
#  585: 'five',
#  586: 'police',
#  587: 'wears',
#  588: 'end',
#  589: 'beer',
#  590: 'skating',
#  591: 'held',
#  592: 'buses',
#  593: 'horns',
#  594: 'waves',
#  595: 'snowboarding',
#  596: 'palm',
#  597: 'plaid',
#  598: 'tarmac',
#  599: 'print',
#  600: 'object',
#  601: 'school',
#  602: 'sliced',
#  603: 'carrot',
#  604: 'restaurant',
#  605: 'pieces',
#  606: 'shower',
#  607: 'plates',
#  608: 'home',
#  609: 'shaped',
#  610: 'fur',
#  611: 'sticker',
#  612: 'image',
#  613: 'throwing',
#  614: 'between',
#  615: 'stainless',
#  616: 'moving',
#  617: 'beak',
#  618: 'hole',
#  619: 'looks',
#  620: 'license',
#  621: 'mountains',
#  622: 'beige',
#  623: '2',
#  624: 'tomato',
#  625: 'safety',
#  626: 'finger',
#  627: 'their',
#  628: 'multi',
#  629: 'vest',
#  630: 'cellphone',
#  631: 'pillows',
#  632: 'jersey',
#  633: 'snowy',
#  634: 'holds',
#  635: 'chain',
#  636: 'blender',
#  637: 'adult',
#  638: 'dressed',
#  639: 'performing',
#  640: 'childs',
#  641: 'curtain',
#  642: 'night',
#  643: 'paint',
#  644: 'motor',
#  645: 'clean',
#  646: 'legs',
#  647: 'watch',
#  648: 'teeth',
#  649: 'all',
#  650: 'railroad',
#  651: 'woods',
#  652: 'crowd',
#  653: 'straw',
#  654: 'pointing',
#  655: 'outdoors',
#  656: 'goggles',
#  657: 'swing',
#  658: 'calm',
#  659: 'tiles',
#  660: 'sticking',
#  661: 'wild',
#  662: 'hit',
#  663: 'cement',
#  664: 'pen',
#  665: 'curb',
#  666: 'grassy',
#  667: 'style',
#  668: 'haired',
#  669: 'lake',
#  670: 'thin',
#  671: 'knob',
#  672: 'covering',
#  673: 'words',
#  674: 'close',
#  675: 'shining',
#  676: 'doughnuts',
#  677: 'different',
#  678: 'outfit',
#  679: 'flight',
#  680: 'graffiti',
#  681: 'seated',
#  682: 'carriage',
#  683: 'working',
#  684: 'meal',
#  685: 'tusk',
#  686: 'seen',
#  687: 'wrist',
#  688: 'lap',
#  689: 'suv',
#  690: 'doors',
#  691: 'bull',
#  692: 'taxi',
#  693: 'skirt',
#  694: 'tea',
#  695: 'decorative',
#  696: 'fan',
#  697: 'deep',
#  698: 'ears',
#  699: 'bush',
#  700: 'walk',
#  701: 'leather',
#  702: 'lawn',
#  703: 'windshield',
#  704: 'smoke',
#  705: 'worn',
#  706: 'meat',
#  707: 'closed',
#  708: 'ice',
#  709: 'birthday',
#  710: 'slices',
#  711: 'tabby',
#  712: 'tongue',
#  713: 'preparing',
#  714: 'french',
#  715: 'intersection',
#  716: 'rain',
#  717: 'banner',
#  718: 'traveling',
#  719: 'match',
#  720: 'tiled',
#  721: 'fashioned',
#  722: 'clocks',
#  723: 'opened',
#  724: 'neon',
#  725: 'liquid',
#  726: 'enclosure',
#  727: 'stacked',
#  728: 'eyeglasses',
#  729: 'towels',
#  730: 'jar',
#  731: 'skies',
#  732: 'setting',
#  733: 'vases',
#  734: 'brushing',
#  735: 'fries',
#  736: 'surfers',
#  737: 'carpet',
#  738: 'eaten',
#  739: 'lots',
#  740: 'poles',
#  741: 'pasture',
#  742: 'blond',
#  743: 'brush',
#  744: 'catching',
#  745: 'here',
#  746: 'vegetable',
#  747: 'furry',
#  748: 'six',
#  749: 'showing',
#  750: 'huge',
#  751: 'office',
#  752: 'upside',
#  753: 'broken',
#  754: 'rack',
#  755: 'scarf',
#  756: 'stairs',
#  757: 'outdoor',
#  758: 'tip',
#  759: 'hood',
#  760: 'yard',
#  761: 'log',
#  762: 'stick',
#  763: 'mounted',
#  764: 'spots',
#  765: 'curly',
#  766: 'resting',
#  767: 'kitten',
#  768: 'shore',
#  769: 'chicken',
#  770: 'ripe',
#  771: 'racquet',
#  772: 'guys',
#  773: 'toddler',
#  774: 'gate',
#  775: 'vehicles',
#  776: 'cab',
#  777: 'duck',
#  778: 'tub',
#  779: 'dining',
#  780: 'rectangular',
#  781: 'wagon',
#  782: 'circular',
#  783: 'place',
#  784: 'having',
#  785: 'headlight',
#  786: 'family',
#  787: 'collar',
#  788: 'bucket',
#  789: 'pepper',
#  790: 'cooking',
#  791: 'roman',
#  792: 'catcher',
#  793: 'bottles',
#  794: 'gloves',
#  795: 'lift',
#  796: 'egg',
#  797: 'panda',
#  798: 'floral',
#  799: 'monkey',
#  800: 'fresh',
#  801: 'candles',
#  802: 'toppings',
#  803: 'delicious',
#  804: 'drink',
#  805: 'cardboard',
#  806: 'items',
#  807: 'pictures',
#  808: 'rear',
#  809: 'band',
#  810: 'telephone',
#  811: 'paved',
#  812: 'machine',
#  813: 'holder',
#  814: 'cord',
#  815: 'walls',
#  816: 'interior',
#  817: 'curved',
#  818: 'church',
#  819: 'growing',
#  820: 'commercial',
#  821: 'dinner',
#  822: 'blurry',
#  823: 'sit',
#  824: 'vintage',
#  825: 'branches',
#  826: 'wetsuit',
#  827: 'net',
#  828: 'apron',
#  829: 'fighter',
#  830: 'electric',
#  831: 'play',
#  832: 'leash',
#  833: 'high',
#  834: 'path',
#  835: 'rider',
#  836: 'used',
#  837: 'sandwiches',
#  838: 'crust',
#  839: 'happy',
#  840: 'tent',
#  841: 'partially',
#  842: 'boots',
#  843: 'glowing',
#  844: 'thick',
#  845: 'dock',
#  846: 'scooter',
#  847: 'poster',
#  848: 'bar',
#  849: 'block',
#  850: 'trim',
#  851: 'panel',
#  852: 'napkin',
#  853: 'airplanes',
#  854: 'military',
#  855: 'floating',
#  856: 'puppy',
#  857: 'garbage',
#  858: 'sheet',
#  859: 'antique',
#  860: 'grill',
#  861: 'clothing',
#  862: 'subway',
#  863: 'platter',
#  864: 'cabinets',
#  865: 'race',
#  866: 'iron',
#  867: 'ring',
#  868: 'umpire',
#  869: 'as',
#  870: 'text',
#  871: 'bending',
#  872: 'tiny',
#  873: 'asphalt',
#  874: 'hotdog',
#  875: 'surfboards',
#  876: 'clothes',
#  877: 'rolling',
#  878: 'flags',
#  879: 'salad',
#  880: 'breakfast',
#  881: 'books',
#  882: 'pepperoni',
#  883: 'have',
#  884: 'boarding',
#  885: 'swimming',
#  886: 'busy',
#  887: 'decorated',
#  888: 'restroom',
#  889: 'kneeling',
#  890: 'steps',
#  891: 'forefront',
#  892: 'horn',
#  893: 'rope',
#  894: 'bare',
#  895: 'shape',
#  896: 'clay',
#  897: 'glazed',
#  898: 'label',
#  899: 'ship',
#  900: 'soda',
#  901: 'mostly',
#  902: 'pie',
#  903: 'necklace',
#  904: 'bags',
#  905: 'frosting',
#  906: 'link',
#  907: 'while',
#  908: 'plain',
#  909: 'they',
#  910: 'wings',
#  911: 'goat',
#  912: 'sprinkles',
#  913: 'skater',
#  914: 'single',
#  915: 'hitting',
#  916: 'urinal',
#  917: 'railway',
#  918: 'dessert',
#  919: 'rice',
#  920: 'landing',
#  921: 'colour',
#  922: 'plants',
#  923: 'parrot',
#  924: 'highway',
#  925: 'paddle',
#  926: 'trail',
#  927: 'juice',
#  928: 'rainbow',
#  929: 'slat',
#  930: 'entrance',
#  931: 'work',
#  932: 'kettle',
#  933: 'balcony',
#  934: 'stopped',
#  935: 'shot',
#  936: 'patio',
#  937: 'shop',
#  938: 'stool',
#  939: 'shaker',
#  940: 'icing',
#  941: 'falling',
#  942: 'hay',
#  943: 'dead',
#  944: 'winter',
#  945: 'lunch',
#  946: 'socks',
#  947: 'control',
#  948: 'headlights',
#  949: 'propeller',
#  950: 'bent',
#  951: 'be',
#  952: 'dot',
#  953: 'touching',
#  954: 'country',
#  955: 'rocky',
#  956: 'mini',
#  957: 'bow',
#  958: 'rusted',
#  959: 'checkered',
#  960: 'tomatoes',
#  961: 'suitcases',
#  962: 'mound',
#  963: 'baked',
#  964: 'power',
#  965: 'cattle',
#  966: 'lighthouse',
#  967: 'wind',
#  968: 'countertop',
#  969: 'perched',
#  970: 'rusty',
#  971: 'figure',
#  972: 'pocket',
#  973: 'sleeve',
#  974: 'star',
#  975: 'who',
#  976: 'mark',
#  977: 'stroller',
#  978: 'horizon',
#  979: 'do',
#  980: 'medium',
#  981: 'cage',
#  982: 'butter',
#  983: 'sill',
#  984: 'multicolored',
#  985: 'art',
#  986: 'bushes',
#  987: 'ornate',
#  988: 'walkway',
#  989: 'terminal',
#  990: 'fireplace',
#  991: 'candle',
#  992: 'stuff',
#  993: 'aircraft',
#  994: 'hard',
#  995: 'trolley',
#  996: 'meters',
#  997: 'key',
#  998: 'midair',
#  999: 'pulled',
#  1000: 'games',
#  ...}

# %%
reverse_source_word_index=x_tokens.index_word
reverse_source_word_index[2227]
# Out:
# 'indoor'

# %%
#padding with post (appending zeros at the end to equalize sentence length)
from keras.preprocessing.sequence import pad_sequences
x_tr = pad_sequences(x_tr,maxlen = trmaxlen_english,padding = 'post')
x_val = pad_sequences(x_val,maxlen = trmaxlen_english,padding = 'post')

# +1 for padding 
x_voc_size   =  len(x_tokens.word_index) +1
print("No of unique words in English",x_voc_size)
# Out:
# No of unique words in English 5570

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
y_tokens = Tokenizer()
y_tokens.fit_on_texts(y_tr)
y_tr = y_tokens.texts_to_sequences(y_tr)
y_val = y_tokens.texts_to_sequences(y_val)
print('x_tr:',y_tr)
print('x_val:',y_val)
# Out:
# x_tr: [[1, 974, 1376, 4856, 1158, 672, 287, 2], [1, 62, 3, 3335, 3336, 2], [1, 147, 2631, 1377, 2], [1, 311, 25, 263, 2], [1, 288, 4857, 4858, 1032, 4859, 2], [1, 4, 4860, 3, 73, 4861, 2], [1, 3, 4862, 79, 2], [1, 119, 160, 4863, 2], [1, 131, 5, 443, 1159, 2], [1, 12, 18, 21, 7, 19, 22, 2], [1, 975, 1378, 6, 2], [1, 27, 1095, 4864, 2], [1, 206, 462, 801, 2], [1, 4865, 3, 4866, 2], [1, 3, 5, 384, 853, 2], [1, 3337, 80, 1096, 1506, 2], [1, 1097, 95, 906, 29, 2], [1, 12, 3338, 8, 432, 1507, 2], [1, 3, 38, 11, 31, 2], [1, 4867, 57, 28, 2], [1, 4868, 134, 224, 2], [1, 976, 360, 2], [1, 3, 38, 11, 31, 2], [1, 802, 71, 2], [1, 3, 4, 26, 14, 2], [1, 3, 29, 69, 1914, 2], [1, 269, 1690, 166, 2], [1, 977, 139, 2], [1, 3, 729, 80, 149, 2], [1, 4, 270, 730, 2], [1, 3, 29, 457, 4869, 1160, 1379, 2], [1, 7, 76, 385, 88, 272, 2], [1, 90, 76, 2], [1, 4870, 2632, 109, 2], [1, 24, 3339, 3, 4, 76, 2], [1, 236, 49, 2], [1, 3, 514, 3, 3340, 37, 2], [1, 3, 111, 70, 1033, 2], [1, 3, 38, 11, 31, 2], [1, 1915, 40, 57, 176, 60, 490, 2], [1, 2218, 3341, 473
, 153, 2], [1, 9439, 10, 275, 2], [1, 27, 2], [1, 3, 182, 742, 1122, 2], [1, 1548, 785, 5480, 799, 125, 2], [1, 239, 323, 2], [1, 485, 584, 2], [1, 62, 3, 1586, 2], [1, 369, 336, 2], [1, 3, 145, 129, 176, 664, 2], [1, 960, 3, 48, 2], [1, 3, 921, 3, 412, 2], [1, 2335, 7, 334, 2], [1, 4, 337, 9, 8, 2], [1, 159, 7, 2], [1, 3, 13, 233, 41, 2], [1, 3, 25, 37, 997, 2], [1, 169, 196, 527, 968, 2], [1, 68, 43, 39, 3, 233, 41, 2], [1, 3, 208, 372, 456, 2], [1, 5, 985, 9, 6, 2], [1, 82, 246, 165, 2] ...

# %%
target_word_index[2227]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-760b27a13bb7> in <module>()
# ----> 1 target_word_index[2227]
#
# KeyError: 2227

# %%
#padding with post (appending zeros at the end to equalize sentence length)
from keras.preprocessing.sequence import pad_sequences
y_tr = pad_sequences(y_tr,maxlen = trmaxlen_malayalam,padding = 'post')
y_val = pad_sequences(y_val,maxlen = trmaxlen_malayalam,padding = 'post')

# +1 for padding 
y_voc_size   =  len(y_tokens.word_index) +1
print("No of unique words in English",y_voc_size)
# Out:
# No of unique words in English 11314

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
x_tokens = Tokenizer()
x_tokens.fit_on_texts(x_tt)
x_tt = x_tokens.texts_to_sequences(x_tt)
print('x_tt:',x_tt)
# Out:
# x_tt: [[121, 12, 596, 35], [131, 12, 56, 3, 597, 16, 132, 7, 93], [2, 11, 400, 7, 2, 598], [401, 599, 402, 104, 21, 11, 147], [162, 283, 16, 600, 148, 11, 44], [284, 3, 1, 11, 94, 4, 1, 285], [105, 3, 1, 66, 5, 21, 1, 106, 4, 1, 113], [2, 13, 403, 69, 14, 3, 39, 4, 1, 66, 5], [2, 22, 404, 5], [1, 54, 14, 83, 21, 9, 1, 41], [601, 31, 25, 8], [114, 3, 1, 6], [53, 403, 69, 3, 1, 66, 5], [1, 17, 602, 7, 34], [2, 45, 5, 77, 21, 2, 35], [33, 603, 37, 49, 6, 75], [17, 20, 4, 604], [605, 405, 21, 1, 11, 44], [2, 225, 3, 2, 5], [406, 187, 133, 38], [57, 3, 1, 11, 147], [1, 6, 14, 149, 4, 122], [53, 26, 188, 163, 2, 188, 606], [226, 607, 608, 9, 164, 1, 41], [407, 5, 3, 1, 78], [5, 7, 1, 227], [2, 95, 14, 228, 7, 76, 4, 1, 115, 12], [9, 3, 39, 4, 134], [11, 116, 228, 3, 1, 41], [609, 14, 135, 7, 58, 15, 610, 19], [2, 23, 17, 20], [165, 3, 11, 44, 4, 63], [22, 408, 69, 3, 66, 5], [2, 11, 611, 7, 227], [123, 3, 66, 5], [612, 4, 229, 3, 113, 5], [1, 131, 12, 14, 286], [287, 14, 3, 2, 67, 5], [22, 67, 287, 5], [613, 288, 3, 1, 66, 5], [614, 45, 66, 5], [615, 616, 3, 2, 136, 5], [36, 57, 83, 21, 9], [24, 3, 617, 5], [409, 24,
, 429, 137, 3, 5], [54, 306, 239, 21, 9, 41], [13, 107, 117, 3, 6], [2, 240, 14, 649, 7, 2, 5], [13, 430, 3, 2, 5], [33, 9, 90, 118], [650, 3, 2, 28, 199], [27, 10, 6], [1, 71, 76, 84, 3, 1, 11, 147, 4, 1, 89], [50, 100, 241, 38], [45, 12, 15, 13, 283, 16, 651, 22, 307], [33, 9, 90, 118, 652, 431], [9, 3, 39, 4, 308], [11, 33, 118, 7, 151], [1, 29, 24, 16, 23, 15, 34, 19], [2, 169, 12, 47, 242], [54, 91, 2, 9, 3, 304, 432], [2, 60, 83, 21, 9, 1, 41], [11, 243, 92, 3, 126], [97, 9, 3, 2, 29, 653, 39], [401, 75, 105, 3, 5], [237, 125, 654, 236, 40, 655, 656], [50, 48, 7, 1, 433, 64], [59, 14, 172, 309, 4, 2, 32], [244, 233, 3, 1, 6], [2, 18, 434, 657], [1, 12, 4, 435], [2, 121, 12,  ...

# %%
from keras.preprocessing.sequence import pad_sequences
x_tt = pad_sequences(x_tt,maxlen = trmaxlen_english,padding = 'post')

# %%
y_tokens = Tokenizer()
y_tokens.fit_on_texts(y_tt)
y_tt = y_tokens.texts_to_sequences(y_tt)

# %%
y_tt = pad_sequences(y_tt,maxlen = trmaxlen_english,padding = 'post')

# %%
pip install keras-applications
# Out:
# Collecting keras-applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.8 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications) (1.5.2)
# Installing collected packages: keras-applications
# Successfully installed keras-applications-1.0.8

# %%
import pandas as pd
import pickle
import numpy as np
import os
import keras
import tensorflow
from keras_applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D,BatchNormalization,Flatten,Input, Convolution2D, Dropout, LSTM, TimeDistributed, Embedding, Bidirectional, Activation, RepeatVector,Concatenate
from keras.models import Sequential, Model
from keras.utils import np_utils
import random
from keras.preprocessing import image, sequence
import matplotlib.pyplot as plt
import keras
from keras import backend as K 
import gensim
from numpy import *
import numpy as np
import pandas as pd 
import re
from tensorflow.keras.applications.vgg16 import VGG16
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed,Conv2D,MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings

# %%
x_voc=x_voc_size
y_voc=y_voc_size

# %%
x_voc
# Out:
# 5570

# %%
y_voc
# Out:
# 11314

# %%
#Model
x_voc=x_voc_size
y_voc=y_voc_size
latent_dim = 512
embedding_dim=512
#Encoder
encoder_inputs = Input(shape=(trmaxlen_english,))
#The model will take as input an integer matrix of size (batch,input_length)and the largest integer (i.e. word index) in the input
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)
print(encoder_inputs.get_shape)
print(enc_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 24) dtype=float32 (created by layer 'input_1')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 24, 512) dtype=float32 (created by layer 'embedding')>>

# %%
#encoder LSTM Layer 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
#The dimension of each state equals to the LSTM unit number
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)
print(encoder_lstm1.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 24, 512), (None, 512), (None, 512)]

# %%
#LSTM layer 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)
print(encoder_lstm2.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 24, 512), (None, 512), (None, 512)]

# %%
#LSTM layer 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
print(encoder_lstm3.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 24, 512), (None, 512), (None, 512)]

# %%
#Decoder
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)
print(decoder_inputs.get_shape)
print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_2')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None, 512) dtype=float32 (created by layer 'embedding_1')>>

# %%
#Decoder LSTM layer1
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])
print(decoder_lstm.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, None, 512), (None, 512), (None, 512)]

# %%
import tensorflow as tf
import os
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
import keras
from keras import backend as K
from keras import activations, initializers, regularizers, constraints, metrics
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import (Dense, Dropout, Activation, Flatten, Reshape, Layer,
                          BatchNormalization, LocallyConnected2D,
                          ZeroPadding2D, Conv2D, MaxPooling2D, Conv2DTranspose,
                          GaussianNoise, UpSampling2D, Input)
#from keras.utils import conv_utils, multi_gpu_model
from keras.layers import Lambda
#from keras.engine import Layer, InputSpec
#from keras.legacy import interfaces

# %%
class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state
            inputs: (batchsize * 1 * de_in_dim)
            states: (batchsize * 1 * de_latent_dim)
            """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch size * en_seq_len * latent_dim
            W_a_dot_s = K.dot(encoder_out_seq, self.W_a)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>', U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            Ws_plus_Uh = K.tanh(W_a_dot_s + U_a_dot_h)
            if verbose:
                print('Ws+Uh>', Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.squeeze(K.dot(Ws_plus_Uh, self.V_a), axis=-1)
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """

            assert_msg = "States must be an iterable. Got {} of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        fake_state_c = K.sum(encoder_out_seq, axis=1)
        fake_state_e = K.sum(encoder_out_seq, axis=2)  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# %%
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# %%
#dense = Dense(fr_vsize, activation='softmax', name='softmax_layer')
#dense_time = TimeDistributed(dense, name='time_distributed_layer')
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)
#decoder_output = dense_time(decoder_concat_input)
print(decoder_dense.output_shape)
# Out:
# (None, None, 11314)

# %%
model = Model([encoder_inputs,decoder_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 24)]         0           []
#
#  embedding (Embedding)          (None, 24, 512)      2851840     ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 24, 512),    2099200     ['embedding[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 24, 512),    2099200     ['lstm[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  embedding_1 (Embedding)        (None, None, 512)    5792768     ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 24, 512),    2099200     ['lstm_1[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  lstm_3 (LSTM)                  [(None, None, 512),  2099200     ['embedding_1[0][0]',
#                                  (None, 512),                     'lstm_2[0][1]',
#                                  (None, 512)]                     'lstm_2[0][2]']
#
#  attention_layer (AttentionLaye  ((None, None, 512),  524800     ['lstm_2[0][0]',
#  r)                              (None, None, 24))                'lstm_3[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 1024)   0           ['lstm_3[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  time_distributed (TimeDistribu  (None, None, 11314)  11596850   ['concat_layer[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 29,163,058
# Trainable params: 29,163,058
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint = ModelCheckpoint("/content/drive/My Drive/Main/modelnmtattention", monitor='val_accuracy')

early_stopping = EarlyStopping(monitor='val_accuracy', patience=5)

callbacks_list = [checkpoint, early_stopping]

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]),epochs=100,batch_size=512,callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 57/57 [==============================] - ETA: 0s - loss: 2.0282 - accuracy: 0.7867INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 62s 905ms/step - loss: 2.0282 - accuracy: 0.7867 - val_loss: 1.2302 - val_accuracy: 0.8411
# Epoch 2/100
# 57/57 [==============================] - ETA: 0s - loss: 1.2918 - accuracy: 0.8312INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 50s 885ms/step - loss: 1.2918 - accuracy: 0.8312 - val_loss: 1.1634 - val_accuracy: 0.8468
# Epoch 3/100
# 57/57 [==============================] - ETA: 0s - loss: 1.1934 - accuracy: 0.8407INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 50s 876ms/step - loss: 1.1934 - accuracy: 0.8407 - val_loss: 1.1070 - val_accuracy: 0.8506
# Epoch 4/100
# 57/57 [==============================] - ETA: 0s - loss: 1.1180 - accuracy: 0.8494INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 867ms/step - loss: 1.1180 - accuracy: 0.8494 - val_loss: 1.0708 - val_accuracy: 0.8542
# Epoch 5/100
# 57/57 [==============================] - ETA: 0s - loss: 1.0679 - accuracy: 0.8553INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 863ms/step - loss: 1.0679 - accuracy: 0.8553 - val_loss: 1.0508 - val_accuracy: 0.8554
# Epoch 6/100
# 57/57 [==============================] - ETA: 0s - loss: 1.0229 - accuracy: 0.8584INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 862ms/step - loss: 1.0229 - accuracy: 0.8584 - val_loss: 1.0270 - val_accuracy: 0.8579
# Epoch 7/100
# 57/57 [==============================] - ETA: 0s - loss: 0.9863 - accuracy: 0.8609INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 50s 881ms/step - loss: 0.9863 - accuracy: 0.8609 - val_loss: 1.0088 - val_accuracy: 0.8604
# Epoch 8/100
# 57/57 [==============================] - ETA: 0s - loss: 0.9534 - accuracy: 0.8631INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 863ms/step - loss: 0.9534 - accuracy: 0.8631 - val_loss: 0.9975 - val_accuracy: 0.8615
# Epoch 9/100
# 57/57 [==============================] - ETA: 0s - loss: 0.9235 - accuracy: 0.8650INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 50s 884ms/step - loss: 0.9235 - accuracy: 0.8650 - val_loss: 0.9822 - val_accuracy: 0.8620
# Epoch 10/100
# 57/57 [==============================] - ETA: 0s - loss: 0.8940 - accuracy: 0.8669INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 860ms/step - loss: 0.8940 - accuracy: 0.8669 - val_loss: 0.9714 - val_accuracy: 0.8641
# Epoch 11/100
# 57/57 [==============================] - ETA: 0s - loss: 0.8646 - accuracy: 0.8693INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s
FO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 50s 880ms/step - loss: 0.0678 - accuracy: 0.9842 - val_loss: 0.7051 - val_accuracy: 0.9059
# Epoch 47/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9852INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 856ms/step - loss: 0.0638 - accuracy: 0.9852 - val_loss: 0.7071 - val_accuracy: 0.9050
# Epoch 48/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9861INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 50s 879ms/step - loss: 0.0602 - accuracy: 0.9861 - val_loss: 0.7051 - val_accuracy: 0.9042
# Epoch 49/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9872INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 48s 855ms/step - loss: 0.0565 - accuracy: 0.9872 - val_loss: 0.7107 - val_accuracy: 0.9048
# Epoch 50/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9878INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 49s 867ms/step - loss: 0.0537 - accuracy: 0.9878 - val_loss: 0.7096 - val_accuracy: 0.9046
# Epoch 51/100
# 57/57 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9884INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Main/modelnmtattention/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f757c4650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef8650d90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2ef85f35d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7f2f77bbb750> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 57/57 [==============================] - 48s 852ms/step - loss: 0.0508 - accuracy: 0.9884 - val_loss: 0.7121 - val_accuracy: 0.9053

# %%
import keras
from matplotlib import pyplot as plt
#history = model1.fit(train_x, train_y,validation_split = 0.1, epochs=50, batch_size=4)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save ("/content/drive/My Drive/Main/modelnmat.h5")

# %%
from keras import models    
model = models.load_model("/content/drive/My Drive/Main/modelnmt")
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
from keras.utils.vis_utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
y_tokens

# %%
reverse_target_word_index=y_tokens.index_word
len(reverse_target_word_index)
# Out:
# 11313

# %%
x_tokens.index_word
# Out:
# {}

# %%
reverse_source_word_index=x_tokens.index_word
len(reverse_source_word_index)
# Out:
# 5569

# %%
target_word_index=y_tokens.word_index
len(target_word_index)
# Out:
# 11313

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=[encoder_inputs],outputs=[encoder_outputs, state_h, state_c])
encoder_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24)]              0
#
#  embedding (Embedding)       (None, 24, 512)           2851840
#
#  lstm (LSTM)                 [(None, 24, 512),         2099200
#                               (None, 512),
#                               (None, 512)]
#
#  lstm_1 (LSTM)               [(None, 24, 512),         2099200
#                               (None, 512),
#                               (None, 512)]
#
#  lstm_2 (LSTM)               [(None, 24, 512),         2099200
#                               (None, 512),
#                               (None, 512)]
#
# =================================================================
# Total params: 9,149,440
# Trainable params: 9,149,440
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    encoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
encoder_inf_states=Input(shape=(trmaxlen_english,512,))
decoder_hidden_state_input = Input(shape=(trmaxlen_english,latent_dim))
print(decoder_inputs.get_shape)
#print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_2')>>

# %%
# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])
attn_inf_out, attn_inf_states = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_inf_out])
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])
decoder_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding_1 (Embedding)        (None, None, 512)    5792768     ['input_2[0][0]']
#
#  input_3 (InputLayer)           [(None, 512)]        0           []
#
#  input_4 (InputLayer)           [(None, 512)]        0           []
#
#  lstm_3 (LSTM)                  [(None, None, 512),  2099200     ['embedding_1[1][0]',
#                                  (None, 512),                     'input_3[0][0]',
#                                  (None, 512)]                     'input_4[0][0]']
#
#  input_6 (InputLayer)           [(None, 24, 512)]    0           []
#
#  attention_layer (AttentionLaye  ((None, None, 512),  524800     ['input_6[0][0]',
#  r)                              (None, None, 24))                'lstm_3[1][0]']
#
#  concat (Concatenate)           (None, None, 1024)   0           ['lstm_3[1][0]',
#                                                                   'attention_layer[1][0]']
#
#  time_distributed (TimeDistribu  (None, None, 11314)  11596850   ['concat[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 20,013,618
# Trainable params: 20,013,618
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    decoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
def decode_sequence(input_seq):
    #img=img[np.newaxis,:]
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict([input_seq])
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sos']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eos'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eos'  or len(decoded_sentence.split()) >= (trmaxlen_malayalam -1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict([input_seq])
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sos']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eos'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eos'  or len(decoded_sentence.split()) >= (trmaxlen_malayalam -1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sos']) and i!=target_word_index['eos']):
            #print(i)
            newString=newString+reverse_target_word_index[i]+' '
            #print(newString)
    return newString

# %%
def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
seq2summary(x_tr[1])
# Out:
# 'സ്ത്രീയുടെ വെളുത്ത വ്യക്തി കുറ്റിച്ചെടി പൂക്കൾ '

# %%
for i in range(25):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,trmaxlen_english)))
    print("\n")
# Out:
# Review: male surfer surfing in still in the ocean
# Original summary: ശാന്തമായ കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# Predicted summary:  ശാന്തമായ കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
#
#
# Review: it is an indoor scene
# Original summary: ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# Predicted summary:  ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
#
#
# Review: computer screens turned on
# Original summary: കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# Predicted summary:  കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
#
#
# Review: man has short hair
# Original summary: മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# Predicted summary:  ദ്വീപ് ബീച്ച് രംഗം
#
#
# Review: photo album open on an adults lap
# Original summary: ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
# Predicted summary:  ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
#
#
# Review: there is a group of girls beside the black car
# Original summary: കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട്
# Predicted summary:  കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട്
#
#
# Review: child in a stroller
# Original summary: ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി
# Predicted summary:  ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി
#
#
# Review: tall metal lightpost
# Original summary: ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ്
# Predicted summary:  ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ്
#
#
# Review: wall is painted white
# Original summary: മതിൽ വെളുത്ത ചായം പൂശി
# Predicted summary:  മതിൽ വെളുത്ത ചായം പൂശി
#
#
# Review: there are several pictures on the wall
# Original summary: ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ
# Predicted summary:  ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ
#
#
# Review: woman facing the ocean
# Original summary: സമുദ്രം അഭിമുഖീകരിക്കുന്ന സ്ത്രീ
# Predicted summary:  സമുദ്രം അഭിമുഖീകരിക്കുന്ന സ്ത്രീ
#
#
# Review: this is an office layout
# Original summary: ഇതൊരു ഓഫീസ് രേഖാചിത്രം
# Predicted summary:  ഇതൊരു ഓഫീസ് രേഖാചിത്രം
#
#
# Review: four metallic chairs
# Original summary: നാല് ലോഹത്തിന്റെ കസേരകൾ
# Predicted summary:  നാല് ലോഹത്തിന്റെ കസേരകൾ
#
#
# Review: clutter is on a table
# Original summary: കോലാഹലം ഒരു മേശപ്പുറത്താണ്
# Predicted summary:  കോലാഹലം ഒരു മേശപ്പുറത്താണ്
#
#
# Review: a white microwave oven
# Original summary: ഒരു വെളുത്ത മൈക്രോവേവ് ഓവൻ
# Predicted summary:  ഒരു കറുത്ത ട്രാഷ് ബാഗ്
#
#
# Review: white suv driving through intersection
# Original summary: കവലയിലൂടെ വൈറ്റ് എസ്‌യുവി ഡ്രൈവിംഗ്
# Predicted summary:  കവലയിലൂടെ വൈറ്റ് എസ്‌യുവി ഡ്രൈവിംഗ്
#
#
# Review: person crossing street with umbrella
# Original summary: കുടയുമായി തെരുവ് മുറിച്ചുകടക്കുന്ന വ്യക്തി
# Predicted summary:  കുടയുമായി തെരുവ് മുറിച്ചുകടക്കുന്ന വ്യക്തി
#
#
# Review: man in gray pants leaning on building
# Original summary: ചാരനിറത്തിലുള്ള പാന്റിലുള്ള മനുഷ്യൻ കെട്ടിടത്തിൽ ചാരിയിരിക്കുന്നു
# Predicted summary:  ചാരനിറത്തിലുള്ള പാന്റിലുള്ള മനുഷ്യൻ കെട്ടിടത്തിൽ ചാരിയിരിക്കുന്നു
#
#
# Review: window on the building
# Original summary: ഒരു കെട്ടിടത്തിലെ വലിയ വിൻഡോ
# Predicted summary:  ഒരു കെട്ടിടത്തിലെ വലിയ വിൻഡോ
#
#
# Review: a man standing in between cars
# Original summary: കാറുകൾക്കിടയിൽ നിൽക്കുന്ന ഒരാൾ
# Predicted summary:  കാറുകൾക്കിടയിൽ നിൽക്കുന്ന ഒരാൾ
#
#
# Review: painting hanging on wall
# Original summary: ചിത്രരചന ചുമരിൽ തൂക്കിയിരിക്കുന്നു
# Predicted summary:  ചുമരിൽ പെയിന്റിംഗ്
#
#
# Review: leg of the chair
# Original summary: കസേരയുടെ കാൽ
# Predicted summary:  കസേരയുടെ കാൽ
#
#
# Review: window of a boat
# Original summary: ഒരു കെട്ടിടത്തിലെ വലിയ വിൻഡോ
# Predicted summary:  ഒരു കെട്ടിടത്തിലെ വലിയ വിൻഡോ
#
#
# Review: the cabinet is wood
# Original summary: കാബിനറ്റ് മരം
# Predicted summary:  കാബിനറ്റ് മരം
#
#
# Review: a man reading a book
# Original summary: ഒരു കറുത്ത ട്രാഷ് ബാഗ്
# Predicted summary:  ഒരു പുസ്തകം വായിക്കുന്ന ഒരാൾ

# %%
for i in range(25):
    print("Review:",seq2text(x_val[i]))
    print("Original summary:",seq2summary(y_val[i]))
    print("Predicted summary:",decode_sequence(x_val[i].reshape(1,trmaxlen_english)))
    print("\n")
# Out:
# Review: a cloudy blue sky
# Original summary: തെളിഞ്ഞ നീലാകാശം
# Predicted summary:  തെളിഞ്ഞ നീലാകാശം
#
#
# Review: window of a building
# Original summary: ഒരു കെട്ടിടത്തിന്റെ വിൻഡോ
# Predicted summary:  ഒരു കെട്ടിടത്തിലെ വലിയ വിൻഡോ
#
#
# Review: a dark grey computer desk with drawers
# Original summary: ഇരുണ്ട ചാരനിറത്തിലുള്ള കമ്പ്യൂട്ടർ ഡെസ്ക്
# Predicted summary:  തുറന്ന ചോക്ലേറ്റും വാഴപ്പഴ സാൻഡ്‌വിച്ചും
#
#
# Review: four legged steel chair on ground
# Original summary: നിലത്ത് നാല് കാലുകളുള്ള ഉരുക്ക് കസേര
# Predicted summary:  നാല് എയർലൈൻ ജീവനക്കാർ
#
#
# Review: man riding a bicycle down a street
# Original summary: തെരുവിൽ സൈക്കിൾ ചവിട്ടുന്ന മനുഷ്യൻ
# Predicted summary:  തെരുവിൽ ഒരു തെരുവിൽ മനുഷ്യൻ
#
#
# Review: these cars are parked on the dirt
# Original summary: ഈ കാറുകൾ അഴുക്കിൽ പാർക്ക് ചെയ്തിരിക്കുന്നു
# Predicted summary:  ഇവ മൂന്ന് വ്യത്യസ്ത നിറങ്ങളിൽ ഉണ്ട്
#
#
# Review: white clouds in the sky
# Original summary: ആകാശത്ത് വെളുത്ത മേഘങ്ങൾ
# Predicted summary:  ആകാശത്ത് വെളുത്ത മേഘങ്ങൾ
#
#
# Review: set of glass doors
# Original summary: ഗ്ലാസ് ഗണം
# Predicted summary:  ഗ്ലാസ് ടോപ്പ് കോഫി പ്ലേറ്റ്
#
#
# Review: the screen rolled up
# Original summary: സ്ക്രീൻ ചുരുട്ടി വെച്ചിരിക്കുന്നു
# Predicted summary:  സ്‌ക്രീൻ ഓണാണ്
#
#
# Review: man wearing a gray sweater
# Original summary: ചാരനിറത്തിലുള്ള സ്വെറ്റർ ധരിച്ച മനുഷ്യൻ
# Predicted summary:  സ്വെറ്റർ ധരിച്ച മനുഷ്യൻ
#
#
# Review: man wearing red shirt
# Original summary: ചുവന്ന ഷർട്ട് ധരിച്ച മനുഷ്യൻ
# Predicted summary:  ദ്വീപ് ബീച്ച് രംഗം
#
#
# Review: the spoon is on the table
# Original summary: സ്പൂൺ മേശപ്പുറത്തുണ്ട്
# Predicted summary:  സ്പൂൺ മേശപ്പുറത്തുണ്ട്
#
#
# Review: small child sitting in a stroller
# Original summary: സ്‌ട്രോളറിൽ ഇരിക്കുന്ന ചെറിയ കുട്ടി
# Predicted summary:  സ്യൂട്ട്‌കേസിനുള്ളിൽ ഇരിക്കുന്ന ചെറിയ കുട്ടി
#
#
# Review: a hanging piece of paper
# Original summary: തൂക്കിയിട്ട ഒരു കടലാസ്
# Predicted summary:  ഒരു കടലാസ് കഷ്ണം
#
#
# Review: the shadow of the tree
# Original summary: മരത്തിന്റെ നിഴൽ
# Predicted summary:  മരത്തിന്റെ നിഴൽ
#
#
# Review: a black suv
# Original summary: ഒരു കറുത്ത എസ്‌യുവി
# Predicted summary:  ഒരു കറുത്ത രജന
#
#
# Review: a white mouse
# Original summary: ഒരു വെളുത്ത മൗസ്
# Predicted summary:  ഒരു വെളുത്ത പുള്ളി
#
#
# Review: car on the road
# Original summary: റോഡിൽ കാർ
# Predicted summary:  വർണ്ണാഭമായ സ്കാർഫ് ധരിച്ച ഒരു സ്ത്രീ
#
#
# Review: man wearing blue and white striped shirt
# Original summary: നീലയും വെള്ളയും വരയുള്ള ഷർട്ട് ധരിച്ച മനുഷ്യൻ
# Predicted summary:  നീലയും വെള്ളയും വരയുള്ള ഷർട്ട് ധരിച്ച മനുഷ്യൻ
#
#
# Review: white wall with wood
# Original summary: വുഡൻ ഉള്ള വെളുത്ത മതിൽ
# Predicted summary:  രുചികരമായ വെളുത്ത പൈപ്പ്
#
#
# Review: the house is beige in color
# Original summary: ബീജ് നിറമുളള വീട്
# Predicted summary:  തുറന്ന മുഖമുള്ള ക്ലോക്ക് കസേര
#
#
# Review: wheel on the van
# Original summary: വാനിലെ ചക്രം
# Predicted summary:  ഒരു കെട്ടിടത്തിലെ വലിയ വിൻഡോ
#
#
# Review: driver side mirror of the vehicle
# Original summary: വാഹനത്തിന്റെ ഡ്രൈവർ മിറർ
# Predicted summary:  ട്രക്കിന്റെ പുറകിലുള്ള ഗാർഫീൽഡ്
#
#
# Review: the tan building to the left
# Original summary: ഇടതുവശത്തുള്ള ടാൻ കെട്ടിടം
# Predicted summary:  വലത് ഓറഞ്ച് നിറമുളള കെട്ടിടം
#
#
# Review: ear of a
# Original summary: ഒരു ചെവി
# Predicted summary:  ഒരു തുണിയുടെ അറ്റം

# %%
#error due to probelm in test data
for i in range(25):
    print("Review:",seq2text(x_tt[i]))
    print("Original summary:",seq2summary(y_tt[i]))
    print("Predicted summary:",decode_sequence(x_tt[i].reshape(1,trmaxlen_english)))
    print("\n")
# Out:
# Review: hanging red palm tennis
# Original summary: കളിക്കാരൻ പച്ച പിച്ചർ കെട്ടിടത്തിലെ
# Predicted summary:  ചുവന്ന ടെന്നീസ് റാക്കറ്റ്
#
#
# Review: bowl red plane on plaid green bathroom white ball
# Original summary: കഴുത്ത് മുറിയിലെ രംഗം ഘടികാരം പച്ച
# Predicted summary:  ഓറഞ്ച് വൈറ്റ് കാർ വായുവിൽ
#
#
# Review: the with frame white the tarmac
# Original summary: ഘടിപ്പിച്ചിരിക്കുന്നു വെളുത്ത കുതിരകൾ
# Predicted summary:  വെളുത്ത ചുമരിൽ വൃത്താകൃതിയിലുള്ള ടൈലുകൾ
#
#
# Review: coat print luggage hand yellow with cake
# Original summary: സർഫ് അകലെ സോസ് വ്യക്തി പെയിന്റ് ഗ്ലാസ്
# Predicted summary:  മഞ്ഞ നിറത്തിലുള്ള പാത്രങ്ങൾ നീലയും വെള്ളയുമാണ്
#
#
# Review: door nose green object room with plate
# Original summary: പയ്യൻ സ്കീസ് തവിട്ടുനിറത്തിലുള്ള തെരുവിൽ വ്യക്തി ഫോട്ടോ
# Predicted summary:  ഇത് തെരുവിലാണ്
#
#
# Review: colorful on a with boat of a vehicle
# Original summary: ആൻഡ് വെളുത്ത മേശപ്പുറത്ത് പിന്നിൽ
# Predicted summary:  ഒരു കൗണ്ടറിൽ ഒരു ആപ്പിൾ ഉപയോഗിച്ച് ഭക്ഷണം
#
#
# Review: by on a baseball is yellow a grey of a dark
# Original summary: ചിത്രം കളിക്കുന്ന ഇരുണ്ട അലങ്കരിച്ച ലോഗോ വിൻഡോ
# Predicted summary:  ഒരു കറുത്ത ക്യാച്ചറിന്റെ മിറ്റ് മുകളിൽ ഒരു സോക്കർ കളിക്കാരിയാണ്
#
#
# Review: the blue mouth bench this on clock of a baseball is
# Original summary: ഇഷ്ടിക ഉപയോഗിച്ച് ജിറാഫ് ഒരു സ്ത്രീ തറ നിന്ന് ചിഹ്നം
# Predicted summary:  ഒരു കുട്ടിയുടെ നീല നിറത്തിലുള്ള ഷൂസ് ഉണ്ട്
#
#
# Review: the sign stripes is
# Original summary: ഒരു ബാഗ് ടെലിവിഷൻ ചുവന്ന
# Predicted summary:  അക്കം 254
#
#
# Review: a side this umbrella yellow and a bus
# Original summary: ഭാഗം ചുവപ്പും നടക്കുന്നു എഞ്ചിൻ
# Predicted summary:  ഒരു വിൻഡോയിലെ വെളുത്ത ചിഹ്നം
#
#
# Review: school people wall man
# Original summary: സിങ്കിൽ ചാരനിറത്തിലുള്ള വിളക്കുകൾ
# Predicted summary:  അവൻ ബേസ്ബോൾ കളിക്കുന്നു
#
#
# Review: board on a in
# Original summary: തവിട്ട് പുള്ളി
# Predicted summary:  ഒരു ബോർഡിൽ ബൈക്ക്
#
#
# Review: orange mouth bench on a baseball is
# Original summary: ചിത്രം ട്രാഷ് ഒരു തറ നിന്ന്
# Predicted summary:  ഒരു ബേസ്ബോൾ കളിക്കാരന്റെ ഓറഞ്ച്
#
#
# Review: a brown sliced white large
# Original summary: ധരിച്ച വാച്ച് ചാരിയിരിക്കുന്ന
# Predicted summary:  ഒരു വെളുത്ത ടൈൽ
#
#
# Review: the holding is zebra yellow the tennis
# Original summary: ഒരു പുഷ്പ ഒരു തൂക്കിയിട്ടിരിക്കുന്ന ഉള്ള
# Predicted summary:  പന്ത് മഞ്ഞയും മഞ്ഞയും ആണ്
#
#
# Review: street carrot sitting shirt in pizza
# Original summary: നായ റൺവേയിൽ ചെയ്തു ബ്രൗൺ പിങ്ക്
# Predicted summary:  പാർക്കിൽ അഴുക്കിൽ തെരുവ് വെളിച്ചം
#
#
# Review: brown wearing of restaurant
# Original summary: പാലം ധരിച്ച നീല
# Predicted summary:  ഒരു വണ്ടി വലിക്കുന്ന കുതിര
#
#
# Review: pieces wet yellow a with plate
# Original summary: വ്യക്തി പ്രകാശം നനഞ്ഞ കേസ്
# Predicted summary:  പിങ്ക് നിറത്തിലുള്ള മുട്ടകൾ
#
#
# Review: the park on the is
# Original summary: മഞ്ഞയാണ് പേപ്പർ
# Predicted summary:  മെറൂൺ ക്ലീനിംഗ് കപ്പ്
#
#
# Review: foreground surfing chair part
# Original summary: സമുദ്രത്തിൽ തടി പിടിക്കുന്നു വെള്ളയും
# Predicted summary:  ഒരു ജിറാഫ് പുല്ല് തിന്നുന്നു
#
#
# Review: bear on a with cake
# Original summary: വെളുത്ത ഡോണട്ട്സ് തിന്നുന്നു
# Predicted summary:  ഒരു ചെറിയ വിൻഡോ ബ്രഷ് പിടിക്കുന്നു
#
#
# Review: a in this next of up
# Original summary: പുഞ്ചിരിക്കുന്നു കൊച്ചുകുട്ടി തലയിണ
# Predicted summary:  ഒരു പവർ ചീസ് ഉണ്ട്
#
#
# Review: orange water lights old the lights shower
# Original summary: ഒരു ഫോണിൽ സ്ലൈസ് പ്ലേറ്റിൽ ഒരു മഞ്ഞ ഫോണിൽ
# Predicted summary:  വലത് ഓറഞ്ച് സിഗ്നൽ വലത് സിഗ്നൽ
#
#
# Review: ear plates home and desk a bus
# Original summary: മുഖം എടുത്ത കീഴിലുള്ള സെൽഫോൺ ഗ്രേ
# Predicted summary:  ഒരു ടാൻ കാറിന്റെ കിടക്ക
#
#
# Review: base is on a toilet
# Original summary: കപ്പൽ ഉള്ള കസേരയിൽ
# Predicted summary:  ഒരു കെട്ടിടത്തിൽ എഴുതുന്നു

# %%
# !pip install sacrebleu
import sacrebleu
import random
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.7 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
temp_o=[]
temp_p=[]
for i in range(1500):
    s=random.randint(0,len(y_tr)-1)
    temp_o.append(seq2summary(y_tr[s]))
    temp_p.append(decode_sequence(x_tr[s].reshape(1,trmaxlen_english)))

bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 87.63433084676325

# %%
temp_o=[]
temp_p=[]
for i in range(998):
    s=random.randint(0,len(y_val)-1)
    temp_o.append(seq2summary(y_val[s]))
    temp_p.append(decode_sequence(x_val[s].reshape(1,trmaxlen_english)))


bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 16.603978828274215

# %%
temp_o=[]
temp_p=[]
for i in range(1400):
    s=random.randint(0,len(y_tt)-1)
    temp_o.append(seq2summary(y_tt[s]))
    temp_p.append(decode_sequence(x_tt[s].reshape(1,trmaxlen_english)))
bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 0.08756335964393985
