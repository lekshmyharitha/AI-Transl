# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import os
import cv2
import matplotlib.image as mp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/drive/My Drive/Main/train.mn.txt') as file:
    mal_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/train.en.txt') as file:
    eng_txt = file.read().split('\n')
with open('/content/drive/My Drive/Main/train_images.txt') as file:
    train_images = file.read().split('\n')

# %%
train_images[-1]
# Out:
# ''

# %%
#removing last elements which containing special characters
mal_txt.pop()
mal_txt.pop()
eng_txt.pop()
eng_txt.pop()
train_images.pop()
print(len(mal_txt))
print(len(eng_txt))
print(len(train_images))
img_path=[]
for s in train_images:
    img_path.append("/content/drive/My Drive/Main/trainimages/train/"+s)
# Out:
# 28930
# 28931
# 28931

# %%
print(mal_txt[1])
print(eng_txt[1])
# Out:
# ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# it is an indoor scene

# %%
mal_txt[0:15]
# Out:
# ['ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ',
#  'ഇത് ഒരു ഇൻഡോർ രംഗമാണ്',
#  'കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി',
#  'മനുഷ്യന് ചെറിയ മുടിയുണ്ട്',
#  'ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു',
#  'കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട്',
#  'ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി',
#  'ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ്',
#  'മതിൽ വെളുത്ത ചായം പൂശി',
#  'ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ',
#  'സമുദ്രം അഭിമുഖീകരിക്കുന്ന സ്ത്രീ',
#  'ഇതൊരു ഓഫീസ് രേഖാചിത്രം',
#  'നാല് ലോഹത്തിന്റെ കസേരകൾ',
#  'കോലാഹലം ഒരു മേശപ്പുറത്താണ്',
#  'ഒരു വെളുത്ത മൈക്രോവേവ് ഓവൻ']

# %%
eng_txt[0:15]
# Out:
# ['Male surfer surfing in still in the ocean',
#  'it is an indoor scene\t\t\t\t\t\t',
#  'Computer screens turned on\t\t\t\t\t\t',
#  'man has short hair\t\t\t\t\t\t',
#  "photo album open on an adult's lap\t\t\t\t\t\t",
#  'there is a group of girls beside the black car\t\t\t\t\t\t',
#  'Child in a stroller\t\t\t\t\t\t',
#  'Tall metal lightpost\t\t\t\t\t\t',
#  'wall is painted white\t\t\t\t\t\t',
#  'there are several pictures on the wall\t\t\t\t\t\t',
#  'woman facing the ocean\t\t\t\t\t\t',
#  'this is an office layout\t\t\t\t\t\t',
#  'four metallic chairs\t\t\t\t\t\t',
#  'Clutter is on a table\t\t\t\t\t\t',
#  'a white microwave oven\t\t\t\t\t\t']

# %%
im=mp.imread(img_path[1])
plt.imshow(im)
print(img_path[1])
print("mal:"+mal_txt[1])
print("eng:"+eng_txt[1])
# Out:
# /content/drive/My Drive/Main/trainimages/train/11.jpg
# mal:ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# eng:it is an indoor scene

# %%
im=mp.imread(img_path[0])
plt.imshow(im)
print(img_path[0])
print("mal:"+mal_txt[0])
print("eng:"+eng_txt[0])
# Out:
# /content/drive/My Drive/Main/trainimages/train/10.jpg
# mal:ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# eng:Male surfer surfing in still in the ocean

# %%
#Manually splitting data for training and texting-due to presence of 3 inputs split using Sklearn  is not efficeint
splits=5000
mal_train=mal_txt[:splits]
eng_train=eng_txt[:splits]

# %%
mal_df = pd.DataFrame(mal_train, columns=['Malayalam']) 
eng_df = pd.DataFrame(eng_train, columns=['English'])

# %%
mal_df.head(10)
# Out:
#                                            Malayalam
# 0        ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# 1                              ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# 2                     കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# 3                          മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# 4       ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
# 5     കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട്
# 6                          ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി
# 7                     ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ്
# 8                             മതിൽ വെളുത്ത ചായം പൂശി
# 9  ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന...

# %%
eng_df.head(10)
# Out:
#                                              English
# 0          Male surfer surfing in still in the ocean
# 1                  it is an indoor scene\t\t\t\t\t\t
# 2             Computer screens turned on\t\t\t\t\t\t
# 3                     man has short hair\t\t\t\t\t\t
# 4     photo album open on an adult's lap\t\t\t\t\t\t
# 5  there is a group of girls beside the black car...
# 6                    Child in a stroller\t\t\t\t\t\t
# 7                   Tall metal lightpost\t\t\t\t\t\t
# 8                  wall is painted white\t\t\t\t\t\t
# 9  there are several pictures on the wall\t\t\t\t...

# %%
#Datacleaning by removing special characters
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r" ᠃", "", text)
    text = re.sub(r" ᠂", "", text)
    text = re.sub(r"-", " ", text)
    text = re.sub(r"<5>", "5", text)
    text = re.sub(r"“ ", "", text)
    text = re.sub(r" ”", "", text)
    text = re.sub(r"[+\.\!\/_,$%^*(+\"\']+|[+——！，〈〉《》。︱？?、．％~@#￥%……&*（）’]", "", text)
    text=text.rstrip()
    return text

# %%
mal_text1 = mal_df["Malayalam"].apply(clean_text)
eng_text1 = eng_df["English"].apply(clean_text)
mal_text2 = list(mal_text1.values)
eng_text2 = list(eng_text1.values)

# %%
#cleaned Malayalm data
mal_text1
# Out:
# 0        ശാന്തമായ  കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# 1                              ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# 2                     കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# 3                          മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# 4       ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
#                             ...
# 4995            ഫ്രിസ്‌ബീ ഉള്ള പുൽത്തകിടിയിൽ ഒരു നായ
# 4996        ഒരു ഉദ്യാനത്തിൽ ചാരനിറത്തിലുള്ള ലോഹ വേലി
# 4997               തവിട്ടുനിറമുള്ള മുടിയുള്ള മനുഷ്യൻ
# 4998                    ഒരു ജിറാഫ് പുല്ല് തിന്നുന്നു
# 4999                      മുൻവശത്തുള്ള ഒരു പെൺകുട്ടി
# Name: Malayalam, Length: 5000, dtype: object

# %%
#cleaned English data
eng_text1
# Out:
# 0       male surfer surfing in still in the ocean
# 1                           it is an indoor scene
# 2                      computer screens turned on
# 3                              man has short hair
# 4               photo album open on an adults lap
#                           ...
# 4995               a dog on a lawn with a frisbee
# 4996                 a gray metal fence in a park
# 4997                           a brown haired man
# 4998                           the floor is tiled
# 4999               a young girl in the foreground
# Name: English, Length: 5000, dtype: object

# %%
mal_text2[1:5]
# Out:
# ['ഇത് ഒരു ഇൻഡോർ രംഗമാണ്',
#  'കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി',
#  'മനുഷ്യന് ചെറിയ മുടിയുണ്ട്',
#  'ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു']

# %%
eng_text2[1:5]
# Out:
# ['it is an indoor scene',
#  'computer screens turned on',
#  'man has short hair',
#  'photo album open on an adults lap']

# %%
#Adding starting and ending tokens
eng_temp=[]
for s in mal_text2:
    temp="sos "+s+" eos"
    eng_temp.append(temp)
#text2=[]
mal_text2=eng_temp
mal_text2[1:10]
# Out:
# ['sos ഇത് ഒരു ഇൻഡോർ രംഗമാണ് eos',
#  'sos കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി eos',
#  'sos മനുഷ്യന് ചെറിയ മുടിയുണ്ട് eos',
#  'sos ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു eos',
#  'sos കറുത്ത കാറിനടുത്ത് ഒരു കൂട്ടം പെൺകുട്ടികളുണ്ട് eos',
#  'sos ഒരു ഉന്തുവണ്ടിയിലെ കുട്ടി eos',
#  'sos ഉയരമുള്ള മെറ്റൽ ലൈറ്റ്പോസ്റ്റ് eos',
#  'sos മതിൽ വെളുത്ത ചായം പൂശി eos',
#  'sos ചാരനിറത്തിലുള്ള റോഡിന്റെ വശങ്ങളിൽ പച്ച പുല്ലിന്റെ സ്ട്രിപ്പുകൾ eos']

# %%
import seaborn as sn
import matplotlib.pyplot as plt
malayalam_words = []
for i in mal_text2:
    malayalam_words.append(len(i.split()))
sn.countplot(malayalam_words).set(title=' Sentence Length -Malayalam')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
english_words = []
for j in eng_text2:
    english_words.append(len(j.split()))
sn.countplot(english_words).set(title=' Sentence Length -English')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
maxlen_malayalam = max(malayalam_words)
maxlen_english = max(english_words)
print('Maximum sentence length-Malayalam :',maxlen_malayalam)
print('Maximum sentence length-English :',maxlen_english)
# Out:
# Maximum sentence length-Malayalam : 13
# Maximum sentence length-English : 13

# %%
#splitting training data into training and validation data
x_tr=eng_text2[:splits-500]
y_tr=mal_text2[:splits-500]
x_val=eng_text2[splits-500:]
y_val=mal_text2[splits-500:]

# %%
x_tr[1:5]
# Out:
# ['it is an indoor scene',
#  'computer screens turned on',
#  'man has short hair',
#  'photo album open on an adults lap']

# %%
y_tr[1:5]
# Out:
# ['sos ഇത് ഒരു ഇൻഡോർ രംഗമാണ് eos',
#  'sos കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി eos',
#  'sos മനുഷ്യന് ചെറിയ മുടിയുണ്ട് eos',
#  'sos ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു eos']

# %%
len(x_tr)
# Out:
# 4500

# %%
len(x_val)
# Out:
# 500

# %%
#Tokening the sentences using Keras tokenizer -Malayalam data
from keras.preprocessing.text import Tokenizer
x_tokens = Tokenizer()
x_tokens.fit_on_texts(x_tr)
x_tr = x_tokens.texts_to_sequences(x_tr)
x_val = x_tokens.texts_to_sequences(x_val)
print('x_tr:',x_tr)
print('x_val:',x_val)
# Out:
# x_tr: [[587, 365, 296, 6, 741, 6, 2, 271], [187, 5, 41, 742, 145], [90, 1049, 393, 3], [8, 43, 237, 66], [221, 1050, 124, 3, 41, 1051, 743], [366, 5, 1, 165, 4, 501, 367, 2, 10, 23], [188, 6, 1, 588], [97, 88, 1052], [14, 5, 222, 7], [366, 48, 331, 744, 3, 2, 14], [21, 272, 2, 271], [22, 5, 41, 442, 1053], [238, 745, 332], [1054, 5, 3, 1, 32], [1, 7, 368, 297], [7, 273, 174, 298, 443], [17, 206, 24, 13, 73], [8, 6, 78, 207, 274, 3, 9], [16, 3, 2, 9], [1, 8, 35, 6, 502, 257], [258, 86, 3, 14], [195, 4, 2, 70], [16, 4, 1, 64], [2, 239, 5, 138], [1, 8, 444, 1, 240], [1, 17, 746, 6, 29], [113, 13, 747, 445], [208, 3, 2, 54], [1, 589, 7, 54], [10, 175, 394], [1, 17, 1055, 590, 6, 2, 241, 4, 2, 23], [18, 23, 44, 299, 1, 24], [23, 3, 2, 24], [748, 749, 20, 1056], [1, 10, 23, 13, 1, 26, 98], [70, 65, 2, 32], [1, 1057, 52, 3, 1, 189], [153, 223, 4, 1, 9], [16, 3, 1, 9], [25, 32, 35, 3, 49, 4, 1, 132], [132, 113, 5, 3], [1, 26, 45], [333, 4, 2, 39], [750, 74, 176, 2, 9], [503, 10, 60, 13, 1, 7, 300], [1, 63, 259, 74], [1, 154], [8, 43, 25, 66], [58, 6, 1, 77], [1, 30, 25, 39, 241], [55, 23, 6, 59, 4, 1, 9], [8, 591, 65, 189], [21, 35, 65, 1, 240, 334], [38, 751, 15, 45], [1, 78, 1058, 301], [2, 26, 748, 752], [63, 132, 6, 2, 99], [1, 97, 395, 39, 275, 2, 504], [70, 276, 41, 1059], [1, 97, 1060, 39], [209, 5, 3, 1061, 14], [2, 67], [2, 1062, 19, 98, 5, 124], [1, 54, 196, 4, 107], [2, 9, 5, 7], [51, 80, 3, 14], [443, 4, 63, 1063], [28, 302, 42, 9], [753, 446, 754, 27], [396, 210, 4, 1064, 11, 1065, 3, 1, 7, 335, 146], [1066, 5, 6, 2, 166], [2, 211, 5, 79], [25, 242, 3, 209], [7, 133, 592, 39], [7, 1067, 3, 2, 24], [18, 243, 6, 369], [2, 27, 5, 15], [8, 36, 336, 42, 19, 4, 37], [1, 8, 206, 2, 24], [27, 3, 2, 14], [16, 6, 1, 155, 134], [2, 90, 177, 5, 15], [114, 1068, 27], [79, 755, 66, 3, 1, 8], [2, 593, 120, 4, 1, 23], [756, 13, 397, 447], [19, 4, 1069, 55, 273], [21, 50, 448, 24], [21, 20, 93, 94], [12, 23, 44, 91, 24, 28], [2, 100, 139, 48, 26], [7, 222, 277, 3, 757], [2, 10, 1070, 1071, 3, 2, 81], [8, 6, 7, 33, 50, 71, 2, 67], [30, 28, 370, 6, 111], [7, 224, 3, 81], [10, 90, 224, 3, 81], [244, 3, 2, 398], [1, 8, 36, 6, 59, 4, 1, 90, 224], [393, 3, 10, 224], [8, 20, 25, 278], [155, 3, 2, 9], [55, 88, 32, 3, 62], [1, 79, 337, 1072], [56, 40, 140], [1073, 177, 5, 7], [26, 100, 371, 302, 42, 1, 78, 60], [12, 61, 178, 55, 23], [38, 1074, 48, 44], [1, 15, 23, 3, 2, 24], [10, 23, 13, 26, 449], [1, 23, 13, 238, 449], [114, 44, 3, 2, 67], [12, 89, 3, 67], [8, 20, 15, 33], [165, 4, 1075, 44, 105, 42, 303, 304], [26, 1076, 758, 225, 450], [226, 4, 505], [366, 5, 1, 759, 3, 760], [16, 3, 7, 134], [305, 48, 97, 399], [51, 23, 367, 400], [22, 5, 1, 17], [506, 3, 2, 306], [2, 9, 13, 1, 26, 211], [2, 154, 5, 761, 71], [28, 6, 2, 111], [10, 61, 5, 44], [2, 8, 6, 2, 28, 15, 338], [114, 274, 245, 10, 507], [7, 451, 3, 16], [2, 1077, 53, 5, 336], [1, 1078, 762, 80, 3, 2, 14], [1, 167, 4, 29, 3, 2, 32], [1079, 594, 1080, 42, 2, 14], [70, 105, 42, 138, 81], [1081, 105, 42, 307], [10, 372, 367, 1, 95], [1, 55, 373, 6, 1, 179], [51, 212, 3, 595], [1082, 1083, 3, 2, 134], [1, 7, 11, 147, 508, 99], [763, 764, 3, 1, 308], [2, 213, 5, 765, 452], [1, 63, 132], [2, 16, 5, 1084], [10, 23, 180, 13, 55, 1085], [1, 238, 1086, 452, 70], [12, 81, 113, 36, 3, 81], [2, 63, 596, 279], [97, 1087, 766], [115, 4, 1, 134, 212], [12, 11, 18, 453, 454], [30, 117, 197], [64, 3, 2, 29], [767, 44, 3, 2, 19, 4, 2, 37], [1, 21, 35, 3, 2, 67], [8, 35, 3, 2, 108], [1, 21, 20, 1, 768, 94], [260, 309, 174, 3, 24], [26, 260, 174, 3, 1, 24], [17, 50, 71, 2, 67, 6, 1, 509, 141], [17, 769, 3, 67], [165, 4, 46, 5, 35], [10, 23, 3, 2, 24], [16, 4, 1, 23], [133, 105, 42, 29], [1, 107, 279, 3, 1, 67], [17, 206, 3, 770], [168, 174, 190, 28], [26, 260, 3, 2, 37], [16, 3, 2, 9], [280, 5, 20, 1, 93, 33], [147, 101, 86, 3, 1, 160], [1, 7, 75, 3, 1, 339], [771, 44, 3, 2, 339], [51, 16, 3, 142], [23, 3, 2, 37], [51, 374], [39, 241, 5, 772], [17, 6, 12, 261], [2, 1088, 5, 455, 237], [135, 6, 2, 31], [1,  ...
# x_val: [[1, 1000, 179, 128], [1, 127, 8, 123, 152], [1007, 3, 287], [363, 83, 890, 162, 234], [1, 82, 1077, 53], [83, 40, 1, 69, 254], [17, 3, 599], [2, 195, 4, 2], [1, 429, 20, 1, 161], [10, 381, 3, 26, 27], [1, 24, 27], [38, 705, 272, 303, 304], [137, 209, 13, 1, 109, 63, 242], [224, 43, 10, 242], [18, 1035, 220, 3, 2, 62], [21, 43, 404], [286, 4, 17, 6, 209], [2, 1125, 5, 93, 11, 15], [1, 21, 20, 1, 15, 935], [56, 35, 3, 163, 4, 61], [258, 4, 1, 31, 277, 86, 3, 2, 14], [311, 198, 203, 200, 163, 4, 61], [8, 3, 1, 171], [2, 116, 5, 126], [7, 11, 18, 166, 6, 2, 24], [15, 768, 3, 2, 9], [8, 5, 20, 1, 33], [115, 4, 1, 204], [1, 363, 83, 72, 1, 119], [197, 162, 1889, 1747, 107], [8, 20, 1, 33], [1, 106, 390, 487], [22, 5, 1, 15, 33], [38, 3, 1, 333], [22, 5, 1, 15, 80], [17, 6, 1, 15, 33], [7, 11, 15, 320], [115, 4, 1, 58], [831, 143, 4, 1, 157, 173], [1, 188, 6, 2, 306], [18, 1462, 3, 1, 32], [324, 310, 5, 10], [17, 65, 1, 941, 511], [363, 83, 5, 123, 387, 175], [1, 116, 35, 118, 1, 39], [1, 18, 659], [69, 110, 6, 1, 69, 325], [366, 48, 135], [21, 13, 18, 11, 7, 226], [1464, 346, 3, 1, 153], [1, 1562, 63, 70, 11, 1585], [722, 3, 1, 54], [22, 5, 1], [1, 10, 158, 413], [153, 3, 1, 7, 54], [45, 3, 2, 37], [286, 4, 6, 209], [20, 93, 33], [1, 84, 11, 1614, 286, 6, 1, 16], [153, 3, 1, 7, 54], [8, 40, 1, 152], [1, 267, 4, 29], [1, 155, 1449, 3, 2, 634], [18, 213, 6, 2, 181, 4, 2, 14], [12, 235, 27, 13, 7, 662], [1166, 3, 2, 497], [137, 53, 3, 2, 9], [8, 20, 15, 33], [106, 5, 315, 610, 1458], [1, 396, 59, 4, 61], [1, 127, 83, 126, 106], [88, 184, 318, 178], [1, 679, 5, 3, 2, 440, 246], [10, 85, 118, 1, 39, 241], [1441, 377, 4, 41], [38, 705, 6, 2, 29], [763, 46, 48, 890, 418], [516, 3], [638, 3, 75], [2, 707, 4, 2, 60], [22, 17, 5, 20, 1, 101], [38, 280, 194, 65, 1, 108], [1, 21, 40, 38, 205, 1003], [46, 35, 118, 41, 164, 166], [135, 385, 2, 31], [17, 5, 123, 69], [2, 8, 5, 294], [10, 353, 3, 1, 363, 83], [17, 1926, 1, 580], [25, 603, 27, 6, 11], [318, 3, 2, 566, 207], [38, 481, 35, 418], [2, 262, 3, 1, 27], [1, 145, 276], [8, 20, 1, 201, 33], [1, 18, 432, 3, 1, 432, 604], [25, 406, 3, 54], [115, 4, 1, 32], [3, 1, 57], [1, 8, 5, 296], [1, 10, 388], [271, 6, 2, 317], [115, 4, 1, 241], [1], [47, 4, 1, 352], [482, 392, 6, 124, 1027], [115, 4, 1, 150], [8, 72, 1, 89], [21, 416, 3, 205, 108], [1, 15, 53, 3, 1, 14], [4, 26, 344], [1, 53, 125, 5, 276], [1, 137, 26, 152], [1, 21, 36, 3, 750, 288], [151, 40], [1, 21, 20, 1, 10, 11, 26, 33], [17, 5, 3, 2, 136], [1, 26, 11, 12, 75, 71], [576, 48, 3, 1, 146], [53, 3, 38, 708, 4, 112], [7, 277, 1337, 3, 92, 77], [22, 21, 5, 20, 1, 425, 4, 230], [1, 1594, 69, 110], [482, 68, 6, 1, 738], [1, 1048], [2, 791, 3, 1, 170], [440, 3, 1, 136], [12, 398, 118, 10, 413], [186, 35, 6, 2, 29], [116, 35, 6, 2, 680], [374, 3, 2, 62], [32, 113, 13, 1, 445], [291, 3, 1, 571, 171], [12, 11, 10, 261, 3, 2, 171], [899, 849, 3, 711], [293, 3, 2, 54], [251, 28, 646, 11, 86, 200, 2, 111], [8, 5, 446, 20, 33], [2, 5, 701], [2, 195, 4, 41, 186], [1, 2001, 98, 13, 1, 7, 1652], [373, 6, 2, 213], [2, 1449, 3, 2, 634], [53, 3, 19, 4, 112], [63, 461, 74, 36, 3, 1, 155, 67, 245, 1, 267, 4, 29], [52, 11, 7, 748, 3, 37], [111, 421, 13, 25, 1263], [1, 140, 3, 49, 4, 1, 101], [10, 11, 7, 150, 6, 2, 29], [503, 172, 4, 554, 131, 3], [1, 188, 490, 110], [21, 123, 69, 3, 325], [1, 18, 270, 13, 11], [2, 31, 5, 15], [278, 3, 1, 159, 122], [8, 43, 109, 66], [8, 1, 4, 1], [1, 10, 11, 93, 386], [107, 6, 2, 221], [8, 40, 1, 69, 254], [861, 21, 10, 820], [2, 10, 11, 7, 195, 4, 1, 150], [8, 6, 1, 250], [594], [8, 20, 1, 161], [1, 7, 128, 288], [7, 322, 408, 3, 55, 317], [1, 18, 11, 7, 158, 90], [17, 258, 1, 1999], [38, 549, 255, 581], [288, 6, 2, 64], [106, 3, 1, 54], [153, 324, 48, 50], [910, 3, 1, 54], [2, 29, 5, 15], [227, 12, 75, 292], [929, 295, 203, 761, 71], [38, 100, 1394, 48, 3, 2, 60], [436, 3, 1, 54], [1, 69, 140, 6, 2, 121], [63, 74, 6, 1, 259], [2, 21, 5, 486], [1, 51, 7, 32], [12, 11, 7, 64], [38, 25, 326, 35], [199, 25, 156, 119],  ...

# %%
#padding with post (appending zeros at the end to equalize sentence length)
from keras.preprocessing.sequence import pad_sequences
x_tr = pad_sequences(x_tr,maxlen = maxlen_english,padding = 'post')
x_val = pad_sequences(x_val,maxlen = maxlen_english,padding = 'post')

# +1 for padding 
x_voc_size   =  len(x_tokens.word_index) +1
print("No of unique words in English",x_voc_size)
# Out:
# No of unique words in English 2040

# %%
# English data preprocessing
from keras.preprocessing.text import Tokenizer
y_tokens = Tokenizer()
y_tokens.fit_on_texts(y_tr)

y_tr = y_tokens.texts_to_sequences(y_tr)
y_val = y_tokens.texts_to_sequences(y_val)

from keras.preprocessing.sequence import pad_sequences
y_tr = pad_sequences(y_tr,maxlen = maxlen_malayalam,padding = 'post')
y_val = pad_sequences(y_val,maxlen = maxlen_malayalam,padding = 'post')

# +1 for padding 
y_voc_size   =  len(y_tokens.word_index) +1
print("No of unique words in Malyalam",y_voc_size)
# Out:
# No of unique words in Malyalam 3530

# %%
pip install keras-applications
# Out:
# Requirement already satisfied: keras-applications in /usr/local/lib/python3.7/dist-packages (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications) (1.5.2)

# %%
import pandas as pd
import pickle
import numpy as np
import os
import keras
import tensorflow
from keras_applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D,BatchNormalization,Flatten,Input, Convolution2D, Dropout, LSTM, TimeDistributed, Embedding, Bidirectional, Activation, RepeatVector,Concatenate
from keras.models import Sequential, Model
from keras.utils import np_utils
import random
from keras.preprocessing import image, sequence
import matplotlib.pyplot as plt
import keras
from keras import backend as K 
import gensim
from numpy import *
import numpy as np
import pandas as pd 
import re
from tensorflow.keras.applications.vgg16 import VGG16
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed,Conv2D,MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings

# %%
#Loading VGG model for Feature Extraction-Removing classification layers from memory
modelvgg = VGG16(include_top=True,weights="imagenet")
modelvgg.layers.pop()
modelvgg = Model(inputs=modelvgg.inputs, outputs=modelvgg.layers[-2].output)
modelvgg.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
pip install cv
# Out:
# Requirement already satisfied: cv in /usr/local/lib/python3.7/dist-packages (1.0.0)

# %%
import cv2
import cv

# %%
#tRY RESNET

# %%
#Resizing image and converting grey scale images into RGB images
#split=5000
imagedata=np.zeros(shape=(splits,224,224,3))
for i in range(splits):
    temp=mp.imread(img_path[i])
    if (len(temp.shape)==3):
       temp=cv2.resize(temp,(224,224))
       imagedata[i]=temp
    elif (len(temp.shape)<3):
       #plt.imshow(temp)
       temp=cv2.cvtColor(temp, cv2.COLOR_BGR2RGB)
       temp=cv2.resize(temp,(224,224))
       imagedata[i]=temp    
imagedata=imagedata/255
imagedata=imagedata.astype(np.float16)

# %%
imagedata[1:10]
# Out:
# array([[[[0.4626  , 0.443   , 0.3254  ],
#          [0.4548  , 0.4353  , 0.3176  ],
#          [0.4666  , 0.447   , 0.3293  ],
#          ...,
#          [0.902   , 0.933   , 0.9453  ],
#          [0.906   , 0.937   , 0.949   ],
#          [0.906   , 0.937   , 0.949   ]],
#
#         [[0.4666  , 0.447   , 0.3293  ],
#          [0.4587  , 0.4392  , 0.3215  ],
#          [0.4707  , 0.451   , 0.3333  ],
#          ...,
#          [0.949   , 0.9805  , 0.9883  ],
#          [0.9453  , 0.9766  , 0.9883  ],
#          [0.9453  , 0.9766  , 0.9883  ]],
#
#         [[0.4707  , 0.451   , 0.3333  ],
#          [0.4626  , 0.443   , 0.3254  ],
#          [0.4785  , 0.4587  , 0.341   ],
#          ...,
#          [0.961   , 0.992   , 1.      ],
#          [0.9453  , 0.9766  , 0.992   ],
#          [0.9453  , 0.9766  , 0.992   ]],
#
#         ...,
#
#         [[0.3098  , 0.2864  , 0.2393  ],
#          [0.341   , 0.3098  , 0.2666  ],
#          [0.3647  , 0.3254  , 0.2864  ],
#          ...,
#          [0.1686  , 0.153   , 0.1059  ],
#          [0.1647  , 0.149   , 0.102   ],
#          [0.1569  , 0.1412  , 0.0941  ]],
#
#         [[0.3098  , 0.2864  , 0.2393  ],
#          [0.3215  , 0.2903  , 0.2471  ],
#          [0.3608  , 0.3176  , 0.2783  ],
#          ...,
#          [0.1608  , 0.1451  , 0.098   ],
#          [0.1647  , 0.149   , 0.102   ],
#          [0.153   , 0.1372  , 0.0902  ]],
#
#         [[0.3176  , 0.298   , 0.2471  ],
#          [0.3215  , 0.2903  , 0.2471  ],
#          [0.349   , 0.3098  , 0.2705  ],
#          ...,
#          [0.153   , 0.1372  , 0.0902  ],
#          [0.1686  , 0.153   , 0.1059  ],
#          [0.149   , 0.1333  , 0.0863  ]]],
#
#
#        [[[0.51    , 0.502   , 0.506   ],
#          [0.506   , 0.506   , 0.51    ],
#          [0.51    , 0.506   , 0.5215  ],
#          ...,
#          [0.392   , 0.408   , 0.447   ],
#          [0.3843  , 0.408   , 0.4548  ],
#          [0.3765  , 0.408   , 0.4587  ]],
#
#         [[0.498   , 0.498   , 0.4902  ],
#          [0.502   , 0.502   , 0.4941  ],
#          [0.502   , 0.4941  , 0.498   ],
#          ...,
#          [0.392   , 0.4197  , 0.4824  ],
#          [0.3804  , 0.4119  , 0.4707  ],
#          [0.3726  , 0.4197  , 0.4666  ]],
#
#         [[0.5176  , 0.498   , 0.502   ],
#          [0.51    , 0.5137  , 0.506   ],
#          [0.4941  , 0.5137  , 0.4902  ],
#          ...,
#          [0.3647  , 0.3882  , 0.451   ],
#          [0.349   , 0.3843  , 0.4353  ],
#          [0.3372  , 0.3843  , 0.4314  ]],
#
#         ...,
#
#         [[0.443   , 0.2864  , 0.1843  ],
#          [0.4587  , 0.298   , 0.1765  ],
#          [0.4785  , 0.306   , 0.1765  ],
#          ...,
#          [0.2471  , 0.1765  , 0.1333  ],
#          [0.255   , 0.1804  , 0.1294  ],
#          [0.255   , 0.1804  , 0.1216  ]],
#
#         [[0.4626  , 0.306   , 0.1843  ],
#          [0.4666  , 0.2942  , 0.196   ],
#          [0.4902  , 0.3137  , 0.1843  ],
#          ...,
#          [0.2118  , 0.1569  , 0.1098  ],
#          [0.2471  , 0.1804  , 0.1333  ],
#          [0.2471  , 0.1726  , 0.1177  ]],
#
#         [[0.4587  , 0.298   , 0.1843  ],
#          [0.4707  , 0.3215  , 0.1804  ],
#          [0.4707  , 0.3176  , 0.1882  ],
#          ...,
#          [0.2313  , 0.1686  , 0.1177  ],
#          [0.2588  , 0.1843  , 0.1294  ],
#          [0.2588  , 0.1686  , 0.1098  ]]],
#
#
#        [[[0.9766  , 0.9727  , 0.9727  ],
#          [0.957   , 0.9688  , 0.933   ],
#          [0.953   , 0.9727  , 0.9805  ],
#          ...,
#          [0.306   , 0.3215  , 0.3254  ],
#          [0.2903  , 0.306   , 0.3098  ],
#          [0.2942  , 0.3098  , 0.3137  ]],
#
#         [[0.996   , 0.992   , 0.996   ],
#          [0.9805  , 0.992   , 0.961   ],
#          [0.9727  , 0.9883  , 1.      ],
#          ...,
#          [0.3137  , 0.3293  , 0.3333  ],
#          [0.298   , 0.3137  , 0.3176  ],
#          [0.3098  , 0.3254  , 0.3293  ]],
#
#         [[0.9097  , 0.953   , 0.9688  ],
#          [0.847   , 0.9214  , 0.937   ],
#          [0.816   , 0.886   , 0.953   ],
#          ...,
#          [0.3215  , 0.3372  , 0.341   ],
#          [0.298   , 0.3137  , 0.3176  ],
#          [0.3137  , 0.3293  , 0.3333  ]],
#
#         ...,
#
#         [[0.341   , 0.3804  , 0.4197  ],
#          [0.349   , 0.3882  , 0.4275  ],
#          [0.349   , 0.3882  , 0.4275  ],
#          ...,
#          [0.00392 , 0.011765, 0.      ],
#          [0.011765, 0.0196  , 0.00784 ],
#          [0.011765, 0.0196  , 0.00784 ]],
#
#         [[0.3254  , 0.3647  , 0.4038  ],
#          [0.3372  , 0.3765  , 0.4119  ],
#          [0.3333  , 0.3687  , 0.408   ],
#          ...,
#          [0.011765, 0.0196  , 0.00784 ],
#          [0.00784 , 0.01569 , 0.00392 ],
#          [0.00784 , 0.01569 , 0.00392 ]],
#
#         [[0.3137  , 0.349   , 0.3882  ],
#          [0.3215  , 0.3608  , 0.4     ],
#          [0.3176  , 0.357   , 0.396   ],
#          ...,
#          [0.00392 , 0.011765, 0.      ],
#          [0.00392 , 0.011765, 0.      ],
#          [0.00392 , 0.011765, 0.      ]]],
#
#
#        ...,
#
#
#        [[[0.682   , 0.678   , 0.855   ],
#          [0.757   , 0.855   , 0.847   ],
#          [0.545   , 0.596   , 0.608   ],
#          ...,
#          [0.5293  , 0.6943  , 0.9844  ],
#          [0.5254  , 0.6904  , 0.9805  ],
#          [0.5293  , 0.6943  , 0.9844  ]],
#
#         [[0.6665  , 0.6626  , 0.8394  ],
#          [0.7646  , 0.855   , 0.859   ],
#          [0.604   , 0.655   , 0.6743  ],
#          ...,
#          [0.537   , 0.702   , 0.992   ],
#          [0.541   , 0.706   , 0.996   ],
#          [0.545   , 0.71    , 0.996   ]],
#
#         [[0.682   , 0.678   , 0.8433  ],
#          [0.757   , 0.851   , 0.855   ],
#          [0.6313  , 0.678   , 0.714   ],
#          ...,
#          [0.545   , 0.71    , 1.      ],
#          [0.537   , 0.702   , 0.992   ],
#          [0.545   , 0.71    , 0.996   ]],
#
#         ...,
#
#         [[0.4119  , 0.4197  , 0.4666  ],
#          [0.4275  , 0.4353  , 0.4824  ],
#          [0.447   , 0.4548  , 0.502   ],
#          ...,
#          [0.678   , 0.6943  , 0.741   ],
#          [0.647   , 0.6665  , 0.71    ],
#          [0.6157  , 0.6313  , 0.678   ]],
#
#         [[0.4     , 0.408   , 0.4548  ],
#          [0.4353  , 0.443   , 0.4902  ],
#          [0.4626  , 0.4707  , 0.5176  ],
#          ...,
#          [0.5176  , 0.537   , 0.5845  ],
#          [0.4548  , 0.4707  , 0.5176  ],
#          [0.4392  , 0.4548  , 0.502   ]],
#
#         [[0.4236  , 0.4314  , 0.4785  ],
#          [0.408   , 0.4158  , 0.4626  ],
#          [0.447   , 0.4548  , 0.502   ],
#          ...,
#          [0.6235  , 0.643   , 0.6904  ],
#          [0.643   , 0.6587  , 0.706   ],
#          [0.639   , 0.655   , 0.702   ]]],
#
#
#        [[[0.3293  , 0.3293  , 0.3333  ],
#          [0.1569  , 0.1608  , 0.1412  ],
#          [0.051   , 0.0549  , 0.03137 ],
#          ...,
#          [0.392   , 0.3293  , 0.2783  ],
#          [0.357   , 0.2942  , 0.2705  ],
#          [0.2354  , 0.1804  , 0.1804  ]],
#
#         [[0.3452  , 0.3452  , 0.353   ],
#          [0.1765  , 0.1804  , 0.1608  ],
#          [0.05884 , 0.06274 , 0.0392  ],
#          ...,
#          [0.408   , 0.3452  , 0.2942  ],
#          [0.3647  , 0.306   , 0.2783  ],
#          [0.2393  , 0.1843  , 0.1843  ]],
#
#         [[0.3372  , 0.3372  , 0.341   ],
#          [0.1921  , 0.196   , 0.1765  ],
#          [0.0549  , 0.05884 , 0.0353  ],
#          ...,
#          [0.4158  , 0.353   , 0.302   ],
#          [0.3647  , 0.306   , 0.2783  ],
#          [0.2313  , 0.1726  , 0.1726  ]],
#
#         ...,
#
#         [[0.3215  , 0.298   , 0.3137  ],
#          [0.3215  , 0.298   , 0.3137  ],
#          [0.3215  , 0.298   , 0.3137  ],
#          ...,
#          [0.1059  , 0.0941  , 0.06665 ],
#          [0.1059  , 0.0941  , 0.06665 ],
#          [0.102   , 0.0902  , 0.06274 ]],
#
#         [[0.3176  , 0.2942  , 0.3098  ],
#          [0.3176  , 0.2942  , 0.3098  ],
#          [0.3176  , 0.2942  , 0.3098  ],
#          ...,
#          [0.102   , 0.0902  , 0.06274 ],
#          [0.102   , 0.0902  , 0.06274 ],
#          [0.098   , 0.0863  , 0.05884 ]],
#
#         [[0.3137  , 0.2903  , 0.306   ],
#          [0.3137  , 0.2903  , 0.306   ],
#          [0.3137  , 0.2903  , 0.306   ],
#          ...,
#          [0.098   , 0.0863  , 0.05884 ],
#          [0.102   , 0.0902  , 0.06274 ],
#          [0.0941  , 0.08234 , 0.0549  ]]],
#
#
#        [[[0.961   , 0.9253  , 0.937   ],
#          [0.961   , 0.9453  , 0.949   ],
#          [0.957   , 0.933   , 0.9414  ],
#          ...,
#          [0.7295  , 0.549   , 0.498   ],
#          [0.6626  , 0.569   , 0.502   ],
#          [0.655   , 0.5767  , 0.4863  ]],
#
#         [[0.961   , 0.9414  , 0.9453  ],
#          [0.965   , 0.949   , 0.953   ],
#          [0.965   , 0.949   , 0.953   ],
#          ...,
#          [0.71    , 0.533   , 0.4785  ],
#          [0.643   , 0.565   , 0.506   ],
#          [0.6353  , 0.5566  , 0.51    ]],
#
#         [[0.9727  , 0.957   , 0.953   ],
#          [0.9688  , 0.953   , 0.957   ],
#          [0.9688  , 0.953   , 0.957   ],
#          ...,
#          [0.7256  , 0.5605  , 0.5137  ],
#          [0.6665  , 0.5884  , 0.545   ],
#          [0.651   , 0.5767  , 0.5176  ]],
#
#         ...,
#
#         [[0.255   , 0.149   , 0.1372  ],
#          [0.2196  , 0.1216  , 0.1098  ],
#          [0.2235  , 0.1412  , 0.149   ],
#          ...,
#          [0.9414  , 0.937   , 0.961   ],
#          [0.9453  , 0.933   , 0.961   ],
#          [0.937   , 0.9253  , 0.953   ]],
#
#         [[0.2235  , 0.1412  , 0.1216  ],
#          [0.2274  , 0.1372  , 0.1255  ],
#          [0.2274  , 0.1333  , 0.1098  ],
#          ...,
#          [0.949   , 0.9453  , 0.9688  ],
#          [0.949   , 0.937   , 0.965   ],
#          [0.9414  , 0.929   , 0.957   ]],
#
#         [[0.2627  , 0.1608  , 0.153   ],
#          [0.2588  , 0.1333  , 0.1333  ],
#          [0.196   , 0.1255  , 0.1216  ],
#          ...,
#          [0.961   , 0.957   , 0.9766  ],
#          [0.929   , 0.9175  , 0.949   ],
#          [0.9253  , 0.9136  , 0.9414  ]]]], dtype=float16)

# %%
with open('/content/drive/My Drive/Main/imagedatas.txt', 'w') as writefile:
    writefile.write("imagedata")

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
from collections import OrderedDict
jpgs=img_path[:splits]
images_new = OrderedDict()
npix = 224
target_size = (npix,npix,3)
for i,name in enumerate(jpgs): 
    filename = name
    image = load_img(filename, target_size=target_size)
    # convert the image pixels to a numpy array
    image = img_to_array(image)
    nimage = preprocess_input(image)
    y_pred = modelvgg.predict(nimage.reshape( (1,) + nimage.shape[:3]))
    images_new [name] = y_pred.flatten()
    if i%200==0:
        print(i,filename)
# Out:
# 0 /content/drive/My Drive/Main/trainimages/train/10.jpg
# 200 /content/drive/My Drive/Main/trainimages/train/739.jpg
# 400 /content/drive/My Drive/Main/trainimages/train/1529.jpg
# 600 /content/drive/My Drive/Main/trainimages/train/2238.jpg
# 800 /content/drive/My Drive/Main/trainimages/train/2970.jpg
# 1000 /content/drive/My Drive/Main/trainimages/train/3693.jpg
# 1200 /content/drive/My Drive/Main/trainimages/train/4450.jpg
# 1400 /content/drive/My Drive/Main/trainimages/train/150275.jpg
# 1600 /content/drive/My Drive/Main/trainimages/train/497937.jpg
# 1800 /content/drive/My Drive/Main/trainimages/train/713300.jpg
# 2000 /content/drive/My Drive/Main/trainimages/train/1159284.jpg
# 2200 /content/drive/My Drive/Main/trainimages/train/1160083.jpg
# 2400 /content/drive/My Drive/Main/trainimages/train/1592294.jpg
# 2600 /content/drive/My Drive/Main/trainimages/train/1592957.jpg
# 2800 /content/drive/My Drive/Main/trainimages/train/2315779.jpg
# 3000 /content/drive/My Drive/Main/trainimages/train/2316528.jpg
# 3200 /content/drive/My Drive/Main/trainimages/train/2317337.jpg
# 3400 /content/drive/My Drive/Main/trainimages/train/2318048.jpg
# 3600 /content/drive/My Drive/Main/trainimages/train/2318796.jpg
# 3800 /content/drive/My Drive/Main/trainimages/train/2319593.jpg
# 4000 /content/drive/My Drive/Main/trainimages/train/2320436.jpg
# 4200 /content/drive/My Drive/Main/trainimages/train/2321247.jpg
# 4400 /content/drive/My Drive/Main/trainimages/train/2322001.jpg
# 4600 /content/drive/My Drive/Main/trainimages/train/2322763.jpg
# 4800 /content/drive/My Drive/Main/trainimages/train/2323538.jpg

# %%
print(list(images_new.values())[1])
# Out:
# [0.6324536 1.3856603 0.        ... 0.        0.        2.182263 ]

# %%
#storing image pixels sepearetely
vgg_feature=np.zeros(shape=(len(jpgs),4096))
for i in range(len(jpgs)):
    vgg_feature[i]=images_new[jpgs[i]]
vgg_feature[1:10]
# Out:
# array([[0.63245362, 1.38566029, 0.        , ..., 0.        , 0.        ,
#         2.1822629 ],
#        [0.54209262, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.93312246],
#        [1.5215044 , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.11626244, 1.3521657 , 0.05647588, ..., 0.        , 2.70661497,
#         0.        ],
#        [2.4945612 , 1.68215179, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.26692578, 4.36360025, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
#splitting image pixels for training and validation
vgg_train_=vgg_feature[:splits-500]
vgg_val=vgg_feature[splits-500:]

# %%
#Generating a repeat vector from image pixels
img_inputs=Input(shape=(4096,))
d_1=Dense(512, activation='relu')(img_inputs)
r_1=RepeatVector(maxlen_english)(d_1)
vf_model = Model(img_inputs, r_1)
vf_model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 4096)]            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 13, 512)           0
# =================================================================
# Total params: 2,097,664
# Trainable params: 2,097,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.layers import Bidirectional

# %%
import keras.backend as K

# %%
x_voc=x_voc_size
y_voc=y_voc_size

# %%
#Model
x_voc=x_voc_size
y_voc=y_voc_size
latent_dim = 512
embedding_dim=512
#Encoder
encoder_inputs = Input(shape=(maxlen_english,))
#The model will take as input an integer matrix of size (batch,input_length)and the largest integer (i.e. word index) in the input
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)
print(encoder_inputs.get_shape)
print(enc_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 13) dtype=float32 (created by layer 'input_7')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, 13, 512) dtype=float32 (created by layer 'embedding_2')>>

# %%
#encoder LSTM Layer 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
#The dimension of each state equals to the LSTM unit number
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)
print(encoder_lstm1.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 13, 512), (None, 512), (None, 512)]

# %%
#LSTM layer 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)
print(encoder_lstm2.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 13, 512), (None, 512), (None, 512)]

# %%
#LSTM layer 3
#encoder_lstm3 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
#encoder_output3, state_h3, state_c3 = encoder_lstm3(encoder_output2)
#print(encoder_lstm3.output_shape)

# %%
r_1
# Out:
# <KerasTensor: shape=(None, 13, 512) dtype=float32 (created by layer 'repeat_vector_1')>

# %%
import keras.backend as K

# %%
#Concatenating image features with text input 
encoder_output2=Concatenate(axis=-1)([encoder_output2,r_1])

# %%
#LSTM layer 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
print(encoder_lstm3.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, 13, 512), (None, 512), (None, 512)]

# %%
#Decoder
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)
print(decoder_inputs.get_shape)
print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_8')>>
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None, 512) dtype=float32 (created by layer 'embedding_3')>>

# %%
#Decoder LSTM layer1
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])
print(decoder_lstm.output_shape)
# Out:
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [(None, None, 512), (None, 512), (None, 512)]

# %%
#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)
print(decoder_dense.output_shape)
# Out:
# (None, None, 3530)

# %%
model = Model([encoder_inputs,decoder_inputs,img_inputs], decoder_outputs)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 13)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 13, 512)      1044480     input_7[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 13, 512), (N 2099200     embedding_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          2097664     input_6[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 13, 512), (N 2099200     lstm_4[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 13, 512)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 13, 1024)     0           lstm_5[0][0]
#                                                                  repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 512)    1807360     input_8[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 13, 512), (N 3147776     concatenate_1[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, None, 512),  2099200     embedding_3[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, None, 3530)   1810890     lstm_7[0][0]
# ==================================================================================================
# Total params: 16,205,770
# Trainable params: 16,205,770
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
import tensorflow as tf

# %%
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
len(x_tr)
# Out:
# 500

# %%
#compiling model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit([x_tr,y_tr[:,:-1],vgg_train_], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,validation_data=([x_val,y_val[:,:-1],vgg_val], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]),epochs=100,batch_size=512)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 15s 433ms/step - loss: 4.9554 - accuracy: 0.5369 - val_loss: 2.2884 - val_accuracy: 0.6478
# Epoch 2/100
# 9/9 [==============================] - 3s 302ms/step - loss: 2.5749 - accuracy: 0.6244 - val_loss: 2.0487 - val_accuracy: 0.7115
# Epoch 3/100
# 9/9 [==============================] - 3s 305ms/step - loss: 2.3819 - accuracy: 0.6532 - val_loss: 2.0066 - val_accuracy: 0.6850
# Epoch 4/100
# 9/9 [==============================] - 3s 298ms/step - loss: 2.2862 - accuracy: 0.6557 - val_loss: 1.9589 - val_accuracy: 0.7002
# Epoch 5/100
# 9/9 [==============================] - 3s 303ms/step - loss: 2.2277 - accuracy: 0.6728 - val_loss: 1.9106 - val_accuracy: 0.7092
# Epoch 6/100
# 9/9 [==============================] - 3s 304ms/step - loss: 2.1678 - accuracy: 0.6919 - val_loss: 1.8535 - val_accuracy: 0.7285
# Epoch 7/100
# 9/9 [==============================] - 3s 306ms/step - loss: 2.1127 - accuracy: 0.7048 - val_loss: 1.8060 - val_accuracy: 0.7422
# Epoch 8/100
# 9/9 [==============================] - 3s 301ms/step - loss: 2.0713 - accuracy: 0.7099 - val_loss: 1.7766 - val_accuracy: 0.7472
# Epoch 9/100
# 9/9 [==============================] - 3s 303ms/step - loss: 2.0396 - accuracy: 0.7118 - val_loss: 1.7580 - val_accuracy: 0.7488
# Epoch 10/100
# 9/9 [==============================] - 3s 302ms/step - loss: 2.0110 - accuracy: 0.7127 - val_loss: 1.7441 - val_accuracy: 0.7473
# Epoch 11/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.9830 - accuracy: 0.7154 - val_loss: 1.7306 - val_accuracy: 0.7487
# Epoch 12/100
# 9/9 [==============================] - 3s 307ms/step - loss: 1.9542 - accuracy: 0.7221 - val_loss: 1.7235 - val_accuracy: 0.7525
# Epoch 13/100
# 9/9 [==============================] - 3s 307ms/step - loss: 1.9242 - accuracy: 0.7271 - val_loss: 1.7051 - val_accuracy: 0.7522
# Epoch 14/100
# 9/9 [==============================] - 3s 306ms/step - loss: 1.8937 - accuracy: 0.7291 - val_loss: 1.6918 - val_accuracy: 0.7557
# Epoch 15/100
# 9/9 [==============================] - 3s 307ms/step - loss: 1.8641 - accuracy: 0.7334 - val_loss: 1.6798 - val_accuracy: 0.7572
# Epoch 16/100
# 9/9 [==============================] - 3s 305ms/step - loss: 1.8358 - accuracy: 0.7355 - val_loss: 1.6694 - val_accuracy: 0.7587
# Epoch 17/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.8076 - accuracy: 0.7381 - val_loss: 1.6553 - val_accuracy: 0.7617
# Epoch 18/100
# 9/9 [==============================] - 3s 296ms/step - loss: 1.7809 - accuracy: 0.7414 - val_loss: 1.6452 - val_accuracy: 0.7642
# Epoch 19/100
# 9/9 [==============================] - 3s 306ms/step - loss: 1.7547 - accuracy: 0.7437 - val_loss: 1.6345 - val_accuracy: 0.7672
# Epoch 20/100
# 9/9 [==============================] - 3s 305ms/step - loss: 1.7303 - accuracy: 0.7470 - val_loss: 1.6261 - val_accuracy: 0.7693
# Epoch 21/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.7062 - accuracy: 0.7485 - val_loss: 1.6162 - val_accuracy: 0.7698
# Epoch 22/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.6834 - accuracy: 0.7505 - val_loss: 1.6120 - val_accuracy: 0.7740
# Epoch 23/100
# 9/9 [==============================] - 3s 305ms/step - loss: 1.6614 - accuracy: 0.7537 - val_loss: 1.6065 - val_accuracy: 0.7760
# Epoch 24/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.6399 - accuracy: 0.7561 - val_loss: 1.6047 - val_accuracy: 0.7755
# Epoch 25/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.6204 - accuracy: 0.7570 - val_loss: 1.6019 - val_accuracy: 0.7760
# Epoch 26/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.6008 - accuracy: 0.7584 - val_loss: 1.5977 - val_accuracy: 0.7765
# Epoch 27/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.5826 - accuracy: 0.7596 - val_loss: 1.5966 - val_accuracy: 0.7765
# Epoch 28/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.5644 - accuracy: 0.7604 - val_loss: 1.5960 - val_accuracy: 0.7760
# Epoch 29/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.5479 - accuracy: 0.7608 - val_loss: 1.5972 - val_accuracy: 0.7762
# Epoch 30/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.5312 - accuracy: 0.7618 - val_loss: 1.5962 - val_accuracy: 0.7770
# Epoch 31/100
# 9/9 [==============================] - 3s 307ms/step - loss: 1.5150 - accuracy: 0.7622 - val_loss: 1.5949 - val_accuracy: 0.7775
# Epoch 32/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.4983 - accuracy: 0.7632 - val_loss: 1.5975 - val_accuracy: 0.7772
# Epoch 33/100
# 9/9 [==============================] - 3s 299ms/step - loss: 1.4832 - accuracy: 0.7642 - val_loss: 1.5989 - val_accuracy: 0.7775
# Epoch 34/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.4669 - accuracy: 0.7646 - val_loss: 1.6016 - val_accuracy: 0.7772
# Epoch 35/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.4512 - accuracy: 0.7662 - val_loss: 1.6047 - val_accuracy: 0.7772
# Epoch 36/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.4361 - accuracy: 0.7675 - val_loss: 1.6062 - val_accuracy: 0.7773
# Epoch 37/100
# 9/9 [==============================] - 3s 303ms/step - loss: 1.4214 - accuracy: 0.7683 - val_loss: 1.6096 - val_accuracy: 0.7773
# Epoch 38/100
# 9/9 [==============================] - 3s 307ms/step - loss: 1.4052 - accuracy: 0.7693 - val_loss: 1.6101 - val_accuracy: 0.7782
# Epoch 39/100
# 9/9 [==============================] - 3s 306ms/step - loss: 1.3903 - accuracy: 0.7706 - val_loss: 1.6134 - val_accuracy: 0.7780
# Epoch 40/100
# 9/9 [==============================] - 3s 305ms/step - loss: 1.3748 - accuracy: 0.7716 - val_loss: 1.6172 - val_accuracy: 0.7780
# Epoch 41/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.3602 - accuracy: 0.7732 - val_loss: 1.6198 - val_accuracy: 0.7790
# Epoch 42/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.3457 - accuracy: 0.7738 - val_loss: 1.6234 - val_accuracy: 0.7783
# Epoch 43/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.3303 - accuracy: 0.7749 - val_loss: 1.6259 - val_accuracy: 0.7783
# Epoch 44/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.3156 - accuracy: 0.7761 - val_loss: 1.6316 - val_accuracy: 0.7773
# Epoch 45/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.3012 - accuracy: 0.7772 - val_loss: 1.6360 - val_accuracy: 0.7782
# Epoch 46/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.2859 - accuracy: 0.7786 - val_loss: 1.6364 - val_accuracy: 0.7777
# Epoch 47/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.2710 - accuracy: 0.7800 - val_loss: 1.6405 - val_accuracy: 0.7778
# Epoch 48/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.2558 - accuracy: 0.7814 - val_loss: 1.6435 - val_accuracy: 0.7783
# Epoch 49/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.2419 - accuracy: 0.7829 - val_loss: 1.6452 - val_accuracy: 0.7788
# Epoch 50/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.2266 - accuracy: 0.7850 - val_loss: 1.6509 - val_accuracy: 0.7780
# Epoch 51/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.2121 - accuracy: 0.7866 - val_loss: 1.6528 - val_accuracy: 0.7783
# Epoch 52/100
# 9/9 [==============================] - 3s 299ms/step - loss: 1.1961 - accuracy: 0.7892 - val_loss: 1.6547 - val_accuracy: 0.7797
# Epoch 53/100
# 9/9 [==============================] - 3s 298ms/step - loss: 1.1820 - accuracy: 0.7900 - val_loss: 1.6555 - val_accuracy: 0.7800
# Epoch 54/100
# 9/9 [==============================] - 3s 308ms/step - loss: 1.1672 - accuracy: 0.7923 - val_loss: 1.6606 - val_accuracy: 0.7795
# Epoch 55/100
# 9/9 [==============================] - 3s 299ms/step - loss: 1.1523 - accuracy: 0.7954 - val_loss: 1.6645 - val_accuracy: 0.7795
# Epoch 56/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.1378 - accuracy: 0.7975 - val_loss: 1.6671 - val_accuracy: 0.7803
# Epoch 57/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.1237 - accuracy: 0.7994 - val_loss: 1.6666 - val_accuracy: 0.7797
# Epoch 58/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.1103 - accuracy: 0.8019 - val_loss: 1.6761 - val_accuracy: 0.7795
# Epoch 59/100
# 9/9 [==============================] - 3s 304ms/step - loss: 1.0963 - accuracy: 0.8050 - val_loss: 1.6758 - val_accuracy: 0.7792
# Epoch 60/100
# 9/9 [==============================] - 3s 305ms/step - loss: 1.0838 - accuracy: 0.8073 - val_loss: 1.6796 - val_accuracy: 0.7795
# Epoch 61/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.0702 - accuracy: 0.8097 - val_loss: 1.6813 - val_accuracy: 0.7798
# Epoch 62/100
# 9/9 [==============================] - 3s 305ms/step - loss: 1.0578 - accuracy: 0.8115 - val_loss: 1.6845 - val_accuracy: 0.7793
# Epoch 63/100
# 9/9 [==============================] - 3s 300ms/step - loss: 1.0436 - accuracy: 0.8144 - val_loss: 1.6870 - val_accuracy: 0.7788
# Epoch 64/100
# 9/9 [==============================] - 3s 301ms/step - loss: 1.0317 - accuracy: 0.8165 - val_loss: 1.6936 - val_accuracy: 0.7803
# Epoch 65/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.0191 - accuracy: 0.8193 - val_loss: 1.6940 - val_accuracy: 0.7795
# Epoch 66/100
# 9/9 [==============================] - 3s 302ms/step - loss: 1.0073 - accuracy: 0.8210 - val_loss: 1.6979 - val_accuracy: 0.7790
# Epoch 67/100
# 9/9 [==============================] - 3s 299ms/step - loss: 0.9938 - accuracy: 0.8233 - val_loss: 1.7009 - val_accuracy: 0.7788
# Epoch 68/100
# 9/9 [==============================] - 3s 306ms/step - loss: 0.9813 - accuracy: 0.8252 - val_loss: 1.7045 - val_accuracy: 0.7797
# Epoch 69/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.9708 - accuracy: 0.8273 - val_loss: 1.7104 - val_accuracy: 0.7810
# Epoch 70/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.9580 - accuracy: 0.8301 - val_loss: 1.7131 - val_accuracy: 0.7803
# Epoch 71/100
# 9/9 [==============================] - 3s 298ms/step - loss: 0.9463 - accuracy: 0.8318 - val_loss: 1.7133 - val_accuracy: 0.7805
# Epoch 72/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.9356 - accuracy: 0.8343 - val_loss: 1.7155 - val_accuracy: 0.7798
# Epoch 73/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.9251 - accuracy: 0.8348 - val_loss: 1.7166 - val_accuracy: 0.7812
# Epoch 74/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.9149 - accuracy: 0.8371 - val_loss: 1.7265 - val_accuracy: 0.7812
# Epoch 75/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.9038 - accuracy: 0.8391 - val_loss: 1.7270 - val_accuracy: 0.7803
# Epoch 76/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.8932 - accuracy: 0.8409 - val_loss: 1.7282 - val_accuracy: 0.7808
# Epoch 77/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.8823 - accuracy: 0.8424 - val_loss: 1.7302 - val_accuracy: 0.7793
# Epoch 78/100
# 9/9 [==============================] - 3s 300ms/step - loss: 0.8726 - accuracy: 0.8436 - val_loss: 1.7330 - val_accuracy: 0.7797
# Epoch 79/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.8623 - accuracy: 0.8466 - val_loss: 1.7377 - val_accuracy: 0.7797
# Epoch 80/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.8527 - accuracy: 0.8473 - val_loss: 1.7375 - val_accuracy: 0.7802
# Epoch 81/100
# 9/9 [==============================] - 3s 300ms/step - loss: 0.8423 - accuracy: 0.8494 - val_loss: 1.7357 - val_accuracy: 0.7810
# Epoch 82/100
# 9/9 [==============================] - 3s 305ms/step - loss: 0.8331 - accuracy: 0.8506 - val_loss: 1.7409 - val_accuracy: 0.7813
# Epoch 83/100
# 9/9 [==============================] - 3s 299ms/step - loss: 0.8237 - accuracy: 0.8525 - val_loss: 1.7459 - val_accuracy: 0.7805
# Epoch 84/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.8132 - accuracy: 0.8539 - val_loss: 1.7474 - val_accuracy: 0.7807
# Epoch 85/100
# 9/9 [==============================] - 3s 299ms/step - loss: 0.8030 - accuracy: 0.8556 - val_loss: 1.7471 - val_accuracy: 0.7803
# Epoch 86/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.7921 - accuracy: 0.8570 - val_loss: 1.7481 - val_accuracy: 0.7810
# Epoch 87/100
# 9/9 [==============================] - 3s 304ms/step - loss: 0.7824 - accuracy: 0.8584 - val_loss: 1.7497 - val_accuracy: 0.7807
# Epoch 88/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.7729 - accuracy: 0.8595 - val_loss: 1.7505 - val_accuracy: 0.7807
# Epoch 89/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.7626 - accuracy: 0.8614 - val_loss: 1.7572 - val_accuracy: 0.7797
# Epoch 90/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.7516 - accuracy: 0.8628 - val_loss: 1.7606 - val_accuracy: 0.7793
# Epoch 91/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.7419 - accuracy: 0.8640 - val_loss: 1.7546 - val_accuracy: 0.7800
# Epoch 92/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.7302 - accuracy: 0.8654 - val_loss: 1.7547 - val_accuracy: 0.7802
# Epoch 93/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.7183 - accuracy: 0.8674 - val_loss: 1.7527 - val_accuracy: 0.7798
# Epoch 94/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.7062 - accuracy: 0.8699 - val_loss: 1.7574 - val_accuracy: 0.7785
# Epoch 95/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.6950 - accuracy: 0.8713 - val_loss: 1.7631 - val_accuracy: 0.7783
# Epoch 96/100
# 9/9 [==============================] - 3s 300ms/step - loss: 0.6829 - accuracy: 0.8731 - val_loss: 1.7592 - val_accuracy: 0.7780
# Epoch 97/100
# 9/9 [==============================] - 3s 301ms/step - loss: 0.6693 - accuracy: 0.8750 - val_loss: 1.7625 - val_accuracy: 0.7758
# Epoch 98/100
# 9/9 [==============================] - 3s 299ms/step - loss: 0.6528 - accuracy: 0.8787 - val_loss: 1.7619 - val_accuracy: 0.7767
# Epoch 99/100
# 9/9 [==============================] - 3s 302ms/step - loss: 0.6377 - accuracy: 0.8799 - val_loss: 1.7640 - val_accuracy: 0.7757
# Epoch 100/100
# 9/9 [==============================] - 3s 303ms/step - loss: 0.6205 - accuracy: 0.8838 - val_loss: 1.7653 - val_accuracy: 0.7758

# %%
import keras
from matplotlib import pyplot as plt
#history = model1.fit(train_x, train_y,validation_split = 0.1, epochs=50, batch_size=4)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
reverse_target_word_index=y_tokens.index_word
reverse_target_word_index
# Out:
# {1: 'sos',
#  2: 'eos',
#  3: 'ഒരു',
#  4: 'കറുത്ത',
#  5: 'വെളുത്ത',
#  6: 'ധരിച്ച',
#  7: 'സ്ത്രീ',
#  8: 'ബാഗ്',
#  9: 'മനുഷ്യൻ',
#  10: 'ട്രാഷ്',
#  11: 'വലിയ',
#  12: 'പച്ച',
#  13: 'നീല',
#  14: 'ചുവന്ന',
#  15: 'വർണ്ണാഭമായ',
#  16: 'സ്കാർഫ്',
#  17: 'വിൻഡോ',
#  18: 'ചാരനിറത്തിലുള്ള',
#  19: 'കെട്ടിടത്തിലെ',
#  20: 'മഞ്ഞ',
#  21: 'വ്യക്തി',
#  22: 'കാർ',
#  23: 'കെട്ടിടത്തിന്റെ',
#  24: 'വെള്ള',
#  25: 'വശത്ത്',
#  26: 'ഇതൊരു',
#  27: 'ചുവപ്പ്',
#  28: 'ചെറിയ',
#  29: 'മതിൽ',
#  30: 'രണ്ട്',
#  31: 'റോഡിന്റെ',
#  32: 'ഒരാൾ',
#  33: 'മേശപ്പുറത്ത്',
#  34: 'രംഗം',
#  35: 'ചിഹ്നം',
#  36: 'പുല്ലിന്റെ',
#  37: 'ഓറഞ്ച്',
#  38: 'മുകളിൽ',
#  39: 'ബീച്ച്',
#  40: 'എഞ്ചിൻ',
#  41: 'ഉള്ള',
#  42: 'വശങ്ങളിൽ',
#  43: 'പാർക്ക്',
#  44: 'ദ്വീപ്',
#  45: 'സ്ട്രിപ്പുകൾ',
#  46: 'തെരുവിൽ',
#  47: 'നിലത്ത്',
#  48: 'വെള്ളയും',
#  49: 'നടക്കുന്നു',
#  50: 'ആളുകൾ',
#  51: 'തവിട്ട്',
#  52: 'തലം',
#  53: 'മരം',
#  54: 'നിറമുള്ള',
#  55: 'ഇരിക്കുന്നു',
#  56: 'ബസ്',
#  57: 'പുല്ല്',
#  58: 'ഷർട്ട്',
#  59: 'കുഞ്ഞ്',
#  60: 'ആന',
#  61: 'നിൽക്കുന്ന',
#  62: 'ജിറാഫ്',
#  63: 'വെള്ളി',
#  64: 'തെരുവ്',
#  65: 'നിൽക്കുന്നു',
#  66: 'ട്രെയിൻ',
#  67: 'ടെന്നീസ്',
#  68: 'വൈറ്റ്',
#  69: 'ട്രക്ക്',
#  70: 'ഇരിക്കുന്ന',
#  71: 'ഗ്ലാസ്',
#  72: 'ഇത്',
#  73: 'വെള്ളത്തിൽ',
#  74: 'കുട',
#  75: 'നായ',
#  76: 'ചുവപ്പും',
#  77: 'പിങ്ക്',
#  78: 'വിമാനം',
#  79: 'പെൺകുട്ടി',
#  80: 'മോട്ടോർ',
#  81: 'മിഠായി',
#  82: 'കറുപ്പും',
#  83: 'വിളക്ക്',
#  84: 'പിടിക്കുന്നു',
#  85: 'കോട്ടൺ',
#  86: 'ചുവരിൽ',
#  87: 'ലൈറ്റ്',
#  88: 'ബേസ്ബോൾ',
#  89: 'കെട്ടിടത്തിന്',
#  90: 'മുന്നിൽ',
#  91: 'നീലയും',
#  92: 'കമ്പ്യൂട്ടർ',
#  93: 'ചുമരിൽ',
#  94: 'ഉണ്ട്',
#  95: 'തൊപ്പി',
#  96: 'തിന്നുന്നു',
#  97: 'ചെയ്യുന്നു',
#  98: 'മനുഷ്യന്റെ',
#  99: 'കൂട്ടം',
#  100: 'അടയാളം',
#  101: 'ആണ്',
#  102: 'റോഡിൽ',
#  103: 'വെളിച്ചം',
#  104: 'തവിട്ടുനിറത്തിലുള്ള',
#  105: 'കുട്ടി',
#  106: 'ഉയരമുള്ള',
#  107: 'കസേര',
#  108: 'ഭാഗം',
#  109: 'പക്ഷി',
#  110: 'നീളമുള്ള',
#  111: 'ട്രാഫിക്',
#  112: 'കെട്ടിടം',
#  113: 'ചെയ്തിരിക്കുന്നു',
#  114: 'തടി',
#  115: 'ചിത്രം',
#  116: 'നിറത്തിലുള്ള',
#  117: 'ജാക്കറ്റ്',
#  118: 'പാത്രം',
#  119: 'പുള്ളി',
#  120: 'പിസ്സ',
#  121: 'ക്ലോക്ക്',
#  122: 'കേക്ക്',
#  123: 'ഘടികാരം',
#  124: 'ബോട്ട്',
#  125: 'ഇരുണ്ട',
#  126: 'കറുത്തതാണ്',
#  127: 'പ്ലേറ്റിൽ',
#  128: 'പൂച്ച',
#  129: 'പ്ലേറ്റ്',
#  130: 'ധരിക്കുന്നു',
#  131: 'മുടിയുള്ള',
#  132: 'പുല്ലിൽ',
#  133: 'ആകാശം',
#  134: 'കൈവശമുള്ള',
#  135: 'മെറ്റൽ',
#  136: 'മൂന്ന്',
#  137: 'ബ്രൗൺ',
#  138: 'പയ്യൻ',
#  139: 'വെളുത്തതാണ്',
#  140: 'നിന്ന്',
#  141: 'തല',
#  142: 'ഫോൺ',
#  143: 'തുറന്ന',
#  144: 'കളിക്കാരൻ',
#  145: 'വാതിൽ',
#  146: 'കട്ടിലിൽ',
#  147: 'ഇഷ്ടിക',
#  148: 'ചെയ്ത',
#  149: 'നടപ്പാതയിൽ',
#  150: 'ധ്രുവത്തിൽ',
#  151: 'പോൾ',
#  152: 'പച്ചയും',
#  153: 'ഓടിക്കുന്നു',
#  154: 'ആകാശത്ത്',
#  155: 'ടോയ്\u200cലറ്റ്',
#  156: 'സൈക്കിൾ',
#  157: 'വയലിൽ',
#  158: 'മുകളിലുള്ള',
#  159: 'ബൈക്ക്',
#  160: 'കാഴ്ച',
#  161: 'ടാൻ',
#  162: 'പഴയ',
#  163: 'കരടി',
#  164: 'കപ്പ്',
#  165: 'നടക്കുന്ന',
#  166: 'സ്ത്രീയുടെ',
#  167: 'വായുവിൽ',
#  168: 'ചുവപ്പാണ്',
#  169: 'പാത്രത്തിൽ',
#  170: 'നീലയാണ്',
#  171: 'സിൽവർ',
#  172: 'പിന്നിൽ',
#  173: 'ഇളം',
#  174: 'ടയർ',
#  175: 'വാൻ',
#  176: 'ചെയ്യുന്ന',
#  177: 'വെളുപ്പും',
#  178: 'രണ്ടുപേർ',
#  179: 'ഇലകൾ',
#  180: 'ആൺകുട്ടി',
#  181: 'ബെഞ്ചിൽ',
#  182: 'മനുഷ്യന്',
#  183: 'നിർത്തി',
#  184: 'കുപ്പി',
#  185: 'ഭക്ഷണം',
#  186: 'വാഴപ്പഴം',
#  187: 'വ്യക്തിയുടെ',
#  188: 'കാൽ',
#  189: 'പൂക്കൾ',
#  190: 'ഉപയോഗിച്ച്',
#  191: 'പാർക്കിംഗ്',
#  192: 'അടുക്കള',
#  193: 'പതാക',
#  194: 'ഹെൽമെറ്റ്',
#  195: 'ബെഞ്ച്',
#  196: 'നിറത്തിലാണ്',
#  197: 'കൈ',
#  198: 'ലാപ്\u200cടോപ്പ്',
#  199: 'തീവണ്ടി',
#  200: 'നിറമാണ്',
#  201: 'മുടിയുണ്ട്',
#  202: 'വരയുള്ള',
#  203: 'ഫ്രെയിം',
#  204: 'ലൈറ്റുകൾ',
#  205: 'നടപ്പാതയിലൂടെ',
#  206: 'വെള്ളം',
#  207: 'മരത്തിൽ',
#  208: 'പർപ്പിൾ',
#  209: 'കസേരയിൽ',
#  210: 'കോഫി',
#  211: 'പ്ലാസ്റ്റിക്',
#  212: 'ജലാംശം',
#  213: 'നിരവധി',
#  214: 'പറക്കുന്നു',
#  215: 'സീബ്ര',
#  216: 'സെൽ',
#  217: 'കിടക്കുന്നു',
#  218: 'സ്കേറ്റ്ബോർഡ്',
#  219: 'തൂക്കിയിരിക്കുന്നു',
#  220: 'ചവറ്റുകുട്ട',
#  221: 'പരസ്പരം',
#  222: 'വ്യക്തിയാണ്',
#  223: 'ടൈ',
#  224: 'തൂക്കിയിട്ടിരിക്കുന്ന',
#  225: 'ചെയ്തു',
#  226: 'ഷർട്ടും',
#  227: 'സ്വർണ്ണ',
#  228: 'വൃത്താകൃതിയിലുള്ള',
#  229: 'കിടക്ക',
#  230: 'മഞ്ഞ്',
#  231: 'റാക്കറ്റ്',
#  232: 'നോക്കുന്നു',
#  233: 'സർഫ്ബോർഡ്',
#  234: 'ബാറ്റ്',
#  235: 'നാല്',
#  236: 'കെട്ടിടത്തിൽ',
#  237: 'ഇല',
#  238: 'തലയിണ',
#  239: 'ജാലകം',
#  240: 'മോണിറ്റർ',
#  241: 'പന്ത്',
#  242: 'മോട്ടോർസൈക്കിൾ',
#  243: 'അടുത്തുള്ള',
#  244: 'ഫ്ലാഗ്',
#  245: 'ടാക്സി',
#  246: 'തലയിൽ',
#  247: 'ചുറ്റും',
#  248: 'വിമാനത്തിന്റെ',
#  249: 'മുറിയിൽ',
#  250: 'കല്ല്',
#  251: 'ജനൽ',
#  252: 'വാഹനം',
#  253: 'തറയിൽ',
#  254: 'വസ്ത്രം',
#  255: 'കളിക്കുന്ന',
#  256: 'കുതിര',
#  257: 'ഷർട്ടിൽ',
#  258: 'കൈവശം',
#  259: 'മുഖം',
#  260: 'കടൽത്തീരത്ത്',
#  261: 'ചായം',
#  262: 'ഗെയിം',
#  263: 'തെരുവിലൂടെ',
#  264: 'മരത്തിന്റെ',
#  265: 'മരങ്ങൾ',
#  266: 'ഇവ',
#  267: 'വിൻഡോയിൽ',
#  268: 'ചെയ്തിരിക്കുന്ന',
#  269: 'പാന്റ്സ്',
#  270: 'പേപ്പർ',
#  271: 'മഞ്ഞയും',
#  272: 'നീലാകാശം',
#  273: 'നിർമ്മിച്ച',
#  274: 'സ്ത്രീക്ക്',
#  275: 'ബോർഡ്',
#  276: 'പെട്ടി',
#  277: 'വേലി',
#  278: 'അഗ്നി',
#  279: 'മുടി',
#  280: 'തവിട്ടുനിറമാണ്',
#  281: 'പക്ഷിയുടെ',
#  282: 'ധരിക്കുന്ന',
#  283: 'മനുഷ്യനാണ്',
#  284: 'റോഡ്',
#  285: 'നഗര',
#  286: 'കഴിക്കുന്നു',
#  287: 'ആപ്പിൾ',
#  288: 'കത്തി',
#  289: 'ബിയർ',
#  290: 'കളിക്കുന്നു',
#  291: 'സൈക്കിളിൽ',
#  292: 'സ്കേറ്റ്ബോർഡിൽ',
#  293: 'ആടുകൾ',
#  294: 'സർഫിംഗ്',
#  295: 'കാറിന്റെ',
#  296: 'മുറിയിലെ',
#  297: 'വൃക്ഷം',
#  298: 'കണ്ണാടി',
#  299: 'നടപ്പാത',
#  300: 'അരികിൽ',
#  301: 'സ്ക്രീൻ',
#  302: 'സീലിംഗിൽ',
#  303: 'സ്ത്രീകൾ',
#  304: 'അമേരിക്കൻ',
#  305: 'മഞ്ഞുവീഴ്ചയിൽ',
#  306: 'വരകൾ',
#  307: 'വാൽ',
#  308: 'ടവർ',
#  309: 'അടയാളങ്ങൾ',
#  310: 'പ്രതിഫലനം',
#  311: 'ബ്ലാക്ക്',
#  312: 'കറുപ്പ്',
#  313: 'കാറുകൾ',
#  314: 'ക്യാമറ',
#  315: 'സ്വെറ്റർ',
#  316: 'കിടക്കുന്ന',
#  317: 'സവാരി',
#  318: 'ചിഹ്നത്തിൽ',
#  319: 'ഓടിക്കുന്ന',
#  320: 'ടെഡി',
#  321: 'സ്യൂട്ട്',
#  322: 'ചെവി',
#  323: 'ചെറുപ്പക്കാരൻ',
#  324: 'കഷണം',
#  325: 'മുൻവശത്ത്',
#  326: 'മുറിച്ചുകടക്കുന്ന',
#  327: 'കട്ടിയുള്ള',
#  328: 'മേൽക്കൂര',
#  329: 'കുപ്പായമുള്ള',
#  330: 'കാറിന്',
#  331: 'സമീപം',
#  332: 'മേശ',
#  333: 'നഗരത്തിലെ',
#  334: 'അവന്റെ',
#  335: 'നിര',
#  336: 'ടെലിവിഷൻ',
#  337: 'കടലാസ്',
#  338: 'ധാരാളം',
#  339: 'നിറഞ്ഞ',
#  340: 'പുസ്തകം',
#  341: 'നിറത്തിൽ',
#  342: 'സീലിംഗ്',
#  343: 'അക്ഷരങ്ങളുള്ള',
#  344: 'വശത്തുള്ള',
#  345: 'സഞ്ചരിക്കുന്ന',
#  346: 'പകൽ',
#  347: 'പുറത്ത്',
#  348: 'ട്രെയിനിൽ',
#  349: 'കുന്നിൻ',
#  350: 'ബോട്ടിൽ',
#  351: 'ജീൻസ്',
#  352: 'ഇതാണ്',
#  353: 'ടൈൽ',
#  354: 'പച്ചയാണ്',
#  355: 'കടും',
#  356: 'റൺവേയിൽ',
#  357: 'തൂവാല',
#  358: 'വ്യക്തമായ',
#  359: 'മേശയിൽ',
#  360: 'ഡോനട്ട്',
#  361: 'കോർട്ടിൽ',
#  362: 'ഹാൻഡിൽ',
#  363: 'പിടിക്കുന്ന',
#  364: 'റെഡ്',
#  365: 'പശു',
#  366: 'ബസിന്റെ',
#  367: 'ജെറ്റ്',
#  368: 'കയ്യിൽ',
#  369: 'ട്രെയിനിന്റെ',
#  370: 'സ്കീയർ',
#  371: 'ഫ്രിസ്ബീ',
#  372: 'മുഖത്ത്',
#  373: 'ലോഹത്തിന്റെ',
#  374: 'മൈക്രോവേവ്',
#  375: 'തിളങ്ങുന്ന',
#  376: 'ചാരനിറമാണ്',
#  377: 'ഡെസ്\u200cകിൽ',
#  378: 'ചെയ്യുക',
#  379: 'നേരെ',
#  380: 'സിങ്ക്',
#  381: 'വീടിന്റെ',
#  382: 'ക്യാബ്',
#  383: 'വെള്ളത്തിനടുത്തുള്ള',
#  384: 'വിമാനത്തിലെ',
#  385: 'വളരെ',
#  386: 'കണ്ണ്',
#  387: 'വള്ളം',
#  388: 'അക്ഷരം',
#  389: 'പേർ',
#  390: 'മുറിയുടെ',
#  391: 'പോലീസ്',
#  392: 'സ്ത്രീയും',
#  393: 'മഞ്ഞിൽ',
#  394: 'പാളി',
#  395: 'മൂലയിൽ',
#  396: 'അടുക്കളയിൽ',
#  397: 'പുറകിൽ',
#  398: 'ടോപ്പ്',
#  399: 'തിളക്കമുള്ള',
#  400: 'വീട്',
#  401: 'സംസാരിക്കുന്നു',
#  402: 'പെൺകുട്ടിയുടെ',
#  403: 'ഒരുമിച്ച്',
#  404: 'ദമ്പതികൾ',
#  405: 'പ്രകാശം',
#  406: 'പൂശിയ',
#  407: 'അലങ്കാര',
#  408: 'ഫാൻ',
#  409: 'അമ്പടയാളം',
#  410: 'വലതുവശത്ത്',
#  411: 'ജാലകമുണ്ട്',
#  412: 'ഭുജം',
#  413: 'പുഷ്പം',
#  414: 'ചിമ്മിനി',
#  415: 'മേഘങ്ങൾ',
#  416: 'ഇടത്',
#  417: 'അഭിമുഖമായി',
#  418: 'പാറ',
#  419: 'പാലം',
#  420: 'നിലത്തു',
#  421: 'കഴിക്കുന്ന',
#  422: 'സർഫ്ബോർഡിൽ',
#  423: 'മണൽ',
#  424: 'ഫയർ',
#  425: 'സാൻഡ്\u200cവിച്ച്',
#  426: 'ജിറാഫുകൾ',
#  427: 'സൈനിക',
#  428: 'ഗതാഗത',
#  429: 'പകുതി',
#  430: 'കോട്ട്',
#  431: 'വൈൻ',
#  432: 'തെരുവിലെ',
#  433: 'ബോൾ',
#  434: 'കുതിരയുടെ',
#  435: 'സ്കേറ്റ്ബോർഡിംഗ്',
#  436: 'ആൻഡ്',
#  437: 'കണ്ണട',
#  438: 'നമ്പർ',
#  439: 'ഫോട്ടോ',
#  440: 'കസേരകൾ',
#  441: 'ഡ്രൈവിംഗ്',
#  442: 'കാബിനറ്റ്',
#  443: 'കൗണ്ടറിൽ',
#  444: 'ടേബിൾ',
#  445: 'തറ',
#  446: 'ഘടിപ്പിച്ചിരിക്കുന്നു',
#  447: 'അകലെ',
#  448: 'ചീസ്',
#  449: 'അടുത്ത്',
#  450: 'മേശയുടെ',
#  451: 'ബാക്ക്പാക്ക്',
#  452: 'മുറി',
#  453: 'പ്ലെയ്ഡ്',
#  454: 'സോഫ',
#  455: 'പ്രദേശം',
#  456: 'ഫോണിൽ',
#  457: 'പോസ്റ്റിൽ',
#  458: 'ടാർമാക്കിൽ',
#  459: 'മേഘം',
#  460: 'അലങ്കരിച്ച',
#  461: 'പുരുഷന്റെ',
#  462: 'കുപ്പായം',
#  463: 'പെയിന്റിംഗ്',
#  464: 'കൊട്ടയിൽ',
#  465: 'റൊട്ടി',
#  466: 'ഡെസ്ക്',
#  467: 'ഗ്രേ',
#  468: 'പ്രതിമ',
#  469: 'ക',
#  470: 'ചതുരം',
#  471: 'കുടകൾ',
#  472: 'ഇടതുവശത്ത്',
#  473: 'ടിവി',
#  474: 'അക്ഷരങ്ങൾ',
#  475: 'തിളങ്ങുന്നു',
#  476: 'ചതുര',
#  477: 'വാസ്',
#  478: 'സർഫ്ബോർഡിലെ',
#  479: 'പ്രവേശന',
#  480: 'കൂമ്പാരം',
#  481: 'ബീജ്',
#  482: 'ആകാശത്തിന്റെ',
#  483: 'കൊണ്ട്',
#  484: 'സീറ്റ്',
#  485: 'പൂക്കളുള്ള',
#  486: 'ഇന്റീരിയർ',
#  487: 'സമീപമുള്ള',
#  488: 'വായിൽ',
#  489: 'വളഞ്ഞ',
#  490: 'വണ്ടി',
#  491: 'വിളക്കുകൾ',
#  492: 'വാണിജ്യ',
#  493: 'ശാഖയിൽ',
#  494: 'വര',
#  495: 'ജോടി',
#  496: 'വസ്ത്രത്തിൽ',
#  497: 'അക്കങ്ങൾ',
#  498: 'ജാക്കറ്റിലുള്ള',
#  499: 'സ്ഥലത്ത്',
#  500: 'ഭക്ഷണത്തിന്റെ',
#  501: 'വീട്ടിൽ',
#  502: 'റോഡിലെ',
#  503: 'ചരട്',
#  504: 'പാത',
#  505: 'നനഞ്ഞ',
#  506: 'കവർ',
#  507: 'സീബ്രയുടെ',
#  508: 'ശിരോകവജം',
#  509: 'ഫ്രിസ്\u200cബീ',
#  510: 'ഗ്ലാസുകൾ',
#  511: 'വാട്ടർ',
#  512: 'വച്ചിരിക്കുന്ന',
#  513: 'ട്രേയിൽ',
#  514: 'ബൈക്കിൽ',
#  515: 'ഷോർട്ട്സ്',
#  516: 'വൈ',
#  517: 'ചതുരാകൃതിയിലുള്ള',
#  518: 'വീഞ്ഞ്',
#  519: 'അതിൽ',
#  520: 'കൈയിൽ',
#  521: 'ഓടുന്നു',
#  522: 'വിരൽ',
#  523: 'ഡബിൾ',
#  524: 'കിടക്കയിൽ',
#  525: 'ട്രെയിനിലെ',
#  526: 'ശേഖരം',
#  527: 'കൈറ്റ്',
#  528: 'ട്രാക്കിൽ',
#  529: 'ഷൂ',
#  530: 'പട്ടം',
#  531: 'വെള്ളത്തിന്',
#  532: 'കൊച്ചുകുട്ടി',
#  533: 'കീഴിൽ',
#  534: 'ടവറിൽ',
#  535: 'പെട്ടിയിൽ',
#  536: 'നായയുടെ',
#  537: 'പൂച്ചയുടെ',
#  538: 'മൃഗങ്ങൾ',
#  539: 'ജിറാഫിന്റെ',
#  540: 'ട്രക്കിന്റെ',
#  541: 'സർഫർ',
#  542: 'ഓവൻ',
#  543: 'എസ്\u200cയുവി',
#  544: 'ഓണാണ്',
#  545: 'തുമ്പിക്കൈ',
#  546: 'പുസ്തക',
#  547: 'ഈന്തപ്പന',
#  548: 'തുറന്നു',
#  549: 'മരത്തിന്',
#  550: 'നരച്ച',
#  551: 'സോസ്',
#  552: 'മഞ്ഞയാണ്',
#  553: 'പെയിന്റ്',
#  554: 'ലൈൻ',
#  555: 'പട്ടിക',
#  556: 'സിഗ്നൽ',
#  557: 'മേൽക്കൂരയുള്ള',
#  558: 'കട്ടിലിന്',
#  559: 'വെളുത്തതും',
#  560: 'ഹോട്ടൽ',
#  561: 'ഭക്ഷണ',
#  562: 'ബോക്സ്',
#  563: 'ലഗേജ്',
#  564: 'നീണ്ട',
#  565: 'നിറച്ച',
#  566: 'സിങ്കിൽ',
#  567: 'അലമാരയിൽ',
#  568: 'കുളം',
#  569: 'എന്ന',
#  570: 'പാവാട',
#  571: 'റിമോട്ട്',
#  572: 'മിറർ',
#  573: 'പാലത്തിൽ',
#  574: 'ഇടതുവശത്തുള്ള',
#  575: 'നിറയെ',
#  576: 'സ്ലാറ്റ്',
#  577: 'കാറാണ്',
#  578: 'കാറിലെ',
#  579: 'ലൈസൻസ്',
#  580: 'റെയിലിംഗ്',
#  581: 'ചാര',
#  582: 'വഴി',
#  583: 'കലം',
#  584: 'സ്റ്റാൻഡിൽ',
#  585: 'വെള്ളിയാണ്',
#  586: 'തൂങ്ങിക്കിടക്കുന്നു',
#  587: 'കൊക്ക്',
#  588: 'തൂക്കിയിട്ട',
#  589: 'കലത്തിൽ',
#  590: 'പോളിൽ',
#  591: 'പാച്ച്',
#  592: 'കടൽത്തീരം',
#  593: 'ഇലകളുള്ള',
#  594: 'തെളിഞ്ഞ',
#  595: 'ശോഭയുള്ള',
#  596: 'പോസ്റ്റ്',
#  597: 'ചാരിയിരിക്കുന്ന',
#  598: 'മേഘങ്ങളുള്ള',
#  599: 'മൂടിയ',
#  600: 'വേലിയിൽ',
#  601: 'റോഡിന്',
#  602: 'സ്ഥാപിച്ചിരിക്കുന്നു',
#  603: 'ട്രക്കിൽ',
#  604: 'സ്കൂൾ',
#  605: 'മതിലിനു',
#  606: 'അവൻ',
#  607: 'മേശപ്പുറത്തുണ്ട്',
#  608: 'വെള്ളത്തിന്റെ',
#  609: 'മാൻ',
#  610: 'വീഡിയോ',
#  611: 'ട്രിം',
#  612: 'കഴുത്തിൽ',
#  613: 'ചെടിയിൽ',
#  614: 'എന്ന്',
#  615: 'കോൺ',
#  616: 'റൗണ്ട്',
#  617: 'ഈ',
#  618: 'പാത്രങ്ങൾ',
#  619: 'തന്റെ',
#  620: 'മൂക്ക്',
#  621: 'തളികയിൽ',
#  622: 'കേസ്',
#  623: 'ബസിലെ',
#  624: 'ആനയുടെ',
#  625: 'സ്യൂട്ട്കേസ്',
#  626: 'ചുമക്കുന്ന',
#  627: 'ഹോട്ട്',
#  628: 'കീബോർഡ്',
#  629: 'ഗോപുരത്തിലെ',
#  630: 'ധരിച്ചിരിക്കുന്നു',
#  631: 'ഗ്ലാസിൽ',
#  632: 'തൊപ്പിയും',
#  633: 'ഡെക്കർ',
#  634: 'കയറുന്ന',
#  635: 'സൺഗ്ലാസുകൾ',
#  636: 'ബാത്ത്റൂം',
#  637: 'മൗസ്',
#  638: 'സോക്കർ',
#  639: 'ഏഷ്യൻ',
#  640: 'വ്യക്തവുമാണ്',
#  641: 'സ്നോബോർഡ്',
#  642: 'മേൽ',
#  643: 'ബോട്ടുകൾ',
#  644: 'മുകളിലൂടെ',
#  645: 'മൃഗം',
#  646: 'ബസ്സിലെ',
#  647: 'വച്ചിരിക്കുന്നു',
#  648: 'കൂട്ടിൽ',
#  649: 'പഴങ്ങൾ',
#  650: 'സ്റ്റോപ്പ്',
#  651: 'സമുദ്രത്തിൽ',
#  652: 'താഴേക്ക്',
#  653: 'ബസുകൾ',
#  654: 'റഫ്രിജറേറ്റർ',
#  655: 'സഞ്ചരിക്കുന്നു',
#  656: 'കരടിയുടെ',
#  657: 'വേലിക്ക്',
#  658: 'വാഴപ്പഴത്തിന്റെ',
#  659: 'ബ്ലെൻഡർ',
#  660: 'പിസ്സയിൽ',
#  661: 'ചിറക്',
#  662: 'പശ്ചാത്തലത്തിലുള്ള',
#  663: 'സ്കീയിംഗ്',
#  664: 'നടത്തുന്ന',
#  665: 'പുരുഷ',
#  666: 'ഓണാക്കി',
#  667: 'ഓഫീസ്',
#  668: 'ഫലം',
#  669: 'കൺട്രോളർ',
#  670: 'ജാലകങ്ങൾ',
#  671: 'നില',
#  672: 'പിൻ',
#  673: 'ഹൗസ്',
#  674: 'മണലിൽ',
#  675: 'തിരശ്ശീല',
#  676: 'ടെലിഫോൺ',
#  677: 'കുളിമുറിയിൽ',
#  678: 'ചെടി',
#  679: 'സ്റ്റീൽ',
#  680: 'കൊണ്ടുള്ള',
#  681: 'രാത്രി',
#  682: 'നിർത്തിയിട്ടിരിക്കുന്ന',
#  683: 'തിരക്കേറിയ',
#  684: 'ക്രോസ്',
#  685: 'വിമാനങ്ങൾ',
#  686: 'പാറകൾ',
#  687: 'ചെറുതാണ്',
#  688: 'ഹൈവേ',
#  689: 'മിനിവാൻ',
#  690: 'സ്കൂട്ടർ',
#  691: 'സൂര്യൻ',
#  692: 'ശൈലിയിലുള്ള',
#  693: 'വലുതാണ്',
#  694: 'അടുത്താണ്',
#  695: 'ചട്ടി',
#  696: 'ഡ്രെസ്സറിൽ',
#  697: 'ഫ്ലാറ്റ്',
#  698: 'ബസ്സിൽ',
#  699: 'ചരക്ക്',
#  700: 'ചുറ്റുമുള്ള',
#  701: 'വെളുത്തതുമായ',
#  702: 'ഗോവണി',
#  703: 'ഡോക്ക്',
#  704: 'മഴവില്ല്',
#  705: 'ജനാല',
#  706: 'മുന്നിലെ',
#  707: 'ഷെൽഫിൽ',
#  708: 'ജീൻസും',
#  709: 'പ്ലാന്റ്',
#  710: 'എഴുത്ത്',
#  711: 'വിൻഡോയിലെ',
#  712: 'വുഡൻ',
#  713: 'നിർത്തിയിട്ടിരിക്കുന്നു',
#  714: 'ശൂന്യമായ',
#  715: 'റോഡിലൂടെ',
#  716: 'ക്രോസിംഗ്',
#  717: 'വാഹനത്തിന്റെ',
#  718: 'ചക്രം',
#  719: 'തെരുവിന്റെ',
#  720: 'മുൻവശത്തെ',
#  721: 'പർവ്വതം',
#  722: 'വിളക്കിൽ',
#  723: 'അടുക്കളയിലെ',
#  724: 'അടുപ്പിൽ',
#  725: 'തുണിയിൽ',
#  726: 'മുൻ',
#  727: 'സെറ്റ്',
#  728: 'മേശയിലെ',
#  729: 'മത്സ്യം',
#  730: 'സ്ട്രീറ്റ്',
#  731: 'വഴിയിൽ',
#  732: 'പേഴ്സ്',
#  733: 'മുകളിലേക്ക്',
#  734: 'കുറ്റിക്കാടുകൾ',
#  735: 'സീബ്രയിൽ',
#  736: 'കയർ',
#  737: 'സുവ',
#  738: 'വാച്ച്',
#  739: 'അഴുക്കുചാലിൽ',
#  740: 'കെട്ടിടമാണ്',
#  741: 'ഗ്രീൻ',
#  742: 'തെരുവിന്',
#  743: 'ചില',
#  744: 'ആഴത്തിലുള്ള',
#  745: 'ട്രാക്കുകൾ',
#  746: 'നടപ്പാതയിലെ',
#  747: 'കോർണർ',
#  748: 'ലെഗ്',
#  749: 'ചാരനിറവും',
#  750: 'റെയിൽ',
#  751: 'പുഷ്പ',
#  752: 'നിറം',
#  753: 'സ്റ്റാപ്ലർ',
#  754: 'കവാടത്തിൽ',
#  755: 'മേശയ്ക്കു',
#  756: 'തക്കാളി',
#  757: 'സ്റ്റൈറോഫോം',
#  758: 'മുകൾവശം',
#  759: 'സമയത്ത്',
#  760: 'മുറ്റത്ത്',
#  761: 'നിറമുണ്ട്',
#  762: 'കപ്പിൽ',
#  763: 'സ്ക്രീനിൽ',
#  764: 'കളിക്കാരന്റെ',
#  765: 'റിബൺ',
#  766: 'ഇരിപ്പിടം',
#  767: 'പറയുന്ന',
#  768: 'കളിപ്പാട്ട',
#  769: 'ജലത്തിന്റെ',
#  770: 'വരികൾ',
#  771: 'പക്ഷികൾ',
#  772: 'പാനൽ',
#  773: 'പുൽത്തകിടിയിലെ',
#  774: 'കാബിനറ്റിൽ',
#  775: 'പിടിച്ചിരിക്കുന്ന',
#  776: 'ഘടിപ്പിച്ചിരിക്കുന്ന',
#  777: 'സ്റ്റഫ്',
#  778: 'ഷർട്ടിലുള്ള',
#  779: 'സ്യൂട്ടിലുള്ള',
#  780: 'പൊതിഞ്ഞ',
#  781: 'സ്പൂൺ',
#  782: 'ഹൈഡ്രാന്റ്',
#  783: 'പിന്നിലുള്ള',
#  784: 'പുല്ലു',
#  785: 'ചോക്ലേറ്റ്',
#  786: 'ഡോണട്ട്സ്',
#  787: 'തവിട്ടുനിറമുള്ള',
#  788: 'വ്യത്യസ്ത',
#  789: 'കയറുന്നു',
#  790: 'സ്കേറ്റ്ബോർഡിലാണ്',
#  791: 'ട്രാക്കുകളിൽ',
#  792: 'തീവണ്ടിയുടെ',
#  793: 'ടോയ്\u200cലറ്റിന്റെ',
#  794: 'തെരുവിലാണ്',
#  795: 'ടാഗ്',
#  796: 'ധരിച്ചിരിക്കുന്ന',
#  797: 'വെള്ളിയും',
#  798: 'പുക',
#  799: 'സോഡ',
#  800: 'കളിപ്പാട്ടം',
#  801: 'ഗോപുരത്തിന്റെ',
#  802: 'സ്നോ',
#  803: 'വലുതും',
#  804: 'കൂടുതൽ',
#  805: 'ഫ്രിസ്\u200cബിയെ',
#  806: 'യുവാവ്',
#  807: 'ഫ്രിഡ്ജിൽ',
#  808: 'സ്റ്റേഷനിൽ',
#  809: 'മേൽക്കൂരയിൽ',
#  810: 'സുന്ദരമായ',
#  811: 'മഞ്ഞുമൂടിയ',
#  812: 'കുതിരകൾ',
#  813: 'പഴത്തിന്റെ',
#  814: 'പൂച്ചയ്ക്ക്',
#  815: 'സർഫ്',
#  816: 'ലൈറ്റുകളുള്ള',
#  817: 'ടി',
#  818: 'ഉപകരണങ്ങൾ',
#  819: 'അലകൾ',
#  820: 'പറക്കുന്ന',
#  821: 'ഗോപുരം',
#  822: 'കാണുന്നു',
#  823: 'ആൺകുട്ടികൾ',
#  824: 'ഫർണിച്ചർ',
#  825: 'ചെരുപ്പ്',
#  826: 'കളിക്കാർ',
#  827: 'സ്കൈ',
#  828: 'പിടിച്ചിരിക്കുന്നു',
#  829: 'കാത്തിരിക്കുന്ന',
#  830: 'ലൈറ്റിൽ',
#  831: 'പത്രം',
#  832: 'വായിക്കുന്ന',
#  833: 'അണിനിരക്കും',
#  834: 'പാസഞ്ചർ',
#  835: 'സിറ്റി',
#  836: 'സ്റ്റാൻഡിന്',
#  837: 'റേസിംഗ്',
#  838: 'വിവിധ',
#  839: 'നിലം',
#  840: 'യുവതി',
#  841: 'പൈ',
#  842: 'മുറിച്ച',
#  843: 'ഉയർത്തിപ്പിടിക്കുന്നു',
#  844: 'നിയോൺ',
#  845: 'സുരക്ഷാ',
#  846: 'ഓഫീസിലെ',
#  847: 'മുറിച്ചു',
#  848: 'ബർഗണ്ടി',
#  849: 'വ്യക്തിക്ക്',
#  850: 'ടൈയും',
#  851: 'പീസ്',
#  852: 'പശുക്കൾ',
#  853: 'തീ',
#  854: 'ഇരുമ്പ്',
#  855: 'പുതിയ',
#  856: 'കുളിമുറിയാണ്',
#  857: 'ആട്',
#  858: 'പിസ്സയുടെ',
#  859: 'ഇട്ട',
#  860: 'പോകുന്നു',
#  861: 'മുൻവശം',
#  862: 'വായുവിലാണ്',
#  863: 'അടുക്കിയിരിക്കുന്നു',
#  864: 'ലെതർ',
#  865: 'വീഞ്ഞു',
#  866: 'കുടിക്കുന്നു',
#  867: 'സ്വിംഗ്',
#  868: 'സ്കീ',
#  869: 'തന്ത്രം',
#  870: 'ചുരുണ്ട',
#  871: 'മീറ്റർ',
#  872: 'പൂച്ചയാണ്',
#  873: 'ബ്രൊക്കോളി',
#  874: 'കുതിരപ്പുറത്ത്',
#  875: 'ഉറങ്ങുന്നു',
#  876: 'ബോയ്',
#  877: 'ചുവന്നതാണ്',
#  878: 'തുരുമ്പിച്ച',
#  879: 'സ്\u200cക്രീൻ',
#  880: 'ഇലക്ട്രിക്',
#  881: 'ഫോട്ടോയിലെ',
#  882: 'സ്നോബോർഡർ',
#  883: 'ബട്ടൺ',
#  884: 'ചെയ്യാൻ',
#  885: 'കടൽത്തീരത്താണ്',
#  886: 'ധാന്യം',
#  887: 'പാണ്ട',
#  888: 'മൈതാനത്ത്',
#  889: 'പല്ല്',
#  890: 'മതിലിന്റെ',
#  891: 'കുളിമുറിയുടെ',
#  892: 'സ്കേറ്റ്ബോർഡിലെ',
#  893: 'കടൽത്തീരത്തെ',
#  894: 'ശാന്തമായ',
#  895: 'കടലിൽ',
#  896: 'ഇൻഡോർ',
#  897: 'മടിയിൽ',
#  898: 'പൂശി',
#  899: 'അഭിമുഖീകരിക്കുന്ന',
#  900: 'കവലയിലൂടെ',
#  901: 'കുടയുമായി',
#  902: 'പാന്റിലുള്ള',
#  903: 'ചാരിയിരിക്കുന്നു',
#  904: 'കസേരയുടെ',
#  905: 'നീന്തുന്നു',
#  906: 'തണലുള്ള',
#  907: 'പോർസലൈൻ',
#  908: 'ഇടുന്നു',
#  909: 'വാതിലുള്ള',
#  910: 'ശാഖ',
#  911: 'ധ്രുവം',
#  912: 'പാനപാത്രം',
#  913: 'കൊട്ട',
#  914: 'തൊപ്പികൾ',
#  915: 'വിദൂര',
#  916: 'മതിലിലാണ്',
#  917: 'നൽകരുത്',
#  918: 'കണ്ണാടിയിൽ',
#  919: 'താഴെ',
#  920: 'ഒപ്പിടുക',
#  921: 'താടി',
#  922: 'ബർഗർ',
#  923: 'വശം',
#  924: 'ഫിക്ചർ',
#  925: 'മോണിറ്ററിന്',
#  926: 'സൺഗ്ലാസ്',
#  927: 'വാതിലുകളുള്ള',
#  928: 'ഫുട്പാത്തിൽ',
#  929: 'ഗ്രൂപ്പ്',
#  930: 'സ്ഥലം',
#  931: 'ബാൻഡ്',
#  932: 'കെട്ടിടങ്ങളാണ്',
#  933: 'കാള',
#  934: 'തലകീഴായി',
#  935: 'ഫോസെറ്റ്',
#  936: 'പൂമുഖത്ത്',
#  937: 'ജനല',
#  938: 'അടച്ചു',
#  939: 'സ്റ്റാൻഡ്',
#  940: 'ചെടിയുടെ',
#  941: 'മഴ',
#  942: 'വെളിച്ചത്തിൽ',
#  943: 'ഷോർട്ട്സിലുള്ള',
#  944: 'കുറ്റിച്ചെടി',
#  945: 'വെള്ളത്തിലൂടെ',
#  946: 'കിളി',
#  947: 'വലത്',
#  948: 'നിരയായി',
#  949: 'പിന്നിലെ',
#  950: 'സ്കീസ്',
#  951: 'വഴിക്ക്',
#  952: 'നടുവിലുള്ള',
#  953: 'ഇടുങ്ങിയ',
#  954: 'ദ്വാരം',
#  955: 'ജീൻ',
#  956: 'പോസ്റ്റിലെ',
#  957: 'പുല്ലുള്ള',
#  958: 'കാർട്ട്',
#  959: 'റാക്ക്',
#  960: 'ആട്ടിൻകുട്ടി',
#  961: 'താൽക്കാലികമായി',
#  962: 'നിർത്തിവച്ചിരിക്കുന്നു',
#  963: 'പുരുഷന്',
#  964: 'കടയിൽ',
#  965: 'പുരുഷനും',
#  966: 'കസേരയ്ക്ക്',
#  967: 'പൂൾ',
#  968: 'വ്യാജ',
#  969: 'ഷോപ്പിംഗ്',
#  970: 'കുളത്തിനടുത്തുള്ള',
#  971: 'ണ്ടറിന്',
#  972: 'തൂങ്ങിക്കിടക്കുന്ന',
#  973: 'മുഴുവൻ',
#  974: 'കൈകൾ',
#  975: 'കൗണ്ടറിന്',
#  976: 'കീഴിലാണ്',
#  977: 'ജാലകത്തിന്',
#  978: 'കുളത്തിൽ',
#  979: 'മനോഹരമായ',
#  980: 'കടലാമ',
#  981: 'ട്രക്കിലെ',
#  982: 'പരവതാനി',
#  983: 'പടികളിൽ',
#  984: 'റെസിഡൻഷ്യൽ',
#  985: 'മുറിക്കുക',
#  986: 'പൂത്തട്ടം',
#  987: 'സ്ത്രീയാണ്',
#  988: 'റിയർ',
#  989: 'പ്രായമായ',
#  990: 'മഗ്',
#  991: 'പോളിലെ',
#  992: 'ബാനറുകൾ',
#  993: 'സ്റ്റോർ',
#  994: 'മെറൂൺ',
#  995: 'ജീപ്പ്',
#  996: 'ലോഹധ്രുവത്തിൽ',
#  997: 'ഷെൽഫ്',
#  998: 'കളർ',
#  999: 'പോസ്റ്റർ',
#  1000: 'ഡെസ്\u200cകിന്',
#  ...}

# %%
reverse_source_word_index=x_tokens.index_word
reverse_source_word_index
# Out:
# {1: 'a',
#  2: 'the',
#  3: 'on',
#  4: 'of',
#  5: 'is',
#  6: 'in',
#  7: 'white',
#  8: 'man',
#  9: 'building',
#  10: 'black',
#  11: 'and',
#  12: 'red',
#  13: 'with',
#  14: 'wall',
#  15: 'blue',
#  16: 'window',
#  17: 'person',
#  18: 'green',
#  19: 'side',
#  20: 'wearing',
#  21: 'woman',
#  22: 'this',
#  23: 'car',
#  24: 'street',
#  25: 'brown',
#  26: 'yellow',
#  27: 'sign',
#  28: 'light',
#  29: 'water',
#  30: 'large',
#  31: 'sky',
#  32: 'table',
#  33: 'shirt',
#  34: 'train',
#  35: 'standing',
#  36: 'sitting',
#  37: 'road',
#  38: 'two',
#  39: 'tree',
#  40: 'holding',
#  41: 'an',
#  42: 'to',
#  43: 'has',
#  44: 'parked',
#  45: 'bus',
#  46: 'people',
#  47: 'head',
#  48: 'are',
#  49: 'top',
#  50: 'walking',
#  51: 'small',
#  52: 'orange',
#  53: 'clock',
#  54: 'plate',
#  55: 'silver',
#  56: 'boy',
#  57: 'glass',
#  58: 'grass',
#  59: 'front',
#  60: 'pole',
#  61: 'truck',
#  62: 'ground',
#  63: 'wooden',
#  64: 'boat',
#  65: 'at',
#  66: 'hair',
#  67: 'sidewalk',
#  68: 'dog',
#  69: 'tennis',
#  70: 'chair',
#  71: 'down',
#  72: 'riding',
#  73: 'umbrella',
#  74: 'bench',
#  75: 'plane',
#  76: 'snow',
#  77: 'field',
#  78: 'gray',
#  79: 'grey',
#  80: 'picture',
#  81: 'desk',
#  82: 'bird',
#  83: 'girl',
#  84: 'cat',
#  85: 'bear',
#  86: 'hanging',
#  87: 'color',
#  88: 'metal',
#  89: 'motorcycle',
#  90: 'computer',
#  91: 'by',
#  92: 'baseball',
#  93: 'pink',
#  94: 'jacket',
#  95: 'bed',
#  96: 'leaves',
#  97: 'tall',
#  98: 'door',
#  99: 'room',
#  100: 'traffic',
#  101: 'hat',
#  102: 'long',
#  103: 'surfboard',
#  104: 'skateboard',
#  105: 'next',
#  106: 'pizza',
#  107: 'food',
#  108: 'phone',
#  109: 'dark',
#  110: 'player',
#  111: 'ceiling',
#  112: 'tower',
#  113: 'lamp',
#  114: 'bike',
#  115: 'part',
#  116: 'giraffe',
#  117: 'kitchen',
#  118: 'near',
#  119: 'horse',
#  120: 'view',
#  121: 'air',
#  122: 'face',
#  123: 'playing',
#  124: 'open',
#  125: 'that',
#  126: 'eating',
#  127: 'young',
#  128: 'toilet',
#  129: 'bowl',
#  130: 'clear',
#  131: 'cake',
#  132: 'floor',
#  133: 'flowers',
#  134: 'house',
#  135: 'clouds',
#  136: 'beach',
#  137: 'round',
#  138: 'wood',
#  139: 'lights',
#  140: 'ball',
#  141: 'city',
#  142: 'airplane',
#  143: 'up',
#  144: 'over',
#  145: 'scene',
#  146: 'couch',
#  147: 'tan',
#  148: 'box',
#  149: 'his',
#  150: 'zebra',
#  151: 'hand',
#  152: 'frisbee',
#  153: 'three',
#  154: 'cup',
#  155: 'brick',
#  156: 'colored',
#  157: 'fire',
#  158: 'laptop',
#  159: 'mans',
#  160: 'post',
#  161: 'helmet',
#  162: 'for',
#  163: 'back',
#  164: 'old',
#  165: 'group',
#  166: 'vehicle',
#  167: 'bottle',
#  168: 'van',
#  169: 'around',
#  170: 'paper',
#  171: 'board',
#  172: 'piece',
#  173: 'hydrant',
#  174: 'driving',
#  175: 'game',
#  176: 'outside',
#  177: 'screen',
#  178: 'behind',
#  179: 'bathroom',
#  180: 'tire',
#  181: 'corner',
#  182: 'left',
#  183: 'during',
#  184: 'fence',
#  185: 'gold',
#  186: 'elephant',
#  187: 'it',
#  188: 'child',
#  189: 'counter',
#  190: 'under',
#  191: 'vase',
#  192: 'day',
#  193: 'coffee',
#  194: 'looking',
#  195: 'leg',
#  196: 'full',
#  197: 'area',
#  198: 'flag',
#  199: 'big',
#  200: 'from',
#  201: 'purple',
#  202: 'tie',
#  203: 'flying',
#  204: 'sheep',
#  205: 'cell',
#  206: 'crossing',
#  207: 'pants',
#  208: 'fruit',
#  209: 'mirror',
#  210: 'pillow',
#  211: 'roof',
#  212: 'plant',
#  213: 'sink',
#  214: 'mountain',
#  215: 'square',
#  216: 'plastic',
#  217: 'can',
#  218: 'arm',
#  219: 'wine',
#  220: 'bananas',
#  221: 'photo',
#  222: 'painted',
#  223: 'windows',
#  224: 'monitor',
#  225: 'parking',
#  226: 'bag',
#  227: 'right',
#  228: 'men',
#  229: 'bridge',
#  230: 'jeans',
#  231: 'stone',
#  232: 'flower',
#  233: 'time',
#  234: 'camera',
#  235: 'stop',
#  236: 'bat',
#  237: 'short',
#  238: 'four',
#  239: 'cabinet',
#  240: 'book',
#  241: 'trunk',
#  242: 'frame',
#  243: 'trees',
#  244: 'handle',
#  245: 'against',
#  246: 'ear',
#  247: 'tail',
#  248: 'pool',
#  249: 'half',
#  250: 'suit',
#  251: 'bright',
#  252: 'baby',
#  253: 'tracks',
#  254: 'racket',
#  255: 'teddy',
#  256: 'cow',
#  257: 'cars',
#  258: 'painting',
#  259: 'park',
#  260: 'taxi',
#  261: 'shorts',
#  262: 'letter',
#  263: 'row',
#  264: 'shelf',
#  265: 'signs',
#  266: 'set',
#  267: 'body',
#  268: 'laying',
#  269: 'ski',
#  270: 'kite',
#  271: 'ocean',
#  272: 'facing',
#  273: 'suv',
#  274: 'leaning',
#  275: 'above',
#  276: 'inside',
#  277: 'line',
#  278: 'sunglasses',
#  279: 'stand',
#  280: 'women',
#  281: 'cloud',
#  282: 'glasses',
#  283: 'rug',
#  284: 'letters',
#  285: 'made',
#  286: 'reflection',
#  287: 'leaf',
#  288: 'seat',
#  289: 'womans',
#  290: 'covered',
#  291: 'knife',
#  292: 'engine',
#  293: 'sandwich',
#  294: 'skateboarding',
#  295: 'jet',
#  296: 'surfing',
#  297: 'oven',
#  298: 'through',
#  299: 'along',
#  300: 'stripe',
#  301: 'basket',
#  302: 'attached',
#  303: 'each',
#  304: 'other',
#  305: 'these',
#  306: 'sand',
#  307: 'television',
#  308: 'stove',
#  309: 'cab',
#  310: 'eye',
#  311: 'american',
#  312: 'daytime',
#  313: 'tv',
#  314: 'stairs',
#  315: 'cut',
#  316: 'pot',
#  317: 'background',
#  318: 'dirt',
#  319: 'rock',
#  320: 'dress',
#  321: 'one',
#  322: 'apple',
#  323: 'out',
#  324: 'giraffes',
#  325: 'court',
#  326: 'horses',
#  327: 'slope',
#  328: 'double',
#  329: 'track',
#  330: 'number',
#  331: 'several',
#  332: 'chairs',
#  333: 'branch',
#  334: 'cart',
#  335: 'striped',
#  336: 'off',
#  337: 'trash',
#  338: 'coat',
#  339: 'tarmac',
#  340: 'lines',
#  341: 'middle',
#  342: 'many',
#  343: 'taken',
#  344: 'banana',
#  345: 'wheel',
#  346: 'couple',
#  347: 'clean',
#  348: 'mouth',
#  349: 'arrow',
#  350: 'bicycle',
#  351: 'animals',
#  352: 'lady',
#  353: 'shoes',
#  354: 'sweater',
#  355: 'runway',
#  356: 'cap',
#  357: 'toy',
#  358: 'neck',
#  359: 'foot',
#  360: 'tile',
#  361: 'carrying',
#  362: 'hands',
#  363: 'little',
#  364: 'skier',
#  365: 'surfer',
#  366: 'there',
#  367: 'beside',
#  368: 'microwave',
#  369: 'distance',
#  370: 'fixture',
#  371: 'signal',
#  372: 'backpack',
#  373: 'faucet',
#  374: 'rocks',
#  375: 'style',
#  376: 'store',
#  377: 'statue',
#  378: 'license',
#  379: 'motor',
#  380: 'case',
#  381: 'numbers',
#  382: 'wears',
#  383: 'tray',
#  384: 'station',
#  385: 'cover',
#  386: 'snowboard',
#  387: 'wii',
#  388: 'suitcase',
#  389: 'shoe',
#  390: 'being',
#  391: 'skiing',
#  392: 'dogs',
#  393: 'turned',
#  394: 'controller',
#  395: 'palm',
#  396: 'colorful',
#  397: 'cheese',
#  398: 'mug',
#  399: 'buildings',
#  400: 'curb',
#  401: 'highway',
#  402: 'base',
#  403: 'haired',
#  404: 'luggage',
#  405: 'police',
#  406: 'bread',
#  407: 'pane',
#  408: 'logo',
#  409: 'umbrellas',
#  410: 'stack',
#  411: 'like',
#  412: 'lit',
#  413: 'keyboard',
#  414: 'empty',
#  415: 'lettering',
#  416: 'talking',
#  417: 'pile',
#  418: 'together',
#  419: 'beige',
#  420: 'rectangular',
#  421: 'fan',
#  422: 'interior',
#  423: 'chimney',
#  424: 'hill',
#  425: 'pair',
#  426: 'bunch',
#  427: 'he',
#  428: 'waiting',
#  429: 'guy',
#  430: 'animal',
#  431: 'lawn',
#  432: 'towel',
#  433: 'napkin',
#  434: 'donut',
#  435: 'military',
#  436: 'fork',
#  437: 'fridge',
#  438: 'finger',
#  439: 'decker',
#  440: 'cows',
#  441: 'blender',
#  442: 'office',
#  443: 'intersection',
#  444: 'reading',
#  445: 'shade',
#  446: 'not',
#  447: 'sauce',
#  448: 'across',
#  449: 'doors',
#  450: 'lot',
#  451: 'curtain',
#  452: 'steel',
#  453: 'plaid',
#  454: 'sofa',
#  455: 'very',
#  456: 'beak',
#  457: 'skirt',
#  458: 'flat',
#  459: 'dresser',
#  460: 'filled',
#  461: 'slat',
#  462: 'says',
#  463: 'writing',
#  464: 'dish',
#  465: 'match',
#  466: 'decorative',
#  467: 'birds',
#  468: 'patch',
#  469: 'block',
#  470: 'railing',
#  471: 'commercial',
#  472: 'ornate',
#  473: 'deep',
#  474: 'rail',
#  475: 'edge',
#  476: 'walk',
#  477: 'cross',
#  478: 'stripes',
#  479: 'design',
#  480: 'apples',
#  481: 'zebras',
#  482: 'hot',
#  483: 'mounted',
#  484: 'lid',
#  485: 'display',
#  486: 'blonde',
#  487: 'held',
#  488: 'garbage',
#  489: 'mouse',
#  490: 'soccer',
#  491: 'asian',
#  492: 'doing',
#  493: 'wet',
#  494: 'electric',
#  495: 'vest',
#  496: 'lying',
#  497: 'refrigerator',
#  498: 'batter',
#  499: 'cream',
#  500: 'foreground',
#  501: 'girls',
#  502: 'between',
#  503: 'thick',
#  504: 'horizon',
#  505: 'oranges',
#  506: 'bull',
#  507: 'gate',
#  508: 'hotel',
#  509: 'busy',
#  510: 'parrot',
#  511: 'cage',
#  512: 'dock',
#  513: 'bikes',
#  514: 'scooter',
#  515: 'print',
#  516: 'machine',
#  517: 'holder',
#  518: 'pipe',
#  519: 'stair',
#  520: 'scarf',
#  521: 'remote',
#  522: 'butter',
#  523: 'rainbow',
#  524: 'cord',
#  525: 'brightly',
#  526: 'tank',
#  527: 'bottom',
#  528: 'entrance',
#  529: 'visible',
#  530: 'headboard',
#  531: 'balcony',
#  532: 'awning',
#  533: 'covering',
#  534: 'curved',
#  535: 'river',
#  536: 'bushes',
#  537: 'container',
#  538: 'some',
#  539: 'hood',
#  540: 'coming',
#  541: 'video',
#  542: 'wave',
#  543: 'sit',
#  544: 'blanket',
#  545: 'leather',
#  546: 'fireplace',
#  547: 'using',
#  548: 'stool',
#  549: 'stuffed',
#  550: 'ready',
#  551: 'nose',
#  552: 'her',
#  553: 'watching',
#  554: 'chocolate',
#  555: 'smiling',
#  556: 'different',
#  557: 'ramp',
#  558: 'doughnut',
#  559: 'sea',
#  560: 'pan',
#  561: 'going',
#  562: 't',
#  563: 'cats',
#  564: 'boys',
#  565: 'motorbike',
#  566: 'players',
#  567: 'restaurant',
#  568: 'passenger',
#  569: 'soup',
#  570: 'boats',
#  571: 'cutting',
#  572: 'ice',
#  573: 'swinging',
#  574: 'motorcycles',
#  575: 'fruits',
#  576: 'pillows',
#  577: 'buses',
#  578: 'stacked',
#  579: 'plates',
#  580: 'trick',
#  581: 'bears',
#  582: 'skiers',
#  583: 'swing',
#  584: 'running',
#  585: 'bow',
#  586: 'zoo',
#  587: 'male',
#  588: 'stroller',
#  589: 'porcelain',
#  590: 'something',
#  591: 'sits',
#  592: 'beneath',
#  593: 'rear',
#  594: 'telephone',
#  595: 'porch',
#  596: 'night',
#  597: 'moving',
#  598: 'minivan',
#  599: 'skis',
#  600: 'hole',
#  601: 'sun',
#  602: 'step',
#  603: 'restroom',
#  604: 'rack',
#  605: 'tub',
#  606: 'suspended',
#  607: 'no',
#  608: 'cargo',
#  609: 'arms',
#  610: 'into',
#  611: 'trail',
#  612: 'docked',
#  613: 'pointed',
#  614: 'steps',
#  615: 'residential',
#  616: 'juice',
#  617: 'looks',
#  618: 'shiny',
#  619: 'rubber',
#  620: 'older',
#  621: 'poster',
#  622: 'mountains',
#  623: 'traveling',
#  624: 'lake',
#  625: 'lampshade',
#  626: 'thin',
#  627: 'corded',
#  628: 'knob',
#  629: 'range',
#  630: 'framed',
#  631: 'bar',
#  632: 'fish',
#  633: 'wagon',
#  634: 'church',
#  635: 'purse',
#  636: 'art',
#  637: 'object',
#  638: 'circle',
#  639: 'dinner',
#  640: 'words',
#  641: 'rope',
#  642: 'walkway',
#  643: 'watch',
#  644: 'circular',
#  645: 'heads',
#  646: 'shining',
#  647: 'stapler',
#  648: 'teeth',
#  649: 'lane',
#  650: 'pier',
#  651: 'petal',
#  652: 'ears',
#  653: 'sunset',
#  654: 'ride',
#  655: 'bush',
#  656: 'styrofoam',
#  657: 'exterior',
#  658: 'doorway',
#  659: 'yard',
#  660: 'log',
#  661: 'you',
#  662: 'trim',
#  663: 'ribbon',
#  664: 'fluffy',
#  665: 'wicker',
#  666: 'panel',
#  667: 'strip',
#  668: 'center',
#  669: 'cupcake',
#  670: 'wetsuit',
#  671: 'spoon',
#  672: 'ladder',
#  673: 'sale',
#  674: 'aircraft',
#  675: 'hard',
#  676: 'hay',
#  677: 'doughnuts',
#  678: 'safety',
#  679: 'tag',
#  680: 'woods',
#  681: 'opened',
#  682: 'airlines',
#  683: 'carrot',
#  684: 'smoke',
#  685: 'soda',
#  686: 'crowd',
#  687: 'beer',
#  688: 'cone',
#  689: 'surf',
#  690: 'straw',
#  691: 'spotted',
#  692: 'kites',
#  693: 'collar',
#  694: 'mostly',
#  695: 'spots',
#  696: 'their',
#  697: 'equipment',
#  698: 'reflecting',
#  699: 'metro',
#  700: 'lined',
#  701: 'racing',
#  702: 'pie',
#  703: 'kid',
#  704: 'neon',
#  705: 'elephants',
#  706: 'burgundy',
#  707: 'shadow',
#  708: 'sides',
#  709: 'buoy',
#  710: 'catcher',
#  711: 'platter',
#  712: 'sleeping',
#  713: 'race',
#  714: 'iron',
#  715: 'jersey',
#  716: 'shower',
#  717: 'leash',
#  718: 'touching',
#  719: 'sandy',
#  720: 'eyeglasses',
#  721: 'meter',
#  722: 'broccoli',
#  723: 'birthday',
#  724: 'holds',
#  725: 'diamond',
#  726: 'flies',
#  727: 'chain',
#  728: 'snowboarder',
#  729: 'button',
#  730: 'suitcases',
#  731: 'panda',
#  732: 'wing',
#  733: 'vegetables',
#  734: 'tied',
#  735: 'surfboards',
#  736: 'rod',
#  737: 'dressed',
#  738: 'bun',
#  739: 'trains',
#  740: 'toppings',
#  741: 'still',
#  742: 'indoor',
#  743: 'lap',
#  744: 'pictures',
#  745: 'metallic',
#  746: 'swimming',
#  747: 'glowing',
#  748: 'construction',
#  749: 'worker',
#  750: 'cement',
#  751: 'story',
#  752: 'hats',
#  753: 'do',
#  754: 'enter',
#  755: 'beard',
#  756: 'burger',
#  757: 'pavement',
#  758: 'leaving',
#  759: 'band',
#  760: 'stage',
#  761: 'upside',
#  762: 'sized',
#  763: 'five',
#  764: 'knobs',
#  765: 'stainless',
#  766: 'plants',
#  767: 'vehicles',
#  768: 'rain',
#  769: 'walks',
#  770: 'crosswalk',
#  771: 'planes',
#  772: 'broken',
#  773: 'paved',
#  774: 'narrow',
#  775: 'radio',
#  776: 'jean',
#  777: 'decorated',
#  778: 'lips',
#  779: 'mantel',
#  780: 'goatee',
#  781: 'houseboat',
#  782: 'cloth',
#  783: 'blinds',
#  784: 'windown',
#  785: 'bouquet',
#  786: 'shopping',
#  787: 'fake',
#  788: 'assorted',
#  789: 'washer',
#  790: 'turtle',
#  791: 'word',
#  792: 'knives',
#  793: 'delivery',
#  794: 'trashcan',
#  795: 'banners',
#  796: 'fallen',
#  797: 'paint',
#  798: 'maroon',
#  799: 'jeep',
#  800: 'snack',
#  801: 'whtie',
#  802: 'walls',
#  803: 'banner',
#  804: 'decorations',
#  805: 'hedges',
#  806: 'way',
#  807: 'leading',
#  808: 'space',
#  809: 'surrounding',
#  810: 'town',
#  811: 'closet',
#  812: 'soap',
#  813: 'nightstand',
#  814: 'dining',
#  815: 'tea',
#  816: 'kettle',
#  817: 'sunlight',
#  818: 'peach',
#  819: 'living',
#  820: 'legs',
#  821: 'numerous',
#  822: 'concrete',
#  823: 'forefront',
#  824: 'mail',
#  825: 'extended',
#  826: 'arched',
#  827: 'balloon',
#  828: 'cliff',
#  829: 'horn',
#  830: 'utility',
#  831: 'close',
#  832: 'picnic',
#  833: 'finish',
#  834: 'pine',
#  835: 'stopped',
#  836: 'pedestal',
#  837: 'urban',
#  838: 'pushing',
#  839: 'tiled',
#  840: 'tractor',
#  841: 'guard',
#  842: 'bare',
#  843: 'shutters',
#  844: 'hedge',
#  845: 'arch',
#  846: 'shot',
#  847: '6',
#  848: 'brownstone',
#  849: 'tomato',
#  850: 'lion',
#  851: 'patio',
#  852: 'spot',
#  853: 'place',
#  854: 'terminal',
#  855: 'aquarium',
#  856: 'patterned',
#  857: 'bamboo',
#  858: 'sheer',
#  859: 'curtains',
#  860: 'median',
#  861: 'stick',
#  862: 'shop',
#  863: 'school',
#  864: 'seats',
#  865: 'rows',
#  866: 'towards',
#  867: 'speaker',
#  868: 'reflections',
#  869: 'beams',
#  870: 'railroad',
#  871: 'vintage',
#  872: 'indoors',
#  873: 'having',
#  874: 'advertisement',
#  875: 'trailer',
#  876: 'silverware',
#  877: 'shaker',
#  878: 'candle',
#  879: 'clay',
#  880: 'branches',
#  881: 'smaller',
#  882: 'icing',
#  883: 'falling',
#  884: 'windshield',
#  885: 'bell',
#  886: 'trolley',
#  887: 'team',
#  888: 'name',
#  889: 'glazed',
#  890: 'posing',
#  891: 'net',
#  892: 'atop',
#  893: 'pickup',
#  894: 'checking',
#  895: 'pineapple',
#  896: 'label',
#  897: 'ship',
#  898: 'african',
#  899: 'sliced',
#  900: 'cupboard',
#  901: 'more',
#  902: 'catch',
#  903: 'skating',
#  904: 'outfit',
#  905: 'owned',
#  906: 'drinks',
#  907: 'skate',
#  908: 'floating',
#  909: 'chef',
#  910: 'meat',
#  911: 'airport',
#  912: 'key',
#  913: 'harness',
#  914: 'ripple',
#  915: 'headlight',
#  916: 'stadium',
#  917: 'cycle',
#  918: 'family',
#  919: 'skateboarder',
#  920: 'grill',
#  921: 'chickens',
#  922: 'bucket',
#  923: 'brass',
#  924: 'headband',
#  925: 'barrier',
#  926: 'mule',
#  927: 'pulling',
#  928: 'ripples',
#  929: 'fighter',
#  930: 'headlights',
#  931: 'goggles',
#  932: 'seating',
#  933: 'clothing',
#  934: 'chin',
#  935: 'uniform',
#  936: 'pepper',
#  937: 'shelves',
#  938: 'transit',
#  939: 'roll',
#  940: 'cooking',
#  941: 'batting',
#  942: 'propeller',
#  943: 'play',
#  944: 'deck',
#  945: 'shown',
#  946: 'heavy',
#  947: 'roman',
#  948: 'numerals',
#  949: 'bikini',
#  950: 'tap',
#  951: 'barriers',
#  952: 'benches',
#  953: 'beam',
#  954: 'subway',
#  955: 'kids',
#  956: 'buttons',
#  957: 'written',
#  958: 'cellphone',
#  959: 'raised',
#  960: 'cabinets',
#  961: 'wire',
#  962: 'new',
#  963: 'necklace',
#  964: 'bald',
#  965: 'hoof',
#  966: 'tug',
#  967: 'dot',
#  968: 'enclosure',
#  969: 'tshirt',
#  970: 'section',
#  971: 'throw',
#  972: 'sail',
#  973: 'country',
#  974: 'wrapped',
#  975: 'tape',
#  976: 'lift',
#  977: 'donuts',
#  978: '9',
#  979: 'snowy',
#  980: 'sneakers',
#  981: 'about',
#  982: 'kept',
#  983: 'persons',
#  984: 'cooked',
#  985: 'gravel',
#  986: 'roadside',
#  987: 'frosting',
#  988: 'waves',
#  989: 'chili',
#  990: 'slices',
#  991: 'curly',
#  992: 'rusted',
#  993: 'string',
#  994: 'plain',
#  995: 'tee',
#  996: 'cloudy',
#  997: 'jar',
#  998: 'macaroni',
#  999: 'both',
#  1000: 'public',
#  ...}

# %%
target_word_index=y_tokens.word_index
target_word_index
# Out:
# {'sos': 1,
#  'eos': 2,
#  'ഒരു': 3,
#  'കറുത്ത': 4,
#  'വെളുത്ത': 5,
#  'ധരിച്ച': 6,
#  'സ്ത്രീ': 7,
#  'ബാഗ്': 8,
#  'മനുഷ്യൻ': 9,
#  'ട്രാഷ്': 10,
#  'വലിയ': 11,
#  'പച്ച': 12,
#  'നീല': 13,
#  'ചുവന്ന': 14,
#  'വർണ്ണാഭമായ': 15,
#  'സ്കാർഫ്': 16,
#  'വിൻഡോ': 17,
#  'ചാരനിറത്തിലുള്ള': 18,
#  'കെട്ടിടത്തിലെ': 19,
#  'മഞ്ഞ': 20,
#  'വ്യക്തി': 21,
#  'കാർ': 22,
#  'കെട്ടിടത്തിന്റെ': 23,
#  'വെള്ള': 24,
#  'വശത്ത്': 25,
#  'ഇതൊരു': 26,
#  'ചുവപ്പ്': 27,
#  'ചെറിയ': 28,
#  'മതിൽ': 29,
#  'രണ്ട്': 30,
#  'റോഡിന്റെ': 31,
#  'ഒരാൾ': 32,
#  'മേശപ്പുറത്ത്': 33,
#  'രംഗം': 34,
#  'ചിഹ്നം': 35,
#  'പുല്ലിന്റെ': 36,
#  'ഓറഞ്ച്': 37,
#  'മുകളിൽ': 38,
#  'ബീച്ച്': 39,
#  'എഞ്ചിൻ': 40,
#  'ഉള്ള': 41,
#  'വശങ്ങളിൽ': 42,
#  'പാർക്ക്': 43,
#  'ദ്വീപ്': 44,
#  'സ്ട്രിപ്പുകൾ': 45,
#  'തെരുവിൽ': 46,
#  'നിലത്ത്': 47,
#  'വെള്ളയും': 48,
#  'നടക്കുന്നു': 49,
#  'ആളുകൾ': 50,
#  'തവിട്ട്': 51,
#  'തലം': 52,
#  'മരം': 53,
#  'നിറമുള്ള': 54,
#  'ഇരിക്കുന്നു': 55,
#  'ബസ്': 56,
#  'പുല്ല്': 57,
#  'ഷർട്ട്': 58,
#  'കുഞ്ഞ്': 59,
#  'ആന': 60,
#  'നിൽക്കുന്ന': 61,
#  'ജിറാഫ്': 62,
#  'വെള്ളി': 63,
#  'തെരുവ്': 64,
#  'നിൽക്കുന്നു': 65,
#  'ട്രെയിൻ': 66,
#  'ടെന്നീസ്': 67,
#  'വൈറ്റ്': 68,
#  'ട്രക്ക്': 69,
#  'ഇരിക്കുന്ന': 70,
#  'ഗ്ലാസ്': 71,
#  'ഇത്': 72,
#  'വെള്ളത്തിൽ': 73,
#  'കുട': 74,
#  'നായ': 75,
#  'ചുവപ്പും': 76,
#  'പിങ്ക്': 77,
#  'വിമാനം': 78,
#  'പെൺകുട്ടി': 79,
#  'മോട്ടോർ': 80,
#  'മിഠായി': 81,
#  'കറുപ്പും': 82,
#  'വിളക്ക്': 83,
#  'പിടിക്കുന്നു': 84,
#  'കോട്ടൺ': 85,
#  'ചുവരിൽ': 86,
#  'ലൈറ്റ്': 87,
#  'ബേസ്ബോൾ': 88,
#  'കെട്ടിടത്തിന്': 89,
#  'മുന്നിൽ': 90,
#  'നീലയും': 91,
#  'കമ്പ്യൂട്ടർ': 92,
#  'ചുമരിൽ': 93,
#  'ഉണ്ട്': 94,
#  'തൊപ്പി': 95,
#  'തിന്നുന്നു': 96,
#  'ചെയ്യുന്നു': 97,
#  'മനുഷ്യന്റെ': 98,
#  'കൂട്ടം': 99,
#  'അടയാളം': 100,
#  'ആണ്': 101,
#  'റോഡിൽ': 102,
#  'വെളിച്ചം': 103,
#  'തവിട്ടുനിറത്തിലുള്ള': 104,
#  'കുട്ടി': 105,
#  'ഉയരമുള്ള': 106,
#  'കസേര': 107,
#  'ഭാഗം': 108,
#  'പക്ഷി': 109,
#  'നീളമുള്ള': 110,
#  'ട്രാഫിക്': 111,
#  'കെട്ടിടം': 112,
#  'ചെയ്തിരിക്കുന്നു': 113,
#  'തടി': 114,
#  'ചിത്രം': 115,
#  'നിറത്തിലുള്ള': 116,
#  'ജാക്കറ്റ്': 117,
#  'പാത്രം': 118,
#  'പുള്ളി': 119,
#  'പിസ്സ': 120,
#  'ക്ലോക്ക്': 121,
#  'കേക്ക്': 122,
#  'ഘടികാരം': 123,
#  'ബോട്ട്': 124,
#  'ഇരുണ്ട': 125,
#  'കറുത്തതാണ്': 126,
#  'പ്ലേറ്റിൽ': 127,
#  'പൂച്ച': 128,
#  'പ്ലേറ്റ്': 129,
#  'ധരിക്കുന്നു': 130,
#  'മുടിയുള്ള': 131,
#  'പുല്ലിൽ': 132,
#  'ആകാശം': 133,
#  'കൈവശമുള്ള': 134,
#  'മെറ്റൽ': 135,
#  'മൂന്ന്': 136,
#  'ബ്രൗൺ': 137,
#  'പയ്യൻ': 138,
#  'വെളുത്തതാണ്': 139,
#  'നിന്ന്': 140,
#  'തല': 141,
#  'ഫോൺ': 142,
#  'തുറന്ന': 143,
#  'കളിക്കാരൻ': 144,
#  'വാതിൽ': 145,
#  'കട്ടിലിൽ': 146,
#  'ഇഷ്ടിക': 147,
#  'ചെയ്ത': 148,
#  'നടപ്പാതയിൽ': 149,
#  'ധ്രുവത്തിൽ': 150,
#  'പോൾ': 151,
#  'പച്ചയും': 152,
#  'ഓടിക്കുന്നു': 153,
#  'ആകാശത്ത്': 154,
#  'ടോയ്\u200cലറ്റ്': 155,
#  'സൈക്കിൾ': 156,
#  'വയലിൽ': 157,
#  'മുകളിലുള്ള': 158,
#  'ബൈക്ക്': 159,
#  'കാഴ്ച': 160,
#  'ടാൻ': 161,
#  'പഴയ': 162,
#  'കരടി': 163,
#  'കപ്പ്': 164,
#  'നടക്കുന്ന': 165,
#  'സ്ത്രീയുടെ': 166,
#  'വായുവിൽ': 167,
#  'ചുവപ്പാണ്': 168,
#  'പാത്രത്തിൽ': 169,
#  'നീലയാണ്': 170,
#  'സിൽവർ': 171,
#  'പിന്നിൽ': 172,
#  'ഇളം': 173,
#  'ടയർ': 174,
#  'വാൻ': 175,
#  'ചെയ്യുന്ന': 176,
#  'വെളുപ്പും': 177,
#  'രണ്ടുപേർ': 178,
#  'ഇലകൾ': 179,
#  'ആൺകുട്ടി': 180,
#  'ബെഞ്ചിൽ': 181,
#  'മനുഷ്യന്': 182,
#  'നിർത്തി': 183,
#  'കുപ്പി': 184,
#  'ഭക്ഷണം': 185,
#  'വാഴപ്പഴം': 186,
#  'വ്യക്തിയുടെ': 187,
#  'കാൽ': 188,
#  'പൂക്കൾ': 189,
#  'ഉപയോഗിച്ച്': 190,
#  'പാർക്കിംഗ്': 191,
#  'അടുക്കള': 192,
#  'പതാക': 193,
#  'ഹെൽമെറ്റ്': 194,
#  'ബെഞ്ച്': 195,
#  'നിറത്തിലാണ്': 196,
#  'കൈ': 197,
#  'ലാപ്\u200cടോപ്പ്': 198,
#  'തീവണ്ടി': 199,
#  'നിറമാണ്': 200,
#  'മുടിയുണ്ട്': 201,
#  'വരയുള്ള': 202,
#  'ഫ്രെയിം': 203,
#  'ലൈറ്റുകൾ': 204,
#  'നടപ്പാതയിലൂടെ': 205,
#  'വെള്ളം': 206,
#  'മരത്തിൽ': 207,
#  'പർപ്പിൾ': 208,
#  'കസേരയിൽ': 209,
#  'കോഫി': 210,
#  'പ്ലാസ്റ്റിക്': 211,
#  'ജലാംശം': 212,
#  'നിരവധി': 213,
#  'പറക്കുന്നു': 214,
#  'സീബ്ര': 215,
#  'സെൽ': 216,
#  'കിടക്കുന്നു': 217,
#  'സ്കേറ്റ്ബോർഡ്': 218,
#  'തൂക്കിയിരിക്കുന്നു': 219,
#  'ചവറ്റുകുട്ട': 220,
#  'പരസ്പരം': 221,
#  'വ്യക്തിയാണ്': 222,
#  'ടൈ': 223,
#  'തൂക്കിയിട്ടിരിക്കുന്ന': 224,
#  'ചെയ്തു': 225,
#  'ഷർട്ടും': 226,
#  'സ്വർണ്ണ': 227,
#  'വൃത്താകൃതിയിലുള്ള': 228,
#  'കിടക്ക': 229,
#  'മഞ്ഞ്': 230,
#  'റാക്കറ്റ്': 231,
#  'നോക്കുന്നു': 232,
#  'സർഫ്ബോർഡ്': 233,
#  'ബാറ്റ്': 234,
#  'നാല്': 235,
#  'കെട്ടിടത്തിൽ': 236,
#  'ഇല': 237,
#  'തലയിണ': 238,
#  'ജാലകം': 239,
#  'മോണിറ്റർ': 240,
#  'പന്ത്': 241,
#  'മോട്ടോർസൈക്കിൾ': 242,
#  'അടുത്തുള്ള': 243,
#  'ഫ്ലാഗ്': 244,
#  'ടാക്സി': 245,
#  'തലയിൽ': 246,
#  'ചുറ്റും': 247,
#  'വിമാനത്തിന്റെ': 248,
#  'മുറിയിൽ': 249,
#  'കല്ല്': 250,
#  'ജനൽ': 251,
#  'വാഹനം': 252,
#  'തറയിൽ': 253,
#  'വസ്ത്രം': 254,
#  'കളിക്കുന്ന': 255,
#  'കുതിര': 256,
#  'ഷർട്ടിൽ': 257,
#  'കൈവശം': 258,
#  'മുഖം': 259,
#  'കടൽത്തീരത്ത്': 260,
#  'ചായം': 261,
#  'ഗെയിം': 262,
#  'തെരുവിലൂടെ': 263,
#  'മരത്തിന്റെ': 264,
#  'മരങ്ങൾ': 265,
#  'ഇവ': 266,
#  'വിൻഡോയിൽ': 267,
#  'ചെയ്തിരിക്കുന്ന': 268,
#  'പാന്റ്സ്': 269,
#  'പേപ്പർ': 270,
#  'മഞ്ഞയും': 271,
#  'നീലാകാശം': 272,
#  'നിർമ്മിച്ച': 273,
#  'സ്ത്രീക്ക്': 274,
#  'ബോർഡ്': 275,
#  'പെട്ടി': 276,
#  'വേലി': 277,
#  'അഗ്നി': 278,
#  'മുടി': 279,
#  'തവിട്ടുനിറമാണ്': 280,
#  'പക്ഷിയുടെ': 281,
#  'ധരിക്കുന്ന': 282,
#  'മനുഷ്യനാണ്': 283,
#  'റോഡ്': 284,
#  'നഗര': 285,
#  'കഴിക്കുന്നു': 286,
#  'ആപ്പിൾ': 287,
#  'കത്തി': 288,
#  'ബിയർ': 289,
#  'കളിക്കുന്നു': 290,
#  'സൈക്കിളിൽ': 291,
#  'സ്കേറ്റ്ബോർഡിൽ': 292,
#  'ആടുകൾ': 293,
#  'സർഫിംഗ്': 294,
#  'കാറിന്റെ': 295,
#  'മുറിയിലെ': 296,
#  'വൃക്ഷം': 297,
#  'കണ്ണാടി': 298,
#  'നടപ്പാത': 299,
#  'അരികിൽ': 300,
#  'സ്ക്രീൻ': 301,
#  'സീലിംഗിൽ': 302,
#  'സ്ത്രീകൾ': 303,
#  'അമേരിക്കൻ': 304,
#  'മഞ്ഞുവീഴ്ചയിൽ': 305,
#  'വരകൾ': 306,
#  'വാൽ': 307,
#  'ടവർ': 308,
#  'അടയാളങ്ങൾ': 309,
#  'പ്രതിഫലനം': 310,
#  'ബ്ലാക്ക്': 311,
#  'കറുപ്പ്': 312,
#  'കാറുകൾ': 313,
#  'ക്യാമറ': 314,
#  'സ്വെറ്റർ': 315,
#  'കിടക്കുന്ന': 316,
#  'സവാരി': 317,
#  'ചിഹ്നത്തിൽ': 318,
#  'ഓടിക്കുന്ന': 319,
#  'ടെഡി': 320,
#  'സ്യൂട്ട്': 321,
#  'ചെവി': 322,
#  'ചെറുപ്പക്കാരൻ': 323,
#  'കഷണം': 324,
#  'മുൻവശത്ത്': 325,
#  'മുറിച്ചുകടക്കുന്ന': 326,
#  'കട്ടിയുള്ള': 327,
#  'മേൽക്കൂര': 328,
#  'കുപ്പായമുള്ള': 329,
#  'കാറിന്': 330,
#  'സമീപം': 331,
#  'മേശ': 332,
#  'നഗരത്തിലെ': 333,
#  'അവന്റെ': 334,
#  'നിര': 335,
#  'ടെലിവിഷൻ': 336,
#  'കടലാസ്': 337,
#  'ധാരാളം': 338,
#  'നിറഞ്ഞ': 339,
#  'പുസ്തകം': 340,
#  'നിറത്തിൽ': 341,
#  'സീലിംഗ്': 342,
#  'അക്ഷരങ്ങളുള്ള': 343,
#  'വശത്തുള്ള': 344,
#  'സഞ്ചരിക്കുന്ന': 345,
#  'പകൽ': 346,
#  'പുറത്ത്': 347,
#  'ട്രെയിനിൽ': 348,
#  'കുന്നിൻ': 349,
#  'ബോട്ടിൽ': 350,
#  'ജീൻസ്': 351,
#  'ഇതാണ്': 352,
#  'ടൈൽ': 353,
#  'പച്ചയാണ്': 354,
#  'കടും': 355,
#  'റൺവേയിൽ': 356,
#  'തൂവാല': 357,
#  'വ്യക്തമായ': 358,
#  'മേശയിൽ': 359,
#  'ഡോനട്ട്': 360,
#  'കോർട്ടിൽ': 361,
#  'ഹാൻഡിൽ': 362,
#  'പിടിക്കുന്ന': 363,
#  'റെഡ്': 364,
#  'പശു': 365,
#  'ബസിന്റെ': 366,
#  'ജെറ്റ്': 367,
#  'കയ്യിൽ': 368,
#  'ട്രെയിനിന്റെ': 369,
#  'സ്കീയർ': 370,
#  'ഫ്രിസ്ബീ': 371,
#  'മുഖത്ത്': 372,
#  'ലോഹത്തിന്റെ': 373,
#  'മൈക്രോവേവ്': 374,
#  'തിളങ്ങുന്ന': 375,
#  'ചാരനിറമാണ്': 376,
#  'ഡെസ്\u200cകിൽ': 377,
#  'ചെയ്യുക': 378,
#  'നേരെ': 379,
#  'സിങ്ക്': 380,
#  'വീടിന്റെ': 381,
#  'ക്യാബ്': 382,
#  'വെള്ളത്തിനടുത്തുള്ള': 383,
#  'വിമാനത്തിലെ': 384,
#  'വളരെ': 385,
#  'കണ്ണ്': 386,
#  'വള്ളം': 387,
#  'അക്ഷരം': 388,
#  'പേർ': 389,
#  'മുറിയുടെ': 390,
#  'പോലീസ്': 391,
#  'സ്ത്രീയും': 392,
#  'മഞ്ഞിൽ': 393,
#  'പാളി': 394,
#  'മൂലയിൽ': 395,
#  'അടുക്കളയിൽ': 396,
#  'പുറകിൽ': 397,
#  'ടോപ്പ്': 398,
#  'തിളക്കമുള്ള': 399,
#  'വീട്': 400,
#  'സംസാരിക്കുന്നു': 401,
#  'പെൺകുട്ടിയുടെ': 402,
#  'ഒരുമിച്ച്': 403,
#  'ദമ്പതികൾ': 404,
#  'പ്രകാശം': 405,
#  'പൂശിയ': 406,
#  'അലങ്കാര': 407,
#  'ഫാൻ': 408,
#  'അമ്പടയാളം': 409,
#  'വലതുവശത്ത്': 410,
#  'ജാലകമുണ്ട്': 411,
#  'ഭുജം': 412,
#  'പുഷ്പം': 413,
#  'ചിമ്മിനി': 414,
#  'മേഘങ്ങൾ': 415,
#  'ഇടത്': 416,
#  'അഭിമുഖമായി': 417,
#  'പാറ': 418,
#  'പാലം': 419,
#  'നിലത്തു': 420,
#  'കഴിക്കുന്ന': 421,
#  'സർഫ്ബോർഡിൽ': 422,
#  'മണൽ': 423,
#  'ഫയർ': 424,
#  'സാൻഡ്\u200cവിച്ച്': 425,
#  'ജിറാഫുകൾ': 426,
#  'സൈനിക': 427,
#  'ഗതാഗത': 428,
#  'പകുതി': 429,
#  'കോട്ട്': 430,
#  'വൈൻ': 431,
#  'തെരുവിലെ': 432,
#  'ബോൾ': 433,
#  'കുതിരയുടെ': 434,
#  'സ്കേറ്റ്ബോർഡിംഗ്': 435,
#  'ആൻഡ്': 436,
#  'കണ്ണട': 437,
#  'നമ്പർ': 438,
#  'ഫോട്ടോ': 439,
#  'കസേരകൾ': 440,
#  'ഡ്രൈവിംഗ്': 441,
#  'കാബിനറ്റ്': 442,
#  'കൗണ്ടറിൽ': 443,
#  'ടേബിൾ': 444,
#  'തറ': 445,
#  'ഘടിപ്പിച്ചിരിക്കുന്നു': 446,
#  'അകലെ': 447,
#  'ചീസ്': 448,
#  'അടുത്ത്': 449,
#  'മേശയുടെ': 450,
#  'ബാക്ക്പാക്ക്': 451,
#  'മുറി': 452,
#  'പ്ലെയ്ഡ്': 453,
#  'സോഫ': 454,
#  'പ്രദേശം': 455,
#  'ഫോണിൽ': 456,
#  'പോസ്റ്റിൽ': 457,
#  'ടാർമാക്കിൽ': 458,
#  'മേഘം': 459,
#  'അലങ്കരിച്ച': 460,
#  'പുരുഷന്റെ': 461,
#  'കുപ്പായം': 462,
#  'പെയിന്റിംഗ്': 463,
#  'കൊട്ടയിൽ': 464,
#  'റൊട്ടി': 465,
#  'ഡെസ്ക്': 466,
#  'ഗ്രേ': 467,
#  'പ്രതിമ': 468,
#  'ക': 469,
#  'ചതുരം': 470,
#  'കുടകൾ': 471,
#  'ഇടതുവശത്ത്': 472,
#  'ടിവി': 473,
#  'അക്ഷരങ്ങൾ': 474,
#  'തിളങ്ങുന്നു': 475,
#  'ചതുര': 476,
#  'വാസ്': 477,
#  'സർഫ്ബോർഡിലെ': 478,
#  'പ്രവേശന': 479,
#  'കൂമ്പാരം': 480,
#  'ബീജ്': 481,
#  'ആകാശത്തിന്റെ': 482,
#  'കൊണ്ട്': 483,
#  'സീറ്റ്': 484,
#  'പൂക്കളുള്ള': 485,
#  'ഇന്റീരിയർ': 486,
#  'സമീപമുള്ള': 487,
#  'വായിൽ': 488,
#  'വളഞ്ഞ': 489,
#  'വണ്ടി': 490,
#  'വിളക്കുകൾ': 491,
#  'വാണിജ്യ': 492,
#  'ശാഖയിൽ': 493,
#  'വര': 494,
#  'ജോടി': 495,
#  'വസ്ത്രത്തിൽ': 496,
#  'അക്കങ്ങൾ': 497,
#  'ജാക്കറ്റിലുള്ള': 498,
#  'സ്ഥലത്ത്': 499,
#  'ഭക്ഷണത്തിന്റെ': 500,
#  'വീട്ടിൽ': 501,
#  'റോഡിലെ': 502,
#  'ചരട്': 503,
#  'പാത': 504,
#  'നനഞ്ഞ': 505,
#  'കവർ': 506,
#  'സീബ്രയുടെ': 507,
#  'ശിരോകവജം': 508,
#  'ഫ്രിസ്\u200cബീ': 509,
#  'ഗ്ലാസുകൾ': 510,
#  'വാട്ടർ': 511,
#  'വച്ചിരിക്കുന്ന': 512,
#  'ട്രേയിൽ': 513,
#  'ബൈക്കിൽ': 514,
#  'ഷോർട്ട്സ്': 515,
#  'വൈ': 516,
#  'ചതുരാകൃതിയിലുള്ള': 517,
#  'വീഞ്ഞ്': 518,
#  'അതിൽ': 519,
#  'കൈയിൽ': 520,
#  'ഓടുന്നു': 521,
#  'വിരൽ': 522,
#  'ഡബിൾ': 523,
#  'കിടക്കയിൽ': 524,
#  'ട്രെയിനിലെ': 525,
#  'ശേഖരം': 526,
#  'കൈറ്റ്': 527,
#  'ട്രാക്കിൽ': 528,
#  'ഷൂ': 529,
#  'പട്ടം': 530,
#  'വെള്ളത്തിന്': 531,
#  'കൊച്ചുകുട്ടി': 532,
#  'കീഴിൽ': 533,
#  'ടവറിൽ': 534,
#  'പെട്ടിയിൽ': 535,
#  'നായയുടെ': 536,
#  'പൂച്ചയുടെ': 537,
#  'മൃഗങ്ങൾ': 538,
#  'ജിറാഫിന്റെ': 539,
#  'ട്രക്കിന്റെ': 540,
#  'സർഫർ': 541,
#  'ഓവൻ': 542,
#  'എസ്\u200cയുവി': 543,
#  'ഓണാണ്': 544,
#  'തുമ്പിക്കൈ': 545,
#  'പുസ്തക': 546,
#  'ഈന്തപ്പന': 547,
#  'തുറന്നു': 548,
#  'മരത്തിന്': 549,
#  'നരച്ച': 550,
#  'സോസ്': 551,
#  'മഞ്ഞയാണ്': 552,
#  'പെയിന്റ്': 553,
#  'ലൈൻ': 554,
#  'പട്ടിക': 555,
#  'സിഗ്നൽ': 556,
#  'മേൽക്കൂരയുള്ള': 557,
#  'കട്ടിലിന്': 558,
#  'വെളുത്തതും': 559,
#  'ഹോട്ടൽ': 560,
#  'ഭക്ഷണ': 561,
#  'ബോക്സ്': 562,
#  'ലഗേജ്': 563,
#  'നീണ്ട': 564,
#  'നിറച്ച': 565,
#  'സിങ്കിൽ': 566,
#  'അലമാരയിൽ': 567,
#  'കുളം': 568,
#  'എന്ന': 569,
#  'പാവാട': 570,
#  'റിമോട്ട്': 571,
#  'മിറർ': 572,
#  'പാലത്തിൽ': 573,
#  'ഇടതുവശത്തുള്ള': 574,
#  'നിറയെ': 575,
#  'സ്ലാറ്റ്': 576,
#  'കാറാണ്': 577,
#  'കാറിലെ': 578,
#  'ലൈസൻസ്': 579,
#  'റെയിലിംഗ്': 580,
#  'ചാര': 581,
#  'വഴി': 582,
#  'കലം': 583,
#  'സ്റ്റാൻഡിൽ': 584,
#  'വെള്ളിയാണ്': 585,
#  'തൂങ്ങിക്കിടക്കുന്നു': 586,
#  'കൊക്ക്': 587,
#  'തൂക്കിയിട്ട': 588,
#  'കലത്തിൽ': 589,
#  'പോളിൽ': 590,
#  'പാച്ച്': 591,
#  'കടൽത്തീരം': 592,
#  'ഇലകളുള്ള': 593,
#  'തെളിഞ്ഞ': 594,
#  'ശോഭയുള്ള': 595,
#  'പോസ്റ്റ്': 596,
#  'ചാരിയിരിക്കുന്ന': 597,
#  'മേഘങ്ങളുള്ള': 598,
#  'മൂടിയ': 599,
#  'വേലിയിൽ': 600,
#  'റോഡിന്': 601,
#  'സ്ഥാപിച്ചിരിക്കുന്നു': 602,
#  'ട്രക്കിൽ': 603,
#  'സ്കൂൾ': 604,
#  'മതിലിനു': 605,
#  'അവൻ': 606,
#  'മേശപ്പുറത്തുണ്ട്': 607,
#  'വെള്ളത്തിന്റെ': 608,
#  'മാൻ': 609,
#  'വീഡിയോ': 610,
#  'ട്രിം': 611,
#  'കഴുത്തിൽ': 612,
#  'ചെടിയിൽ': 613,
#  'എന്ന്': 614,
#  'കോൺ': 615,
#  'റൗണ്ട്': 616,
#  'ഈ': 617,
#  'പാത്രങ്ങൾ': 618,
#  'തന്റെ': 619,
#  'മൂക്ക്': 620,
#  'തളികയിൽ': 621,
#  'കേസ്': 622,
#  'ബസിലെ': 623,
#  'ആനയുടെ': 624,
#  'സ്യൂട്ട്കേസ്': 625,
#  'ചുമക്കുന്ന': 626,
#  'ഹോട്ട്': 627,
#  'കീബോർഡ്': 628,
#  'ഗോപുരത്തിലെ': 629,
#  'ധരിച്ചിരിക്കുന്നു': 630,
#  'ഗ്ലാസിൽ': 631,
#  'തൊപ്പിയും': 632,
#  'ഡെക്കർ': 633,
#  'കയറുന്ന': 634,
#  'സൺഗ്ലാസുകൾ': 635,
#  'ബാത്ത്റൂം': 636,
#  'മൗസ്': 637,
#  'സോക്കർ': 638,
#  'ഏഷ്യൻ': 639,
#  'വ്യക്തവുമാണ്': 640,
#  'സ്നോബോർഡ്': 641,
#  'മേൽ': 642,
#  'ബോട്ടുകൾ': 643,
#  'മുകളിലൂടെ': 644,
#  'മൃഗം': 645,
#  'ബസ്സിലെ': 646,
#  'വച്ചിരിക്കുന്നു': 647,
#  'കൂട്ടിൽ': 648,
#  'പഴങ്ങൾ': 649,
#  'സ്റ്റോപ്പ്': 650,
#  'സമുദ്രത്തിൽ': 651,
#  'താഴേക്ക്': 652,
#  'ബസുകൾ': 653,
#  'റഫ്രിജറേറ്റർ': 654,
#  'സഞ്ചരിക്കുന്നു': 655,
#  'കരടിയുടെ': 656,
#  'വേലിക്ക്': 657,
#  'വാഴപ്പഴത്തിന്റെ': 658,
#  'ബ്ലെൻഡർ': 659,
#  'പിസ്സയിൽ': 660,
#  'ചിറക്': 661,
#  'പശ്ചാത്തലത്തിലുള്ള': 662,
#  'സ്കീയിംഗ്': 663,
#  'നടത്തുന്ന': 664,
#  'പുരുഷ': 665,
#  'ഓണാക്കി': 666,
#  'ഓഫീസ്': 667,
#  'ഫലം': 668,
#  'കൺട്രോളർ': 669,
#  'ജാലകങ്ങൾ': 670,
#  'നില': 671,
#  'പിൻ': 672,
#  'ഹൗസ്': 673,
#  'മണലിൽ': 674,
#  'തിരശ്ശീല': 675,
#  'ടെലിഫോൺ': 676,
#  'കുളിമുറിയിൽ': 677,
#  'ചെടി': 678,
#  'സ്റ്റീൽ': 679,
#  'കൊണ്ടുള്ള': 680,
#  'രാത്രി': 681,
#  'നിർത്തിയിട്ടിരിക്കുന്ന': 682,
#  'തിരക്കേറിയ': 683,
#  'ക്രോസ്': 684,
#  'വിമാനങ്ങൾ': 685,
#  'പാറകൾ': 686,
#  'ചെറുതാണ്': 687,
#  'ഹൈവേ': 688,
#  'മിനിവാൻ': 689,
#  'സ്കൂട്ടർ': 690,
#  'സൂര്യൻ': 691,
#  'ശൈലിയിലുള്ള': 692,
#  'വലുതാണ്': 693,
#  'അടുത്താണ്': 694,
#  'ചട്ടി': 695,
#  'ഡ്രെസ്സറിൽ': 696,
#  'ഫ്ലാറ്റ്': 697,
#  'ബസ്സിൽ': 698,
#  'ചരക്ക്': 699,
#  'ചുറ്റുമുള്ള': 700,
#  'വെളുത്തതുമായ': 701,
#  'ഗോവണി': 702,
#  'ഡോക്ക്': 703,
#  'മഴവില്ല്': 704,
#  'ജനാല': 705,
#  'മുന്നിലെ': 706,
#  'ഷെൽഫിൽ': 707,
#  'ജീൻസും': 708,
#  'പ്ലാന്റ്': 709,
#  'എഴുത്ത്': 710,
#  'വിൻഡോയിലെ': 711,
#  'വുഡൻ': 712,
#  'നിർത്തിയിട്ടിരിക്കുന്നു': 713,
#  'ശൂന്യമായ': 714,
#  'റോഡിലൂടെ': 715,
#  'ക്രോസിംഗ്': 716,
#  'വാഹനത്തിന്റെ': 717,
#  'ചക്രം': 718,
#  'തെരുവിന്റെ': 719,
#  'മുൻവശത്തെ': 720,
#  'പർവ്വതം': 721,
#  'വിളക്കിൽ': 722,
#  'അടുക്കളയിലെ': 723,
#  'അടുപ്പിൽ': 724,
#  'തുണിയിൽ': 725,
#  'മുൻ': 726,
#  'സെറ്റ്': 727,
#  'മേശയിലെ': 728,
#  'മത്സ്യം': 729,
#  'സ്ട്രീറ്റ്': 730,
#  'വഴിയിൽ': 731,
#  'പേഴ്സ്': 732,
#  'മുകളിലേക്ക്': 733,
#  'കുറ്റിക്കാടുകൾ': 734,
#  'സീബ്രയിൽ': 735,
#  'കയർ': 736,
#  'സുവ': 737,
#  'വാച്ച്': 738,
#  'അഴുക്കുചാലിൽ': 739,
#  'കെട്ടിടമാണ്': 740,
#  'ഗ്രീൻ': 741,
#  'തെരുവിന്': 742,
#  'ചില': 743,
#  'ആഴത്തിലുള്ള': 744,
#  'ട്രാക്കുകൾ': 745,
#  'നടപ്പാതയിലെ': 746,
#  'കോർണർ': 747,
#  'ലെഗ്': 748,
#  'ചാരനിറവും': 749,
#  'റെയിൽ': 750,
#  'പുഷ്പ': 751,
#  'നിറം': 752,
#  'സ്റ്റാപ്ലർ': 753,
#  'കവാടത്തിൽ': 754,
#  'മേശയ്ക്കു': 755,
#  'തക്കാളി': 756,
#  'സ്റ്റൈറോഫോം': 757,
#  'മുകൾവശം': 758,
#  'സമയത്ത്': 759,
#  'മുറ്റത്ത്': 760,
#  'നിറമുണ്ട്': 761,
#  'കപ്പിൽ': 762,
#  'സ്ക്രീനിൽ': 763,
#  'കളിക്കാരന്റെ': 764,
#  'റിബൺ': 765,
#  'ഇരിപ്പിടം': 766,
#  'പറയുന്ന': 767,
#  'കളിപ്പാട്ട': 768,
#  'ജലത്തിന്റെ': 769,
#  'വരികൾ': 770,
#  'പക്ഷികൾ': 771,
#  'പാനൽ': 772,
#  'പുൽത്തകിടിയിലെ': 773,
#  'കാബിനറ്റിൽ': 774,
#  'പിടിച്ചിരിക്കുന്ന': 775,
#  'ഘടിപ്പിച്ചിരിക്കുന്ന': 776,
#  'സ്റ്റഫ്': 777,
#  'ഷർട്ടിലുള്ള': 778,
#  'സ്യൂട്ടിലുള്ള': 779,
#  'പൊതിഞ്ഞ': 780,
#  'സ്പൂൺ': 781,
#  'ഹൈഡ്രാന്റ്': 782,
#  'പിന്നിലുള്ള': 783,
#  'പുല്ലു': 784,
#  'ചോക്ലേറ്റ്': 785,
#  'ഡോണട്ട്സ്': 786,
#  'തവിട്ടുനിറമുള്ള': 787,
#  'വ്യത്യസ്ത': 788,
#  'കയറുന്നു': 789,
#  'സ്കേറ്റ്ബോർഡിലാണ്': 790,
#  'ട്രാക്കുകളിൽ': 791,
#  'തീവണ്ടിയുടെ': 792,
#  'ടോയ്\u200cലറ്റിന്റെ': 793,
#  'തെരുവിലാണ്': 794,
#  'ടാഗ്': 795,
#  'ധരിച്ചിരിക്കുന്ന': 796,
#  'വെള്ളിയും': 797,
#  'പുക': 798,
#  'സോഡ': 799,
#  'കളിപ്പാട്ടം': 800,
#  'ഗോപുരത്തിന്റെ': 801,
#  'സ്നോ': 802,
#  'വലുതും': 803,
#  'കൂടുതൽ': 804,
#  'ഫ്രിസ്\u200cബിയെ': 805,
#  'യുവാവ്': 806,
#  'ഫ്രിഡ്ജിൽ': 807,
#  'സ്റ്റേഷനിൽ': 808,
#  'മേൽക്കൂരയിൽ': 809,
#  'സുന്ദരമായ': 810,
#  'മഞ്ഞുമൂടിയ': 811,
#  'കുതിരകൾ': 812,
#  'പഴത്തിന്റെ': 813,
#  'പൂച്ചയ്ക്ക്': 814,
#  'സർഫ്': 815,
#  'ലൈറ്റുകളുള്ള': 816,
#  'ടി': 817,
#  'ഉപകരണങ്ങൾ': 818,
#  'അലകൾ': 819,
#  'പറക്കുന്ന': 820,
#  'ഗോപുരം': 821,
#  'കാണുന്നു': 822,
#  'ആൺകുട്ടികൾ': 823,
#  'ഫർണിച്ചർ': 824,
#  'ചെരുപ്പ്': 825,
#  'കളിക്കാർ': 826,
#  'സ്കൈ': 827,
#  'പിടിച്ചിരിക്കുന്നു': 828,
#  'കാത്തിരിക്കുന്ന': 829,
#  'ലൈറ്റിൽ': 830,
#  'പത്രം': 831,
#  'വായിക്കുന്ന': 832,
#  'അണിനിരക്കും': 833,
#  'പാസഞ്ചർ': 834,
#  'സിറ്റി': 835,
#  'സ്റ്റാൻഡിന്': 836,
#  'റേസിംഗ്': 837,
#  'വിവിധ': 838,
#  'നിലം': 839,
#  'യുവതി': 840,
#  'പൈ': 841,
#  'മുറിച്ച': 842,
#  'ഉയർത്തിപ്പിടിക്കുന്നു': 843,
#  'നിയോൺ': 844,
#  'സുരക്ഷാ': 845,
#  'ഓഫീസിലെ': 846,
#  'മുറിച്ചു': 847,
#  'ബർഗണ്ടി': 848,
#  'വ്യക്തിക്ക്': 849,
#  'ടൈയും': 850,
#  'പീസ്': 851,
#  'പശുക്കൾ': 852,
#  'തീ': 853,
#  'ഇരുമ്പ്': 854,
#  'പുതിയ': 855,
#  'കുളിമുറിയാണ്': 856,
#  'ആട്': 857,
#  'പിസ്സയുടെ': 858,
#  'ഇട്ട': 859,
#  'പോകുന്നു': 860,
#  'മുൻവശം': 861,
#  'വായുവിലാണ്': 862,
#  'അടുക്കിയിരിക്കുന്നു': 863,
#  'ലെതർ': 864,
#  'വീഞ്ഞു': 865,
#  'കുടിക്കുന്നു': 866,
#  'സ്വിംഗ്': 867,
#  'സ്കീ': 868,
#  'തന്ത്രം': 869,
#  'ചുരുണ്ട': 870,
#  'മീറ്റർ': 871,
#  'പൂച്ചയാണ്': 872,
#  'ബ്രൊക്കോളി': 873,
#  'കുതിരപ്പുറത്ത്': 874,
#  'ഉറങ്ങുന്നു': 875,
#  'ബോയ്': 876,
#  'ചുവന്നതാണ്': 877,
#  'തുരുമ്പിച്ച': 878,
#  'സ്\u200cക്രീൻ': 879,
#  'ഇലക്ട്രിക്': 880,
#  'ഫോട്ടോയിലെ': 881,
#  'സ്നോബോർഡർ': 882,
#  'ബട്ടൺ': 883,
#  'ചെയ്യാൻ': 884,
#  'കടൽത്തീരത്താണ്': 885,
#  'ധാന്യം': 886,
#  'പാണ്ട': 887,
#  'മൈതാനത്ത്': 888,
#  'പല്ല്': 889,
#  'മതിലിന്റെ': 890,
#  'കുളിമുറിയുടെ': 891,
#  'സ്കേറ്റ്ബോർഡിലെ': 892,
#  'കടൽത്തീരത്തെ': 893,
#  'ശാന്തമായ': 894,
#  'കടലിൽ': 895,
#  'ഇൻഡോർ': 896,
#  'മടിയിൽ': 897,
#  'പൂശി': 898,
#  'അഭിമുഖീകരിക്കുന്ന': 899,
#  'കവലയിലൂടെ': 900,
#  'കുടയുമായി': 901,
#  'പാന്റിലുള്ള': 902,
#  'ചാരിയിരിക്കുന്നു': 903,
#  'കസേരയുടെ': 904,
#  'നീന്തുന്നു': 905,
#  'തണലുള്ള': 906,
#  'പോർസലൈൻ': 907,
#  'ഇടുന്നു': 908,
#  'വാതിലുള്ള': 909,
#  'ശാഖ': 910,
#  'ധ്രുവം': 911,
#  'പാനപാത്രം': 912,
#  'കൊട്ട': 913,
#  'തൊപ്പികൾ': 914,
#  'വിദൂര': 915,
#  'മതിലിലാണ്': 916,
#  'നൽകരുത്': 917,
#  'കണ്ണാടിയിൽ': 918,
#  'താഴെ': 919,
#  'ഒപ്പിടുക': 920,
#  'താടി': 921,
#  'ബർഗർ': 922,
#  'വശം': 923,
#  'ഫിക്ചർ': 924,
#  'മോണിറ്ററിന്': 925,
#  'സൺഗ്ലാസ്': 926,
#  'വാതിലുകളുള്ള': 927,
#  'ഫുട്പാത്തിൽ': 928,
#  'ഗ്രൂപ്പ്': 929,
#  'സ്ഥലം': 930,
#  'ബാൻഡ്': 931,
#  'കെട്ടിടങ്ങളാണ്': 932,
#  'കാള': 933,
#  'തലകീഴായി': 934,
#  'ഫോസെറ്റ്': 935,
#  'പൂമുഖത്ത്': 936,
#  'ജനല': 937,
#  'അടച്ചു': 938,
#  'സ്റ്റാൻഡ്': 939,
#  'ചെടിയുടെ': 940,
#  'മഴ': 941,
#  'വെളിച്ചത്തിൽ': 942,
#  'ഷോർട്ട്സിലുള്ള': 943,
#  'കുറ്റിച്ചെടി': 944,
#  'വെള്ളത്തിലൂടെ': 945,
#  'കിളി': 946,
#  'വലത്': 947,
#  'നിരയായി': 948,
#  'പിന്നിലെ': 949,
#  'സ്കീസ്': 950,
#  'വഴിക്ക്': 951,
#  'നടുവിലുള്ള': 952,
#  'ഇടുങ്ങിയ': 953,
#  'ദ്വാരം': 954,
#  'ജീൻ': 955,
#  'പോസ്റ്റിലെ': 956,
#  'പുല്ലുള്ള': 957,
#  'കാർട്ട്': 958,
#  'റാക്ക്': 959,
#  'ആട്ടിൻകുട്ടി': 960,
#  'താൽക്കാലികമായി': 961,
#  'നിർത്തിവച്ചിരിക്കുന്നു': 962,
#  'പുരുഷന്': 963,
#  'കടയിൽ': 964,
#  'പുരുഷനും': 965,
#  'കസേരയ്ക്ക്': 966,
#  'പൂൾ': 967,
#  'വ്യാജ': 968,
#  'ഷോപ്പിംഗ്': 969,
#  'കുളത്തിനടുത്തുള്ള': 970,
#  'ണ്ടറിന്': 971,
#  'തൂങ്ങിക്കിടക്കുന്ന': 972,
#  'മുഴുവൻ': 973,
#  'കൈകൾ': 974,
#  'കൗണ്ടറിന്': 975,
#  'കീഴിലാണ്': 976,
#  'ജാലകത്തിന്': 977,
#  'കുളത്തിൽ': 978,
#  'മനോഹരമായ': 979,
#  'കടലാമ': 980,
#  'ട്രക്കിലെ': 981,
#  'പരവതാനി': 982,
#  'പടികളിൽ': 983,
#  'റെസിഡൻഷ്യൽ': 984,
#  'മുറിക്കുക': 985,
#  'പൂത്തട്ടം': 986,
#  'സ്ത്രീയാണ്': 987,
#  'റിയർ': 988,
#  'പ്രായമായ': 989,
#  'മഗ്': 990,
#  'പോളിലെ': 991,
#  'ബാനറുകൾ': 992,
#  'സ്റ്റോർ': 993,
#  'മെറൂൺ': 994,
#  'ജീപ്പ്': 995,
#  'ലോഹധ്രുവത്തിൽ': 996,
#  'ഷെൽഫ്': 997,
#  'കളർ': 998,
#  'പോസ്റ്റർ': 999,
#  'ഡെസ്\u200cകിന്': 1000,
#  ...}

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=[encoder_inputs,img_inputs],outputs=[encoder_outputs, state_h, state_c])
encoder_model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 13)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 13, 512)      1044480     input_7[0][0]
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 13, 512), (N 2099200     embedding_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          2097664     input_6[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 13, 512), (N 2099200     lstm_4[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 13, 512)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 13, 1024)     0           lstm_5[0][0]
#                                                                  repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 13, 512), (N 3147776     concatenate_1[0][0]
# ==================================================================================================
# Total params: 10,488,320
# Trainable params: 10,488,320
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    encoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(maxlen_english,latent_dim))
print(decoder_inputs.get_shape)
#print(dec_emb.get_shape)
# Out:
# <bound method KerasTensor.get_shape of <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'input_8')>>

# %%
# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])
decoder_model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 512)    1807360     input_8[0][0]
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 512)]        0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 512)]        0
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, None, 512),  2099200     embedding_3[2][0]
#                                                                  input_12[0][0]
#                                                                  input_13[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 13, 512)]    0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, None, 3530)   1810890     lstm_7[2][0]
# ==================================================================================================
# Total params: 5,717,450
# Trainable params: 5,717,450
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    decoder_model,
    to_file='model.png',
    show_shapes=True,
    show_layer_names=True,
    rankdir='TB'
)

# %%
def decode_sequence(input_seq,img):
    img=img[np.newaxis,:]
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict([input_seq,img])
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sos']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eos'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eos'  or len(decoded_sentence.split()) >= (maxlen_malayalam -1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sos']) and i!=target_word_index['eos']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

for i in range(5):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
    print("\n")
# Out:
# Review: male surfer surfing in still in the ocean
# Original summary: ശാന്തമായ കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# Predicted summary:  ഒരു വ്യക്തി നടക്കുന്നു
#
#
# Review: it is an indoor scene
# Original summary: ഇത് ഒരു ഇൻഡോർ രംഗമാണ്
# Predicted summary:  ഇതൊരു കുളിമുറിയാണ്
#
#
# Review: computer screens turned on
# Original summary: കമ്പ്യൂട്ടർ സ്ക്രീനുകൾ ഓണാക്കി
# Predicted summary:  മേശപ്പുറത്ത് കറുത്ത സിംഹ പ്രതിമ
#
#
# Review: man has short hair
# Original summary: മനുഷ്യന് ചെറിയ മുടിയുണ്ട്
# Predicted summary:  കറുത്ത സ്യൂട്ട് ജാക്കറ്റ് ധരിച്ച മനുഷ്യൻ
#
#
# Review: photo album open on an adults lap
# Original summary: ഫോട്ടോ ആൽബം മുതിർന്നവരുടെ മടിയിൽ തുറക്കുന്നു
# Predicted summary:  ചുമരിൽ ഘടിപ്പിച്ചിരിക്കുന്ന വെളുത്ത ഷവർഹെഡ്

# %%
i=4
print("Review:",seq2text(x_tr[i]))
#print("Original summary:",seq2summary(y_tr[i]))
print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,maxlen_english),vgg_train_[i]))
plt.imshow(imagedata[i].astype(np.float32))
# Out:
# Review: photo album open on an adults lap
# Predicted summary:  ചുമരിൽ ഘടിപ്പിച്ചിരിക്കുന്ന വെളുത്ത ഷവർഹെഡ്

# %%
i=0
print("Review:",seq2text(x_tr[i]))
print("Original summary:",seq2summary(y_tr[i]))
print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_len_english),vgg_imfea[i]))
plt.imshow(imagedata[i].astype(np.float32))
# Out:
# Review: male surfer surfing in still in the ocean
# Original summary: ശാന്തമായ കടലിൽ സർഫിങ് നടത്തുന്ന പുരുഷ സർഫർ
# Predicted summary:  സമുദ്രത്തിലെ നല്ല തിരകൾ

# %%
# !pip install sacrebleu
import sacrebleu
import random
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.9 MB/s
# Collecting portalocker
#   Downloading portalocker-2.3.2-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.4 portalocker-2.3.2 sacrebleu-2.0.0

# %%
temp_o=[]
temp_p=[]
for i in range(50):
    s=random.randint(0,len(y_tr)-1)
    temp_o.append(seq2summary(y_tr[s]))
    temp_p.append(decode_sequence(x_tr[s].reshape(1,maxlen_english),vgg_train_[s]))

bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 13.293934569155521

# %%
temp_o=[]
temp_p=[]
for i in range(5000):
    s=random.randint(0,len(y_tr)-1)
    temp_o.append(seq2summary(y_tr[s]))
    temp_p.append(decode_sequence(x_tr[s].reshape(1,maxlen_english),vgg_train_[s]))

bleu = sacrebleu.corpus_bleu(temp_o, [temp_p],lowercase=True, tokenize='intl')
print(bleu.score)
# Out:
# 13.805804701931676
